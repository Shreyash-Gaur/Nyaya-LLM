# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 28.6 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_phi4_mini/qlora_phase1_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_phi4_mini/lora_phase1_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 1 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase1_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 1 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: PHI4_LORA
# Loading 4-bit quantization config...
# Loading base model: microsoft/Phi-4-mini-instruct...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/194 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase1_phi4_mini/lora_phase1_phi4_mini...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 1 EVALUATION: PHI4_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever causes grievous hurt to any woman, being an officer or a member of the a...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misidentifies the section and provides an incorrect description of the offense.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Certificate of authentication...
#   Score  : 2/5  — The model answer incorrectly focuses on a certificate of authentication rather than the admissibility of electronic records as per Section 65B.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : Any person arrested or detained in contravention of the provisions of section 50...
#   Score  : 1/5  — The model answer is not related to Section 53A of the Code of Criminal Procedure, 1973, and instead refers to bail provisions.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Moto...
#   Score  : 1/5  — The model answer is completely incorrect as Section 105J falls under the Code of Criminal Procedure, 1973.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Code of Criminal Procedure, 1973 deals with S...
#   Score  : 4/5  — The answer captures the essence of Section 31 but includes unnecessary repetition and an incomplete sentence.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : Every Court shall, as far as practicable, dispose of every case which it has tak...
#   Score  : 1/5  — The model answer is not related to Section 104 of the Code of Criminal Procedure, 1973 and provides an unrelated statement about case disposal time.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : Any Court may, at any stage of a proceeding, direct the accused to be released o...
#   Score  : 1/5  — The model answer is not related to Section 405 of the Code of Criminal Procedure, 1973 and instead discusses bail provisions.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Magistrate of the first class convicts a person of an offence punishable ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When any Court, having jurisdiction to try a person for an offence, has reason t...
#   Score  : 1/5  — The model answer is not related to Section 247 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure instead of the Code of Civil Procedure and adds an unnecessary term.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Motor Vehicles Act, 1988 deals with Recovery...
#   Score  : 2/5  — The model answer incorrectly states that the State Government can recover arrears from the insured, while the reference indicates the Claims Tribunal issues a certificate to the Collector for recovery.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court, at the conclusion of a trial, is of opinion that the accused is ...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973 and instead provides unrelated information about sentencing.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: offences affecting the public health, safety...
#   Score  : 2/5  — The model incorrectly identifies the section and its context, referring to the wrong chapter and a different offense.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is close but omits the specific punishment details from the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever commits theft by taking away or by converting to his own use any movable...
#   Score  : 1/5  — The model answer is completely unrelated and incorrectly describes theft instead of Section 424 of the IPC.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18: section 238: Procedure when accused...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question asked.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : Whoever sells or lets hire any motor vehicle or causes any motor vehicle to be s...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Magistrate has taken cognizance of an offence, he may, at any time before...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect regarding the content of Section 157 of the Code of Criminal Procedure, 1973.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 23: section 282 to 284
# Section 283: Pro...
#   Score  : 2/5  — The model answer incorrectly focuses on Section 283 instead of Section 284, and does not provide the correct content for Section 284.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : Every decree shall be pronounced in open Court, and shall be recorded in writing...
#   Score  : 1/5  — The model answer is not related to Section 89 of the Code of Civil Procedure, 1908 and instead repeats irrelevant information.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, the law states that Recording of confessions and statements. Ev...
#   Score  : 2/5  — The answer is partially correct but contains notable legal errors, as it omits the requirement for the recording to be made in the course of an investigation and the mention of audio-video electronic means.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 8: section 107 to section 110
# Section 1...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as related to arresting absconding individuals instead of providing the correct legal context regarding security for good behavior from persons disseminating seditious matters.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever commits the offence of theft by taking away or by converting to his own ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, the law states by Section 346 (Wrongful confinement in secret) ...
#   Score  : 4/5  — The answer captures the essence of the law but omits the specific penalties and the role of public servants.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : When the Court has to decide whether a document is genuine or not, it may, in or...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 26: section 336Criminal Procedure Code,...
#   Score  : 2/5  — The model answer incorrectly describes Section 337 and refers to wrong sections.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Magistrate of the first class or a Magistrate of the second class is cond...
#   Score  : 1/5  — The model answer is not related to the question and contains no information about Section 265A of the Code of Criminal Procedure, 1973.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, the law enacted by the State Government in this behalf shall be...
#   Score  : 4/5  — The model captures the essence of the section but incorrectly attributes the transfer rule to the State Government rather than the Code of Civil Procedure.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever commits the offence of theft by taking away or by converting to his own ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, the law states that Wrongful confinement for three or more days...
#   Score  : 2/5  — The model answer incorrectly states the maximum imprisonment term as seven years instead of two years.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits the offence of murder shall be punished with death, or imprisonm...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the actual content of Section 358 of the Indian Penal Code.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) The Court shall, when the suit is instituted, issue a summons to the defenda...
#   Score  : 1/5  — The model answer is not related to Section 25 of the Code of Civil Procedure, 1908, and instead appears to be about service of summons.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) A person shall not be entitled to drive a motor vehicle unless he is at leas...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, missing the key points about learner's and driving licences.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 2/5  — The model answer does not accurately capture the key legal requirement of presenting the instrument within a reasonable time after it is made.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Execution of decrees
#
# (1) ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing execution of decrees instead of administering oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : Every decree of dissolution of marriage shall be in the form annexed to this Act...
#   Score  : 1/5  — The model answer is not related to Section 18 of the Indian Divorce Act, 1869, which deals with petitions for declaring a marriage null and void.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : A person shall not be convicted of an offence punishable under this Chapter for ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever commits theft by taking away any property from the possession of any per...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 32: section 406: Procedure when accused...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question asked.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer without any errors.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When any Court, at any stage of a proceeding, is satisfied that the accused has ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect regarding the content of Section 478 of the Code of Criminal Procedure, 1973.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, the law of Indian Succession Act, 1865 (9 of 1865) relating to ...
#   Score  : 4/5  — The model answer captures the essence of the section but omits the specific reference to the Indian Evidence Act and the chapter context.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, the law section 169 (Procedure and powers of Claims Tribunals) ...
#   Score  : 3/5  — Gets the general idea but misses important legal details such as the summary procedure and specific powers of the tribunal.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) A person shall not be entitled to compensation under this Act for any injury...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing compensation rather than the carrying of passengers.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 32: section 375: Appeal against convict...
#   Score  : 2/5  — The model answer incorrectly describes Section 375 as dealing with appeals, while it actually pertains to the prohibition of appeals for guilty pleas.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 4/5  — The model answer captures the essence of the bar to further suit but incorrectly omits the phrase 'any particular cause of action' and incorrectly uses 'anima' instead of 'final'.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences affecting the public
# Section 149: Pu...
#   Score  : 4/5  — The model answer captures the essence of Section 149 but incorrectly identifies the punishment and omits the key point about liability for all members of the assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 36: section 478: section 479: section 4...
#   Score  : 2/5  — The model incorrectly references multiple sections instead of focusing on section 479, missing the key legal meaning.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Power of State Government to m...
#   Score  : 2/5  — The model answer incorrectly interprets Section 198A as granting powers to the State Government to make rules, instead of addressing the responsibility of authorities to comply with road design, construction, and maintenance standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : A person shall not drive a motor vehicle unless he is at least eighteen years of...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to a different section of the Motor Vehicles Act, 1988.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and accurately identifies the relevant act.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Code of Civil Procedure, 1908 deals with Decr...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Hindu Marriage Act, and omits the specific conditions for granting relief as per Section 23.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 13:
# Section 166: Proof of foreign law
#
# A fore...
#   Score  : 1/5  — The model answer is completely incorrect, discussing proof of foreign law instead of the power of jury or assessors to put questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1973 deals with P...
#   Score  : 2/5  — The model answer incorrectly references Section 17 and omits key details about requiring consent from the Central Government.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Any person arrested or detained in the execution of a warrant issued under this ...
#   Score  : 1/5  — The model answer is completely unrelated to the question and does not address Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 4: offences against the state
# Section 64: Sale o...
#   Score  : 2/5  — The model answer incorrectly identifies Section 64 as relating to the sale of arms, ammunition, and materials to the enemy, which is not accurate.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, the law stands revoked by the Supreme Court that the contracts ...
#   Score  : 2/5  — The model answer incorrectly states that the contracts are voidable and does not capture the key legal meaning of Section 92.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, the law states that Whoever imports or exports counterfeit coin...
#   Score  : 4/5  — The model answer is close but incorrectly specifies a maximum term of imprisonment of seven years instead of three years.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : Every decree shall be pronounced in open Court, and shall be recorded in writing...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 124 of the Code of Civil Procedure, 1908.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : A person convicted of an offence punishable under this Act shall, in addition to...
#   Score  : 1/5  — The model answer is not related to Section 112 of the Motor Vehicles Act, 1988 and instead discusses disqualification for driving offences.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, the law states that every Hindu marriage solemnized after the c...
#   Score  : 2/5  — The model answer is partially correct but omits important details about the registration process and the conditions under which registration can be made optional.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : (1) The State Government may, by notification in the Official Gazette, make rule...
#   Score  : 1/5  — The model answer is not related to Section 7 of the Code of Civil Procedure, 1908, and instead discusses rules-making powers of the State Government.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences relating to coinage
# Section 128: Sal...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its punishment, and mischaracterizes the offense.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is not related to Section 100 of the Negotiable Instruments Act, 1881 and provides an incorrect statement about dishonored instruments.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : Any Court may, at any stage of a proceeding, direct the investigation of any fac...
#   Score  : 1/5  — The model answer is not related to Section 34 of the Code of Criminal Procedure, 1973, and instead discusses investigative procedures.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer without any errors.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 21: offences against the person
# Section 376A: Ga...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to gang rape and prescribes capital punishment, which is not accurate.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Execution of decrees
#
# (1) ...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question asked.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : Every decree shall be pronounced in open Court, and shall be recorded in writing...
#   Score  : 1/5  — The model answer is not related to Section 43 of the Code of Civil Procedure, 1908, and provides an incorrect statement about the content of a decree.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Execution of decrees
#
# (1) W...
#   Score  : 2/5  — The model answer incorrectly describes Section 34 as related to execution of decrees instead of interest, which is a significant legal error.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 9:
# Section 118: Proof of facts necessary to e...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as about proving rights instead of competency to testify.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 5:
# Section 52: Liability of owner
#
# The owner o...
#   Score  : 2/5  — The model answer incorrectly interprets Section 52 as dealing with the owner's liability and does not address the prohibition on altering the vehicle.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: offences relating to coinage
# Section 365: Co...
#   Score  : 2/5  — The model incorrectly identifies the section as related to counterfeiting coin instead of kidnapping or abduction.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : A person shall not be convicted of an offence punishable under this Chapter unle...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, the law states by Section 128 (Safety measures for drivers and ...
#   Score  : 2/5  — The model answer incorrectly attributes the power to make rules to the State Government instead of the Central Government as per the reference answer.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 21: offences affecting the public tranquillity  ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrectly identifies the section.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : Every decree shall be pronounced in open Court, and shall be recorded in writing...
#   Score  : 1/5  — The model answer is completely unrelated and incorrectly states the content of Section 66.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly interprets Section 174 as relating to liability of the owner of a motor vehicle, whereas it actually pertains to recovery of money from an insurer.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 31: section 402
#
# The Court may, at any ...
#   Score  : 2/5  — The model answer is about bail and custody, which is not related to Section 402 of the Code of Criminal Procedure, 1973.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 5:
# Section 38: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly interprets Section 38 as dealing with liability of the owner, while the reference answer explains it as granting power to make rules.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : Every decree of dissolution of marriage shall be made absolute, and shall be so ...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead discusses the time frame for appeals in divorce cases.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : Every decree shall be pronounced in open Court, and shall be delivered in open C...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, the law states by Section 31 (Liability of drawee of cheque) th...
#   Score  : 2/5  — The model answer incorrectly defines the drawee's liability and instead describes the nature of a banker's liability under a different section.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Code of Civil Procedu...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Indian Evidence Act, 1872.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 13: section 166B
# Criminal Law (India an...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 166B and refers to the wrong chapter and section.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, the law states that when any person attends an inquiry under Su...
#   Score  : 4/5  — The answer captures the essence of the inquiry but omits the specific sections (111, 112, 113) and the involvement of a Magistrate.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16: section 202: Power of High Court to...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the question about Section 202 of the Code of Criminal Procedure, 1973.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Indian Divor...
#   Score  : 1/5  — The model answer is completely incorrect as Section 7 of the Hindu Marriage Act, 1955 pertains to ceremonies for Hindu marriages, not the Indian Divorce Act, 1869.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidancements for mutually satisfactory disposition' falls ...
#   Score  : 4/5  — Correct core content but with a minor error in spelling 'Guidelines' as 'Guidancements'.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 4/5  — The model answer captures the essence of the legal concept but incorrectly references the Code of Criminal Procedure instead of the Indian Penal Code, and omits the part about punishment.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, corruptly executes any function of such nature ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Instrument payable at a...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as relating to instruments payable at a definite time instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 13:
# Section 165: Proof of facts necessary to ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 165 as relating to proof of rights, liabilities, or customs instead of the judge's power to put questions or order production.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The model answer captures the essence of Section 108A correctly but omits the specific mention of 'in India' for the abetted act, which is a minor but important detail.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court, at the conclusion of a trial, or at any stage of a trial, is of ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court, at the time of passing any judgment, considers it necessary to r...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, referring to a different section of the Code of Criminal Procedure.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, the law states that whoever commits undue influence or personat...
#   Score  : 4/5  — Correct core content but minor precision error in the maximum term of imprisonment.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits the offence of rape on a woman aged twelve years or older but le...
#   Score  : 2/5  — The model answer incorrectly states the age range and the punishment, missing the key elements of multiple perpetrators and life imprisonment.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits the offence of robbery by sudden or intimate assault, or by putt...
#   Score  : 2/5  — The model answer incorrectly describes an offense of robbery instead of the actual content of Section 328 IPC.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is not relevant to the question about Section 63 of the Negotiable Instruments Act, 1881.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Application of Act to suits inst...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors as it misinterprets Section 57, which is about remarriage rights, not about the application of the act to suits in England.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When the accused is in custody, the Court may, at any time, direct that he be re...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 228 of the Code of Criminal Procedure, 1973.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a member of any armed forces, intentionally discharges any firear...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Petition to annul a decree of ju...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as related to petitions to annul a decree of judicial separation instead of addressing the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A person shall not be entitled to compensation under this Act for any damage...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, the law explains:
#
# Payment in due course of crossed cheque. — W...
#   Score  : 3/5  — The model answer captures the essence of the section but omits important details about the rights and positions of the parties involved.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : A witness may be compelled to attend the Court, and may be compelled to answer a...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and thus is completely incorrect.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Frauduliously' falls under the Indian Penal Code, 1860....
#   Score  : 4/5  — Correct core content but with a slight imprecision in the spelling of 'Fraudulently' as 'Frauduliously'.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Divorce ...
#   Score  : 2/5  — The model answer is partially correct but contains a notable legal error as the Indian Divorce Act, 1869 is not the correct act.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 1/5  — The model answer is completely incorrect as Section 108 does not fall under the Code of Civil Procedure, 1908.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : A person shall not be convicted of an offence punishable under this Chapter unle...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 102: Proof of facts necessary to e...
#   Score  : 2/5  — The model answer incorrectly focuses on proving the existence of a right rather than the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 3:
# Section 35: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly interprets Section 35 as relating to the liability of the owner of a motor vehicle, rather than the power of the court to disqualify a conductor's license holder.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source for Section 351, when it actually belongs to the Indian Penal Code, 1860.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, the law states that Bribery means giving, offering, or attempti...
#   Score  : 3/5  — The answer captures the essence of bribery but includes unnecessary and confusing details about public servants and business-related matters, which are not part of Section 171B.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences affecting the publicTranquilityPubli...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its intent, confusing it with wrongful confinement instead of false evidence.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque drawn, made or issued in India sha...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 9:
# Section 117: Proof of facts necessary to e...
#   Score  : 2/5  — The model answer incorrectly interprets Section 117 and its application.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Procedure in case of petition for...
#   Score  : 2/5  — The model answer incorrectly describes the section's purpose and does not capture the key legal meaning of Section 6.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, corruptly executes any function of such nature ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 105 of the Indian Penal Code.
#
# 💾 Raw results saved → /kaggle/working/results/phase1_eval_phi4_lora.json
#
# ============================================================
# 📊  PHASE 1 SUMMARY — PHI4_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.32 / 5.0
#
#   Score distribution:
#     5/5  █████████████████████████ (25)
#     4/5  ██████████████ (14)
#     3/5  ███ (3)
#     2/5  ██████████████████████████████████████████████████ (50)
#     1/5  ██████████████████████████████████████████████████████████ (58)
#
#   By task type:
#     Act Identification   avg=3.92  (n=39)
#     Direct Q&A           avg=1.13  (n=31)
#     Explanation          avg=2.34  (n=59)
#     Summarization        avg=1.05  (n=21)
# ============================================================
