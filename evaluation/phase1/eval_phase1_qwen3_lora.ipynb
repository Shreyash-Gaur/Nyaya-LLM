# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.1 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_phi4_mini/qlora_phase1_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_phi4_mini/lora_phase1_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 1 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase1_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 1 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: QWEN3_LORA
# Loading 4-bit quantization config...
# Loading base model: Qwen/Qwen3-4B-Instruct-2507...
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 1 EVALUATION: QWEN3_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes grievous hurt to any person, shall be punished with i...
#   Score  : 2/5  — The model answer incorrectly states the punishment as up to 10 years instead of at least 10 years, and omits the specific mention of acid and disfigurement.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Electronic Records
#
# The provi...
#   Score  : 4/5  — The answer captures the essence of Section 65B but does not explicitly mention the conditions for admissibility of electronic records.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : In any inquiry into an offence under section 177, section 178, section 179, sect...
#   Score  : 1/5  — The model answer is not relevant to the question and appears to be a list of sections from the Indian Penal Code, which is unrelated to Section 53A of the Code of Criminal Procedure.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Indi...
#   Score  : 1/5  — The model answer is completely incorrect as Section 105J falls under the Code of Criminal Procedure, 1973.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1979 deals with Sentence i...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure, and omits important details about the order of punishments.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is not related to Section 104 of the Code of Criminal Procedure and instead discusses provisions related to arrest and informing the person of the offense.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is not related to Section 405 of the Code of Criminal Procedure, 1973, and provides incorrect information about the arrest process.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1961.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is not related to Section 323 of the Code of Criminal Procedure, 1973 and provides unrelated information about arrest procedures.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested, the officer making the arrest shall forthwith take su...
#   Score  : 1/5  — The model answer is not related to Section 247 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 1/5  — The model answer is completely incorrect as Section 132 does not fall under the Indian Evidence Act, 1872.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model incorrectly refers to the wrong code and provides an unrelated explanation.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing arrest procedures instead of the content of Section 253.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9: offences affecting the public health  safety ...
#   Score  : 2/5  — The model incorrectly identifies the section as related to unlawful assemblies instead of false statements in elections.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer captures the key legal meaning but omits the specific punishment details provided in the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being a public servant, and being legally b...
#   Score  : 1/5  — The model answer is completely unrelated and does not capture the key legal meaning of Section 424 of the Indian Penal Code.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 17:
# Section 238: Power to order produc...
#   Score  : 2/5  — The model answer incorrectly interprets Section 238 as dealing with the production of documents instead of compliance with Section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : The drawer of a bill of exchange, note or draft, not being a cheque, is liable t...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the actual content of Section 99 of the Negotiable Instruments Act, 1881.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules regarding the time and place for the pay...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant information about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a police officer receives information that a person is likely to commit an ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 157 and provides a summary of Section 156 instead.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 22:
# Successful prosecution
#
# When a cas...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors. It discusses the wrong section (284 vs 22) and misinterprets the purpose of the section.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[Notwithstanding anything contained in the last two articles of Chapter V, no p...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the main idea of recording confessions and statements, but incorrectly repeats 'when the accused is a person of unsound mind' multiple times and includes irrelevant information about children.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Criminal Law (Application of this C...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 108 of the Code of Criminal Procedure, 1973.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being a public servant, and being legally b...
#   Score  : 1/5  — The model answer is not semantically correct; it discusses public servants and duties, while the reference answer talks about public nuisances.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 2/5  — The model answer incorrectly states the purpose of wrongful confinement in secret and omits the key element of keeping the confinement hidden from interested parties.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : When the Court is satisfied that a document is one of the kind mentioned in the ...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act, 1872 and provides an incorrect legal statement.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 26:
# Successful prosecution of a case
#
# ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses the wrong section and topic.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : In any inquiry, trial or other proceeding under this Code, the Court may, if it ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 4/5  — The model captures the main idea but adds unnecessary details that are not part of Section 40.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being a public servant, and being legally b...
#   Score  : 1/5  — The model answer is completely unrelated and incorrectly applies provisions from a different section of the IPC.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 - Wrongful confineme...
#   Score  : 4/5  — Correct core content but includes redundant phrase 'Wrongful confinement for three or more days'.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits house-breaking, shall be punished with imprisonment of either de...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the question about Section 358 of the IPC.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) The Court may, in its discretion, order a party to furnish security in the f...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about security bonds.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) A State Government may, by order, authorise the use of any vehicle, not bein...
#   Score  : 1/5  — The model answer is not related to Section 14 of the Motor Vehicles Act, 1988, and instead discusses unrelated provisions.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure as the Indian Penal Code.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable to order must be crossed g...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses crossing of instruments instead of the presentation requirement for promissory notes under Section 62.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power to make rules
#
# The S...
#   Score  : 2/5  — The model answer incorrectly describes Section 139 as about making rules instead of administering oaths.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : No such decree shall be made, except upon a petition presented to the District C...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and contains a notable legal error.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may, by order, authorise any prescribed authority to re...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being a public servant in the same office a...
#   Score  : 1/5  — The model answer is not semantically correct; it refers to offenses under different sections of the IPC, which is unrelated to Section 336.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Indian Penal Code, 1860....
#   Score  : 2/5  — The model answer incorrectly identifies the Indian Penal Code, 1860 as the relevant code, when it should be the Code of Civil Procedure, 1908.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Overview
# Summary
# In every case of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses the wrong section (406 vs. 177/178) and the wrong context (assault cases vs. transfer of cases).
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Indian Penal C...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure as the Indian Penal Code.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested, the officer making the arrest shall forthwith take su...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead refers to the procedure for arrest and forwarding of an accused.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Evidence Act, 1872 deals with Saving ...
#   Score  : 4/5  — The model answer is close but incorrectly references the Indian Succession Act from 1925 instead of 1865.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model answer captures the essence of the powers of Claims Tribunals but incorrectly states that they are established by the Central Government and have the powers of an original appellate authority, which is not accurate according to the reference.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may, by order, authorise any prescribed authority to re...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing permits instead of carrying passengers on motor cycles.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 27:
# Section 375: Power to arrest
#
# The ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it incorrectly describes Section 375 regarding power to arrest instead of the correct content about appeals for guilty pleas.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Indian Divorce Act, 1869 deals With Bar to fu...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, and misinterprets the section's application.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure as the Indian Penal Code.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 7: offences against the state
# Section 149: Abetm...
#   Score  : 2/5  — The model answer incorrectly identifies Section 149 as relating to abetment of mutiny instead of offenses committed by members of an unlawful assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 36:
# Severity 479: Power to arrest and ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 479 as dealing with arrest powers instead of disqualification of judges and magistrates.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Power to make rules
#
# 1[Power t...
#   Score  : 2/5  — The model answer incorrectly interprets Section 198A as being about power to make rules instead of standards for road design, construction, and maintenance.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules regarding the time and place for the pay...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Code of Civil Procedure, 1908 deals with Decr...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant, discussing the Code of Civil Procedure instead of the Hindu Marriage Act.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Evidence of fact to be prove...
#   Score  : 2/5  — The model answer incorrectly states that Section 166 deals with evidence from documents instead of the power of jury or assessors to put questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Indian Penal Code, 1860 deals with Protection...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure, and misinterprets the section's purpose.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is not related to Section 161 of the Code of Criminal Procedure, 1973, and instead discusses the procedure for dealing with arrests.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Punishment for abetme...
#   Score  : 2/5  — The model answer incorrectly interprets Section 64 as dealing with abetment rather than non-payment of fine.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Indian Contract Act, 1872 deals with Voidance...
#   Score  : 2/5  — The model answer incorrectly refers to the Indian Contract Act instead of the Motor Vehicles Act and misidentifies the type of contract involved.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1961 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly states the year of the Indian Penal Code as 1961 instead of 1860.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[124. Power to make rules.--The State Government may make rules for the time be...
#   Score  : 1/5  — The model answer is not related to the question about Section 124 of the Code of Civil Procedure, 1908, and instead provides a general outline of powers to make rules under the Act.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) A State Government may, by order, authorise any prescribed authority to gran...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988, and instead discusses licensing of drivers, which is unrelated to the question.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1954 deals with Registrati...
#   Score  : 4/5  — The model answer captures the essence of Section 8 but includes an incomplete sentence at the end and a minor error in the year of the act.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : (1) The State Government may, by notification in the Official Gazette, appoint p...
#   Score  : 1/5  — The model answer is not semantically correct as it does not reflect the content of Section 7 of the Code of Civil Procedure, 1908.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences against the state
# Section 128: Abetm...
#   Score  : 2/5  — The model answer incorrectly identifies the section as abetment of mutiny instead of the correct offense of allowing a prisoner to escape.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable to order must be crossed g...
#   Score  : 1/5  — The model answer is completely unrelated to the question and contains no relevant legal information.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : The State Government may, by order, direct that any person who is, or has been, ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets the section and its powers.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 1/5  — The model answer is completely incorrect as Section 370 does not exist in the Indian Evidence Act, 1872.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Sexual interco...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its punishment, missing the key elements of causing death or persistent vegetative state.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power to make rules
#
# The S...
#   Score  : 2/5  — The model answer incorrectly interprets Section 147 as about making rules instead of consent from persons under disability.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : 1[43. Power to make rules.--The High Court may, from time to time, by order, mak...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about making rules, instead of summarizing Section 43.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Power to make rules
#
# The St...
#   Score  : 2/5  — The model answer incorrectly describes Section 34 as about making rules instead of interest.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 118: Evidence of fact to be inferr...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as about evidence of facts to be inferred, rather than competency to testify.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly describes Section 52 as relating to the power of the State Government to make rules, instead of addressing the alteration of motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 18: criminal trespass
# Section 365: Punishment fo...
#   Score  : 2/5  — The model incorrectly places Section 365 in Chapter 18 instead of Chapter 16 and misstates the punishment term.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may, by order, authorise any person to grant permits to...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals With Safety m...
#   Score  : 3/5  — The model answer omits the specific requirement for pillion riders to sit on a proper seat and the mention of the central government's power to prescribe additional safety measures.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 18: offences affecting the human body
# Section 41...
#   Score  : 2/5  — The model answer incorrectly identifies Section 410 as related to abetting an offense instead of defining stolen property.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable to order is said to be “dr...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing drawers and bearers instead of delivery of negotiable instruments.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : Where a decree is passed against a person by a Civil Court, that person may, wit...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power to make rules
#
# (1) The Ce...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question asked.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Summary
# In every case of the offen...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses abetment of suicide instead of Section 402 on revision cases.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Power to make rules
#
# (1) The Cen...
#   Score  : 2/5  — The answer incorrectly attributes the power to the Central Government instead of the State Government, and omits key points about the appointment and control of authorities.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : The Court may, on the application of either party, and on being satisfied of the...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead refers to a different section of the act.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[146. Power to make rules.-- The State Government may make rules for the time b...
#   Score  : 1/5  — The model answer is not related to the question and provides an incorrect statement about Section 146.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 2/5  — The model answer incorrectly states that a non-bank drawee must give the same reasons for refusing payment as a banker, which is not the correct interpretation of Section 31.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 10:
# Criminal Law (Repealed)
#
# Criminal ...
#   Score  : 2/5  — The model answer incorrectly refers to Chapter 10 as 'Criminal Law (Repealed)' and states that the section has been repealed, which is not accurate for Section 166B.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the essence of Section 116 but incorrectly includes the part about committing to custody and trying the person, which is not part of the inquiry process.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Power to order search...
#   Score  : 2/5  — The model answer incorrectly interprets Section 202 as granting power to order a search rather than postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 4/5  — Correct core content but incorrect year of the act.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable to order is said to be “dr...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 2/5  — The model incorrectly identifies the section as part of the Code of Criminal Procedure instead of the Indian Penal Code, and does not mention the specific punishment.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits house-breaking, shall be punished with imprisonment of either de...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the actual content of Section 290 of the Indian Penal Code.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 2:
# Section 36: Acceptance
#
# The holder ...
#   Score  : 2/5  — The model answer incorrectly focuses on acceptance instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 165: When witness may be compelle...
#   Score  : 2/5  — The model answer incorrectly interprets Section 165 as allowing the judge to compel a witness to produce a document, when in fact it gives the judge the power to ask questions and order production of documents.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculing maturity of bill or note payable so many months aft...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1979 deals with Abetment...
#   Score  : 4/5  — The model answer is close but incorrectly references the year 1979 instead of 1860 for the Indian Penal Code.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, he shall be produced before a Magistrate, unless he d...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing production before a Magistrate instead of the content of Section 339.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall forthwith inform ...
#   Score  : 1/5  — The model answer is not related to Section 310 of the Code of Criminal Procedure, 1973 and instead discusses arrest procedures.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model answer captures the essence of the section but unnecessarily repeats 'being a member of a public service committee' multiple times, which is not required.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a woman, commits rape on any other woman shall be punished with i...
#   Score  : 2/5  — The model answer incorrectly describes the statute and does not capture the key legal meaning of Section 376DB.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits house-breaking, shall be punished with imprisonment of either de...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to house-breaking instead of the content of Section 328.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable to order must be crossed g...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881, and thus is completely incorrect.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Power to make orders
#
# The Distri...
#   Score  : 2/5  — The model answer incorrectly interprets Section 57 as granting power to make orders, while the reference correctly states it pertains to liberty to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested under this section, he shall be taken before a Magistr...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing release on bond rather than the transfer of cases as per Section 228.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : The Court shall, in the exercise of its powers of revision, take into account th...
#   Score  : 1/5  — The model answer is not related to Section 171B of the Indian Penal Code and instead refers to a different section.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Power to make orders
#
# The Distri...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as about the power to make orders instead of addressing the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A State Government may, by order, authorise the use of any vehicle, whether ...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 27 of the Motor Vehicles Act, 1988.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 128 but omits the key point about the rights and position of the payer and payee as stated in the reference answer.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : When the Court is satisfied that a document is one of the kind specified in sect...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and thus is completely incorrect.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Penal Co...
#   Score  : 1/5  — The model answer is completely incorrect as Section 35 'Power of Court to disqualify' does not fall under the Indian Penal Code, 1860 but under the Motor Vehicles Act, 1988.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may, by order, authorise any prescribed authority to is...
#   Score  : 1/5  — The model answer is not related to Section 119 of the Motor Vehicles Act, 1988 and provides an unrelated statement about issuing permits.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 6:
# Section 102: Proof of fact relevant to que...
#   Score  : 4/5  — Correct core content but minor error in chapter number and slight imprecision in stating the section purpose.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power to make rules
#
# (1) The Cen...
#   Score  : 1/5  — The model answer is completely incorrect, discussing rules making powers instead of disqualification powers.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source for Section 351, when it actually belongs to the Indian Penal Code, 1860.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant, discussing the wrong section of the wrong code.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false evidence and offences against the stat...
#   Score  : 2/5  — The model incorrectly identifies the section as about false evidence instead of fraudulent decrees, and the punishment details are inaccurate.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a promissory note, bill of exchange or cheque is made payable to the order...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Evidence of fact to be proved...
#   Score  : 2/5  — The model answer incorrectly interprets Section 117 and provides unrelated information about secondary sources.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Power to make decrees for grantin...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 and introduces unnecessary repetition.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : The word “public” denotes the public generally, or the public generally in gener...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# 💾 Raw results saved → /kaggle/working/results/phase1_eval_qwen3_lora.json
#
# ============================================================
# 📊  PHASE 1 SUMMARY — QWEN3_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.36 / 5.0
#
#   Score distribution:
#     5/5  ██████████████████████████ (26)
#     4/5  ███████████████ (15)
#     3/5  █ (1)
#     2/5  █████████████████████████████████████████████████████ (53)
#     1/5  ███████████████████████████████████████████████████████ (55)
#
#   By task type:
#     Act Identification   avg=3.95  (n=39)
#     Direct Q&A           avg=1.13  (n=31)
#     Explanation          avg=2.41  (n=59)
#     Summarization        avg=1.10  (n=21)
# ============================================================
