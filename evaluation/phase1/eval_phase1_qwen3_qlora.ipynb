# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.1 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_phi4_mini/qlora_phase1_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_phi4_mini/lora_phase1_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 1 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase1_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 1 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: QWEN3_QLORA
# Loading 4-bit quantization config...
# Loading base model: Qwen/Qwen3-4B-Instruct-2507...
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 1 EVALUATION: QWEN3_QLORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, and being legally bound as such public servant ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Presumption as to electronic ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 65B as dealing with presumptions about postal services rather than admissibility of electronic records.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested on a charge of committing an offence triable under sec...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 53A and includes unrelated sections from other laws.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Code...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals with Sentence i...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure, and misinterprets the application of the section.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, whether on a warrant or otherwise, and is not in a st...
#   Score  : 1/5  — The model answer is not related to Section 104 of the Code of Criminal Procedure, 1973, and instead discusses search and arrest procedures.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a sentence has been passed in appeal or revision, the Appellate Court or th...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it describes the power to alter or reduce sentences rather than the certification process described in Section 405.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is sentenced to imprisonment for life or to imprisonment for a ter...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing fines and property sales instead of the transfer of cases to the Court of Session.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of an offence punishable with imprisonment for a term o...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 247 of the Code of Criminal Procedure, 1973.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the relevant act, when it should be the Code of Civil Procedure, 1908.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer incorrectly refers to the Code of Criminal Procedure instead of the Motor Vehicles Act, and misinterprets the purpose of Section 174.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is accused of an offence punishable with imprisonment for a term o...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973 and instead refers to different sections.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9: offences relating to elections
# Section 171G: ...
#   Score  : 4/5  — The model answer correctly identifies the section and provides the punishment, but omits the key requirement that the statement must be false and made with intent to affect the election result.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is close but omits the specific punishment details from the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever dishonestly receives or retains any property, knowing or having reason t...
#   Score  : 2/5  — The model answer describes a different offense (receiving/storing stolen property) than the one specified in Section 424 (concealment or removal of property).
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Evidence for defence
# ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 to relate to evidence taking rather than compliance with Section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note, bill of exchange or cheque is made payable to a specifie...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[(1) The Central Government may, by notification in the Official Gazette, make ...
#   Score  : 1/5  — The model answer is not related to the question about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a police officer has made a report under section 156, the Magistrate to who...
#   Score  : 1/5  — The model answer is not semantically correct as it discusses a different section (156) and a different aspect of the code than what was asked about (157).
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 22:
# Section 284: Procedure of Magistra...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 284 and provides incorrect information about the procedure.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[(1) A foreign State may sue in any Court otherwise competent to try the suit, ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer deviates from the question and includes irrelevant information about preventing escape, which is not related to Section 164.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter:
# Section 108: Procedure of Magistrate ...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as related to issuing summons for offenses, while the reference answer correctly explains it as related to disseminating seditious matters.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being legally bound to give information on certain conditions regarding...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 2/5  — The model answer incorrectly describes the punishment and intent required for wrongful confinement in secret, which differs from the reference.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : When a witness is being questioned as to a matter about which he was not origina...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the actual content of Section 158 of the Indian Evidence Act.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 23:
# Section 337: Procedure for committ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 337 and provides an incorrect procedure.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : Notwithstanding anything contained in this Code or any other law for the time be...
#   Score  : 1/5  — The model answer is not related to the question about Section 265A of the Code of Criminal Procedure, 1973.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 2/5  — The model answer includes extraneous information not related to the question and omits the key point about transfer to another state's court.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, being sentenced to imprisonment for life, or to imprisonment for a term...
#   Score  : 1/5  — The model answer is not related to Section 373 of the Indian Penal Code and is about a different section.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is mostly correct but includes redundant and unnecessary information about various time periods that are not part of the core legal meaning.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes bodily pain or injury to any person, in order to the ...
#   Score  : 2/5  — The model answer describes a different section of the IPC, specifically Section 354, not Section 358.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) A decree may be executed either by the Court which passed it, or by the Cour...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing execution of decrees instead of transfer of suits.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) A Regional Transport Authority may, after giving notice of not less than 30 ...
#   Score  : 1/5  — The model answer is not related to the content of Section 14 of the Motor Vehicles Act, 1988 and contains irrelevant information.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Code of Crim...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : When a promissory note, bill of exchange or cheque is required by law to be prot...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to protesting instead of presenting the promissory note for sight.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power to issue process for...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 139 to be about issuing process for payment of debt instead of administering oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : Every husband or wife may present a petition to the District Court 1 *** for the...
#   Score  : 4/5  — The model answer captures the essence of Section 18, allowing for petitions for dissolution or nullity, but incorrectly states that the petition must be made by the petitioner in the suit, which is not a requirement.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Any person who, drives a motor vehicle in contravention of the provisions of...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the reference answer.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes grievous hurt, for the purpose of extorting from the ...
#   Score  : 1/5  — The model answer is legally incorrect and unrelated to the content of Section 336 of the Indian Penal Code.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 406: Procedure when warran...
#   Score  : 2/5  — The model answer incorrectly describes Section 406 as about the procedure when a warrant cannot be issued, instead of the power to transfer cases and appeals.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a Court of Session or Court of a Chief Judicial Magistrate, or a Sessions J...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Code of Civil Procedure, 1908 deals with Sav...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure and the wrong year for the Indian Succession Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model captures the essence of Section 169 but misinterprets the scope of the tribunal's powers and the nature of the proceedings.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : 1[(1) The Central Government may, after consultation with the State Governments,...
#   Score  : 1/5  — The model answer is not semantically correct as it does not address the specific requirements for carrying passengers on a two-wheeled motor cycle as stated in Section 128.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 28:
# Section 375: Procedure for trial o...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, discussing the wrong section and topic.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 2/5  — The model answer incorrectly states that Section 12 bars suits based on previous convictions rather than preclusion of further suits based on the same cause of action.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences against the public tranquillity
# Sect...
#   Score  : 2/5  — The model answer incorrectly describes Section 149 as dealing with omission to give information, instead of describing the liability of members of an unlawful assembly for offenses committed in pursuit of their common object.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 34:
# Section 479: Power to issue proces...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 as relating to drawing bonds instead of disqualification of judges and magistrates.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Punishment for offences relati...
#   Score  : 2/5  — The model answer incorrectly identifies the section's focus on construction, maintenance, sale, and alteration of motor vehicles and components instead of road design, construction, and maintenance.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[134. Power of police to arrest without warrant.--Notwithstanding anything cont...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing police powers instead of the requirements for drivers after an accident.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Code of Civil Procedure, 1908 deals with Decr...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Hindu Marriage Act and provides irrelevant details about costs and arrests.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Procedure when witness is no...
#   Score  : 2/5  — The model answer incorrectly describes Section 166 as dealing with witnesses not present in court, while the reference correctly states it concerns juries and assessors.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1973 deals with P...
#   Score  : 4/5  — The answer captures the main idea but omits the requirement for consent from the Central Government and the mention of maintaining law and order.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Every police officer receiving information of the probable or actual commission ...
#   Score  : 2/5  — The model answer does not capture the key legal meaning of Section 161, which pertains to examination of persons acquainted with the case by police officers.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Amount of fine
#
# The a...
#   Score  : 2/5  — The model answer incorrectly focuses on the amount of fine rather than the sentencing for non-payment of fine as stated in the reference answer.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Motor Vehicles Act, 1988 deals with Voidance ...
#   Score  : 4/5  — The model captures the essence of Section 92 but omits the specific context of transport vehicles and the nature of the claims involved.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 5/5  — The model answer is semantically identical to the reference answer and captures all the key legal details accurately.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[(1) No person shall, except on the authority of a warrant issued by a Court, e...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) The Central Government may, by notification in the Official Gazette, make ru...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988 and instead discusses rule-making powers.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 2/5  — The model answer contains notable legal errors, misinterpreting Section 8 as dealing with voidability and registration deadlines instead of registration procedures.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : (1) The Court shall be open for the transaction of business during business hour...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the content of Section 7 of the Code of Civil Procedure, 1908.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences relating to the army, navy and air f...
#   Score  : 2/5  — The model answer incorrectly defines Section 128 and its application.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note, bill of exchange or cheque is required by law to be prot...
#   Score  : 2/5  — The model answer contains notable legal errors as it incorrectly states that the instrument must be protested when required by law, and omits the key points about notarization and specific conditions for protest.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : Every police officer not below the rank of sub-inspector may arrest or cause to ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 34 of the Code of Criminal Procedure, 1973.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Sexual interco...
#   Score  : 2/5  — The model answer incorrectly reinterprets Section 376A as dealing with'sexual intercourse by person in authority' instead of the actual content regarding causing death or persistent vegetative state.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Procedure in respect of su...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and its application.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : 1[(1) No Court shall try any suit or proceeding in the exercise of its original ...
#   Score  : 1/5  — The model answer is not related to the question about Section 43 of the Code of Civil Procedure, 1908, and instead discusses the jurisdiction of courts.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Execution of decrees
#
# 1[(1)...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 34 to be about execution of decrees instead of interest.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 8:
# Section 118: Proof of oral agreement, wher...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as related to proof of oral agreements and provides an inaccurate explanation.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Transfer of certificate of regis...
#   Score  : 2/5  — The model answer incorrectly describes Section 52 as related to transfer of certificate of registration instead of alteration of motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : When a person is sentenced to imprisonment for life, or to imprisonment for a te...
#   Score  : 1/5  — The model answer is not related to Section 365 of the Indian Penal Code, 1860, and instead discusses commencement of imprisonment.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, after giving notice of not less than thi...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Motor Vehicles Act, 1988 and provides incorrect information.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly applies it to all motor vehicles instead of just two-wheeled motorcycles.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: criminal trespass
# Section 410: Punishment fo...
#   Score  : 2/5  — The model answer incorrectly identifies Section 410 as relating to criminal trespass and provides an incorrect punishment, missing the key legal definition of stolen property.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note, bill of exchange or cheque is made payable to a specifie...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets the section's focus on delivery rather than consent for claiming the instrument.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[(1) Where a decree is sent for execution in another State, it shall be sent to...
#   Score  : 1/5  — The model answer is not related to Section 66 of the Code of Civil Procedure, 1908 and instead discusses provisions related to execution of decrees.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power of State Government to ma...
#   Score  : 2/5  — The model answer incorrectly describes Section 174 as about the power to make rules instead of recovery of money from insurers.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 402: Power to arrest in ca...
#   Score  : 1/5  — The model answer is completely unrelated to the question and contains errors about the section's content.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Transfer of certificate of regis...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 38 to be about the transfer of certificates of registration instead of the power to make rules.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : Every petition under this Act shall be served by post on the party against whom ...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and provides an unrelated statement about service of petitions.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[146. Procedure in respect of summons and warrant in case of refusal to execute...
#   Score  : 1/5  — The model answer is not semantically correct; it discusses a different section of the Code of Civil Procedure.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 2/5  — The model answer incorrectly states that the drawee is not liable to the banker, which is not accurate according to the reference answer.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 12:
# Section 166B: Report of the invest...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 166B as relating to reports of investigations rather than letters of request for international cooperation.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer contains notable legal errors, such as mentioning police officers instead of Magistrates and including an incomplete and irrelevant clause about examination.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Power to issue proces...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 202 and provides incorrect information about issuing process for witnesses.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : In a promissory note, the maker is called the “debtor”, and in a bill of exchang...
#   Score  : 1/5  — The model answer is not related to the question about Section 20 of the Negotiable Instruments Act, 1881.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Indian Penal Code, 1860 deals with Failure ...
#   Score  : 4/5  — The model answer is close but incorrectly states the maximum term of imprisonment as two years instead of one year.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being legally bound to give information on certain conditions regarding...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Liability of banker for...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its purpose, which is about liability of bankers rather than the liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 11:
# Section 165: Procedure in cases where evi...
#   Score  : 2/5  — The model answer incorrectly describes Section 165 as related to evidence taken against an accused without warrant, which is not accurate.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The model captures the essence of Section 108A but adds the punishment details, which are not part of the section's definition.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is accused of an offence triable by a Court of Session, and in the...
#   Score  : 1/5  — The model answer is not related to Section 339 of the Code of Criminal Procedure, 1973, and instead discusses a different section of the code.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is accused of an offence punishable under section 196, section 197...
#   Score  : 1/5  — The model answer is not related to the question about Section 310 of the Code of Criminal Procedure, 1973.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — Correct core content with minor precision error (two years instead of one year).
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, commits rape on a woman under twelve years of age shall be punished wit...
#   Score  : 4/5  — The model answer captures the essence of the punishment but omits the specific condition involving multiple perpetrators and the common intention.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt to any person, for the purpose of extorting from...
#   Score  : 2/5  — The model answer describes a different offense (wrongful restraint) than what Section 328 IPC defines (causing hurt through poison or drugs).
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : When a promissory note, bill of exchange or cheque is required by law to be prot...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to protesting an instrument instead of allowing the drawee time to consider acceptance.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Grounds for decree of dissolutio...
#   Score  : 4/5  — The model answer captures the essence of Section 57 but incorrectly identifies it as grounds for a decree of dissolution of marriage instead of the liberty to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of an offence punishable with imprisonment for a term o...
#   Score  : 2/5  — The model answer incorrectly describes Section 228 as applicable to offenses punishable with imprisonment for seven years or upwards, while the reference discusses transfer of cases to lower courts.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, corruptly or negligently, omits to give informa...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Grounds for dissolution of marri...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as dealing with grounds for dissolution of marriage instead of the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, after giving notice of not less than thi...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer is close but incorrectly defines 'crossed cheque' as 'payable to order' and 'bearer', which are different concepts.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : When the question is whether a man is alive or dead, and it is shown that he was...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and thus is completely incorrect.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Motor Vehicles ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[(1) The Central Government may, by notification in the Official Gazette, make ...
#   Score  : 1/5  — The model answer is not related to the question and provides rules for issuing permits instead of the content of Section 119.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 102: Presumption as to documents r...
#   Score  : 2/5  — The model answer incorrectly describes Section 102 as dealing with presumptions about documents and agreements, while the reference correctly states it concerns the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Discharge of cheque
#
# (1) A chequ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 35 as relating to cheques instead of disqualification of conductors.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 2/5  — The model answer incorrectly describes a different section of the IPC, specifically Section 171A, instead of Section 171B.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false evidence and offences against public j...
#   Score  : 2/5  — The model answer incorrectly describes Section 208 as related to false statements in declarations instead of fraudulent causing or suffering of decrees.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a cheque is uncrossed, the holder may cross it generally or specially.
# Whe...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Confession not to be proved a...
#   Score  : 2/5  — The model answer incorrectly states the section and its purpose, which is about estoppel rather than confessions.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Grounds for dissolution of marria...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as dealing with grounds for dissolution of marriage instead of addressing pending suits.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, legally bound as such public servant to cause t...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the question about Section 105 of the Indian Penal Code.
#
# 💾 Raw results saved → /kaggle/working/results/phase1_eval_qwen3_qlora.json
#
# ============================================================
# 📊  PHASE 1 SUMMARY — QWEN3_QLORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.65 / 5.0
#
#   Score distribution:
#     5/5  █████████████████████████████████████ (37)
#     4/5  ██████████████ (14)
#     3/5   (0)
#     2/5  ██████████████████████████████████████████████████████████ (58)
#     1/5  █████████████████████████████████████████ (41)
#
#   By task type:
#     Act Identification   avg=4.77  (n=39)
#     Direct Q&A           avg=1.35  (n=31)
#     Explanation          avg=2.42  (n=59)
#     Summarization        avg=1.29  (n=21)
# ============================================================
