# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.5 MB/s eta 0:00:00:00:0100:01

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_phi4_mini/qlora_phase1_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_phi4_mini/lora_phase1_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 1 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase1_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        # 🚨 Force Gemma to compute in FP32 to prevent NaN overflow!
        compute_dtype = torch.float32
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float32
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 1 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: GEMMA3_LORA
# Loading 4-bit quantization config...
# Loading base model: google/gemma-3-4b-it...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 1 EVALUATION: GEMMA3_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a surgeon, shoemaker, dentist, barber or masseur, or being in the...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to a different section of the IPC and does not address the specific act of throwing acid or administering acid.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 3:
# Section 65B: Presumption as to digital sig...
#   Score  : 2/5  — The model answer incorrectly focuses on digital signatures instead of the admissibility of electronic records, containing a notable legal error.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : The provisions of this Chapter relating to the powers of the police officer in c...
#   Score  : 1/5  — The model answer is not related to the content of Section 53A of the Code of Criminal Procedure, 1973, and instead discusses unrelated procedural matters.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Indi...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source of Section 105J, when it actually belongs to the Indian Penal Code, 1860.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals in simple words...
#   Score  : 2/5  — The model incorrectly applies Section 31 to the Indian Penal Code instead of the Code of Criminal Procedure, and omits key details about consecutive sentences.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 103, h...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 419, h...
#   Score  : 1/5  — The model answer is about bail and not related to the certification of decisions or orders as stated in Section 405 of the Code of Criminal Procedure, 1973.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 155, t...
#   Score  : 1/5  — The model answer is not related to Section 323 of the Code of Criminal Procedure, 1973 and provides information about section 155 and 157 instead.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested in the course of an investigation under section 246, t...
#   Score  : 1/5  — The model answer is not related to the content of Section 247 and instead refers to a different section (246) of the Code of Criminal Procedure.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 2/5  — The model answer incorrectly identifies the relevant act, which is the Code of Civil Procedure, 1908.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Motor Vehicles Act, 1988 deals about Recover...
#   Score  : 2/5  — The model answer incorrectly states that the insurer can recover the amount, while the reference indicates the Claims Tribunal issues a certificate to the Collector for recovery.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Magistrate has to take cognizance of an offence which is not triable by h...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 12: bribery and corruption
# Section 171G: Bribery...
#   Score  : 2/5  — The model incorrectly categorizes the section under Chapter 12 and misinterprets the nature of the offense.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals Abetting in In...
#   Score  : 4/5  — Correct core content but includes additional penalty details not present in the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever, fraudulently or dishonestly performs or assists in the performance of a...
#   Score  : 2/5  — The model answer does not accurately capture the key elements of Section 424 of the Indian Penal Code, specifically focusing on property concealment rather than fraud or dishonesty.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 238: Power of High Court to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 to be about the power of the High Court to make rules, instead of the requirement for Magistrates to comply with Section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a promissory note or bill of exchange has been dishonoured by non-acceptan...
#   Score  : 1/5  — The model answer incorrectly references multiple sections instead of accurately stating the content of Section 99.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[125. Power of State Government to make rules.-- The State Government may make ...
#   Score  : 1/5  — The model answer is not semantically correct and does not address the question about the specific provision of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a police officer has reason to believe that an offence has been committed b...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it describes a different section of the Code of Criminal Procedure, 1973 (Section 156) rather than Section 157.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 284: Power of Magistrate to ...
#   Score  : 2/5  — The model answer incorrectly states that the section allows for the examination of a witness in person, while the reference explains the power to dispense with attendance and issue a commission.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this Code relating to the powers of the State Government and t...
#   Score  : 1/5  — The model answer is not related to the question about Section 89 of the Code of Civil Procedure, 1908.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Indian Evidence Act, 1872 deals with Recordi...
#   Score  : 2/5  — The model incorrectly identifies the section from the Indian Evidence Act instead of the Code of Criminal Procedure, and omits the key point about recording by a magistrate.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Section 108: Power of High Court to...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 108 of the Code of Criminal Procedure, 1973.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a watchman, negligently omits to discharge the duty of a watchman...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer captures the essence of wrongful confinement in secret but incorrectly includes conditions about the place of confinement being secret and the ability to be released on demand, which are not part of Section 346.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : When the question is whether a particular act was done by a particular person, t...
#   Score  : 1/5  — The model answer is not related to the content of Section 158 of the Indian Evidence Act, 1872.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Title: Chapter :
# Section 337: Power of High Co...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 337 and provides an incorrect description.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 161 of...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Indian Divorce Act, 1869 deals in Transfer of...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, and provides an inaccurate description of the section.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, fraudulently or with intent to defraud, conceals the birth of a child, ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is accurate and captures the key legal meaning, with only a minor difference in wording regarding the duration of confinement.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a soldier, sailor or airman in the Army, Navy or Air Force of the...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : The provisions of this Code relating to the powers of the Court and the duties o...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 25 of the Code of Civil Procedure, 1908.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) No person shall drive any motor vehicle in any public place without a licenc...
#   Score  : 1/5  — The model answer is not related to Section 14 of the Motor Vehicles Act, 1988 and instead provides unrelated information about driving without a license.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 4/5  — Correct core content but incorrect year of the Code of Criminal Procedure.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : The provisions of this Act relating to promissory notes and bills of exchange sh...
#   Score  : 1/5  — The model answer is not relevant to the question and does not capture the key legal meaning of Section 62.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power of State Government ...
#   Score  : 2/5  — The model answer incorrectly describes Section 139 as about the power of the State Government to make rules, while the reference answer correctly states it is about administering oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : Every person who has been married, whether within or without India, and who is a...
#   Score  : 2/5  — The model answer contains notable legal errors, as it incorrectly states that the section deals with grounds for dissolution rather than declaring marriages null and void.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[178. Power of State Government to make rules.-- The State Government may make ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever drives any vehicle or causes or attempts to cause any other person to dr...
#   Score  : 3/5  — The model answer captures the essence of recklessness or negligence endangering life but incorrectly specifies the punishment and the context of driving a vehicle.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Indian Penal Code, 1860....
#   Score  : 2/5  — The model answer incorrectly identifies the Indian Penal Code, 1860 as the relevant code, when it should be the Code of Civil Procedure, 1908.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Title: The Code of Criminal Procedure, 1973
#
# 1[...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not address Section 406 of the Code of Criminal Procedure, 1973, and instead provides repealed sections and unrelated information.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested in the course of an investigation under section 477, h...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Penal Code, 1860 deals with Saving of...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Indian Evidence Act and provides an outdated reference to the Indian Succession Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals about Procedu...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions compared to the reference.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) No person shall drive a motor vehicle in any public place unless he has a va...
#   Score  : 1/5  — The model answer is not related to the content of Section 128 of the Motor Vehicles Act, 1988, and instead discusses requirements for driving licenses and permits which are unrelated to the specific section.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Title: Chapter :
# Section 375: Power of High Co...
#   Score  : 1/5  — The model answer is completely unrelated to the question and does not address Section 375 of the Code of Criminal Procedure, 1973.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Indian Divorce Act, 1869 deals about Bar to f...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, 1908, leading to a significant legal error.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, instead of the Indian Penal Code, 1860.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences against the public tranquillity
# Sect...
#   Score  : 4/5  — Correct core content but includes outdated information about repeal.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Title: Chapter :
# Section 479: Power of High Co...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 479 to refer to the power of the High Court to make rules, rather than the disqualification of judges and magistrates.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Power of State Government to m...
#   Score  : 2/5  — The model answer incorrectly interprets Section 198A as relating to the power of the State Government to make rules instead of the responsibility of authorities to comply with road design, construction, and maintenance standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[134. Power of State Government to make rules.-- The State Government may make ...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the question about Section 134 of the Motor Vehicles Act, 1988.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the India...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals in simple term...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to the Indian Divorce Act instead of the Hindu Marriage Act and does not capture the key legal meaning of Section 23.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 166: When oral confessions are not...
#   Score  : 2/5  — The model answer incorrectly interprets Section 166 as dealing with oral confessions instead of jury questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Indian Penal Code, 1860 deals with Protection...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure and misstates the requirement as needing consent from an officer commanding the unit or a Magistrate, rather than requiring consent from the Central Government.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : When a police officer has reason to believe that any person is present in any pl...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Punishment of offence...
#   Score  : 2/5  — The model answer incorrectly describes Section 64 as related to religious punishment rather than fines and imprisonment.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Indian Penal Code, 1860 deals about Voidance ...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Motor Vehicles Act and provides an unrelated explanation.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer captures the core meaning but includes unnecessary details about impressions and marks of government authorities, which are not part of the section's actual content.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this Chapter relating to the service of summons and notices an...
#   Score  : 1/5  — The model answer is not related to Section 124 of the Code of Civil Procedure, 1908 and instead refers to the service of notices and decrees in small cause courts.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) No person shall drive a motor vehicle in any public place without a licence ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets the original section and introduces irrelevant clauses.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals on Registration...
#   Score  : 2/5  — The model answer incorrectly interprets Section 8 as dealing with registration rather than providing for the registration of Hindu marriages, and includes irrelevant information about validity of marriages.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : The provisions of this Code relating to the powers of the Court and the duties o...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the specific section of the Code of Civil Procedure, 1908.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: the stage of preparation, attempt, and prepar...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 128 of the Indian Penal Code.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act relating to promissory notes and bills of exchange sh...
#   Score  : 1/5  — The model answer is not relevant to the question about Section 100 of the Negotiable Instruments Act, 1881.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested in the course of an investigation under section 25, he...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 34 of the Code of Criminal Procedure, 1973.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: unnatural offences
# Section 376A: Sexual inte...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to unnatural offenses and misstates the punishment and conditions for the offense.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power of High Court to mak...
#   Score  : 2/5  — The model answer incorrectly interprets Section 147 as about the power of the High Court to make rules, instead of dealing with consent or agreements from persons under disability.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : The provisions of this Code relating to the procedure of High Courts and the rul...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the content of Section 43 of the Code of Civil Procedure, 1908.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Power of High Court to make...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 34 of the Code of Civil Procedure, 1908.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 3:
# Section 118: When oral evidence may be pro...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as about oral evidence and primary evidence, instead of competency to testify.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly focuses on the power of the state government to make rules instead of explaining Section 52 regarding alterations to motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: theft
# Section 365: Punishment for robbery
#
# W...
#   Score  : 2/5  — The model incorrectly identifies the section as related to robbery and misstates the intent requirement.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) No person shall drive a motor vehicle in any public place unless he has a va...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Motor Vehicles Act, 1988 and provides incorrect information.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals in Safety mea...
#   Score  : 3/5  — The model answer misses the specific mention of two-wheeled motor cycles and the requirement for a proper seat for pillion riders.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: the theft
# Section 410: Theft
#
# The word “thef...
#   Score  : 2/5  — The model incorrectly defines Section 410 as related to theft instead of stolen property, and provides an incorrect definition of theft.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act relating to promissory notes and bills of exchange sh...
#   Score  : 1/5  — The model answer is not legally accurate as it does not address the content of Section 46, instead it provides an unrelated statement about application of provisions.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this Code relating to the procedure of High Courts and the pro...
#   Score  : 1/5  — The model answer is not related to the question about Section 66 of the Code of Civil Procedure, 1908.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power of State Government to ma...
#   Score  : 1/5  — The model answer is completely incorrect and does not address the actual content of Section 174.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Title: The State of Maharashtra.
#
# 1[State of Ma...
#   Score  : 2/5  — The model answer is not relevant to the question about Section 402 of the Code of Criminal Procedure, 1973.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Power of State Government to mak...
#   Score  : 4/5  — The answer captures the essence of Section 38 but omits the specific mention of licensing authorities and the conditions for exemptions.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : The Court may, in any such case, make such order as it thinks fit respecting the...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead refers to court powers under a different section.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this Code relating to the service of summons and notices, and ...
#   Score  : 1/5  — The model answer is not related to Section 146 of the Code of Civil Procedure, 1908 and instead discusses service of summons and notices and execution of decrees.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals about ...
#   Score  : 2/5  — The model answer incorrectly attributes liability to the drawer rather than the drawee, and misinterprets the section's intent.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 166B: Power of State Governm...
#   Score  : 2/5  — The model answer incorrectly describes the section as about making rules instead of letters of request.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Indian Evidence Act, 1872 deals in Inquiry a...
#   Score  : 2/5  — The model incorrectly refers to the Indian Evidence Act instead of the Code of Criminal Procedure, and omits key details about the Magistrate's role.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 202: Power of Magistrate to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 202 to refer to the examination of witnesses instead of postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Indian Divor...
#   Score  : 1/5  — The model answer is completely incorrect as Section 7 of the Hindu Marriage Act, 1955 pertains to ceremonies for Hindu marriages, not the Indian Divorce Act, 1869.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act relating to promissory notes and bills of exchange sh...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1996 deals with...
#   Score  : 2/5  — The model incorrectly refers to the wrong code (Code of Criminal Procedure instead of Indian Penal Code) and misstates the punishment.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a watchman, negligently omits to discharge the duty of a watchman...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the reference answer.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 2:
# Section 36: Presentment for payment...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as related to presentment for payment instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 165: Power of Magistrate to order ...
#   Score  : 2/5  — The model answer incorrectly describes Section 165 as relating to a Magistrate's power to examine witnesses, while the reference answer correctly states it pertains to a Judge's power to put questions and order production.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals about Abetmen...
#   Score  : 4/5  — Correct core content but includes a minor error by stating the section was repealed.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 337 or...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to sections 337 and 338 instead of sections 330 and 335, and misstates the purpose of the section.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested in the course of an investigation under section 299, s...
#   Score  : 1/5  — The model answer is not related to Section 310 of the Code of Criminal Procedure, 1973, and instead refers to different sections.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model answer captures the essence of the section but omits the maximum term of imprisonment and the possibility of both imprisonment and fine.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, at any time after the passing of this Act, commits the offence of rape,...
#   Score  : 2/5  — The model answer incorrectly states the age requirement and the punishment, missing the key elements of multiple perpetrators and life imprisonment.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt to any person, or to any animal, by splashing wa...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : The provisions of this Act relating to promissory notes and bills of exchange sh...
#   Score  : 1/5  — The model answer is not related to the content of Section 63 of the Negotiable Instruments Act, 1881, and thus is completely incorrect.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Power of Court to make decrees
#
# ...
#   Score  : 4/5  — Correctly identifies the section and its purpose, but misinterprets the actual content of Section 57.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested in the course of an investigation under section 155, h...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 228 of the Code of Criminal Procedure, 1973.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever, at an election, gives or offers to give, or takes or accepts, or attemp...
#   Score  : 3/5  — The model answer captures the essence of the offense but omits the specific mention of 'electoral right' and the provision about declaration of public policy.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Power of High Court to make rule...
#   Score  : 2/5  — The model answer incorrectly focuses on the power of the High Court to make rules instead of explaining the legal position of the wife during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) No person shall drive a motor vehicle in any public place unless he has a va...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, not addressing any part of Section 27 of the Motor Vehicles Act, 1988.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals about...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 128 which is about payment in due course, not negotiation restrictions.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : When the Court has to form an opinion as to the meaning of any document, electro...
#   Score  : 1/5  — The model answer is not related to the content of Section 40 of the Indian Evidence Act and introduces an unrelated term 'anecdote'.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Divorce ...
#   Score  : 1/5  — The model answer is completely incorrect as Section 35 'Power of Court to disqualify' does not fall under the Indian Divorce Act, 1869.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[119. Power of State Government to make rules.-- The State Government may make ...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about the power of the State Government to make rules.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 2:
# Section 102: When oral evidence may be pro...
#   Score  : 2/5  — The model answer incorrectly describes Section 102 as about secondary evidence and oral evidence, while the reference discusses the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly identifies Section 35 as relating to rule-making powers instead of disqualification.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 4/5  — The model captures the essence of Section 171B but includes unnecessary and slightly confusing language like 'or makes, or gives or claims, or returns, or takes, or has received' which can be simplified.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 12: false trails, false documents and false prop...
#   Score  : 2/5  — The model answer incorrectly identifies Section 208 and its content, referring to false weights and measures instead of fraudulent decrees.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act relating to promissory notes, bills of exchange and c...
#   Score  : 1/5  — The model answer is not related to Section 144 of the Negotiable Instruments Act, 1881 and provides an unrelated statement about negotiable instruments.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 3:
# Section 117: When oral evidence may be pro...
#   Score  : 2/5  — The model answer incorrectly describes Section 117 and does not address the estoppel principle for acceptors of bills of exchange, bailees, or licensees.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Power of High Court to make rules...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as granting power to the High Court to make rules, while the reference correctly states that it deals with pending suits.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Nothing is an offence which is done by a child under seven years of age....
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# 💾 Raw results saved → /kaggle/working/results/phase1_eval_gemma3_lora.json
#
# ============================================================
# 📊  PHASE 1 SUMMARY — GEMMA3_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.35 / 5.0
#
#   Score distribution:
#     5/5  ██████████████████████████ (26)
#     4/5  ███████████ (11)
#     3/5  ███ (3)
#     2/5  ███████████████████████████████████████████████████████████ (59)
#     1/5  ███████████████████████████████████████████████████ (51)
#
#   By task type:
#     Act Identification   avg=3.97  (n=39)
#     Direct Q&A           avg=1.23  (n=31)
#     Explanation          avg=2.27  (n=59)
#     Summarization        avg=1.19  (n=21)
# ============================================================
