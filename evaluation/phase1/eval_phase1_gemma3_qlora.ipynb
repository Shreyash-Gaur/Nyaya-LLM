# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_phi4_mini/qlora_phase1_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_phi4_mini/lora_phase1_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_qwen3_4b/qlora_phase1_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_qwen3_4b/lora_phase1_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase1_gemma3_4b/lora_phase1_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 1 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase1_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        # 🚨 Force Gemma to compute in FP32 to prevent NaN overflow!
        compute_dtype = torch.float32
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float32
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 1 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: GEMMA3_QLORA
# Loading 4-bit quantization config...
# Loading base model: google/gemma-3-4b-it...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/qlora_phase1_gemma3_4b/qlora_phase1_gemma3_4b...
# Loading judge model (Qwen2.5-7B 4-bit)...
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 1 EVALUATION: GEMMA3_QLORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, except as hereinafter excepted, voluntarily causes grievous hurt by mea...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not accurately reflect the specific provisions regarding acid attacks in Section 326A of the Indian Penal Code.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Presumption as to electronic ...
#   Score  : 2/5  — The model answer incorrectly describes Section 65B as about presuming the genuineness of electronic records, when it actually deals with the admissibility of electronic records.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : The provisions of section 52 shall apply in relation to the identification of an...
#   Score  : 1/5  — The model answer is not semantically correct and does not address the key legal meaning of Section 53A.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Indi...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source of Section 105J, when it actually belongs to the Indian Penal Code, 1860.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals with Sentence i...
#   Score  : 2/5  — The answer incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure and misstates the purpose of Section 31.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested on a charge of committing an offence which includes, o...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 104 of the Code of Criminal Procedure, 1973.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : The High Court may pass any sentence authorised by law.
# 		The High Court may, su...
#   Score  : 1/5  — The model answer is not related to Section 405 of the Code of Criminal Procedure, 1973 and instead provides unrelated provisions.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is acquitted upon the ground that he acted without the consent of ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 323 of the Code of Criminal Procedure, 1973.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : If the Magistrate does not convict, the accused shall be discharged, and in all ...
#   Score  : 1/5  — The model answer is not related to the content of Section 247 and instead refers to different sections.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 2/5  — The model answer incorrectly identifies the relevant act, which is the Code of Civil Procedure, 1908.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Motor Vehicles Act, 1988 deals with Recovery...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, such as the omission of the Claims Tribunal and the Collector's role.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a summons has been issued to any person to appear before a Magistrate or Co...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it describes a different section of the Code of Criminal Procedure, 1973.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9: offences relating to elections
# Section 171G: ...
#   Score  : 2/5  — The model incorrectly identifies the section as being about bribery instead of false statements.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is semantically correct but omits the specific punishment details from the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever dishonestly receives any stolen property, knowing or having reason to be...
#   Score  : 2/5  — The model answer describes a different section of the IPC (Section 429) and does not match the content of Section 424.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 17:
# Section 238: When accused shall be...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 and its purpose.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a promissory note or bill of exchange has been dishonoured by non-acceptan...
#   Score  : 2/5  — The model answer contains notable legal errors, as it misinterprets the section to allow acceptance instead of noting dishonour.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[Duty to give information as to accidents. -- (1) Where an accident occurs in w...
#   Score  : 1/5  — The model answer is not related to the question about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 23:
# Section 284: Service of summons on...
#   Score  : 2/5  — The model answer incorrectly describes Section 284 as dealing with service of summons on corporations instead of dispensing with witness attendance and issuing commissions.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[89. Execution of decree outside jurisdiction.-- So much of any decree which pu...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions, such as misinterpreting the scope of Section 164 and including irrelevant information from Section 175.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Section 108: Power of Magistrate to...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as related to search warrants instead of security for good behavior.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, by any act, or by any illegal omission, obstructs any public servant in...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it describes a different section of the IPC (Section 291) rather than Section 290.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 2/5  — The model answer incorrectly includes fear of death or grievous hurt, which is not part of the legal definition of wrongful confinement in secret.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : The Court may presume that any book to which it may refer for information on mat...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act and provides an unrelated legal provision.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 24:
# Section 337: Procedure in cases of...
#   Score  : 2/5  — The model answer incorrectly describes Section 337 and its procedure, which is about a lunatic prisoner capable of making a defense, not an unsound mind incapable of making a defense.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of section 421 and so much of section 422 as relates to the issue...
#   Score  : 1/5  — The model answer is not related to Section 265A of the Code of Criminal Procedure, 1973, and instead refers to sections 421 and 422.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 2/5  — The model answer includes extraneous information not relevant to the question and omits the key point about the decree being sent to the appropriate court in another state.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever buys, hires or otherwise obtains possession of any person under the age ...
#   Score  : 4/5  — The model answer is accurate and captures the key elements of Section 373, including the intent and possible punishments. However, it omits the specific mention of 'unlawful and immoral purpose' from the reference answer.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is accurate and captures the key legal meaning, but it incorrectly states the maximum term of imprisonment as three years instead of two years.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever wrongfully confines any person for the purpose of extorting from such pe...
#   Score  : 1/5  — The model answer is not related to Section 358 of the Indian Penal Code and provides a different section's content.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : 1[25. Suits by or against Government.]— Rep. by the Limitation Act, 1963 (36 of ...
#   Score  : 2/5  — The model answer incorrectly identifies Section 25 as related to suits by or against the government, which is not accurate.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) No person shall drive a motor vehicle or cause or allow a motor vehicle to b...
#   Score  : 1/5  — The model answer is not related to Section 14 of the Motor Vehicles Act, 1988, and instead discusses insurance policies, which is unrelated to the content of the reference answer.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Code of Crim...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note or bill of exchange, made payable at a specified bank, must be...
#   Score  : 2/5  — The model answer contains notable legal errors as it incorrectly states the presentation should be made at a specified bank rather than to the maker for sight.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power of Court to amend
#
# T...
#   Score  : 2/5  — The model answer incorrectly describes Section 139 as about amending judgments instead of administering oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : Every petition under this Act shall be served on the party to be affected thereb...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and contains significant errors.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Whoever, being required by or under this Act or the rules made thereunder to...
#   Score  : 2/5  — The model answer contains notable legal errors, as it refers to keeping registers and returns instead of traveling without a proper pass or ticket.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever does any act so rashly or negligently as to endanger human life, or the ...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly increases the maximum fine from 250 rupees to 500 rupees.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 32:
# Section 406: Power of High Court t...
#   Score  : 2/5  — The model answer incorrectly describes Section 406 as granting power to High Courts to confer powers on persons, whereas it actually pertains to the Supreme Court's power to transfer cases.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a person has been convicted on a trial held by a Metropolitan Magistrate or...
#   Score  : 1/5  — The model answer is completely unrelated to the question and does not address Section 478 of the Code of Criminal Procedure, 1973.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Succession Act, 1925 deals with Savin...
#   Score  : 4/5  — The model correctly identifies the relevant act and the purpose of Section 100, but incorrectly states that it is part of the Indian Succession Act rather than the Indian Evidence Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model answer captures the essence of Section 169 but omits the procedural aspects and the enforcement powers of the tribunal.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) Where an offence under this Act has been committed by a minor, his guardian ...
#   Score  : 1/5  — The model answer is not related to Section 128 of the Motor Vehicles Act, 1988 and provides incorrect information.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 29:
# Section 375: Procedure in cases su...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 375 and does not address the key points about appeals and guilty pleas.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Indian Divorce Act, 1869 deals with Bar to fu...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, and misinterprets the scope of Section 12.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences against the public tranquillity
# Sect...
#   Score  : 4/5  — The model answer correctly identifies the section and provides the punishment, but incorrectly states the section title and omits the key legal principle that all members of the assembly can be held responsible for the actions of others within the assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 35:
# Section 479: Power of High Court t...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 and does not capture the key legal meaning.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Punishment for offences commit...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to punishment for juvenile offenses instead of road safety standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government or any authority authorised in this behalf by the State...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about declaring notified areas, which is not mentioned in the reference answer.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals with Decree in...
#   Score  : 1/5  — The model answer is completely incorrect as it refers to the Indian Divorce Act, 1869 instead of the Hindu Marriage Act, 1955 and provides an unrelated explanation about decrees.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Public servant concealing de...
#   Score  : 2/5  — The model answer incorrectly describes Section 166, which is about jury or assessor questioning, not reporting offenses.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1973 deals with P...
#   Score  : 3/5  — The model answer misses the key point about requiring consent from the Central Government and the exception for maintaining order.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Any Chief Judicial Magistrate may, without a warrant, search any place within hi...
#   Score  : 1/5  — The model answer is completely unrelated to the question and does not address Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Sentence of imprisonm...
#   Score  : 2/5  — The model answer incorrectly describes Section 64 as relating to the punishment for non-payment of fine, when it actually pertains to sentencing for offenses punishable with both imprisonment and fine.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Motor Vehicles Act, 1988 deals with Voidance ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 92 and its purpose.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 5/5  — The model answer is semantically correct and captures all the key legal elements of the reference answer without any errors.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[High Court may determine issue.] — Subject to such rules as may be made by the...
#   Score  : 1/5  — The model answer is not related to Section 124 of the Code of Civil Procedure, 1908 and provides an unrelated statement about court procedures.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) Where an application for compensation is made to the Claims Tribunal or any ...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 112 of the Motor Vehicles Act, 1988.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 2/5  — The answer is repetitive and lacks specific details about the registration process.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : 1[(1) The following provisions shall not apply to any Court which is a Court of ...
#   Score  : 2/5  — The model answer incorrectly includes the Workmen's Breach of Contract Act and the Motor Vehicles Act, and omits the specific reference to the Provincial Small Cause Courts Act and Berar Small Cause Courts Law.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences relating to coin and stamps
# Section ...
#   Score  : 2/5  — The model incorrectly identifies the chapter and provides outdated information about the section being repealed.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note or bill of exchange made, drawn or accepted outside India shal...
#   Score  : 1/5  — The model answer is not related to Section 100 of the Negotiable Instruments Act, 1881, which deals with protests and better security.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : Every police officer or other person arresting any person without warrant, or in...
#   Score  : 1/5  — The model answer is completely unrelated to Section 34 of the Code of Criminal Procedure, 1973.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Punishment for...
#   Score  : 2/5  — The model answer incorrectly interprets Section 376A as relating to gang rape instead of the specific offense of causing death or persistent vegetative state.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power to make such orders ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and introduces unrelated content.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : 1[43. Execution of decree outside India.-- So much of the foregoing sections of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, misinterpreting the scope and intent of Section 43.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Power to amend
#
# The Court m...
#   Score  : 2/5  — The model answer incorrectly describes Section 34 as about amending defects rather than ordering interest.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 118: Presumption as to genuineness...
#   Score  : 2/5  — The model answer incorrectly describes Section 118, which is about witness competency, not presumptions regarding certified copies.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly focuses on the state government's rule-making power instead of the actual content of Section 52 regarding alterations to motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: kidnapping, abduction, slavery and forced la...
#   Score  : 2/5  — The model incorrectly defines the intent and punishment for Section 365.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The Central Government may, by notification in the Official Gazette, specify...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 2/5  — The model answer incorrectly describes stopping requirements instead of safety measures for drivers and pillion riders.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: offences relating to coin and currency
# Secti...
#   Score  : 2/5  — The model answer incorrectly interprets Section 410 as relating to theft of government stamps instead of stolen property.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a negotiable instrument indorsed in blank may, without signing his...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[66. Power of Court to transfer suits.— Subject to such conditions and limitati...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power of State Government to ma...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 174 to be about rule-making powers instead of recovery of money from insurers.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 31:
# Section 402: Power of High Court t...
#   Score  : 1/5  — The model answer is completely unrelated to the question and reference answer.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Driving Licences
#
# (1) Every pers...
#   Score  : 2/5  — The model answer incorrectly interprets Section 38 as being about driving licenses and conduct certificates instead of rules-making powers.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : Every petition under this Act for a decree of dissolution of marriage, or of nul...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869 and instead discusses service of petitions, which is unrelated to the content of Section 59.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[High Court may determine issue or make decree on merits.]—
#
# (1) Where an issue...
#   Score  : 1/5  — The model answer is not related to Section 146 of the Code of Civil Procedure, 1908, and instead discusses the powers of the High Court regarding referred issues and amendments to judgments.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 2/5  — The model answer incorrectly describes the liability of the drawee and instead discusses crossing and protesting of cheques.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 13:
# Section 166B: Power of State Gover...
#   Score  : 2/5  — The model answer incorrectly describes Section 166B as about the power to make rules instead of the request for investigation from foreign countries.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Indian Evidence Act, 1872 deals with Inquiry...
#   Score  : 2/5  — The model answer incorrectly refers to Section 116 of the Indian Evidence Act instead of the Code of Criminal Procedure, and misinterprets the purpose of the section.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 14:
# Section 202: Power of Magistrate t...
#   Score  : 2/5  — The model answer incorrectly describes Section 202 as related to ordering medical examinations and does not address the actual content regarding postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker of a promissory note or cheque, the acceptor of a bill of exchange, an...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Indian Penal Code, 1860 deals with Failure ...
#   Score  : 4/5  — The model captures the essence of the section but omits the requirement of sufficient cause and the burden of proof.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, by any act, or by any illegal omission, obstructs a public servant in t...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Presentment for payment...
#   Score  : 2/5  — The model answer incorrectly describes Section 36, which is about liability of prior parties to a holder in due course, instead of presentment for payment of promissory notes.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 165: Rep. by the Prevention of Co...
#   Score  : 2/5  — The model answer incorrectly states that Section 165 was repealed by the Prevention of Corruption Act, 1988, instead of providing the actual content of the section.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 2/5  — The model answer incorrectly states that the section has been repealed, which is not accurate.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When the person required by any Court, or other person, to execute a bond is a m...
#   Score  : 1/5  — The model answer is not related to Section 339 of the Code of Criminal Procedure, 1973.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of section 309 shall apply, with such modifications as the circum...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and contains a significant error.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The answer captures the essence of the section but omits the imprisonment component and slightly misstates the fine amount.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, commits rape on a woman under twelve years of age, shall be punished wi...
#   Score  : 2/5  — The model answer incorrectly states the punishment and omits the part about multiple perpetrators and common intention.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt by means of any instrument for shooting, stabbin...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : The holder of a negotiable instrument, without the consent of the maker or accep...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Power to make such orders after ...
#   Score  : 2/5  — The model answer incorrectly describes Section 57 as about making orders related to children, while the reference correctly states it is about the liberty to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : If the accused refuses to plead or does not plead, or his plea is such that the ...
#   Score  : 1/5  — The model answer is not semantically correct; it discusses a different section (207) and a different scenario (refusal to plead) rather than summarizing Section 228.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever without the general or special authority of any candidate incurs or auth...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Power to make such orders after ...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as dealing with orders after the decree rather than the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The Central Government may, by notification in the Official Gazette, specify...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 128 but omits the key detail about the rights and position of the parties involved.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : The Court may presume the existence of the following facts, in order to enable i...
#   Score  : 1/5  — The model answer is not related to the content of Section 40 of the Indian Evidence Act, 1872.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Motor Vehicles ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[Duty to give information as to accidents. -- (1) Every person who is or has be...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing duty to report accidents instead of driving rules.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 102: Burden of proof as to particu...
#   Score  : 4/5  — Correct core content but uses less precise language than the reference answer.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly states that Section 35 pertains to the power of the state government to make rules, while the reference answer correctly explains the court's power to disqualify conductors.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 2/5  — The model answer incorrectly describes the punishment and conditions for bribery under Section 171B, which is not about influencing elections but about giving or accepting gratification related to electoral rights.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false evidence and offences against public j...
#   Score  : 2/5  — The model answer incorrectly describes Section 208 as related to fraudulently obtaining a decree, while the reference explains it as fraudulently causing or suffering a decree for an improper amount.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a cheque is crossed generally, the banker on whom it is drawn shall not pa...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Burden of proof as to existen...
#   Score  : 2/5  — The model answer incorrectly identifies the section as about the burden of proof and misinterprets its content.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Grounds for dissolution of marria...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as dealing with grounds for dissolution of marriage instead of addressing how pending suits should be handled.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Whoever, having accepted or agreed to receive any property or valuable security ...
#   Score  : 1/5  — The model answer is not related to Section 105 of the Indian Penal Code and instead discusses a different section of the code.
#
# 💾 Raw results saved → /kaggle/working/results/phase1_eval_gemma3_qlora.json
#
# ============================================================
# 📊  PHASE 1 SUMMARY — GEMMA3_QLORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.57 / 5.0
#
#   Score distribution:
#     5/5  ███████████████████████████████████ (35)
#     4/5  ███████████ (11)
#     3/5  █ (1)
#     2/5  █████████████████████████████████████████████████████████████ (61)
#     1/5  ██████████████████████████████████████████ (42)
#
#   By task type:
#     Act Identification   avg=4.59  (n=39)
#     Direct Q&A           avg=1.16  (n=31)
#     Explanation          avg=2.34  (n=59)
#     Summarization        avg=1.57  (n=21)
# ============================================================
