# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 29.0 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: QWEN3_LORA
# Loading 4-bit quantization config...
# Loading base model: Qwen/Qwen3-4B-Instruct-2507...
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: QWEN3_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a member of a gang, commits criminal trespass, shall, if such cri...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 65B: Electronic Records
#
# The prov...
#   Score  : 2/5  — The model answer incorrectly focuses on digital signatures and certificates instead of explaining the admissibility of electronic records as per Section 65B.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 53A of the Code of Criminal Procedure.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Code...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the source, when it actually belongs to the Code of Criminal Procedure, 1973.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Code of Criminal Procedure, 1973 deals with S...
#   Score  : 4/5  — The answer captures the main points but includes an unnecessary and confusing additional clause.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is not related to Section 104 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to all warrants for the arrest of a p...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant legal information about Section 405 of the Code of Criminal Procedure, 1973.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : The High Court may, by rules, prescribing the manner in which such proceedings s...
#   Score  : 1/5  — The model answer is not related to Section 323 of the Code of Criminal Procedure, 1973 and instead discusses the powers of the High Court.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of committing an offence, and it is brought to the noti...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 247 of the Code of Criminal Procedure, 1973.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the relevant act, when it should be the Code of Civil Procedure, 1908.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Code of Civil Procedure, 1908 deals with Rec...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Motor Vehicles Act, and omits the key detail about the Claims Tribunal issuing a certificate to the Collector.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to every warrant issued by a Court in...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant legal information about Section 253 of the Code of Criminal Procedure, 1973.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:Section 171G
#
# The following clauses shall be dee...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 171G and provides irrelevant information about special conditions instead of the actual legal content.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly states the punishment for abetting outside India.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being in any office as such public servant,...
#   Score  : 1/5  — The model answer is not legally equivalent to Section 424 of the Indian Penal Code.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Power to arrest and p...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 to relate to arrest and detention rather than compliance with Section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : The drawer of a bill of exchange or cheque is liable thereon to all persons deri...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the actual content of Section 99 of the Negotiable Instruments Act, 1881.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the question about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is not related to Section 157 of the Code of Criminal Procedure, 1973 and instead discusses the declaration of places of public importance.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 21:
# Section 284: Power to arrest and p...
#   Score  : 2/5  — The model answer incorrectly describes Section 284 as relating to the power to arrest and produce an accused, whereas it actually pertains to issuing a commission for the examination of a witness.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[ 1*** * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * ...
#   Score  : 4/5  — The answer captures the essence of Section 89, including the formulation of settlement terms and referral options, but includes unnecessary formatting.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the key points about who can record confessions and the requirement for a written statement, but omits the mention of recording by audio-video electronic means.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Section 108: Power to arrest in cer...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as about power to arrest, while the reference explains it concerns security for good behavior regarding dissemination of seditious matters.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, and being in any office as such public servant,...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 2/5  — The model answer incorrectly specifies the punishment and the condition for the offense, deviating from the reference answer.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : The Court may presume that any document purporting to be a certificate of deposi...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act and instead refers to Section 158 of the Indian Evidence Act regarding certificates and books of accounts.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 26:
# Section 337: Sentence of death
#
# Wh...
#   Score  : 2/5  — The model answer incorrectly describes Section 337 as related to the sentence of death, while the reference answer correctly explains it pertains to the procedure for a lunatic prisoner.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall be deemed to have been in force for the pur...
#   Score  : 1/5  — The model answer is not related to the content of Section 265A of the Code of Criminal Procedure, 1973, and instead refers to sub-sections of section 106A, which is unrelated.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 3/5  — The model answer captures the main idea but includes unnecessary and confusing details about 'foreign State' and 'previous of the State Government', which are not part of the reference answer.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, fraudulently or with intent that may cause loss to the State or to any ...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the content of Section 373 of the Indian Penal Code.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is close but slightly imprecise as the maximum punishment is two years, not three years.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, and being legally bound as such public servant ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, referring to a different section of the IPC.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : 1[25. Power to make rules.-- (1) The High Court and the District Judge may make ...
#   Score  : 2/5  — The model answer incorrectly describes the section as about making rules rather than transferring suits, appeals, or proceedings.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the content of Section 14 of the Motor Vehicles Act, 1988, and instead discusses rule-making powers.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Code of Crim...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : The drawer of a bill of exchange or cheque is liable thereon to all parties, exc...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Negotiable Instruments Act, 1881, and instead discusses liability among parties to a bill or cheque.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power to make rules
#
# 1[139...
#   Score  : 2/5  — The model answer incorrectly focuses on the power to make rules instead of the administration of oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : The Court may, from time to time, make rules for the purposes of this Act, and f...
#   Score  : 1/5  — The model answer is not related to the content of Section 18 of the Indian Divorce Act, 1869.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes grievous hurt, in order to the committing of any offe...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, referring to 'grievous hurt' instead of the key elements of 'rashly or negligently' and 'endangering human life or personal safety'.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Criminal Procedure, 1973....
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the relevant act, when it should be the Code of Civil Procedure, 1908.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 406: Sentence of death
#
# Th...
#   Score  : 2/5  — The model answer incorrectly interprets Section 406 as relating to the sentence of death instead of the transfer of cases and appeals.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a person is convicted of an offence punishable under any section of Chapter...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Evidence Act, 1872 deals with Saving ...
#   Score  : 4/5  — The model answer is close but incorrectly references the Indian Succession Act, 1925 instead of 1865.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model answer captures the essence of the section but misinterprets the scope, focusing on claims for payment and disputes rather than the procedural and evidentiary powers.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the content of Section 128 of the Motor Vehicles Act, 1988, and instead refers to a different section of the act.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 27:
# Section 375: Power to arrest and t...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 375 which deals with appeals for guilty pleas, not arrest powers.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 3/5  — The model answer is close but incorrectly states that no Court can take cognizance of a pending suit, which is not the intent of Section 12.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:Section 149: Punishment for abetting offence pun...
#   Score  : 2/5  — The model answer incorrectly describes Section 149 as relating to abetting an offense, whereas it actually pertains to liability of members of an unlawful assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter:
# Section 479: Evidence of person convi...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 as related to evidence of theft, while the reference answer correctly states it pertains to a judge or magistrate's personal interest.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section : Section 198A
#
# 1[198A. Power of Sta...
#   Score  : 2/5  — The model answer incorrectly interprets Section 198A and focuses on rule-making powers instead of the requirement for compliance with road design, construction, and maintenance standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Whoever drives a motor vehicle in contravention of the provisions of section...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing penalties for contravention of different sections rather than the content of Section 134.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Code of Civil Procedure, 1908 deals with Decr...
#   Score  : 2/5  — The model answer incorrectly refers to the Code of Civil Procedure instead of the Hindu Marriage Act, and does not capture the specific conditions for granting relief as stated in the reference answer.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Evidence of fact to be prove...
#   Score  : 2/5  — The model answer incorrectly describes Section 166 as dealing with secondary evidence instead of the power of jury or assessors to put questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1971 deals with P...
#   Score  : 2/5  — The answer is partially correct but contains notable legal errors, as it misinterprets the scope and application of Section 45.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of committing an offence, he shall be presumed to be ac...
#   Score  : 1/5  — The model answer is not related to Section 161 of the Code of Criminal Procedure, 1973, and instead discusses unrelated concepts.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:-
# Section 64: Punishment for abetment of suicide...
#   Score  : 2/5  — The model answer incorrectly interprets Section 64 as relating to abetment of suicide instead of the actual content about fines and imprisonment.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Indian Penal Code, 1860 deals with Voidance o...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Motor Vehicles Act, and misinterprets the section's scope.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but slightly imprecise by including 'or causes or attempts to cause' which is not part of the original section.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this section shall apply to the execution of decrees in all Co...
#   Score  : 1/5  — The model answer is not related to the question about Section 124 of the Code of Civil Procedure, 1908.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may, by notification in the Official Gazette, declare a...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988, which deals with speed limits rather than no entry zones.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 3/5  — The model answer captures the essence of registration but omits important details about the conditions and the role of the State Government.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : The provisions of this Code shall apply to all suits, appeals and other proceedi...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not accurately reflect the specific exclusions mentioned in Section 7 of the Code of Civil Procedure, 1908.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:Section 128
#
# The offences defined in sections 12...
#   Score  : 4/5  — Correctly identifies the section and provides the relevant legal content, but does not explicitly mention the punishment.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a promissory note, bill of exchange or cheque, not being the banke...
#   Score  : 1/5  — The model answer is not related to Section 100 of the Negotiable Instruments Act, 1881 and provides an incorrect statement about partial payments.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to the Code of Criminal Procedure, 1952 instead of 1973 and incorrectly describes the withdrawal of powers.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 18: sexual offences
# Section 376A: Punishment for...
#   Score  : 2/5  — The model answer incorrectly identifies the section as punishment for rape and provides incorrect details about the punishment.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power to make rules
#
# 1[1-1...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and introduces unrelated content about making rules.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : 1[ 1(1) The State Government may make rules for the time being in force in the S...
#   Score  : 1/5  — The model answer is not related to the question and provides rules for the Court of Small Causes instead of summarizing Section 43.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Power to make rules
#
# (1) Th...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 34 of the Code of Civil Procedure, 1908.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 118: Opinion as to existence of fa...
#   Score  : 2/5  — The model answer incorrectly describes Section 118, which is about witness competency, instead of explaining the section's actual content regarding relevant facts for explanation.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section : Section 52
#
# (1) The State Governme...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 52 and does not address the core requirement regarding alteration of motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:Section 365
#
# If, at the time of committing an of...
#   Score  : 2/5  — The model answer is not legally equivalent to Section 365 of the Indian Penal Code, 1860, as it describes a different section related to custody.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the content of Section 62 of the Motor Vehicles Act, 1988.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 2/5  — The model answer incorrectly states that the Central and State Governments can make rules about safety devices, while the reference answer specifies the number of passengers allowed.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:-
# Section 410: Punishment for abetment of suicid...
#   Score  : 1/5  — The model answer is completely incorrect, discussing abetment of suicide instead of explaining Section 410 regarding stolen property.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker, acceptor or payor of a promissory note, bill of exchange or cheque, a...
#   Score  : 2/5  — The model answer contains notable legal errors as it misinterprets the section's content regarding delivery and conditional transfer of instruments.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this Part relating to the execution of decrees shall be deemed...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant legal information about Section 66 of the Code of Civil Procedure, 1908.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section : Section 174
#
# (Procedure for granti...
#   Score  : 2/5  — The model answer incorrectly describes Section 174 as related to granting permits instead of recovery of money from insurers.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 402: Sentence of death
#
# Wh...
#   Score  : 2/5  — The model answer incorrectly focuses on the sentence of death instead of the power of the High Court to withdraw or transfer revision cases.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Power of State Government to mak...
#   Score  : 4/5  — The answer captures the essence of Section 38 but includes unnecessary details about comfort and safety not explicitly mentioned in the reference.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : The Court may, from time to time, make rules for the purposes of this Act, and f...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead refers to court rules.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : The provisions of this section shall apply to the execution of decrees in all Co...
#   Score  : 1/5  — The model answer is not semantically correct and does not match the content of Section 146 of the Code of Civil Procedure, 1908.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 4/5  — The model answer captures the key legal meaning but includes an additional condition about dishonour that is not present in the reference answer.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Code of Criminal Proc...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the relevant act, instead of the Indian Evidence Act, 1872.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter:
# Section 166B: Procedure in case of re...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 166B and provides incorrect details about Section 166A.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 3/5  — The answer misses the key point that the inquiry is to determine the truth of the information, not to condemn the offender.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Power to arrest and p...
#   Score  : 2/5  — The model answer incorrectly describes Section 202 as about power to arrest and produce accused instead of postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 4/5  — Correct core content but incorrect year of the act.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker, drawee, accepter and payee of a promissory note, bill of exchange or ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 4/5  — The model answer correctly identifies the relevant section but misattributes it to the Code of Criminal Procedure instead of the Indian Penal Code, and incorrectly states the maximum fine as one thousand rupees.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, and being legally bound as such public servant ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 2:
# Section 36: Instrument payable by i...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as related to instruments payable by instalments instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 165: Evidence of fact to be prove...
#   Score  : 2/5  — The model answer incorrectly interprets Section 165 as dealing with evidence of one fact being used to prove another, when in fact it deals with the judge's power to question witnesses and order production of documents.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The model answer correctly captures the essence of Section 108A but adds the punishment details, which are not part of the section's definition.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to every warrant issued by a Court in...
#   Score  : 1/5  — The model answer is not related to Section 339 of the Code of Criminal Procedure, 1973, and instead discusses provisions of the Mental Patients Act, 1984.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to all warrants for the arrest of a w...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly omits the key elements of undue influence or personation, instead focusing on the omission of precautions.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Repealed by the Sexual Offences (Repeals and Condonations) Act, 1981 (45 of 1981...
#   Score  : 1/5  — The model answer is completely incorrect as it states that the section has been repealed, which is not true according to the reference answer.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits house-breaking, shall, if he by such act commits an offence puni...
#   Score  : 2/5  — The model answer is legally incorrect as it refers to a different section of the IPC and does not address the intent to cause hurt or facilitate an offense.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : The drawer of a bill of exchange or cheque is liable thereon to all parties, exc...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881, and instead discusses liability of the drawer, which is unrelated to the section.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Grounds of petition
#
# The followi...
#   Score  : 2/5  — The model answer incorrectly interprets Section 57 as providing grounds for a petition instead of granting liberty to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is convicted of an offence punishable under any section of Chapter...
#   Score  : 1/5  — The model answer is not related to Section 228 of the Code of Criminal Procedure, 1973, and instead refers to a different section of the law.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : The provisions of this Chapter shall apply to the offence of corruption, bribery...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not capture the specific elements of bribery as stated in Section 171B.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Grounds of decree for dissolutio...
#   Score  : 2/5  — The model answer incorrectly identifies Section 31 as about grounds for dissolution of marriage instead of the wife's legal position during desertion.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A State Government may make rules for the purpose of carrying into effect th...
#   Score  : 2/5  — The model answer incorrectly attributes the power to make rules to the State Government instead of the Central Government, and omits several key points from Section 27.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 128 but omits the key point about the rights and position of the parties involved.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : The Court shall presume that any document purporting to be a certificate of regi...
#   Score  : 1/5  — The model answer is irrelevant and does not address the content of Section 40 of the Indian Evidence Act.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Code of Civil P...
#   Score  : 2/5  — The model answer is partially correct but contains a notable legal error as Section 35 does not fall under the Code of Civil Procedure, 1908.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the content of Section 119 of the Motor Vehicles Act, 1988, and instead discusses rules-making powers of the State Government.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 6:
# Section 102: Admissions
#
# Admissions are re...
#   Score  : 4/5  — Correctly identifies the section and its general purpose, but mislabels it as about admissions instead of the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly describes Section 35 as granting power to the State Government to make rules instead of the court's power to disqualify.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 2/5  — The model answer incorrectly defines the section in terms of general bribery rather than specifically electoral rights, and omits the key elements of accepting or accepting a reward for exercising electoral rights.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter:Section 208
#
# Whoever, being a public servant, an...
#   Score  : 2/5  — The model answer incorrectly reinterprets Section 208 and does not capture its actual legal meaning.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a promissory note, bill of exchange or cheque, not being a banker,...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Opinion as to existence of fa...
#   Score  : 2/5  — The model answer incorrectly describes Section 117 and provides an unrelated example.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Power to make orders
#
# The Distric...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as granting power to make orders, while the reference correctly states it deals with pending suits.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : The word “public” denotes the community of the general public....
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_qwen3_lora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — QWEN3_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.57 / 5.0
#
#   Score distribution:
#     5/5  ███████████████████████████████ (31)
#     4/5  █████████████████ (17)
#     3/5  ████ (4)
#     2/5  ████████████████████████████████████████████████████ (52)
#     1/5  ██████████████████████████████████████████████ (46)
#
#   By task type:
#     Act Identification   avg=4.41  (n=39)
#     Direct Q&A           avg=1.23  (n=31)
#     Explanation          avg=2.54  (n=59)
#     Summarization        avg=1.19  (n=21)
# ============================================================
