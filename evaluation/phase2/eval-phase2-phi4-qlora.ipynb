# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.3 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: PHI4_QLORA
# Loading 4-bit quantization config...
# Loading base model: microsoft/Phi-4-mini-instruct...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/194 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: PHI4_QLORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, by any means whatsoever, causes permanent or partial destruction, remov...
#   Score  : 2/5  — The model answer incorrectly describes the offense and punishment, which do not match the reference.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Proof of digital signature
#
# T...
#   Score  : 2/5  — The model answer incorrectly focuses on digital signatures instead of the admissibility of electronic records as per Section 65B.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : Where, in a case instituted on a police report, the accused appears or is brough...
#   Score  : 1/5  — The model answer is not related to Section 53A of the Code of Criminal Procedure, 1973, and instead discusses unrelated procedural matters.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Code...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Code of Criminal Procedure, 1973 deals with S...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions, such as incorrectly stating the conditions under which consecutive sentences can be ordered.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 104 of the Code of Criminal Procedure, 1973.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Court of Session has, after a conviction, commuted a sentence of death fo...
#   Score  : 1/5  — The model answer is not related to Section 405 of the Code of Criminal Procedure, 1973, and instead discusses a different legal procedure.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any person, having been convicted by a Court of Session, or by any other Co...
#   Score  : 1/5  — The model answer is not related to Section 323 of the Code of Criminal Procedure, 1973 and instead discusses the procedure for filing an appeal.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When any Court has, under section 396 of the Criminal Law (Procedure) Act, 1977,...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Code of Civil Procedure, 1908 deals with Rec...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Motor Vehicles Act, and misinterprets the process for recovery.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : If, when such evidence has been taken, or at any previous stage of the case, the...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973, and instead discusses different sections.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9:
# Section 171G: Failure to give information re...
#   Score  : 2/5  — The model answer incorrectly describes Section 171G as 'Failure to give information regarding offence' instead of 'False statement in connection with an election', and the penalty described is also incorrect.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is close but omits the specific location context ('being within India').
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever commits mischief by destroying or moving any light-house or lighthouse o...
#   Score  : 1/5  — The model answer is not related to Section 424 of the Indian Penal Code and instead refers to a different section dealing with mischief.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Procedure in respect ...
#   Score  : 2/5  — The model answer incorrectly describes section 238 as relating to summons-cases and search warrants instead of compliance with section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note or bill of exchange, made, drawn or accepted, as the case may ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may make rules for the purpose of carrying into effect ...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant information about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any such Court has, on an application made to it under section 159, determi...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 157 of the Code of Criminal Procedure, 1973.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 22:
# Section 284: Procedure in case of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 284 and provides information about a different section.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : (1) Where a decree is for the recovery of immovable property situate in two or m...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer incorrectly describes the conditions under which a police officer can record a confession, missing the key point about who can record confessions and statements.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 8:
# Section 108: Procedure in case of p...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as related to persons of unsound mind, while the reference correctly states it pertains to dissemination of seditious materials.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, or being in the presence of a public servant, c...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 290 of the Indian Penal Code.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 2/5  — The model answer incorrectly specifies the duration of a search warrant and omits the key elements of preventing discovery by interested parties or public servants.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : The Court may, if it thinks fit, issue a commission for the examination of any p...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act, 1872 and provides an unrelated legal provision instead.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 25:
# Section 337: Procedure in case of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 337 and its application.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : Where a Court of Session or a Court of a Magistrate of the first class has, on a...
#   Score  : 1/5  — The model answer is not related to Section 265A of the Code of Criminal Procedure, 1973 and instead refers to a different section of the code.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 4/5  — The model answer captures the essence of Section 40 but omits the specific requirement for rules in force in the receiving state.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever commits the offence of kidnapping from the person of another, in order t...
#   Score  : 1/5  — The model answer is not legally equivalent to Section 373 of the Indian Penal Code and instead refers to Section 340 which deals with kidnapping.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is accurate and captures the key legal meaning, but it incorrectly states that the maximum fine is one thousand rupees instead of two years.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt to any person, in order to extort from the suffe...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) Where a decree is for the partition of any undivided estate or of a share of...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing partition and maintenance instead of the transfer of suits, appeals, or proceedings.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may, by notification in the Official Gazette, make one ...
#   Score  : 1/5  — The model answer is completely unrelated and does not address Section 14 of the Motor Vehicles Act, 1988.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable to
# bearer is negotiable by...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Negotiable Instruments Act, 1881, and instead discusses negotiability of instruments, which is unrelated to the content of Section 62.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: [Repealed]
#
# [Omitted in th...
#   Score  : 2/5  — The model answer incorrectly states that Section 139 has been repealed, which is not accurate.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : In any proceeding under this Act, the Court may from time to time, and on such t...
#   Score  : 2/5  — The model answer is not legally equivalent to the reference answer; it discusses granting a decree of judicial separation rather than declaring a marriage null and void.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, on an application made to it under sub-s...
#   Score  : 1/5  — The model answer is not related to Section 178 of the Motor Vehicles Act, 1988 and provides information about a different section.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 1/5  — The model answer is completely incorrect as Section 47 falls under the Code of Civil Procedure, 1908, not the Indian Divorce Act, 1869.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes hurt by doing any act so rashly or negligently as to ...
#   Score  : 4/5  — The model captures the essence of the section but incorrectly includes 'voluntarily' and 'knowingly', which are not part of the original text.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 31:
# Section 406: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes Section 406 as about procedure for revision, while it actually pertains to the power of the Supreme Court to transfer cases and appeals.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : A Court of Session may, at any stage of any proceeding in any such Court, direct...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and thus is completely incorrect.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Divorce Act, 1869 deals with Saving o...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act and an incorrect year for the Indian Succession Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions compared to the reference.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) The State Government may, by notification in the Official Gazette, make one ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect regarding the content of Section 128 of the Motor Vehicles Act, 1988.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 27:
# Section 375: Procedure in cases to...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 375 and provides information about summary trials instead.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 3/5  — The model answer captures the essence of the bar to further suit but omits the critical point that the plaintiff is precluded from instituting a new suit on the same cause of action.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: criminal conspiracy
# Section 149: Punishment f...
#   Score  : 2/5  — The model answer incorrectly identifies Section 149 as relating to criminal conspiracy instead of unlawful assemblies.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 17:
# Section 479: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 as dealing with the procedure for the removal of a deceased person's body, when in fact it deals with recusals due to personal interest.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 14:
# Section 198A: Punishment for causing death...
#   Score  : 2/5  — The model answer incorrectly interprets Section 198A and does not address the actual content regarding road design, construction, and maintenance standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : A conductor, driver or attendant, or any other person in charge of a stage carri...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals with Decree in...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Hindu Marriage Act and provides irrelevant information about adjournments and costs.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 11:
# Section 166: Evidence of certain facts by...
#   Score  : 2/5  — The model answer incorrectly interprets Section 166, which pertains to jury or assessor questioning, not evidence for a deceased person.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Civil Procedure, 1908 deals with Prot...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Code of Criminal Procedure and omits key details about the need for central government consent and the application to other categories of forces.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Any Magistrate may, for the purpose of enabling any person to give evidence in a...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to a Magistrate instead of a police officer and includes unnecessary provisions about summonses and females.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 4: general exceptions
# Section 64: Act of a child...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 64 of the Indian Penal Code.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Motor Vehicles Act, 1988 deals with Voidance ...
#   Score  : 2/5  — The model answer deviates significantly from the reference, focusing on insurance contracts instead of contracts restrictive of liability for passengers.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly states the maximum term of imprisonment as seven years instead of three years.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : The Court may, at any time, and on such
# occasion as it thinks fit, remove any su...
#   Score  : 1/5  — The model answer is not related to Section 124 of the Code of Civil Procedure, 1908 and provides an unrelated legal concept.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) A Regional Transport Authority may, on an application made to it under sub-s...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988 and instead discusses granting stage carriage permits, which is unrelated to the question.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 4/5  — The model answer captures the essence of registration but incorrectly references the Indian Marriage Act instead of the Hindu Marriage Act.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : The State Government may, by notification in the Official Gazette, declare that ...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the question about Section 7 of the Code of Civil Procedure, 1908.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences against the state
# Section 128: Wagin...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to waging war instead of allowing a prisoner to escape.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note or bill of exchange has been noted or protested for non-p...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it describes the cancellation of a protest rather than the creation of one.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : The State Government may, by notification in the Official Gazette, make any area...
#   Score  : 2/5  — The model answer is not legally equivalent to the reference and contains notable legal errors.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Punishment for...
#   Score  : 2/5  — The model answer incorrectly interprets Section 376A as applying to repeat offenders and misstates the punishment.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: [Repealed]
#
# [Omitted in th...
#   Score  : 2/5  — The model incorrectly states that Section 147 has been repealed and omitted, which is not accurate according to the reference answer.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : (1) Where a decree is for the partition of any undivided estate or of a share of...
#   Score  : 1/5  — The model answer is not related to Section 43 of the Code of Civil Procedure, 1908, and instead discusses physical partition of land, which is unrelated to the execution of decrees.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: [Repealed]
#
# [Provisions of ...
#   Score  : 2/5  — The model incorrectly states that Section 34 has been repealed and provides an unrelated statement about the application of the Code.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 118: Proof of execution of documen...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 and introduces irrelevant information about proving document execution.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 5:
# Section 52: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly interprets Section 52 and does not address the alteration of motor vehicles as per the reference.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: criminal force and assault
# Section 365: Puni...
#   Score  : 2/5  — The model incorrectly places Section 365 under Chapter 17 instead of Chapter 16, and misinterprets the intent of confinement as being for labor or an unlawful act rather than secret and wrongful.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The State Government may, by notification in the Official Gazette, make one ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 2/5  — The model answer incorrectly describes the rules for driving rather than the safety measures for drivers and pillion riders.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: mischief
# Section 410: Mischief by killing or...
#   Score  : 2/5  — The model answer incorrectly identifies Section 410 as related to mischief rather than stolen property.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker of a promissory note or the drawer of a bill of exchange is the person...
#   Score  : 2/5  — The answer is partially correct but contains notable legal errors, as it misinterprets Section 46 which is about delivery, not liability.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : (1) Where a decree is for the recovery of immovable property situate in two or m...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 14:
# Section 174: Power of State Government to ...
#   Score  : 2/5  — The model answer incorrectly describes Section 174 as about the power to make rules instead of recovery of money from insurers.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 402: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly addresses the section, focusing on admissibility of evidence instead of the transfer or withdrawal of revision cases.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 5:
# Section 38: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly interprets Section 38 as relating to liability of owners for accidents, instead of the actual content about the power to make rules.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : In case the Court is satisfied, after a decree of judicial separation, that the ...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869 and provides an unrelated legal provision.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : (1) Subject to such conditions and limitations as may be prescribed, any
# ministr...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 4/5  — The model answer captures the key legal meaning but omits the requirement for the drawee to have sufficient funds and the need to pay upon demand.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 12:
# Section 166B: Punishment for abetm...
#   Score  : 2/5  — The model answer incorrectly describes Section 166B as related to abetting offenses against state power instead of requests for international cooperation.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Civil Procedure, 1908 deals with Inq...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Code of Criminal Procedure and omits key details about the role of the Magistrate.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes Section 202 and its purpose, instead discussing a different section related to mentally unfit individuals.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker of a promissory note or the drawer of a bill of exchange is, in the ab...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 20 and provides information about promissory notes and bills of exchange instead.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Indian Penal Code, 1860 deals with Failure ...
#   Score  : 4/5  — The model answer captures the key legal meaning accurately and concisely, with minor differences in wording.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, or being in the presence of a public servant, c...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Liability of agent for ...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as regarding liability of agents for presentment, while the reference answer correctly states it concerns the liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 11:
# Section 165: Compensation to be in lieu o...
#   Score  : 2/5  — The model answer incorrectly interprets Section 165 as dealing with compensation instead of the judge's powers to put questions and order production.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The answer captures the essence of Section 108A but incorrectly specifies that the abetment must be of an offence under Chapter X or XI, which is not accurate.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : If, when such evidence has been taken, or at any previous stage of the case, the...
#   Score  : 1/5  — The model answer is not related to Section 339 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any such Court is satisfied that it is necessary in the interests of justic...
#   Score  : 1/5  — The model answer is not related to Section 310 of the Code of Criminal Procedure, 1973, and instead discusses summonses and warrants.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model answer is accurate and captures the key legal meaning, but it adds 'at such election' which is not necessary and slightly imprecise.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant or having control over a minor or a person of un...
#   Score  : 2/5  — The model answer incorrectly describes the punishment and age range, and omits the key elements of multiple perpetrators and common intention.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt by doing any act so rashly or negligently as to ...
#   Score  : 2/5  — The model answer is not legally equivalent to Section 328 of the IPC and instead refers to a different section dealing with negligence.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : Subject to the provisions of section 62, a promissory note, bill of exchange or ...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881 and instead discusses presentment for payment, which is covered under different sections.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter VIII
# Section 57: Power to make such orders as ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 57 and does not address the specific provision regarding remarriage after a decree.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : If, when such evidence has been taken, or at any previous stage of the case, the...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question asked.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, or being in charge of a public office, corruptl...
#   Score  : 2/5  — The model answer incorrectly defines bribery under a different section of the IPC and does not capture the essence of Section 171B.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter IV
# Section 31: Power to order alimony pending ...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as about alimony and misinterprets its purpose.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, on an application made to it under sub-s...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 128 but omits the key aspect of the rights and position of the parties involved after the payment.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : When the question is whether a fact is applicable to a particular fact in issue,...
#   Score  : 2/5  — The model answer is not legally equivalent to the reference answer and contains a notable legal error.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Motor Vehicles ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 1/5  — The model answer is completely incorrect as Section 108 does not fall under the Code of Civil Procedure, 1908.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : A State Government may make rules for the purpose of carrying into effect the pr...
#   Score  : 1/5  — The model answer is not related to the content of Section 119 of the Motor Vehicles Act, 1988.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 102: Proof of execution of documen...
#   Score  : 2/5  — The model answer incorrectly focuses on Section 105 of the Indian Registration Act instead of explaining Section 102 of the Indian Evidence Act.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 4:
# Section 35: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly describes Section 35 as related to liability of the owner/driver/conductor, while the reference correctly states it pertains to disqualification of a conductor's license.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 3/5  — The model answer omits the key elements of inducement and acceptance of gratification, and incorrectly specifies 'public servant' as a prerequisite.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false evidence and offences against public j...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to public servants and the bidding for property, which does not align with the actual content of Section 208.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : The Court may issue a temporary injunction, either on its own motion or on the a...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 8:
# Section 117: Proof of execution of documen...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 117 and provides an incorrect explanation.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Power to make rules
#
# The High Cou...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 6 to refer to the power to make rules instead of addressing the continuation of pending suits.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : The right of private defence of the person extends, under the restrictions menti...
#   Score  : 2/5  — The model answer incorrectly focuses on the right of private defence of the person instead of the right of private defence of property as stated in Section 105.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_phi4_qlora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — PHI4_QLORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.55 / 5.0
#
#   Score distribution:
#     5/5  ██████████████████████████████████ (34)
#     4/5  ███████████ (11)
#     3/5  ██ (2)
#     2/5  ████████████████████████████████████████████████████████████ (60)
#     1/5  ███████████████████████████████████████████ (43)
#
#   By task type:
#     Act Identification   avg=4.54  (n=39)
#     Direct Q&A           avg=1.26  (n=31)
#     Explanation          avg=2.36  (n=59)
#     Summarization        avg=1.33  (n=21)
# ============================================================
