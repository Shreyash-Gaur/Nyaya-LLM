# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.6 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float32
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float32
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: GEMMA3_QLORA
# Loading 4-bit quantization config...
# Loading base model: google/gemma-3-4b-it...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: GEMMA3_QLORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, except in the case provided for by section 334, voluntarily causes grie...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not address the specific act of throwing acid or administering acid as stated in Section 326A.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Section 65B of the Indian Evidence Act, 1872 deals with Presumption as to digita...
#   Score  : 2/5  — The model answer incorrectly focuses on digital signatures and presumes the information in the schedule is correct, which does not align with the actual content of Section 65B.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : Every police officer or other person arresting any person without warrant shall ...
#   Score  : 1/5  — The model answer is completely unrelated to Section 53A of the Code of Criminal Procedure, 1973.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Code...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals with Sentence i...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure and misinterprets the purpose of Section 31.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : Any Magistrate or police officer may seize and detain for such period as he thin...
#   Score  : 2/5  — The model answer contains notable legal errors and does not accurately reflect the content of Section 104 of the Code of Criminal Procedure, 1973.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is sentenced to imprisonment, the Court passing the sentence may, ...
#   Score  : 1/5  — The model answer is not related to Section 405 of the Code of Criminal Procedure, 1973, and instead discusses the levying of fines.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : If the accused refuses to plead, or does not plead, or claims to be tried or the...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a Magistrate has made an order under section 245, section 246 or section 24...
#   Score  : 1/5  — The model answer is not related to the content of Section 247 and appears to be discussing other sections.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Motor Vehicles Act, 1988 deals with Recovery...
#   Score  : 2/5  — The model answer incorrectly describes the purpose of Section 174, which is about recovering money from insurers as arrear of land revenue, not about claims between insurers.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : If the accused refuses to plead, or does not plead, or claims to be tried or the...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973, and instead refers to different sections.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9: offences relating to elections
# Section 171G: ...
#   Score  : 2/5  — The model incorrectly identifies the section as 'Personation at elections' instead of 'False statement in connection with an election', and omits the key elements of the offense.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 5/5  — The model answer accurately captures the key legal meaning without any errors.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever dishonestly misappropriates or converts to his own use any movable prope...
#   Score  : 2/5  — The model answer describes a different section of the IPC and does not accurately reflect the content of Section 424.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Power to stop proceed...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 and its context.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : Presentment of promissory note or bill of exchange for sight must be made during...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses presentment of notes rather than noting dishonour as required by Section 99.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[Duty of driver to stop at the scene of an accident. --(1) The driver of a moto...
#   Score  : 1/5  — The model answer is not related to the question about Section 125 of the Motor Vehicles Act, 1988.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : Any police officer may, if he has reason to believe that a person is about to co...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 23:
# Section 284: Record in summons-cas...
#   Score  : 2/5  — The model answer incorrectly describes Section 284 as related to summons-cases instead of the correct provision regarding dispensing with witness attendance.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[89. When notice may be dispensed with.]—
#
# (1) In a suit for the recovery of im...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing dispensing with notice requirements instead of the settlement process.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the key points but omits the mention of recording by audio-video electronic means and the condition that the confession or statement must be made during an investigation.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Section 108: Power of Magistrate to...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misidentifies Section 108 and provides an incorrect description of its content.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever habitually displays any such obscene object in any public place, or habi...
#   Score  : 1/5  — The model answer is completely incorrect and does not match the content of Section 290 of the Indian Penal Code.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — Correct core content with a slight improvement in clarity by specifying 'the public' and 'any person who is bound by law to give information on the subject'.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : No public officer shall be compelled to disclose to any person, or to any public...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act and contains irrelevant information.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 25:
# Section 337: Procedure in cases to...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 337 and does not address the key points about a lunatic prisoner being certified capable of making a defense.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : The Court shall, before releasing on probation of good conduct, take into accoun...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 4/5  — The model answer captures the key legal meaning but includes unnecessary details from Section 39, which are not relevant to the question.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever buys, hires or otherwise obtains possession of any person under the age ...
#   Score  : 4/5  — The model answer captures the essential elements of Section 373 but omits the mention of 'illicit intercourse' and 'unlawful and immoral purpose', which are important parts of the section.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is accurate and captures the key legal meaning, but omits the 'or more' part after 'three days', which is a minor precision error.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever assaults or uses criminal force to any person, in attempt to commit thef...
#   Score  : 1/5  — The model answer is completely incorrect, describing a different section of the IPC.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : 1[(1)] Where a suit has been duly instituted, no defendant shall be arrested or ...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 25 of the Code of Civil Procedure, 1908.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure as the Indian Army Act.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) A State Government may, by notification in the Official Gazette, declare tha...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 14 of the Motor Vehicles Act, 1988.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Code of Crim...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable to
# order, is dishonoured b...
#   Score  : 2/5  — The model answer discusses dishonour of negotiable instruments rather than the presentation requirement for promissory notes under Section 62.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power to direct payment of...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : Any person competent to present a petition under this Act, shall be competent to...
#   Score  : 1/5  — The model answer is not related to the content of Section 18 of the Indian Divorce Act, 1869.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Whoever, being disqualified under section 3 or section 4, drives a motor veh...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, referring to different sections and penalties.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 1/5  — The model answer is completely incorrect as Section 47 falls under the Code of Civil Procedure, 1908, not the Indian Divorce Act, 1869.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever does any act so rashly or negligently as to endanger human life, or the ...
#   Score  : 4/5  — The model answer captures the essence correctly but has minor inaccuracies in the maximum punishment terms.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 406: Power of Magistrate t...
#   Score  : 2/5  — The model answer incorrectly describes Section 406 as pertaining to Magistrates instead of the Supreme Court, and does not mention the transfer of cases or appeals.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : No Court shall take cognizance of any offence punishable under this Chapter afte...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and provides unrelated information instead.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Evidence Act, 1872 deals with Saving ...
#   Score  : 5/5  — The model answer is semantically correct and conveys the key legal meaning accurately.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model answer captures the essence of the section but omits the key points about summary procedure and enforcement of evidence, which are crucial aspects of Section 169.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : 1[Scheme for golden hour. -- (1) Notwithstanding anything contained in this Act ...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 128 of the Motor Vehicles Act, 1988.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 27:
# Section 375: Procedure in appeals ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 375 and provides incorrect information about the procedure for appeals.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 2/5  — The model answer incorrectly states that Section 12 bars second appeals rather than further suits, and does not capture the core meaning of the bar to further suit.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences against the public tranquillity
# Sect...
#   Score  : 4/5  — The model answer correctly identifies the section and provides the punishment, but incorrectly states the section title and omits the key legal principle that all members of the assembly can be held responsible for the actions of others within the assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 35:
# Section 479: Power of Court to con...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 as about converting summons cases to warrant cases, which is not the correct legal meaning.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Offences by juveniles
#
# 1[198A....
#   Score  : 2/5  — The model answer incorrectly identifies Section 198A as relating to offenses by juveniles instead of standards for road design, construction, and maintenance.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : The driver of a motor vehicle shall cause the vehicle to stop and remain station...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals with Decree in...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Hindu Marriage Act and includes irrelevant details.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Public prosecutors and the G...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 166 regarding the power of juries and assessors to ask questions instead of addressing the role of public prosecutors.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1973 deals with P...
#   Score  : 2/5  — The model answer incorrectly states that the section deals with cognizance of offenses rather than protection from arrest, and omits the requirement for consent from the Central Government.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Any Metropolitan Magistrate or Judicial Magistrate may, if he thinks fit, impoun...
#   Score  : 1/5  — The model answer is completely unrelated to the question and does not address Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Limit of imprisonment...
#   Score  : 2/5  — The model answer incorrectly describes Section 64 as related to non-attendance and the duration of imprisonment for non-payment, which is not accurate.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Motor Vehicles Act, 1988 deals with Voidance ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 92 to apply to insurance policies rather than passenger transport contracts.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly states the maximum term of imprisonment as five years instead of three years.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[124. Power of High Court to transfer suits.— Notwithstanding anything containe...
#   Score  : 1/5  — The model answer is not related to Section 124 of the Code of Civil Procedure, 1908 and instead discusses rules for examining witnesses.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : 1[112. Power of State Government to make rules.--(1) The State Government may ma...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988, and instead discusses the power to make rules.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 4/5  — The core content is correct, but the phrasing and inclusion of 'in-texto' and 'Buddhists, Jains and Sikhs' are not accurate to the reference answer.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : The provisions in Part X contained in the Act, 1859 (4 of 5 of 1859), shall, so ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to an incorrect section and act of the Code of Civil Procedure.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: false evidence and offences against public ju...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its purpose, referring to receiving property instead of allowing a prisoner to escape.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : Presentment of promissory note or bill of debt for payment is unnecessary in ord...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses presentment rather than the requirements for protesting dishonored instruments.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : Whenever a person is acquitted upon the ground that, at the time when the offenc...
#   Score  : 1/5  — The model answer is not related to the content of Section 34 of the Code of Criminal Procedure, 1973, and instead discusses a different section or concept.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Sexual interco...
#   Score  : 1/5  — The model answer is completely incorrect, as it misinterprets Section 376A and provides a different section's content instead.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power to amend
#
# (1) Every ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and introduces unrelated content.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : 1[(1)] 2 [High Courts . . . . . . . . . . . . . . . . . . . . . . . . . . . . . ...
#   Score  : 2/5  — The model answer is incomplete and does not capture the key legal meaning of Section 43.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: Power to amend
#
# (1) Every s...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 34 of the Code of Civil Procedure, 1908.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 8:
# Section 118: Proof of good faith in transa...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as related to proof of good faith in transactions and intoxication, which is not the correct interpretation.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Special provisions as to permits...
#   Score  : 2/5  — The model answer incorrectly addresses a different section of the Motor Vehicles Act, 1988, missing the key legal details of Section 52 regarding alterations to motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: kidnapping, abduction, and wrongful restrain...
#   Score  : 4/5  — The model answer captures the essence of Section 365 but uses the term 'abduction' instead of 'kidnapping or abducting,' which is slightly imprecise.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, in addition to the powers conferred by s...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 3/5  — The model answer omits key points about the maximum number of passengers and the requirement for a proper seat.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: criminal breach  trust
# Section 410: Dishones...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its definition, leading to a significant legal error.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable to
# order, is dishonoured b...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses dishonour of negotiable instruments rather than the delivery requirements for completion of acceptance, indorsement, or making.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[66. Execution of decrees passed by Civil Courts in causes involving immovable ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Driving by a drunken person or ...
#   Score  : 2/5  — The model answer incorrectly describes Section 174 as related to driving under the influence, when it actually pertains to recovery of money from an insurer.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 32:
# Section 402: Power of High Court t...
#   Score  : 2/5  — The model answer incorrectly interprets Section 402 as being about transferring cases and appeals rather than about the power of the High Court to withdraw or transfer revision cases.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Power of State Government to mak...
#   Score  : 4/5  — The answer captures the essence of Section 38 but omits the specific mention of licensing authorities and the exemption conditions for drivers and conductors.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : The husband or any creditor of, or person claiming under
# him, may apply to the C...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead refers to a different section or concept.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : 1, 2This Part applies only in the case of a suit by or against the Government 2 ...
#   Score  : 1/5  — The model answer is not semantically correct; it discusses different parts of the Code of Civil Procedure rather than the specific content of Section 146.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 4/5  — The model answer captures the key legal meaning but omits the crucial aspect of the drawee's liability to pay upon demand and compensate for losses if they fail to do so.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 11:
# Section 166B: Power of Magistrate ...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 166B of the Code of Criminal Procedure, 1973.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the essence of Section 116 but incorrectly includes unrelated content about searches and arrests.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Power of Magistrate t...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 202 to relate to showing cause for arrest rather than postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : Every person capable of contracting, according to the law to which he is subject...
#   Score  : 1/5  — The model answer is not related to Section 20 of the Negotiable Instruments Act, 1881, and instead provides unrelated information about contracting capacity.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Indian Penal Code, 1860 deals with Failure ...
#   Score  : 4/5  — The model answer is close to the reference but slightly imprecise in stating 'and a bond' instead of 'or on bond without sureties'.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily obstructs any sale of property offered for sale by the lawfu...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Presentment
#
# Presentmen...
#   Score  : 2/5  — The model answer incorrectly focuses on presentment rather than liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 165: Person who gives false infor...
#   Score  : 2/5  — The model answer incorrectly describes Section 165 as related to giving false information to police officers, which is not accurate.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The model captures the essence of Section 108A but incorrectly states that the abettor must enter into or agree to carry out the conspiracy in India, which is not required by the section.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : Whenever a person is required by any Court or other authority to show cause why ...
#   Score  : 1/5  — The model answer is not related to Section 339 of the Code of Criminal Procedure, 1973, and instead discusses a different provision regarding bonds.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to all summons-cases tried before a M...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant legal information about Section 310 of the Code of Criminal Procedure, 1973.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — Correct core content but slightly redundant by stating 'commits the offence of personation at an election' which is implied.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever has sexual intercourse with his own wife, who is living separately, whet...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the question about Section 376DB of the Indian Penal Code.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes grievous hurt to any person being a public servant in...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to different sections and offenses than those mentioned in the question.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : The indorsement of a negotiable instrument must, in order to negotiate the same,...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881, and instead discusses indorsement requirements, which are covered under different sections.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Power to remove certain suits
#
# T...
#   Score  : 4/5  — Correctly identifies the section and its purpose, but misinterprets the actual content of Section 57.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : If the accused refuses to plead, or does not plead, or claims to be tried or the...
#   Score  : 1/5  — The model answer is not related to Section 228 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever:
# gives a loan or makes any other payment to any person or his agent, or ...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions compared to the reference answer.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Power to remove
#
# The Court, afte...
#   Score  : 2/5  — The model answer incorrectly focuses on powers to remove rather than the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A Regional Transport Authority may, in addition to the powers conferred by s...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not address the concept of payment in due course and instead focuses on the restrictions on crossing cheques.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : Statements of facts in issue or relevant facts, made in published maps or charts...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act and provides an incorrect statement about relevant facts.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Divorce ...
#   Score  : 1/5  — The model answer is completely incorrect as Section 35 'Power of Court to disqualify' does not fall under the Indian Divorce Act, 1869.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) No person shall drive any motor vehicle and no owner of a motor vehicle shal...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, providing different legal requirements than those stated in Section 119.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 102: Proof of good faith in transa...
#   Score  : 2/5  — The model answer incorrectly describes Section 102 as relating to proof of good faith and intoxication, which is not the correct interpretation.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly identifies the power of the state government instead of the court, and omits the key details about the court's power to disqualify.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 4/5  — The answer captures the essence of Section 171B but omits the part about accepting gratification and the exception for declarations of public policy.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false evidence and offences against public j...
#   Score  : 4/5  — The model answer captures the essence of Section 208 but incorrectly identifies the offense as fraudulent claim to protection from arrest or trial instead of fraudulent suffering of a decree for a sum not due.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : Notwithstanding anything contained in the Code of Criminal Procedure, 1973 (2 of...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to compoundable offenses under Section 138 instead of the content of Section 144.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Proof of good faith in transa...
#   Score  : 2/5  — The model answer incorrectly interprets Section 117 as dealing with proof of good faith in transactions involving active confidence, rather than estoppel related to bills of exchange, bails, and licenses.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter : Chapter 5
# Section 6: Grounds of divorce
#
# The ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as dealing with grounds of divorce instead of addressing the continuation of pending suits.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Whoever abets the commission of an offence punishable with imprisonment for life...
#   Score  : 1/5  — The model answer is not related to Section 105 of the Indian Penal Code and instead discusses abetting an offense, which is a different section of the code.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_gemma3_qlora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — GEMMA3_QLORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.72 / 5.0
#
#   Score distribution:
#     5/5  █████████████████████████████████████ (37)
#     4/5  ████████████████████ (20)
#     3/5  █ (1)
#     2/5  ████████████████████████████████████████████████ (48)
#     1/5  ████████████████████████████████████████████ (44)
#
#   By task type:
#     Act Identification   avg=4.64  (n=39)
#     Direct Q&A           avg=1.26  (n=31)
#     Explanation          avg=2.66  (n=59)
#     Summarization        avg=1.48  (n=21)
# ============================================================
