# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.2 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: PHI4_LORA
# Loading 4-bit quantization config...
# Loading base model: microsoft/Phi-4-mini-instruct...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/194 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase2_phi4_mini/lora_phase2_phi4_mini...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: PHI4_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever causes grievous hurt to any woman, being pregnant with child of hers by ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to a different section of the IPC and a different crime.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Proof of electronic records
#
# ...
#   Score  : 4/5  — The model answer captures the essence of Section 65B but omits the key points about the conditions for admissibility and the specific types of media involved.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : Notwithstanding anything contained in any law or in any order, rule or regulatio...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 53A of the Code of Criminal Procedure, 1973.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Moto...
#   Score  : 1/5  — The model answer is completely incorrect as Section 105J falls under the Code of Criminal Procedure, 1973.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals with Sentence i...
#   Score  : 2/5  — The model incorrectly applies Section 31 to the Indian Penal Code instead of the Code of Criminal Procedure, and misinterprets the purpose of the section.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court has taken cognizance of an offence or a complaint, it may, at any...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court has issued a warrant for the arrest of any person, and such perso...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court, whether inquiring or trial, has satisfied itself that there is s...
#   Score  : 1/5  — The model answer is not related to Section 323 of the Code of Criminal Procedure, 1973 and provides information about issuing warrants instead.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When any Court, at any stage of a proceeding under this Code, considers it exped...
#   Score  : 1/5  — The model answer is not semantically correct and does not capture the key legal meaning of Section 247.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple terms, Section 174 of the Code of Civil Procedure, 1908 deals with Rec...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Motor Vehicles Act, and the explanation is not relevant to the question.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court has issued a warrant for the arrest of any person, and such perso...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973 and instead discusses bail provisions.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 13: offences affecting the public revenue
# Sectio...
#   Score  : 2/5  — The model incorrectly identifies the chapter and misinterprets the section's intent and punishment.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is close but omits the specific location context ('being within India') and the equivalence to abetting counterfeiting within India.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever commits robbery by means of fire or explosion, or of any noxious thing, ...
#   Score  : 1/5  — The model answer is not related to Section 424 of the Indian Penal Code and instead discusses various methods of committing robbery, which is unrelated to the question.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Procedure when accuse...
#   Score  : 2/5  — The model answer incorrectly describes section 238 as dealing with an accused's absconding, while the reference answer correctly states it pertains to compliance with section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : No person driving a motor vehicle shall discharge any material solid or liquid s...
#   Score  : 2/5  — The model answer is partially correct but contains a notable legal error, as it refers to discharging substances instead of hampering the driver's control.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court has issued a warrant for the arrest of any person, it may, at any...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : The Court shall, as far as practicable, dispose of the case within the time spec...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 284 and does not address the key points about dispensing with witness attendance and issuing commissions.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : The Court shall, as far as may be, dispose of every suit in which it is institut...
#   Score  : 1/5  — The model answer is not related to Section 89 of the Code of Civil Procedure, 1908 and hence is completely incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the key points but omits the provision for recording by audio-video electronic means and the condition that the confession or statement can be made at any time before the inquiry or trial.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 8:
# Section 108: Procedure when accused...
#   Score  : 2/5  — The model answer incorrectly describes Section 108 as dealing with accused absconding, while the reference answer correctly explains it relates to dissemination of seditious materials.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever commits theft in a building, tent or other temporary structure, or in an...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model captures the essence of wrongful confinement in secret but omits the specific mention of the intention to keep the confinement unknown to interested parties and public servants.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : A witness shall not be compelled to answer any question if the answer would tend...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act, 1872.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 26:
# Section 337: Procedure in case of ...
#   Score  : 1/5  — The model answer is completely unrelated to the actual content of Section 337 of the Code of Criminal Procedure, 1973.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : In every Criminal Court, there shall be a separate division for dealing with off...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 4/5  — Correct core content but adds unnecessary detail about the decree-holder's desire.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, being a member of any armed force, armed with arms, ammunition or explo...
#   Score  : 1/5  — The model answer is completely unrelated to the reference and question, discussing a different section of the IPC.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer is close but incorrectly states the fine amount as ten thousand rupees instead of the correct range.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : A person is said to commit criminal conspiracy, if he agrees with one or more pe...
#   Score  : 1/5  — The model answer is not related to Section 358 of the Indian Penal Code and describes criminal conspiracy instead.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) Where a decree is passed in favour of a plaintiff and the defendant fails to...
#   Score  : 1/5  — The model answer is not related to Section 25 of the Code of Civil Procedure, 1908, and instead discusses liens on property, which is unrelated to the content of Section 25.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 1/5  — The model answer is completely incorrect as Section 131 falls under the Code of Criminal Procedure, not the Code of Civil Procedure.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) A State Government may, by notification in the Official Gazette, make rules ...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 14 of the Motor Vehicles Act, 1988.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 2/5  — The model answer incorrectly reinterprets the section, missing the requirement for presentment within a reasonable time and the consequences of non-compliance.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Execution of decree
#
# (1) W...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing execution of decrees instead of administering oaths on affidavits.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : In every decree of dissolution of marriage, the Court shall specify the date of ...
#   Score  : 1/5  — The model answer is not related to the content of Section 18 of the Indian Divorce Act, 1869, which pertains to petitions for declaring a marriage null and void.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : No person shall drive a motor vehicle unless he carries a certificate of insuran...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes grievous hurt to any woman, being pregnant with this ...
#   Score  : 2/5  — The model answer is about a different section of the IPC and does not match the reference.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Code of Civil Procedure, 1908...
#   Score  : 4/5  — Correct core content but missing the title of the section.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 31:
# Section 406: Procedure when accuse...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the actual content of Section 406 of the Code of Criminal Procedure, 1973.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Code of Criminal Procedure, 1973...
#   Score  : 4/5  — Correctly identifies the relevant act but lacks the section title.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When any Court of Session convicts an accused person of an offence punishable wi...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead discusses the procedure for capital cases.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple terms, Section 100 of the Indian Divorce Act, 1869 deals with Saving o...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Indian Evidence Act and provides an incorrect year for the Indian Succession Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model answer captures the essence of the powers of Claims Tribunals but incorrectly states they have the powers of a civil court of small causes, which is not accurate according to the reference.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : (1) A State Government may, by notification in the Official Gazette, make rules ...
#   Score  : 1/5  — The model answer is not related to the content of Section 128 of the Motor Vehicles Act, 1988.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : For the purposes of this Code, the term “Court” includes any officer or other pe...
#   Score  : 2/5  — The model answer does not address Section 375 of the Code of Criminal Procedure, 1973, and instead provides a definition of 'Court' which is unrelated to the question.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 4/5  — The model answer captures the essence of the bar to further suit but includes redundant and repetitive language that does not add value.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, instead of the Indian Penal Code, 1860.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : The word “thug” denotes a member of a gang of robbers and murderers, who habitua...
#   Score  : 1/5  — The model answer is not related to Section 149 of the Indian Penal Code and instead provides a definition of 'thug', which is unrelated to the question.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 36:
# Section 479: Procedure in case of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 479 to be about the procedure for conviction rather than the disqualification of judges or magistrates.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Liability of insurer in case o...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the actual content of Section 198A of the Motor Vehicles Act, 1988.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : No person driving a motor vehicle shall wear any clothing which may interfere wi...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Motor...
#   Score  : 1/5  — The model answer is completely incorrect as Section 124 does not fall under the Motor Vehicles Act, 1988.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Code of Civil Procedure, 1908 deals with Decr...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Hindu Marriage Act, and does not capture the specific conditions for granting relief as per Section 23.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : The Indian Evidence Act, 1872
# Chapter 13:
# Section 166: Proof of documents purpo...
#   Score  : 2/5  — The model answer incorrectly describes Section 166 as related to proving documents, while it actually pertains to the power of juries or assessors to ask questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Civil Procedure, 1908 deals with Prot...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure and mentions a 24-hour detention limit, which is not part of Section 45.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : Any Magistrate may, at any stage of a proceeding under this Code, issue a warran...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 5: offences against the state
# Section 64: Punish...
#   Score  : 2/5  — The model answer incorrectly identifies Section 64 as relating to mischief instead of non-payment of fine, and does not address the key elements of the section.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Indian Easements Act, 1882 deals with Voidanc...
#   Score  : 2/5  — The model incorrectly refers to the Indian Easements Act instead of the Motor Vehicles Act and misinterprets the scope of the section.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly states the maximum term of imprisonment as seven years instead of three years.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : (1) Where any person desires to sue or defend in any Court, he shall, in order t...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect regarding the content of Section 124 of the Code of Civil Procedure, 1908.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : No person shall drive a motor vehicle unless he carries with him a certificate o...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it does not address the key points about speed limits and public places as stated in the reference answer.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 2/5  — The model answer incorrectly states that registration is under the Indian Succession Act, 1857, instead of the Hindu Marriage Act, 1955.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : (1) Where any suit is instituted in a Court in the State of a foreign country, t...
#   Score  : 1/5  — The model answer is not related to Section 7 of the Code of Civil Procedure, 1908, and provides an unrelated provision instead.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences affecting the public
# Section 128: Sa...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its punishment, and misidentifies the offense.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is not related to Section 100 of the Negotiable Instruments Act, 1881, which deals with protests and better security.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : When any Court has taken cognizance of an offence or a complaint, it may, at any...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses directing investigations rather than withdrawing powers as stated in Section 34.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Code of Civil Procedure, 1908...
#   Score  : 1/5  — The model answer is completely incorrect as Section 370 does not fall under the Code of Civil Procedure, 1908.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: sexual offences and punishment for the offen...
#   Score  : 2/5  — The model answer incorrectly defines Section 376A as related to rape and abortion, while the reference correctly identifies it as related to causing death or persistent vegetative state.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section : 147. Execution of decree. Exe...
#   Score  : 2/5  — The model answer incorrectly interprets Section 147 as dealing with the execution of decrees rather than consent or agreements from parties under disability.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : (1) Where any suit is instituted in a Court of inferior jurisdiction, the Court ...
#   Score  : 1/5  — The model answer is not about Section 43 of the Code of Civil Procedure, 1908, but rather about a different rule regarding stays of suits.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section : 34. Execution of decree. Exec...
#   Score  : 2/5  — The model answer incorrectly describes Section 34 as relating to execution of decrees instead of interest, which is a significant legal error.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : The Indian Evidence Act, 1872 deals with Section 118 titled 'Presumption as to t...
#   Score  : 2/5  — The model answer incorrectly identifies Section 118 and provides an inaccurate description of its content.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 7:
# Section 52: Liability of owner
#
# The owner o...
#   Score  : 2/5  — The model answer incorrectly focuses on the owner's liability rather than the alteration of the vehicle as per Section 52.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : The word “person” denotes a human being, whether male or female....
#   Score  : 4/5  — Captures the essence of Section 365 but omits the key elements of the crime and punishment.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : A person driving a motor vehicle shall not drive the vehicle unless he is at lea...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 4/5  — The model captures the essence of safety measures for drivers and pillion riders but incorrectly omits the specific mention of two-wheeled motor cycles and the provision for the central government to prescribe additional safety measures.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 21: offences affecting the public - nuisance 1
# S...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing a different section of the IPC.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : In every suit in which any person is summoned to attend as a witness, the Court ...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 66 of the Code of Civil Procedure, 1908.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 13:
# Section 174: Liability of insurer
#
# (1) Whe...
#   Score  : 2/5  — The model answer incorrectly interprets Section 174 as relating to liability of insurers rather than recovery of money from insurers as arrears of land revenue.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 31:
# Section 402: Procedure in case of ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing a different section of the code.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 5:
# Section 38: Liability of insurer
#
# (1) Where...
#   Score  : 1/5  — The model answer is completely incorrect, discussing liability of insurers instead of the power of state government to make rules.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : A decree of dissolution of marriage may be made absolute either at the conclusio...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869 and instead discusses grounds for dissolution of marriage, which is unrelated to the question.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : In every suit in which the Court has to determine the rights of parties as to an...
#   Score  : 1/5  — The model answer is not related to Section 146 of the Code of Civil Procedure, 1908, and instead refers to a different section.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 2/5  — The model answer incorrectly defines the drawee as the one who draws the cheque and dishonours it, which is not accurate.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Code of Civil Procedure, 1908...
#   Score  : 2/5  — The model answer is partially correct but contains a notable legal error as Section 138 does not fall under the Code of Civil Procedure, 1908.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 13:
# Section 166B: Procedure in cases o...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the actual content of Section 166B.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The answer captures the essence of Section 116 but omits the specific circumstances under which the inquiry must occur and the method of conducting the inquiry.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Procedure in case of ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 202 and provides information about a different section.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidancements for mutually satisfactory disposition' falls ...
#   Score  : 1/5  — The model answer is completely incorrect as it refers to the wrong code and wrong section name.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 2/5  — The model answer incorrectly identifies the section from the Code of Criminal Procedure instead of the Indian Penal Code, and omits the key element of 'without sufficient cause'.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits theft in respect of any property belonging to Government or any ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrectly describes theft instead of public nuisance as per Section 290 of the IPC.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 5:
# Section 36: Indorsement in blank
#
# A...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as relating to indorsements in blank instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Every fact which is relevant shall be relevant whether it is relevant to proving...
#   Score  : 2/5  — The model answer does not address Section 165 of the Indian Evidence Act, 1872, but instead provides a definition of relevant facts under Section 165.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly states that the punishment is the same as if the offense had been committed in India, while the reference indicates that the section deals with abetting offenses committed outside India.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Court has convicted an accused person and sentenced him to death, it may,...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing recall of sentences instead of Section 339.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When any Court has issued a warrant for the arrest of any person, it may, at any...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model answer captures the key legal meaning but includes unnecessary repetition and specifies 'unlawfully' which is not part of the original text.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, corruptly influences any person to execute any ...
#   Score  : 1/5  — The model answer is not related to the question and provides an incorrect legal provision.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, corruptly executes any act of sexual nature tow...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque payable at a fixed period after si...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881, and thus is completely incorrect.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter 6:
# Section 57: Procedure in case of dissolutio...
#   Score  : 2/5  — The model answer incorrectly describes Section 57 as related to the procedure for dissolution of marriage and includes irrelevant information about arrears and costs.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When any Court has convicted any person of an offence punishable under section 3...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 228 of the Code of Criminal Procedure, 1973.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : The State Government may, by notification in the Official Gazette, make rules fo...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter 5 :
# Section 31: Divorce on petition
#
# Any perso...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as related to divorce petitions instead of the wife's legal position during desertion.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) A transport undertaking shall be deemed to be a transport undertaking of the...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 128 but omits the critical part about the rights and position of the parties involved.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : A witness shall be deemed to have sufficient knowledge of any matter of which he...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and thus is completely incorrect.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Frauduliously' falls under the Indian Penal Code, 1860....
#   Score  : 4/5  — Correct core content but with a slight imprecision in the spelling of 'Fraudulently' as 'Frauduliously'.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Divorce ...
#   Score  : 1/5  — The model answer is completely incorrect as Section 35 'Power of Court to disqualify' does not fall under the Indian Divorce Act, 1869.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : The State Government may, by notification in the Official Gazette, make rules fo...
#   Score  : 1/5  — The model answer is not related to the question and contains no relevant information about Section 119 of the Motor Vehicles Act, 1988.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : The Indian Evidence Act, 1872 deals with Section 102 titled 'Presumption as to t...
#   Score  : 2/5  — The model answer incorrectly identifies Section 102 as dealing with presumption of time of death, while it actually addresses the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Civil P...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Civil Procedure, 1908 as the relevant act, when it should be the Code of Criminal Procedure, 1973.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter 4:
# Section 35: Liability of owner of motor veh...
#   Score  : 2/5  — The model answer incorrectly describes Section 35 as relating to liability of the owner of a motor vehicle instead of the power of the court to disqualify.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 4/5  — The model captures the essence of bribery but misinterprets the specific context of electoral rights and public servants.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : The word “person” denotes a human being, whether male or female....
#   Score  : 2/5  — The answer is partially correct but contains notable legal errors as it misinterprets the section and does not address the key elements of Section 208.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : In calculating the period of limitation for the purpose of section 21, the perio...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : The Indian Evidence Act, 1872 deals with Section 117 titled 'Presumption as to t...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misidentifies Section 117 and provides an incorrect description of its content.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter 2:
# Section 6: Procedure in case of petition fo...
#   Score  : 2/5  — The model answer incorrectly describes the purpose of Section 6 and does not capture the key legal meaning of the section.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : A person is said to commit criminal conspiracy, if he agrees with one or more pe...
#   Score  : 1/5  — The model answer is about criminal conspiracy instead of the right of private defence of property as required by the question.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_phi4_lora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — PHI4_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.28 / 5.0
#
#   Score distribution:
#     5/5  ██████████████████████ (22)
#     4/5  ███████████████████ (19)
#     3/5   (0)
#     2/5  ███████████████████████████████████████████████ (47)
#     1/5  ██████████████████████████████████████████████████████████████ (62)
#
#   By task type:
#     Act Identification   avg=3.67  (n=39)
#     Direct Q&A           avg=1.06  (n=31)
#     Explanation          avg=2.39  (n=59)
#     Summarization        avg=1.19  (n=21)
# ============================================================
