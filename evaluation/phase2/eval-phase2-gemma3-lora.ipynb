# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 33.0 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
# ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        compute_dtype = torch.float32
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=False,
        torch_dtype=torch.float32
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: GEMMA3_LORA
# Loading 4-bit quantization config...
# Loading base model: google/gemma-3-4b-it...
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: GEMMA3_LORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes grievous hurt by means of an acid, or by means of fir...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it lists multiple methods of causing harm without specifying acid or the intent required.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 65B: Presumption as to electronic r...
#   Score  : 2/5  — The model answer incorrectly describes Section 65B as dealing with presumptions about electronic records, when it actually deals with the admissibility of such records.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : The provisions of this Chapter relating to the powers of the High Court and the ...
#   Score  : 1/5  — The model answer is not related to the content of Section 53A of the Code of Criminal Procedure, 1973.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Nego...
#   Score  : 2/5  — The model answer is partially correct but contains a notable legal error as Section 105J does not fall under the Negotiable Instruments Act, 1881.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Indian Penal Code, 1860 deals with Sentence i...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure, and omits key details about the order of punishments.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to every Court issuing a search warra...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference and contains a significant error.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : The High Court may, from time to time, make rules regulating the proceedings of ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : The High Court may, from time to time, make rules regulating the manner in which...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a Magistrate has issued a search warrant, he shall search the premises or t...
#   Score  : 1/5  — The model answer is not related to Section 247 of the Code of Criminal Procedure, 1973, and instead refers to a different section dealing with search warrants.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 1/5  — The model answer is completely incorrect as Section 132 does not fall under the Indian Evidence Act, 1872.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Motor Vehicles Act, 1988 deals with Recovery...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, such as omitting the role of the Claims Tribunal and the Collector.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested, the officer making the arrest shall, if so required b...
#   Score  : 1/5  — The model answer is not related to Section 253 of the Code of Criminal Procedure, 1973 and provides incorrect information about the arrest process.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: bribery and illegal provisions
# Section 171G:...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to bribery and provides an incorrect definition of the section.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — Correct core content but includes an additional detail about the punishment which is not explicitly mentioned in the reference answer.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever commits mischief by destroying, defacing, marking, repairing or otherwis...
#   Score  : 2/5  — The model answer is about a different section of the IPC and does not capture the key legal meaning of Section 424.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 238: Power of Magistrate to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 238 to relate to search and seizure instead of compliance with Section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a negotiable instrument, in order to render the holder liable to h...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[125. Power of State Government to make rules.-- (1) The State Government may m...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about the power of the state government to make rules.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall, so far as may be, apply also to any Court-...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 284: Power of Magistrate to ...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 284 of the Code of Criminal Procedure, 1973.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[89. Execution of decrees passed by Civil Courts in other countries. -- (1) Whe...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing the execution of decrees instead of the settlement of disputes.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 4/5  — The model answer captures the essence of Section 164 but omits the specific mention of recording by audio-video electronic means and the requirement for the presence of an advocate.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 108: Power of Magistrate to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 108 and its purpose.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, knowingly performs any act in the discharge of ...
#   Score  : 1/5  — The model answer is not legally equivalent to Section 290 of the Indian Penal Code.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer captures the essence of wrongful confinement but omits the specific intent of secrecy, which is a key element of Section 346.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : The Court shall presume, until the contrary is proved, that every document purpo...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act and instead refers to Section 158 of the Indian Succession Act.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 337: Power of Magistrate to ...
#   Score  : 1/5  — The model answer is completely unrelated to the question and reference answer.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall apply to any Magistrate, including the Chie...
#   Score  : 2/5  — The answer is not legally equivalent to the reference and contains notable legal errors.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Indian Divorce Act, 1869 deals with Transfer ...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, and misinterprets the scope of transfer.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever, fraudulently or with intent to cause loss to the Government, buys, sell...
#   Score  : 1/5  — The model answer is not legally equivalent to Section 373 of the Indian Penal Code.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 5/5  — The model answer is semantically identical to the reference answer and captures all the key legal details accurately.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits mischief by doing any act which causes or which he knows to be l...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and appears to be describing a different section of the IPC.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : [Collector to be liable to pay costs of suit.] — Rep. by the Code of Civil Proce...
#   Score  : 1/5  — The model answer is not related to the question and provides incorrect information.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) No person driving a motor vehicle shall, without reasonable care and attenti...
#   Score  : 1/5  — The model answer is not related to Section 14 of the Motor Vehicles Act, 1988, and instead addresses a different section or regulation.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Indian Penal...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the M...
#   Score  : 1/5  — The model answer is completely incorrect as Section 133 does not fall under the Motor Vehicles Act, 1988.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : Subject to the provisions of section 63, the holder of a negotiable instrument m...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors as it does not address the key points of Section 62 regarding presentment of promissory notes.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1898
# Chapter :
# Section 139: [Repealed]
#
# 1[Repealed by ...
#   Score  : 2/5  — The model incorrectly refers to the wrong year of the Code of Civil Procedure and states that the section is repealed, which is not accurate for the 1908 version.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : The Court shall have jurisdiction to make all-or-any decrees in any suit institu...
#   Score  : 1/5  — The model answer is not related to Section 18 of the Indian Divorce Act, 1869, which pertains to petitions for declaring a marriage null and void.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[178. Power of State Government to make rules.-- (1) The State Government may m...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the content of Section 178 of the Motor Vehicles Act, 1988.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 1/5  — The model answer is completely incorrect as Section 47 falls under the Code of Civil Procedure, 1908, not the Indian Divorce Act, 1869.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever drives any vehicle at a speed which is dangerous to the public, shall be...
#   Score  : 2/5  — The model answer introduces an irrelevant element (driving at a dangerous speed) not present in the original section.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Indian Penal Code, 1860....
#   Score  : 2/5  — The model answer incorrectly identifies the Indian Penal Code, 1860 as the relevant code, when it should be the Code of Civil Procedure, 1908.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 406: Power of High Court to ...
#   Score  : 2/5  — The model answer incorrectly states that Section 406 pertains to the power of High Courts to direct trials, while it actually concerns the Supreme Court's power to transfer cases and appeals.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested in the course of an investigation under section 477, t...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973, and instead discusses a different section.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Penal Code, 1860 deals with Saving of...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Indian Evidence Act and includes multiple redundant references to the Wills Act.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 2/5  — The model answer contains notable legal errors, such as misinterpreting the scope of Section 169 and omitting key procedural aspects.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : 1[128. Power of State Government to make rules.-- (1) The State Government may m...
#   Score  : 1/5  — The model answer is not semantically correct as it does not address the specific provisions regarding carrying passengers on two-wheeled motor cycles as stated in Section 128.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 375: Power of Magistrate to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 375 to be about summary trials instead of appeals for guilty pleas.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Indian Divorce Act, 1869 deals with Bar to fu...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Code of Civil Procedure, and misinterprets the scope of Section 12.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, instead of the Indian Penal Code, 1860.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8:
# Section 149: Punishment for rioting
#
# Whoever...
#   Score  : 4/5  — The model answer correctly identifies the section and its purpose but provides an incorrect and incomplete definition, focusing on punishment rather than the legal principle.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973 (44 of 1973) Chapter 26: repealed. . . . . . . ...
#   Score  : 4/5  — The model answer captures the essence of Section 479 but incorrectly states that the chapter has been repealed.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Driving of motor vehicle by pe...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to driving age instead of road safety standards.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[134. Power of State Government to make rules.-- (1) Notwithstanding anything i...
#   Score  : 1/5  — The model answer is not related to the question and contains irrelevant information about the power of the state government to make rules.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the India...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually belongs to the Indian Penal Code, 1860.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals with Decree in...
#   Score  : 2/5  — The model answer incorrectly refers to the Indian Divorce Act instead of the Hindu Marriage Act and provides an incorrect definition of Section 23.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 166: Evidence as to the existence o...
#   Score  : 4/5  — The model answer captures the essence of Section 166 but misinterprets its content, focusing on the admissibility of evidence rather than the power of the jury or assessors to ask questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Indian Penal Code, 1860 deals with Protection...
#   Score  : 2/5  — The model incorrectly refers to the Indian Penal Code instead of the Code of Criminal Procedure, and misinterprets the section's purpose.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : When a police officer has reason to believe that a person is about to commit, is...
#   Score  : 1/5  — The model answer is completely unrelated to the question and reference answer.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3:
# Section 64: Act done by one person, with com...
#   Score  : 2/5  — The model answer is not about Section 64 of the IPC, but rather about Section 14 of the IPC, which deals with joint liability.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Indian Penal Code, 1860 deals with Voidance o...
#   Score  : 2/5  — The model answer incorrectly refers to the Indian Penal Code instead of the Motor Vehicles Act and misinterprets the section's purpose.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly specifies a minimum value of five rupees for punishment, which is not mentioned in the original section.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[124. Power of High Court to make rules.-- (1) The High Court may make such rul...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : 1[112. Power of State Government to make rules.-- (1) The State Government may m...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988 and instead discusses the power of the State Government to make rules.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, omitting key details about the registration process and conditions.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : [Repealed by the Civil Procedure (Amendment) Act, 1908 (22
# (iii.)) see art. 2 an...
#   Score  : 1/5  — The model answer is completely incorrect as it refers to an amendment act from 1908 that repealed the section, rather than summarizing the content of Section 7.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 5:
# Section 128: Person who is a minor
#
# The word...
#   Score  : 2/5  — The model incorrectly identifies 'person who is a minor' as the subject of Section 128, which is not accurate.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a negotiable instrument, in order to render the holder liable to h...
#   Score  : 2/5  — The answer is partially correct but contains notable legal errors, as it misinterprets the purpose and process of protesting a dishonored instrument.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested, the officer making the arrest shall, if so required b...
#   Score  : 1/5  — The model answer is not related to Section 34 of the Code of Criminal Procedure, 1973, and instead discusses the procedure for showing a commission during an arrest.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: criminal force
# Section 376A: Sexual intercou...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its punishment, leading to a significant legal error.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Power of High Court to mak...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and introduces irrelevant information about rules.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : [Collector to be liable to pay costs of suit.] — Rep. by the Code of Civil Proce...
#   Score  : 1/5  — The model answer is not related to the question and provides an incorrect statement about the collector being liable for costs.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: [Repealed]
#
# 3[Repealed.]—Th...
#   Score  : 2/5  — The model answer incorrectly states that Section 34 has been repealed and provides unrelated information.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 118: Proof of contents of electroni...
#   Score  : 2/5  — The model answer incorrectly describes Section 118 as pertaining to electronic records instead of witness competency.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly interprets Section 52 as granting powers to the State Government instead of regulating alterations to motor vehicles.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: theft
# Section 365: Theft
#
# Theft is the takin...
#   Score  : 2/5  — The model incorrectly identifies Section 365 as relating to theft instead of kidnapping or abduction, and provides an incorrect definition.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Where any person is convicted of an offence under section 184 or section 185...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Motor Vehicles Act, 1988 and instead lists various sections of the act, which is incorrect.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 4/5  — The model answer captures the essence of the section but omits the specific mention of two-wheeled motor cycles and the central government's authority to prescribe additional safety measures.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 18: offences relating to documents and to stampe...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 410 of the Indian Penal Code, 1860.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The holder of a negotiable instrument, in order to render the holder liable to h...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets the section and its requirements.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[66. Power of High Court to make rules.-- (1) The High Court may make such rule...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the question about Section 66 of the Code of Civil Procedure, 1908.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power of State Government to ma...
#   Score  : 2/5  — The model answer incorrectly describes Section 174 as about the power to make rules instead of recovery of money from insurers.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 402: Power of Magistrate to ...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 402 which deals with the power of the High Court to withdraw or transfer revision cases, not the power of a Magistrate to try cases summarily.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Driving licence
#
# (1) The driving...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing driving licences instead of rules-making powers.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : 1[59. Power of Court to make such orders as it thinks fit.--In any suit under th...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead appears to be about court powers in a different context.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[146. Power of High Court to make rules.—
#
# (1) The High Court may make such rul...
#   Score  : 1/5  — The model answer is not related to the question and provides rules about the High Court's power to make rules, which is not what Section 146 of the Code of Civil Procedure, 1908 states.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 4/5  — The model answer captures the essence of the drawee's liability but omits the part about compensation for loss or damage.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Code of Criminal Proc...
#   Score  : 2/5  — The model answer incorrectly identifies the Code of Criminal Procedure, 1973 as the relevant act, instead of the Indian Evidence Act, 1872.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 166B: Power of High Court to...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Indian Evidence Act, 1872 deals with Inquiry...
#   Score  : 2/5  — The model incorrectly refers to the Indian Evidence Act instead of the Code of Criminal Procedure, and omits key details about the circumstances under which the inquiry must occur.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter :
# Section 202: Power of Magistrate to ...
#   Score  : 2/5  — The model answer incorrectly describes Section 202 as related to summary trials, while the reference answer correctly explains it pertains to postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act, as to the present, apply to all negotiable instrumen...
#   Score  : 1/5  — The model answer is not related to the specific content of Section 20 of the Negotiable Instruments Act, 1881, and instead discusses general provisions of the act.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Code of Criminal Procedure, 1973 deals with...
#   Score  : 4/5  — The model answer is close but incorrectly identifies the IPC as CCP, and omits the requirement of sufficient cause and the associated burden of proof.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, fraudulently or dishonestly performs or omits t...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter :
# Section 36: Presentment for payment
# ...
#   Score  : 2/5  — The model answer incorrectly describes Section 36 as related to presentment for payment instead of liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 165: Power of Magistrate to order p...
#   Score  : 4/5  — Correctly identifies the section but mislabels it as a Magistrate's power instead of a Judge's, and omits the part about asking questions.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 4/5  — Correct core content but includes a minor error by stating the section was repealed.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is arrested on a charge of having committed an offence, the police...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : The High Court may, from time to time, make rules regulating the manner in which...
#   Score  : 1/5  — The model answer is not related to the question about Section 310 of the Code of Criminal Procedure, 1973.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — The model captures the essence of the section but omits the imprisonment component and the disqualification part.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits the offence of rape shall be punished with rigorous imprisonment...
#   Score  : 2/5  — The model answer incorrectly states the conditions for the offense and the punishment, missing the key elements of multiple perpetrators and the specific punishment.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt to any person, by dragging or by any act which c...
#   Score  : 2/5  — The model answer describes a different section of the IPC and does not match the content of Section 328.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : A promissory note, bill of exchange or cheque must be presented for payment at t...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it discusses presentation for payment instead of the requirement for acceptance of a bill of exchange.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Power of High Court to make rule...
#   Score  : 2/5  — The model answer incorrectly interprets Section 57 as granting power to the High Court to make rules, instead of providing the liberty to parties to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is arrested, the officer making the arrest shall, if so required b...
#   Score  : 1/5  — The model answer is not related to Section 228 of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 1/5  — The model answer is completely incorrect as Section 268 falls under the Code of Criminal Procedure, 1973, not the Motor Vehicles Act, 1988.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a candidate at an election, gives or offers to give, or accepts o...
#   Score  : 3/5  — The model answer captures the essence of the offense but omits the specific context of electoral rights and the provision about public policy.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Power to make rules
#
# The High Co...
#   Score  : 2/5  — The model answer incorrectly describes Section 31 as about making rules for service of notice, while the reference answer correctly explains the legal status of the wife during a period of desertion.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) No person driving a motor vehicle shall, without reasonable care and attenti...
#   Score  : 1/5  — The model answer is not related to Section 27 of the Motor Vehicles Act, 1988 and provides an unrelated legal statement instead.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 4/5  — The model captures the essence of Section 128 but omits the key point about the rights and position of the banker and payee as stated in the reference answer.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : The Court shall presume, until the contrary is proved, that every oral statement...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and instead refers to a different section of the act.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Indian Penal Co...
#   Score  : 1/5  — The model answer is completely incorrect as Section 35 'Power of Court to disqualify' does not fall under the Indian Penal Code, 1860 but under the Motor Vehicles Act, 1988.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : No person shall drive a motor vehicle at a speed exceeding the speed limit in an...
#   Score  : 2/5  — The model answer contains notable legal errors as it misinterprets the section and introduces new requirements not found in the original text.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 102: Proof of facts in issue
#
# Facts...
#   Score  : 4/5  — Correctly identifies the section and its general purpose, but misinterprets the actual content of the section.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Power of State Government to mak...
#   Score  : 2/5  — The model answer incorrectly describes Section 35 as granting power to the state government to make rules, instead of describing the court's power to disqualify.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 4/5  — The answer captures the essence of Section 171B but omits the specific conditions regarding electoral rights and the exception for declarations of public policy.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 11: false light, false colours, and other offenc...
#   Score  : 2/5  — The model answer incorrectly identifies the section and its purpose, leading to a fundamentally flawed explanation.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : The provisions of this Act, as to the validity of the consideration of a negotia...
#   Score  : 1/5  — The model answer is not related to Section 144 of the Negotiable Instruments Act, 1881 and provides an unrelated legal statement.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter :
# Section 117: Proof of contents of electroni...
#   Score  : 2/5  — The model answer incorrectly describes Section 117 and does not capture the key legal meaning.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: [Repealed]
#
# 1[Section 6. Rep. by ...
#   Score  : 4/5  — The model answer correctly identifies that Section 6 has been repealed, but does not provide the context or the original content of the section as per the reference answer.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : The word “public” is used in a broad sense, and includes any class of the public...
#   Score  : 2/5  — The model answer is not relevant to the question about Section 105 of the Indian Penal Code, 1860, and instead discusses the meaning of 'public' which is unrelated.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_gemma3_lora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — GEMMA3_LORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.45 / 5.0
#
#   Score distribution:
#     5/5  ███████████████████████████ (27)
#     4/5  █████████████████ (17)
#     3/5  █ (1)
#     2/5  ████████████████████████████████████████████████████████ (56)
#     1/5  █████████████████████████████████████████████████ (49)
#
#   By task type:
#     Act Identification   avg=3.87  (n=39)
#     Direct Q&A           avg=1.29  (n=31)
#     Explanation          avg=2.54  (n=59)
#     Summarization        avg=1.24  (n=21)
# ============================================================
