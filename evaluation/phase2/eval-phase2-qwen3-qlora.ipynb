# %%
# !pip install peft bitsandbytes accelerate huggingface_hub -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.8 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
import torch
import json
import re
import os
import random
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline
from peft import PeftModel
from datetime import datetime
import warnings
import transformers
warnings.filterwarnings("ignore")
transformers.logging.set_verbosity_error()

# ==========================================
# 🎯 SELECT THE MODEL TO EVALUATE
# ==========================================
# ACTIVE_MODEL = "phi4_qlora"
# ACTIVE_MODEL = "phi4_lora"
ACTIVE_MODEL = "qwen3_qlora"
# ACTIVE_MODEL = "qwen3_lora"
# ACTIVE_MODEL = "gemma3_qlora"
# ACTIVE_MODEL = "gemma3_lora"

# ==========================================
# ⚙️  PATHS — edit dataset name to match yours
# ==========================================
ADAPTER_DATASET = "/kaggle/input/datasets/shreyashgaurgla/nyaya-adapters"   # ← change to your adapter dataset path
DATA_DATASET    = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"  # ← change to your data dataset path

CONFIGS = {
    "phi4_qlora":   {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_phi4_mini/qlora_phase2_phi4_mini"},
    "phi4_lora":    {"base_model": "microsoft/Phi-4-mini-instruct", "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_phi4_mini/lora_phase2_phi4_mini"},
    "qwen3_qlora":  {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b"},
    "qwen3_lora":   {"base_model": "Qwen/Qwen3-4B-Instruct-2507",  "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_qwen3_4b/lora_phase2_qwen3_4b"},
    "gemma3_qlora": {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/qlora_phase2_gemma3_4b/qlora_phase2_gemma3_4b"},
    "gemma3_lora":  {"base_model": "google/gemma-3-4b-it",          "adapter_dir": f"{ADAPTER_DATASET}/lora_phase2_gemma3_4b/lora_phase2_gemma3_4b"},
}

TEST_DATA_PATH = f"{DATA_DATASET}/all_acts_test.jsonl"
NUM_SAMPLES    = 150
SEED           = 42
RESULTS_DIR    = "/kaggle/working/results"
JUDGE_RETRIES  = 3

# ==========================================
# 🏷️  TASK TYPE DETECTOR
# ==========================================
def detect_task_type(instruction: str) -> str:
    il = instruction.lower()
    if il.startswith("explain"):
        return "Explanation"
    elif il.startswith("summarize"):
        return "Summarization"
    elif il.startswith("what does"):
        return "Direct Q&A"
    elif il.startswith("under which act"):
        return "Act Identification"
    else:
        return "Other"

# ==========================================
# 📦  LOAD TEST SAMPLES
# ==========================================
def load_test_samples(filepath: str, num_samples: int) -> list:
    with open(filepath, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]
    random.seed(SEED)
    return random.sample(data, min(num_samples, len(data)))

# ==========================================
# 🤖  GENERATION
# ==========================================
def generate_response(model, tokenizer, instruction: str) -> str:
    prompt = f"### Instruction:\n{instruction}\n\n### Response:\n"
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=300,
            temperature=0.1,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return full_output.split("### Response:\n")[-1].strip()

# ==========================================
# 🧑‍⚖️  JUDGE — HuggingFace (no Ollama needed)
# ==========================================
JUDGE_PROMPT_TEMPLATE = """You are a strict legal AI evaluator. Score the MODEL ANSWER against the REFERENCE ANSWER.

SCORING RUBRIC:
  5 - Perfect. Legally accurate, complete, no errors.
  4 - Good. Correct core content, minor omissions or slight imprecision.
  3 - Acceptable. Gets the general idea but misses important legal details.
  2 - Poor. Partially correct but contains notable legal errors.
  1 - Wrong. Fabricated law, completely incorrect, or irrelevant answer.

IMPORTANT:
- Score based on semantic correctness, NOT exact wording match.
- The reference may be long. The model only needs to capture the key legal meaning.
- If the model answer is legally equivalent to the reference but phrased differently, score it high.

QUESTION:
{instruction}

REFERENCE ANSWER:
{reference}

MODEL ANSWER:
{prediction}

Respond ONLY with a valid JSON object, nothing else:
{{"score": <int 1-5>, "reasoning": "<one concise sentence>"}}"""

judge_pipe = None

def load_judge():
    global judge_pipe
    print("Loading judge model (Qwen2.5-7B 4-bit)...")

    judge_bnb = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4"
    )

    judge_model = AutoModelForCausalLM.from_pretrained(
        "Qwen/Qwen2.5-7B-Instruct",
        quantization_config=judge_bnb,
        device_map="auto",
        torch_dtype=torch.float16
    )
    judge_model.generation_config.max_length = None

    judge_tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")

    judge_pipe = pipeline(
        "text-generation",
        model=judge_model,
        tokenizer=judge_tokenizer,
    )
        # clears the conflicting defaults
    judge_pipe.model.generation_config.max_length = None
    judge_pipe.model.generation_config.min_length = 0
    print("Judge loaded.\n")

def judge_score(instruction: str, reference: str, prediction: str) -> tuple:
    prompt = JUDGE_PROMPT_TEMPLATE.format(
        instruction=instruction,
        reference=reference[:600],
        prediction=prediction[:600]
    )

    for attempt in range(JUDGE_RETRIES):
        try:
            output = judge_pipe(
                prompt,
                max_new_tokens=150,
                min_new_tokens=10,
                do_sample=False,
                return_full_text=False,
                pad_token_id=judge_pipe.tokenizer.eos_token_id
            )
            response = output[0]["generated_text"].strip()

            # Strip markdown fences
            response = re.sub(r"```(?:json)?", "", response).strip()

            if not response:
                raise ValueError("Empty response from judge")

            match = re.search(r"\{.*?\}", response, re.DOTALL)
            if not match:
                raise ValueError(f"No JSON found. Raw: {response[:150]}")

            parsed = json.loads(match.group())
            score  = int(parsed["score"])

            if not (1 <= score <= 5):
                raise ValueError(f"Score out of range: {score}")

            return score, parsed.get("reasoning", "")

        except Exception as e:
            print(f"      ⚠️  Judge attempt {attempt + 1} failed: {e}")
            if attempt == JUDGE_RETRIES - 1:
                return 0, "Judge error — skipped"

    return 0, "Judge error — skipped"

# ==========================================
# 📊  SUMMARY PRINTER
# ==========================================
def print_summary(results: list, model_name: str):
    valid = [r for r in results if r["score"] > 0]

    if not valid:
        print("No valid scores to summarise.")
        return

    overall_avg = sum(r["score"] for r in valid) / len(valid)

    by_task    = defaultdict(list)
    score_dist = defaultdict(int)

    for r in valid:
        by_task[r["task_type"]].append(r["score"])
        score_dist[r["score"]] += 1

    print("\n" + "=" * 60)
    print(f"📊  PHASE 2 SUMMARY — {model_name.upper()}")
    print("=" * 60)
    print(f"  Scored      : {len(valid)} / {len(results)} samples")
    print(f"  Overall avg : {overall_avg:.2f} / 5.0")

    print("\n  Score distribution:")
    for s in range(5, 0, -1):
        count = score_dist.get(s, 0)
        bar   = "█" * count
        print(f"    {s}/5  {bar} ({count})")

    print("\n  By task type:")
    for task in sorted(by_task.keys()):
        scores = by_task[task]
        avg    = sum(scores) / len(scores)
        print(f"    {task:<20} avg={avg:.2f}  (n={len(scores)})")

    print("=" * 60)

# ==========================================
# 🚀  MAIN
# ==========================================
def main():
    cfg = CONFIGS[ACTIVE_MODEL]
    os.makedirs(RESULTS_DIR, exist_ok=True)
    output_file = f"{RESULTS_DIR}/phase2_eval_{ACTIVE_MODEL}.json"

    print(f"\n🚀 Evaluating: {ACTIVE_MODEL.upper()}")
    print("Loading 4-bit quantization config...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16
    )

    print(f"Loading base model: {cfg['base_model']}...")
    base_model = AutoModelForCausalLM.from_pretrained(
        cfg["base_model"],
        quantization_config=bnb_config,
        device_map="auto",
        trust_remote_code=("qwen" in ACTIVE_MODEL),
        torch_dtype=torch.float16
    )

    print(f"Loading LoRA adapter: {cfg['adapter_dir']}...")
    try:
        model = PeftModel.from_pretrained(base_model, cfg["adapter_dir"])
        model.eval()
    except Exception as e:
        print(f"\n❌ Could not load adapter. Did training finish?\n{e}")
        return

    tokenizer = AutoTokenizer.from_pretrained(
        cfg["base_model"],
        trust_remote_code=("qwen" in ACTIVE_MODEL)
    )

    # Load judge after main model to avoid VRAM conflict
    load_judge()

    print(f"\nLoading {NUM_SAMPLES} test samples (seed={SEED})...")
    samples = load_test_samples(TEST_DATA_PATH, NUM_SAMPLES)

    print(f"\n{'='*60}")
    print(f"⚖️   PHASE 2 EVALUATION: {ACTIVE_MODEL.upper()}")
    print(f"{'='*60}\n")

    results = []

    for i, sample in enumerate(samples, 1):
        instruction  = sample["instruction"]
        ground_truth = sample["output"]
        task_type    = detect_task_type(instruction)

        print(f"[{i:02d}/{NUM_SAMPLES}] [{task_type}]")
        print(f"  Prompt : {instruction[:80]}...")

        prediction = generate_response(model, tokenizer, instruction)
        print(f"  Answer : {prediction[:80]}...")

        score, reasoning = judge_score(instruction, ground_truth, prediction)
        print(f"  Score  : {score}/5  — {reasoning}\n")

        results.append({
            "model":        ACTIVE_MODEL,
            "task_type":    task_type,
            "instruction":  instruction,
            "ground_truth": ground_truth,
            "prediction":   prediction,
            "score":        score,
            "reasoning":    reasoning,
            "timestamp":    datetime.now().isoformat()
        })

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"💾 Raw results saved → {output_file}")
    print_summary(results, ACTIVE_MODEL)


if __name__ == "__main__":
    main()
# Out:
# 🚀 Evaluating: QWEN3_QLORA
# Loading 4-bit quantization config...
# Loading base model: Qwen/Qwen3-4B-Instruct-2507...
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# Loading LoRA adapter: /kaggle/input/datasets/shreyashgaurgla/nyaya-adapters/qlora_phase2_qwen3_4b/qlora_phase2_qwen3_4b...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Loading judge model (Qwen2.5-7B 4-bit)...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Judge loaded.
#
#
# Loading 150 test samples (seed=42)...
#
# ============================================================
# ⚖️   PHASE 2 EVALUATION: QWEN3_QLORA
# ============================================================
#
# [01/150] [Act Identification]
#   Prompt : Under which Act does Section 221 titled 'Where it is doubtful what offence has b...
#   Answer : Section 221 titled 'Where it is doubtful what offence has been committed' falls ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [02/150] [Direct Q&A]
#   Prompt : What does Section 326A of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, legally bound as such public servant to keep in...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [03/150] [Act Identification]
#   Prompt : Under which Act does Section 88A titled 'Presumption as to electronic messages' ...
#   Answer : Section 88A titled 'Presumption as to electronic messages' falls under the India...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [04/150] [Explanation]
#   Prompt : Explain Section 65B of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 5:
# Section 65B: Presumption as to electronic ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 65B as dealing with presumptions about secure electronic records, while the reference correctly explains its role in admitting computer-generated records.
#
# [05/150] [Summarization]
#   Prompt : Summarize Section 53A of Code of Criminal Procedure, 1973....
#   Answer : Notwithstanding anything contained in section 53, when a person is arrested on a...
#   Score  : 1/5  — The model answer is not related to Section 53A of the Code of Criminal Procedure, 1973, and instead refers to a different section.
#
# [06/150] [Act Identification]
#   Prompt : Under which Act does Section 105J titled 'Certain transfers to be null and void'...
#   Answer : Section 105J titled 'Certain transfers to be null and void' falls under the Code...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [07/150] [Explanation]
#   Prompt : Explain Section 31 (Sentence in cases of conviction of several offences at one t...
#   Answer : In simple words, Section 31 of the Code of Criminal Procedure, 1973 deals with S...
#   Score  : 4/5  — The answer captures the main idea but omits the specific provision regarding the order of punishments and the exception for the Indian Penal Code.
#
# [08/150] [Direct Q&A]
#   Prompt : What does Section 104 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a warrant for the arrest of any person has been executed, the officer who a...
#   Score  : 1/5  — The model answer is not related to Section 104 of the Code of Criminal Procedure, 1973, and instead discusses the procedure for taking bail and keeping a person in custody after arrest.
#
# [09/150] [Direct Q&A]
#   Prompt : What does Section 405 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a person is accused of more offences than one of the same kind committed wi...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [10/150] [Act Identification]
#   Prompt : Under which Act does Section 416 titled 'Postponement of capital sentence on pre...
#   Answer : Section 416 titled 'Postponement of capital sentence on pregnant woman' falls un...
#   Score  : 2/5  — The model incorrectly identifies the Code of Criminal Procedure, 1973 as the source, when it actually falls under the Indian Penal Code, 1860.
#
# [11/150] [Direct Q&A]
#   Prompt : What does Section 323 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a Magistrate takes cognizance of an offence under clause a), b), c) or d) o...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and contains irrelevant information from other sections of the Code of Criminal Procedure.
#
# [12/150] [Summarization]
#   Prompt : Summarize Section 247 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of more offences than one of the same kind committed at...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 247 of the Code of Criminal Procedure, 1973.
#
# [13/150] [Act Identification]
#   Prompt : Under which Act does Section 132 titled 'Exemption of certain women from persona...
#   Answer : Section 132 titled 'Exemption of certain women from personal appearance' falls u...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [14/150] [Explanation]
#   Prompt : Explain Section 174 (Recovery of money from insurer as arrear of land revenue) i...
#   Answer : In simple words, Section 174 of the Code of Civil Procedure, 1908 deals with Rec...
#   Score  : 2/5  — The model incorrectly refers to the Code of Civil Procedure instead of the Motor Vehicles Act, and misinterprets the section's purpose.
#
# [15/150] [Direct Q&A]
#   Prompt : What does Section 253 of Code of Criminal Procedure, 1973 state?...
#   Answer : When the accused is not represented by a pleader, the Magistrate shall, before p...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing the process for pleading guilty rather than the specific provisions of Section 253.
#
# [16/150] [Explanation]
#   Prompt : Explain Section 171G of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 9: offences relating to elections
# Section 171G: ...
#   Score  : 2/5  — The model answer incorrectly rephrases the section as about undue influence instead of false statements.
#
# [17/150] [Explanation]
#   Prompt : Explain Section 236 (Abetting in India the counterfeiting out of India of coin) ...
#   Answer : In simple words, Section 236 of the Indian Penal Code, 1860 deals with Abetting ...
#   Score  : 4/5  — The model answer is close to the reference but omits the specific punishment details.
#
# [18/150] [Summarization]
#   Prompt : Summarize Section 424 of Indian Penal Code, 1860....
#   Answer : Whoever, with intent to cause a person to die, or to cause a person to suffer gr...
#   Score  : 1/5  — The model answer is not related to Section 424 of the Indian Penal Code and instead refers to Section 307, which deals with criminal intent.
#
# [19/150] [Explanation]
#   Prompt : Explain Section 238 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 18:
# Section 238: Evidence for prosecut...
#   Score  : 2/5  — The model answer incorrectly describes section 238 as related to evidence and sentencing, while the reference correctly states it pertains to compliance with section 207.
#
# [20/150] [Direct Q&A]
#   Prompt : What does Section 99 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note or bill of exchange has been dishonoured by non-acceptanc...
#   Score  : 4/5  — The model answer captures the essence of section 99 but includes unnecessary details about 'being previously noted for non-payment' and 'also the date of maturity', which are not part of the original text.
#
# [21/150] [Direct Q&A]
#   Prompt : What does Section 125 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[125. Power of Central Government to make rules.--(1) The Central Government ma...
#   Score  : 1/5  — The model answer is not related to the question asked and provides rules instead of the stated provision.
#
# [22/150] [Direct Q&A]
#   Prompt : What does Section 157 of Code of Criminal Procedure, 1973 state?...
#   Answer : When a complaint of a non-cognizable offence is made to a police officer, he sha...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect regarding the content of Section 157.
#
# [23/150] [Explanation]
#   Prompt : Explain Section 284 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 22:
# Section 284: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes a different section of the Code of Criminal Procedure, 1973.
#
# [24/150] [Direct Q&A]
#   Prompt : What does Section 89 of Code of Civil Procedure, 1908 state?...
#   Answer : The Court may, in the case of a suit by or against the Ruler of a foreign State,...
#   Score  : 1/5  — The model answer is not related to Section 89 of the Code of Civil Procedure, 1908, and thus is completely incorrect.
#
# [25/150] [Explanation]
#   Prompt : Explain Section 164 (Recording of confessions and statements) in simple terms....
#   Answer : In simple words, Section 164 of the Code of Criminal Procedure, 1973 deals with ...
#   Score  : 2/5  — The model answer incorrectly states that all statements are considered confessions and omits the role of magistrates.
#
# [26/150] [Act Identification]
#   Prompt : Under which Act does Section 94 titled 'Act to which a person is compelled by th...
#   Answer : Section 94 titled 'Act to which a person is compelled by threats' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [27/150] [Explanation]
#   Prompt : Explain Section 108 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 7:
# Section 108: Procedure of Magistrat...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing a different section of the Code of Criminal Procedure.
#
# [28/150] [Summarization]
#   Prompt : Summarize Section 290 of Indian Penal Code, 1860....
#   Answer : Whoever, being a public servant, legally bound as such public servant to keep in...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [29/150] [Explanation]
#   Prompt : Explain Section 346 (Wrongful confinement in secret) in simple terms....
#   Answer : In simple words, Section 346 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer captures the essence of wrongful confinement in secret but omits the specific requirement of hiding the confinement from interested parties or public servants.
#
# [30/150] [Act Identification]
#   Prompt : Under which Act does Section 321 titled 'Voluntarily causing hurt' fall?...
#   Answer : Section 321 titled 'Voluntarily causing hurt' falls under the Indian Penal Code,...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [31/150] [Direct Q&A]
#   Prompt : What does Section 158 of Indian Evidence Act, 1872 state?...
#   Answer : No confession or admission made to a police officer, by a person who afterwards ...
#   Score  : 1/5  — The model answer is not related to Section 158 of the Indian Evidence Act, 1872 and instead refers to sections of the Code of Criminal Procedure, 1973.
#
# [32/150] [Explanation]
#   Prompt : Explain Section 337 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 24:
# Section 337: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes Section 337, which is about lunatic prisoners, instead of the correct topic of multiple offenses.
#
# [33/150] [Direct Q&A]
#   Prompt : What does Section 265A of Code of Criminal Procedure, 1973 state?...
#   Answer : The provisions of this Chapter shall have effect notwithstanding anything incons...
#   Score  : 1/5  — The model answer is not related to the content of Section 265A and is instead a general provision from the Code of Criminal Procedure.
#
# [34/150] [Explanation]
#   Prompt : Explain Section 40 (Transfer of decree to Court in another State) in simple term...
#   Answer : In simple words, Section 40 of the Code of Civil Procedure, 1908 deals with Tran...
#   Score  : 4/5  — The model answer captures the key legal meaning but omits the specific mention of 'rules in force in that State' from the reference answer.
#
# [35/150] [Act Identification]
#   Prompt : Under which Act does Section 123 titled 'Concealing with intent to facilitate de...
#   Answer : Section 123 titled 'Concealing with intent to facilitate design to wage war' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [36/150] [Summarization]
#   Prompt : Summarize Section 373 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes pain, shall be punished with imprisonment of either d...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [37/150] [Explanation]
#   Prompt : Explain Section 343 (Wrongful confinement for three or more days) in simple term...
#   Answer : In simple words, Section 343 of the Indian Penal Code, 1860 deals with Wrongful ...
#   Score  : 4/5  — The model answer includes additional elements not present in the reference answer, such as the intent to cause death, grievous hurt, or extortion, which are not part of Section 343.
#
# [38/150] [Direct Q&A]
#   Prompt : What does Section 358 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes grievous hurt to any person, in order to the committi...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to grievous hurt instead of assault or criminal force under Section 358.
#
# [39/150] [Act Identification]
#   Prompt : Under which Act does Section 264 titled 'Fraudulent use of false instrument for ...
#   Answer : Section 264 titled 'Fraudulent use of false instrument for weighing' falls under...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [40/150] [Summarization]
#   Prompt : Summarize Section 25 of Code of Civil Procedure, 1908....
#   Answer : (1) In a suit instituted against a public officer in respect of any act purporti...
#   Score  : 1/5  — The model answer is not related to Section 25 of the Code of Civil Procedure, 1908, and instead discusses defenses in suits involving public officers and the definition of 'Government'.
#
# [41/150] [Act Identification]
#   Prompt : Under which Act does Section 131 titled 'Power of certain armed force officers t...
#   Answer : Section 131 titled 'Power of certain armed force officers to disperse assembly' ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [42/150] [Summarization]
#   Prompt : Summarize Section 14 of Motor Vehicles Act, 1988....
#   Answer : (1) Subject to the provisions of this Act and to such rules as the Central Gover...
#   Score  : 1/5  — The model answer is completely unrelated and does not address the content of Section 14 of the Motor Vehicles Act, 1988.
#
# [43/150] [Act Identification]
#   Prompt : Under which Act does Section 306 titled 'Tender of pardon to accomplice' fall?...
#   Answer : Section 306 titled 'Tender of pardon to accomplice' falls under the Code of Crim...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [44/150] [Act Identification]
#   Prompt : Under which Act does Section 133 titled 'Conditional order for removal of nuisan...
#   Answer : Section 133 titled 'Conditional order for removal of nuisance' falls under the C...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [45/150] [Summarization]
#   Prompt : Summarize Section 62 of Negotiable Instruments Act, 1881....
#   Answer : The holder of a cheque, who is not the drawer, may transmit the cheque, by endor...
#   Score  : 1/5  — The model answer is completely unrelated to Section 62 of the Negotiable Instruments Act, 1881.
#
# [46/150] [Explanation]
#   Prompt : Explain Section 139 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 139: Power to issue commissions...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 139 and provides an incorrect description of its content.
#
# [47/150] [Direct Q&A]
#   Prompt : What does Section 18 of Indian Divorce Act, 1869 state?...
#   Answer : 1[18. Maintenance of certificates of divorce and nullity.-- The certificates ref...
#   Score  : 1/5  — The model answer is not legally equivalent to the reference answer and provides an incorrect statement about maintenance of certificates rather than the content of Section 18 regarding nullity petitions.
#
# [48/150] [Act Identification]
#   Prompt : Under which Act does Section 104A titled 'When noting equivalent to protest' fal...
#   Answer : Section 104A titled 'When noting equivalent to protest' falls under the Negotiab...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [49/150] [Direct Q&A]
#   Prompt : What does Section 178 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Any person driving a motor vehicle in any public place shall make to the rig...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, not matching the reference at all.
#
# [50/150] [Act Identification]
#   Prompt : Under which Act does Section 47 titled 'Questions to be determined by the Court ...
#   Answer : Section 47 titled 'Questions to be determined by the Court executing decree' fal...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [51/150] [Summarization]
#   Prompt : Summarize Section 336 of Indian Penal Code, 1860....
#   Answer : Whoever voluntarily causes grievous hurt to any person, in order to the committi...
#   Score  : 2/5  — The model answer describes a different section of the IPC, specifically Section 338, rather than Section 336.
#
# [52/150] [Act Identification]
#   Prompt : Under which Act does Section 69 titled '[Repealed]' fall?...
#   Answer : Section 69 titled '[Repealed]' falls under the Code of Civil Procedure, 1908....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [53/150] [Act Identification]
#   Prompt : Under which Act does Section 443 titled 'Power to order sufficient bail when tha...
#   Answer : Section 443 titled 'Power to order sufficient bail when that first taken is insu...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [54/150] [Act Identification]
#   Prompt : Under which Act does Section 2 titled 'Punishment of offences committed within I...
#   Answer : Section 2 titled 'Punishment of offences committed within India' falls under the...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [55/150] [Explanation]
#   Prompt : Explain Section 406 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 406: Power to direct tende...
#   Score  : 2/5  — The model answer incorrectly describes Section 406 as relating to a power to direct tender of pardon, which is not accurate.
#
# [56/150] [Act Identification]
#   Prompt : Under which Act does Section 229 titled 'Conviction on plea of guilty' fall?...
#   Answer : Section 229 titled 'Conviction on plea of guilty' falls under the Code of Crimin...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [57/150] [Summarization]
#   Prompt : Summarize Section 478 of Code of Criminal Procedure, 1973....
#   Answer : When a Court in India, in the exercise of its powers under section 476 or sectio...
#   Score  : 1/5  — The model answer is not related to Section 478 of the Code of Criminal Procedure, 1973.
#
# [58/150] [Explanation]
#   Prompt : Explain Section 100 (Saving of provisions of Indian Succession Act relating to w...
#   Answer : In simple words, Section 100 of the Indian Evidence Act, 1872 deals with Saving ...
#   Score  : 4/5  — The model answer is close but incorrectly mentions 'execution, delivery and registration' which are not part of Section 100.
#
# [59/150] [Explanation]
#   Prompt : Explain Section 169 (Procedure and powers of Claims Tribunals) in simple terms....
#   Answer : In simple words, Section 169 of the Motor Vehicles Act, 1988 deals with Procedur...
#   Score  : 4/5  — The model captures the essence of the section but omits the summary procedure and the enforcement of evidence and documents, which are key aspects.
#
# [60/150] [Summarization]
#   Prompt : Summarize Section 128 of Motor Vehicles Act, 1988....
#   Answer : 1[128. Duty to give information as to certain offences.--(1) Any person, being r...
#   Score  : 1/5  — The model answer is completely unrelated to the question about Section 128 of the Motor Vehicles Act, 1988.
#
# [61/150] [Explanation]
#   Prompt : Explain Section 375 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 27:
# Section 375: Procedure when Magist...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect, discussing a different section of the code.
#
# [62/150] [Act Identification]
#   Prompt : Under which Act does Section 63 titled 'Secondary evidence' fall?...
#   Answer : Section 63 titled 'Secondary evidence' falls under the Indian Evidence Act, 1872...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [63/150] [Explanation]
#   Prompt : Explain Section 12 (Bar to further suit) in simple terms....
#   Answer : In simple words, Section 12 of the Code of Civil Procedure, 1908 deals with Bar ...
#   Score  : 2/5  — The model answer incorrectly describes the bar to further suit as relating to second appeals rather than the prohibition of filing a new suit.
#
# [64/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Security for keeping the peace on convi...
#   Answer : Section 106 titled 'Security for keeping the peace on conviction' falls under th...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [65/150] [Explanation]
#   Prompt : Explain Section 149 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 8: offences against the public tranquillity
# Sect...
#   Score  : 2/5  — The model answer incorrectly interprets Section 149 as abetting a riot instead of defining liability for offenses committed by members of an unlawful assembly.
#
# [66/150] [Explanation]
#   Prompt : Explain Section 479 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 36:
# Section 479: Procedure in case of ...
#   Score  : 2/5  — The model answer incorrectly describes Section 479 as dealing with minors, while the reference answer correctly explains the section regarding personal interest of judges and magistrates.
#
# [67/150] [Explanation]
#   Prompt : Explain Section 198A of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 198A: Penalty for contravention of s...
#   Score  : 2/5  — The model answer incorrectly identifies Section 198A as related to unattended railway level crossings instead of road design, construction, and maintenance.
#
# [68/150] [Direct Q&A]
#   Prompt : What does Section 134 of Motor Vehicles Act, 1988 state?...
#   Answer : 1[134. Punishment for failing to comply with safety measures.--(1) Whoever drive...
#   Score  : 2/5  — The model answer incorrectly focuses on punishment for non-compliance with safety measures instead of the duty to provide medical attention after an accident.
#
# [69/150] [Act Identification]
#   Prompt : Under which Act does Section 124 titled 'Security for unexpired period of bond' ...
#   Answer : Section 124 titled 'Security for unexpired period of bond' falls under the Code ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [70/150] [Act Identification]
#   Prompt : Under which Act does Section 267 titled 'Power to require attendance of prisoner...
#   Answer : Section 267 titled 'Power to require attendance of prisoners' falls under the Co...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [71/150] [Explanation]
#   Prompt : Explain Section 23 (Decree in proceedings.) in simple terms....
#   Answer : In simple words, Section 23 of the Indian Divorce Act, 1869 deals with Decree in...
#   Score  : 2/5  — The model incorrectly refers to the Indian Divorce Act instead of the Hindu Marriage Act and omits key elements of the definition.
#
# [72/150] [Explanation]
#   Prompt : Explain Section 166 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 166: Production of documents or e...
#   Score  : 2/5  — The model answer incorrectly describes Section 166 as relating to the production of documents instead of the power of juries or assessors to put questions.
#
# [73/150] [Explanation]
#   Prompt : Explain Section 45 (Protection of members of the Armed Forces from arrest) in si...
#   Answer : In simple words, Section 45 of the Code of Criminal Procedure, 1973 deals with P...
#   Score  : 4/5  — The model answer captures the core legal meaning but omits the specific reference to 'discharge of his official duties' and the potential application to other categories of forces as mentioned in the reference answer.
#
# [74/150] [Summarization]
#   Prompt : Summarize Section 161 of Code of Criminal Procedure, 1973....
#   Answer : When a police officer has completed the examination of a person in the course of...
#   Score  : 1/5  — The model answer is completely unrelated to the content of Section 161 of the Code of Criminal Procedure, 1973.
#
# [75/150] [Explanation]
#   Prompt : Explain Section 64 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 3: punishments
# Section 64: Punishment of abetmen...
#   Score  : 2/5  — The model answer incorrectly describes Section 64, which is about fines, not abetment.
#
# [76/150] [Act Identification]
#   Prompt : Under which Act does Section 106 titled 'Disposal of article found in vehicles' ...
#   Answer : Section 106 titled 'Disposal of article found in vehicles' falls under the Motor...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [77/150] [Explanation]
#   Prompt : Explain Section 92 (Voidance of contracts restrictive of liability) in simple te...
#   Answer : In simple words, Section 92 of the Motor Vehicles Act, 1988 deals with Voidance ...
#   Score  : 2/5  — The model answer incorrectly describes the section as dealing with voidance of contracts restrictive of liability when it actually pertains to refunds for passengers.
#
# [78/150] [Explanation]
#   Prompt : Explain Section 237 (Import or export of counterfeit coin) in simple terms....
#   Answer : In simple words, Section 237 of the Indian Penal Code, 1860 deals with Import or...
#   Score  : 4/5  — The model answer is close but incorrectly states the maximum term of imprisonment as seven years instead of three years.
#
# [79/150] [Direct Q&A]
#   Prompt : What does Section 124 of Code of Civil Procedure, 1908 state?...
#   Answer : Nothing in this Code shall be deemed to confer upon any person the right to inst...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [80/150] [Summarization]
#   Prompt : Summarize Section 112 of Motor Vehicles Act, 1988....
#   Answer : (1) The Central Government may, by notification in the Official Gazette, make re...
#   Score  : 1/5  — The model answer is not related to the content of Section 112 of the Motor Vehicles Act, 1988, and instead discusses regulations for armed forces personnel.
#
# [81/150] [Explanation]
#   Prompt : Explain Section 8 (Registration of Hindu marriages.) in simple terms....
#   Answer : In simple words, Section 8 of the Hindu Marriage Act, 1955 deals with Registrati...
#   Score  : 2/5  — The model answer contains notable legal errors and omissions, such as discussing dowry and marriage ceremonies instead of registration.
#
# [82/150] [Summarization]
#   Prompt : Summarize Section 7 of Code of Civil Procedure, 1908....
#   Answer : The Court shall not, in executing a decree, issue process for the arrest of a pe...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [83/150] [Act Identification]
#   Prompt : Under which Act does Section 36 titled 'Effect caused partly by act and partly b...
#   Answer : Section 36 titled 'Effect caused partly by act and partly by omission' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [84/150] [Explanation]
#   Prompt : Explain Section 128 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 6: offences against the state
# Section 128: Breac...
#   Score  : 2/5  — The model answer incorrectly identifies the section as related to unlawful assemblies instead of prisoner escapes.
#
# [85/150] [Direct Q&A]
#   Prompt : What does Section 100 of Negotiable Instruments Act, 1881 state?...
#   Answer : When a promissory note or bill of exchange has been dishonoured by non-acceptanc...
#   Score  : 4/5  — The answer captures the core legal meaning but omits the requirement for certification by a notary public and the context of the acceptor's insolvency or credit impeachment.
#
# [86/150] [Summarization]
#   Prompt : Summarize Section 34 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of more offences than one of the same kind committed at...
#   Score  : 1/5  — The model answer is completely unrelated to Section 34 of the Code of Criminal Procedure, 1973.
#
# [87/150] [Act Identification]
#   Prompt : Under which Act does Section 370 titled 'Procedure in case of difference of opin...
#   Answer : Section 370 titled 'Procedure in case of difference of opinion' falls under the ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [88/150] [Explanation]
#   Prompt : Explain Section 376A of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: sexual offences
# Section 376A: Sexual interco...
#   Score  : 4/5  — The model captures the key elements of the punishment but incorrectly identifies the offense as'sexual intercourse by a person guilty of rape' instead of the specific act of causing death or persistent vegetative state.
#
# [89/150] [Explanation]
#   Prompt : Explain Section 147 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 147: Procedure in respect of su...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 147 and provides an incorrect section title.
#
# [90/150] [Summarization]
#   Prompt : Summarize Section 43 of Code of Civil Procedure, 1908....
#   Answer : The Court shall not, in executing a decree for the payment of money, issue a war...
#   Score  : 1/5  — The model answer is not related to the question and does not address Section 43 of the Code of Civil Procedure, 1908.
#
# [91/150] [Explanation]
#   Prompt : Explain Section 34 of the Code of Civil Procedure, 1908....
#   Answer : Code of Civil Procedure, 1908
# Chapter :
# Section 34: [Repealed]
#
# [Collector to b...
#   Score  : 2/5  — The model incorrectly states that Section 34 has been repealed and provides an unrelated provision instead.
#
# [92/150] [Explanation]
#   Prompt : Explain Section 118 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 118: Confession by accused while i...
#   Score  : 2/5  — The model answer incorrectly identifies and explains a different section of the Indian Evidence Act, which is not related to the question asked.
#
# [93/150] [Explanation]
#   Prompt : Explain Section 52 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 52: Cancellation and suspension of d...
#   Score  : 1/5  — The model answer is completely incorrect and irrelevant to the question about Section 52 of the Motor Vehicles Act, 1988.
#
# [94/150] [Explanation]
#   Prompt : Explain Section 365 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 16: kidnapping, abduction, slavery and forced la...
#   Score  : 4/5  — The model answer captures the essence of Section 365 but incorrectly rephrases 'kidnaps or abducts' as 'takes or entices', which is not an accurate representation of the section.
#
# [95/150] [Direct Q&A]
#   Prompt : What does Section 62 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) Subject to the provisions of this Act and to such rules as the Central Gover...
#   Score  : 1/5  — The model answer is not related to Section 62 of the Motor Vehicles Act, 1988 and provides an unrelated section from the Act.
#
# [96/150] [Explanation]
#   Prompt : Explain Section 128 (Safety measures for drivers and pillion riders) in simple t...
#   Answer : In simple words, Section 128 of the Motor Vehicles Act, 1988 deals with Safety m...
#   Score  : 2/5  — The model answer incorrectly focuses on licensing and training instead of safety measures for drivers and pillion riders.
#
# [97/150] [Explanation]
#   Prompt : Explain Section 410 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 17: the receiving  stolen property
# Section 410: ...
#   Score  : 4/5  — The model correctly identifies the section and provides the punishment, but omits the definition of'stolen property' provided in the original section.
#
# [98/150] [Direct Q&A]
#   Prompt : What does Section 46 of Negotiable Instruments Act, 1881 state?...
#   Answer : The maker of a promissory note or a maker or acceptor of a bill of exchange is s...
#   Score  : 1/5  — The model answer is not related to Section 46 of the Negotiable Instruments Act, 1881 and provides incorrect information about dishonour of instruments.
#
# [99/150] [Direct Q&A]
#   Prompt : What does Section 66 of Code of Civil Procedure, 1908 state?...
#   Answer : 1[(1) In a suit instituted against a public officer in respect of an act purport...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [100/150] [Explanation]
#   Prompt : Explain Section 174 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 174: Power to arrest without warrant...
#   Score  : 1/5  — The model answer is completely incorrect and unrelated to the reference answer.
#
# [101/150] [Explanation]
#   Prompt : Explain Section 402 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 30:
# Section 402: Procedure when warran...
#   Score  : 2/5  — The model answer is about a different section of the Code of Criminal Procedure, 1973, and does not address Section 402.
#
# [102/150] [Explanation]
#   Prompt : Explain Section 38 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 38: Transfer of permit
#
# (1) Notwiths...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it misinterprets Section 38 as being about transfer of permits instead of the state government's power to make rules.
#
# [103/150] [Summarization]
#   Prompt : Summarize Section 59 of Indian Divorce Act, 1869....
#   Answer : The decree may, in the case of a marriage solemnized in a State to which this Ac...
#   Score  : 1/5  — The model answer is not related to Section 59 of the Indian Divorce Act, 1869, and instead discusses the execution of decrees.
#
# [104/150] [Direct Q&A]
#   Prompt : What does Section 146 of Code of Civil Procedure, 1908 state?...
#   Answer : Where a decree is for the payment of money, the Court may, in addition to the pr...
#   Score  : 1/5  — The model answer is not related to Section 146 of the Code of Civil Procedure, 1908, which deals with proceedings and applications, not interest rates.
#
# [105/150] [Explanation]
#   Prompt : Explain Section 31 (Liability of drawee of cheque) in simple terms....
#   Answer : In simple words, Section 31 of the Negotiable Instruments Act, 1881 deals with L...
#   Score  : 4/5  — The model answer captures the essence of the drawee's liability but incorrectly states that the drawee must pay upon demand without considering the condition of having sufficient funds.
#
# [106/150] [Act Identification]
#   Prompt : Under which Act does Section 138 titled 'Order of examinations' fall?...
#   Answer : Section 138 titled 'Order of examinations' falls under the Indian Evidence Act, ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [107/150] [Explanation]
#   Prompt : Explain Section 166B of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 11:
# Section 166B: Reporting of non-com...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [108/150] [Explanation]
#   Prompt : Explain Section 116 (Inquiry as to truth of information) in simple terms....
#   Answer : In simple words, Section 116 of the Indian Evidence Act, 1872 deals with Inquiry...
#   Score  : 2/5  — The model incorrectly refers to the Indian Evidence Act instead of the Code of Criminal Procedure, and does not accurately describe the process of inquiry as required by Section 116.
#
# [109/150] [Explanation]
#   Prompt : Explain Section 202 of the Code of Criminal Procedure, 1973....
#   Answer : Code of Criminal Procedure, 1973
# Chapter 16:
# Section 202: Power to summon perso...
#   Score  : 2/5  — The model answer incorrectly describes Section 202 as relating to summoning witnesses instead of postponement of issuing process.
#
# [110/150] [Act Identification]
#   Prompt : Under which Act does Section 7 titled 'Ceremonies for a Hindu marriage.' fall?...
#   Answer : Section 7 titled 'Ceremonies for a Hindu marriage.' falls under the Hindu Marria...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [111/150] [Act Identification]
#   Prompt : Under which Act does Section 265C titled 'Guidelines for mutually satisfactory d...
#   Answer : Section 265C titled 'Guidelines for mutually satisfactory disposition' falls und...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [112/150] [Direct Q&A]
#   Prompt : What does Section 20 of Negotiable Instruments Act, 1881 state?...
#   Answer : In a negotiable instrument not required by law to be noted or protested, any par...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [113/150] [Explanation]
#   Prompt : Explain Section 229A (Failure by person released on bail or bond to appear in Co...
#   Answer : In simple words, Section 229A of the Indian Penal Code, 1860 deals with Failure ...
#   Score  : 4/5  — The model answer captures the essence of the section but incorrectly specifies the maximum punishment as up to one month and 500 rupees instead of one year and a higher fine.
#
# [114/150] [Direct Q&A]
#   Prompt : What does Section 290 of Indian Penal Code, 1860 state?...
#   Answer : Whoever, being a public servant, legally bound as such public servant to keep in...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [115/150] [Explanation]
#   Prompt : Explain Section 36 of the Negotiable Instruments Act, 1881....
#   Answer : Negotiable Instruments Act, 1881
# Chapter 3:
# Section 36: Liability of banker for...
#   Score  : 2/5  — The model answer incorrectly describes Section 36, attributing it to liability of a banker rather than the liability of prior parties to a holder in due course.
#
# [116/150] [Explanation]
#   Prompt : Explain Section 165 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 10:
# Section 165: Public Officers
#
# No public o...
#   Score  : 2/5  — The model answer incorrectly identifies Section 165 as relating to public officers instead of the judge's powers.
#
# [117/150] [Act Identification]
#   Prompt : Under which Act does Section 182 titled 'False information, with intent to cause...
#   Answer : Section 182 titled 'False information, with intent to cause public servant to us...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [118/150] [Act Identification]
#   Prompt : Under which Act does Section 23 titled 'Calculating maturity of bill or note pay...
#   Answer : Section 23 titled 'Calculating maturity of bill or note payable so many months a...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [119/150] [Explanation]
#   Prompt : Explain Section 108A (Abetment in India of offences outside India) in simple ter...
#   Answer : In simple words, Section 108A of the Indian Penal Code, 1860 deals with Abetment...
#   Score  : 2/5  — The model answer incorrectly defines the section as dealing with public servants and negligence, which is not accurate.
#
# [120/150] [Direct Q&A]
#   Prompt : What does Section 339 of Code of Criminal Procedure, 1973 state?...
#   Answer : When the finding states that the accused person committed the act charged but di...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [121/150] [Direct Q&A]
#   Prompt : What does Section 310 of Code of Criminal Procedure, 1973 state?...
#   Answer : When the examination of the witnesses (if any) for the defence is complete, the ...
#   Score  : 1/5  — The model answer is completely unrelated and incorrect.
#
# [122/150] [Explanation]
#   Prompt : Explain Section 171F (Punishment for undue influence or personation at an electi...
#   Answer : In simple words, Section 171F of the Indian Penal Code, 1860 deals with Punishme...
#   Score  : 4/5  — Correct core content but omits the mention of imprisonment as part of the punishment.
#
# [123/150] [Direct Q&A]
#   Prompt : What does Section 376DB of Indian Penal Code, 1860 state?...
#   Answer : Whoever, commits the offence of rape on a woman under sixteen years of age shall...
#   Score  : 2/5  — The model answer incorrectly states the age limit and the punishment, missing the key elements of multiple perpetrators and life imprisonment.
#
# [124/150] [Direct Q&A]
#   Prompt : What does Section 328 of Indian Penal Code, 1860 state?...
#   Answer : Whoever voluntarily causes hurt, if he does so with the intention of disfiguring...
#   Score  : 2/5  — The model answer is partially correct but contains notable legal errors, as it refers to disfiguring the body or face instead of administering poison or stupefying drugs as stated in Section 328.
#
# [125/150] [Summarization]
#   Prompt : Summarize Section 63 of Negotiable Instruments Act, 1881....
#   Answer : When a promissory note or bill of exchange has been dishonoured by non-acceptanc...
#   Score  : 1/5  — The model answer is not related to Section 63 of the Negotiable Instruments Act, 1881, and instead discusses dishonour and presentment for payment, which are different provisions.
#
# [126/150] [Explanation]
#   Prompt : Explain Section 57 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 57: Grounds for decree of nullity
#
# T...
#   Score  : 2/5  — The model answer incorrectly focuses on grounds for decree of nullity instead of explaining Section 57 regarding liberty to remarry.
#
# [127/150] [Summarization]
#   Prompt : Summarize Section 228 of Code of Criminal Procedure, 1973....
#   Answer : When a person is accused of an offence for which there is a special or local law...
#   Score  : 2/5  — The model answer incorrectly suggests that the case is referred to a Chief Judicial Magistrate or Chief Metropolitan Magistrate, whereas the reference indicates the case can be transferred to a lower level Judicial Magistrate.
#
# [128/150] [Act Identification]
#   Prompt : Under which Act does Section 268 titled 'Power of State Government to exclude ce...
#   Answer : Section 268 titled 'Power of State Government to exclude certain persons from op...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [129/150] [Direct Q&A]
#   Prompt : What does Section 171B of Indian Penal Code, 1860 state?...
#   Answer : Whoever commits the offence of bribery shall be punished with imprisonment of ei...
#   Score  : 2/5  — The model answer omits the key elements of the definition of bribery and the conditions under which it applies.
#
# [130/150] [Explanation]
#   Prompt : Explain Section 31 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 31: Grounds for dissolution of marri...
#   Score  : 2/5  — The model answer incorrectly interprets Section 31 as grounds for dissolution of marriage instead of describing the wife's legal position during the continuance of an order of protection.
#
# [131/150] [Direct Q&A]
#   Prompt : What does Section 27 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The Central Government may make rules for the purpose of carrying into effec...
#   Score  : 2/5  — The model answer contains notable legal errors and does not accurately reflect the content of Section 27 of the Motor Vehicles Act, 1988.
#
# [132/150] [Act Identification]
#   Prompt : Under which Act does Section 44 titled 'Production of vehicle at the time of reg...
#   Answer : Section 44 titled 'Production of vehicle at the time of registration' falls unde...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [133/150] [Explanation]
#   Prompt : Explain Section 128 (Payment in due course of crossed cheque) in simple terms....
#   Answer : In simple words, Section 128 of the Negotiable Instruments Act, 1881 deals with ...
#   Score  : 3/5  — The model answer misses the key point about the rights and position of the payee and drawer in relation to the payment of a crossed cheque.
#
# [134/150] [Summarization]
#   Prompt : Summarize Section 40 of Indian Evidence Act, 1872....
#   Answer : When the question is whether a man is alive or dead, and it is shown that he was...
#   Score  : 1/5  — The model answer is not related to Section 40 of the Indian Evidence Act, 1872, and provides an unrelated legal rule.
#
# [135/150] [Act Identification]
#   Prompt : Under which Act does Section 25 titled 'Fraudulently' fall?...
#   Answer : Section 25 titled 'Fraudulently' falls under the Indian Penal Code, 1860....
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [136/150] [Act Identification]
#   Prompt : Under which Act does Section 295A titled 'Deliberate and malicious acts intended...
#   Answer : Section 295A titled 'Deliberate and malicious acts intended to outrage religious...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [137/150] [Act Identification]
#   Prompt : Under which Act does Section 35 titled 'Power of Court to disqualify' fall?...
#   Answer : Section 35 titled 'Power of Court to disqualify' falls under the Motor Vehicles ...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [138/150] [Act Identification]
#   Prompt : Under which Act does Section 108 titled 'Certain powers of State Government exer...
#   Answer : Section 108 titled 'Certain powers of State Government exercisable by the Centra...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [139/150] [Direct Q&A]
#   Prompt : What does Section 119 of Motor Vehicles Act, 1988 state?...
#   Answer : (1) The Central Government may, by notification in the Official Gazette, make ru...
#   Score  : 1/5  — The model answer is not related to Section 119 of the Motor Vehicles Act, 1988 and instead refers to rules-making powers.
#
# [140/150] [Act Identification]
#   Prompt : Under which Act does Section 81 titled 'Duration and renewal of permits' fall?...
#   Answer : Section 81 titled 'Duration and renewal of permits' falls under the Motor Vehicl...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [141/150] [Explanation]
#   Prompt : Explain Section 102 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 6:
# Section 102: Production of document called...
#   Score  : 2/5  — The model answer incorrectly describes Section 102 as relating to the production of documents, while the reference correctly states it concerns the burden of proof.
#
# [142/150] [Act Identification]
#   Prompt : Under which Act does Section 384 titled 'Summary dismissal of appeal' fall?...
#   Answer : Section 384 titled 'Summary dismissal of appeal' falls under the Code of Crimina...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference exactly.
#
# [143/150] [Explanation]
#   Prompt : Explain Section 35 of the Motor Vehicles Act, 1988....
#   Answer : Motor Vehicles Act, 1988
# Chapter :
# Section 35: Suspension of driving licence in...
#   Score  : 3/5  — The model answer incorrectly states that the section deals with suspension of driving licences instead of conductor's licences, and omits the specific period for disqualification.
#
# [144/150] [Act Identification]
#   Prompt : Under which Act does Section 351 titled 'Appeals from convictions under sections...
#   Answer : Section 351 titled 'Appeals from convictions under sections 344, 345, 349 and 35...
#   Score  : 5/5  — The model answer is semantically correct and matches the reference answer exactly.
#
# [145/150] [Explanation]
#   Prompt : Explain Section 171B (Bribery) in simple terms....
#   Answer : In simple words, Section 171B of the Indian Penal Code, 1860 deals with Bribery....
#   Score  : 4/5  — The model captures the essence of Section 171B but omits the key elements of giving or accepting a gratification for electoral rights, and includes an incorrect statement about punishment.
#
# [146/150] [Explanation]
#   Prompt : Explain Section 208 of the Indian Penal Code, 1860....
#   Answer : Indian Penal Code, 1860
# Chapter 12: offences relating to documents and to proper...
#   Score  : 2/5  — The model answer incorrectly identifies Section 208 as related to false documents and misstates the section's actual content.
#
# [147/150] [Direct Q&A]
#   Prompt : What does Section 144 of Negotiable Instruments Act, 1881 state?...
#   Answer : Where a cheque is required, under section 138, to be protested for non-payment, ...
#   Score  : 1/5  — The model answer is not related to Section 144 of the Negotiable Instruments Act, 1881 and provides an incorrect statement about section 138.
#
# [148/150] [Explanation]
#   Prompt : Explain Section 117 of the Indian Evidence Act, 1872....
#   Answer : Indian Evidence Act, 1872
# Chapter 7:
# Section 117: Production of document called...
#   Score  : 2/5  — The model answer incorrectly describes Section 117 as relating to the production of documents, whereas it actually pertains to estoppel in relation to bills of exchange, bails, and licenses.
#
# [149/150] [Explanation]
#   Prompt : Explain Section 6 of the Indian Divorce Act, 1869....
#   Answer : Indian Divorce Act, 1869
# Chapter :
# Section 6: Grounds of decree
#
# The following ...
#   Score  : 2/5  — The model answer incorrectly interprets Section 6 as dealing with grounds for a decree of nullity rather than addressing how pending suits are handled.
#
# [150/150] [Summarization]
#   Prompt : Summarize Section 105 of Indian Penal Code, 1860....
#   Answer : Whoever commits an offence punishable with imprisonment which includes imprisonm...
#   Score  : 1/5  — The model answer is not related to the question and does not capture the key legal meaning of Section 105 of the Indian Penal Code.
#
# 💾 Raw results saved → /kaggle/working/results/phase2_eval_qwen3_qlora.json
#
# ============================================================
# 📊  PHASE 2 SUMMARY — QWEN3_QLORA
# ============================================================
#   Scored      : 150 / 150 samples
#   Overall avg : 2.70 / 5.0
#
#   Score distribution:
#     5/5  ██████████████████████████████████████ (38)
#     4/5  ██████████████████ (18)
#     3/5  ██ (2)
#     2/5  █████████████████████████████████████████████ (45)
#     1/5  ███████████████████████████████████████████████ (47)
#
#   By task type:
#     Act Identification   avg=4.92  (n=39)
#     Direct Q&A           avg=1.39  (n=31)
#     Explanation          avg=2.49  (n=59)
#     Summarization        avg=1.10  (n=21)
# ============================================================
