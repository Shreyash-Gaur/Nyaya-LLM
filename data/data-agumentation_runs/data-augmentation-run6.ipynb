# %%
# !pip install jsonschema transformers accelerate sentencepiece bitsandbytes tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.7 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
"""
==============================================================
Nyaya-LLM  —  Phase 2 Dataset Augmentation (Kaggle / P100)
==============================================================
Augments all three splits (train, val, test) using a
HuggingFace model loaded directly on the P100 GPU.

Long sections (>3000 chars) are chunked at subsection
boundaries so every part of the statute gets covered.
==============================================================
"""

import json
import re
import os
import time
import torch
import shutil
import gc
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from jsonschema import validate, ValidationError

# ==============================
# ⚙️  CONFIG
# ==============================
MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"

# ── Paths ───────────────────────────────────────────────────
INPUT_DIR  = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"
OUTPUT_DIR = "/kaggle/working/augmented"
WIP_DATASET_PATH = "/kaggle/input/datasets/shreyashgaurgla/nyaya-augmented-wip" # For Run 2+

SPLITS = {
    "train": "all_acts_train.jsonl"
}

# ── Processing Limits ───────────────────────────────────────
CHUNK_SIZE  = 3000    
RETRY_LIMIT = 3       
MAX_RUNTIME_HOURS = 10.4

# ==============================
# 📦  JSON SCHEMA
# ==============================
AUGMENT_SCHEMA = {
    "type": "object",
    "properties": {
        "instruction": {"type": "string"},
        "input":       {"type": "string"},
        "output":      {"type": "string"}
    },
    "required": ["instruction", "input", "output"]
}

# ==============================
# 💬  PROMPT (CHAT TEMPLATE)
# ==============================
SYSTEM_PROMPT = """You are a strict Indian legal dataset generator.

RULES:
1. Only use the provided statute text. Do NOT add outside legal knowledge.
2. Do NOT invent punishments, sections, or acts not mentioned in the text.
3. Output STRICT JSON only. No markdown, no explanation, no preamble.
4. Return exactly ONE valid JSON object.
5. The instruction must be a realistic question a layperson or law student would ask.
6. The output must apply or explain the statute — not just quote it verbatim."""

def build_messages(original_instruction: str, chunk: str) -> list:
    user_msg = f"""ORIGINAL INSTRUCTION:
{original_instruction}

STATUTE TEXT:
{chunk}

---
Generate a new, enriched training example that:
- Asks a reasoning or application question about this statute text
- Answers it using ONLY the information in the statute text above
- Does NOT reference sections or provisions outside the text above

Respond ONLY with this JSON format, nothing else:
{{
  "instruction": "...",
  "input": "",
  "output": "..."
}}"""

    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg}
    ]

# ==============================
# ✂️  CHUNKER
# ==============================
def chunk_text(text: str, max_chars: int = CHUNK_SIZE) -> list:
    if len(text) <= max_chars:
        return [text]

    parts   = text.split("\n\n")
    chunks  = []
    current = ""

    for part in parts:
        if len(part) > max_chars:
            if current:
                chunks.append(current.strip())
                current = ""
            sentences = re.split(r'(?<=[.;])\s+', part)
            for sentence in sentences:
                if len(current) + len(sentence) <= max_chars:
                    current += " " + sentence
                else:
                    if current:
                        chunks.append(current.strip())
                    current = sentence
        elif len(current) + len(part) + 2 <= max_chars:
            current += "\n\n" + part
        else:
            if current:
                chunks.append(current.strip())
            current = part

    if current:
        chunks.append(current.strip())

    return [c for c in chunks if len(c) >= 50]

# ==============================
# 🤖  MODEL LOADING
# ==============================
def load_model():
    print(f"Loading {MODEL_NAME} in 4-bit on GPU...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16, 
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.float16,
        trust_remote_code=True
    )
    model.eval()
    print("Model loaded.\n")
    return model, tokenizer

# ==============================
# 🔁  GENERATION (WITH OOM KILLER)
# ==============================
def generate(model, tokenizer, messages: list) -> str:
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.2,
            do_sample=True,
            top_p=0.8,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id
        )

    new_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    result = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    
    del inputs
    del outputs
    del new_tokens
    torch.cuda.empty_cache()
    gc.collect()
    
    return result

# ==============================
# 🔍  JSON EXTRACTION
# ==============================
def extract_json(text: str):
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        return None
    try:
        return json.loads(match.group())
    except Exception:
        return None

# ==============================
# 🛡️  HALLUCINATION GUARD 
# ==============================
def hallucination_guard(original_text: str, generated_output: str) -> bool:
    orig_words  = set(re.findall(r'\w+', original_text.lower()))
    gen_words   = set(re.findall(r'\w+', generated_output.lower()))
    overlap     = len(orig_words & gen_words)

    # Dynamically require either 8 words, OR 30% of the chunk (whichever is smaller)
    required_overlap = min(7, len(orig_words) // 3)
    
    return overlap >= required_overlap

# ==============================
# 💾  CHECKPOINT HELPER
# ==============================
def load_processed_keys(output_path: str) -> set:
    processed = set()
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    key = (obj.get("source_instruction", ""), obj.get("chunk_index", 0))
                    processed.add(key)
                except Exception:
                    pass
    return processed

# ==============================
# 🚀  MAIN
# ==============================
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # --- RUN 2 RESTORATION LOGIC ---
    if os.path.exists(WIP_DATASET_PATH):
        print("Restoring previous progress from WIP dataset...")
        for filename in os.listdir(WIP_DATASET_PATH):
            if filename.endswith(".jsonl"):
                src = os.path.join(WIP_DATASET_PATH, filename)
                dst = os.path.join(OUTPUT_DIR, filename)
                shutil.copy2(src, dst)
                print(f"✅ Restored: {filename}")
        print("Ready to resume!\n")
    # -------------------------------
    
    START_TIME = time.time()
    MAX_RUNTIME_SEC = MAX_RUNTIME_HOURS * 3600 

    model, tokenizer = load_model()

    total_written = 0
    total_skipped = 0

    for split_name, filename in SPLITS.items():
        input_path  = os.path.join(INPUT_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, f"all_acts_{split_name}_augmented.jsonl")

        if not os.path.exists(input_path):
            print(f"⚠️  {input_path} not found — skipping {split_name}")
            continue

        with open(input_path, "r", encoding="utf-8") as f:
            data = [json.loads(line) for line in f]

        processed_keys = load_processed_keys(output_path)
        total_chunks = sum(len(chunk_text(d["output"])) for d in data)

        print(f"\n{'='*60}")
        print(f"📂  Split         : {split_name.upper()}")
        print(f"    Samples       : {len(data)}")
        print(f"    Total chunks  : {total_chunks}")
        print(f"    Already done  : {len(processed_keys)}")
        print(f"    Remaining     : {total_chunks - len(processed_keys)}")
        print(f"{'='*60}\n")

        split_written = 0
        split_skipped = 0

        pbar = tqdm(data, desc=f"Augmenting {split_name}")
        with open(output_path, "a", encoding="utf-8") as outfile:
            for example in pbar:
                instruction = example["instruction"]
                chunks      = chunk_text(example["output"])

                for chunk_idx, chunk in enumerate(chunks):
                    
                    if time.time() - START_TIME > MAX_RUNTIME_SEC:
                        print(f"\n⚠️ REACHED {MAX_RUNTIME_HOURS} HOURS. GRACEFULLY STOPPING.")
                        print(f"📊 Stats this run -> Written: {split_written} | Skipped: {split_skipped}")
                        print(f"💾 Files safely saved to: {OUTPUT_DIR}")
                        return 
                    
                    key = (instruction, chunk_idx)

                    if key in processed_keys:
                        continue

                    retries = 0
                    success = False

                    while retries < RETRY_LIMIT and not success:
                        try:
                            messages = build_messages(instruction, chunk)
                            raw      = generate(model, tokenizer, messages)
                            parsed   = extract_json(raw)

                            if parsed is None:
                                raise ValueError("No JSON found")

                            validate(instance=parsed, schema=AUGMENT_SCHEMA)

                            if not hallucination_guard(chunk, parsed["output"]):
                                raise ValueError("Hallucination guard failed")

                            parsed["source_instruction"] = instruction
                            parsed["chunk_index"]        = chunk_idx
                            parsed["total_chunks"]       = len(chunks)
                            parsed["split"]              = split_name

                            outfile.write(json.dumps(parsed, ensure_ascii=False) + "\n")
                            outfile.flush()
                            success       = True
                            split_written += 1

                        except (ValidationError, ValueError):
                            retries += 1
                            time.sleep(0.2)
                        except Exception as e:
                            print(f"\n❌ Unexpected error: {e}")
                            retries += 1
                            time.sleep(1)

                    if not success:
                        split_skipped += 1
                        
                    # LIVE TRACKER: Updates the progress bar with real-time stats!
                    pbar.set_postfix({"Written": split_written, "Skipped": split_skipped})

        total_written += split_written
        total_skipped += split_skipped

        print(f"\n✅  {split_name} done")
        print(f"    Written : {split_written}")
        print(f"    Skipped : {split_skipped}")
        print(f"    Saved   : {output_path}")

    print(f"\n{'='*60}")
    print(f"🏁  AUGMENTATION COMPLETE")
    print(f"    Total written : {total_written}")
    print(f"    Total skipped : {total_skipped}")
    print(f"    Output dir    : {OUTPUT_DIR}")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# Restoring previous progress from WIP dataset...
# ✅ Restored: all_acts_train_augmented.jsonl
# Ready to resume!
#
# Loading Qwen/Qwen2.5-7B-Instruct in 4-bit on GPU...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded.
#
#
# ============================================================
# 📂  Split         : TRAIN
#     Samples       : 7752
#     Total chunks  : 7935
#     Already done  : 5746
#     Remaining     : 2189
# ============================================================
# Augmenting train:   0%|          | 0/7752 [00:00<?, ?it/s]
# Augmenting train:   0%|          | 0/7752 [00:16<?, ?it/s, Written=1, Skipped=0]
# Augmenting train:   0%|          | 1/7752 [00:16<34:44:57, 16.14s/it, Written=1, Skipped=0]
# Augmenting train:   0%|          | 1/7752 [00:21<34:44:57, 16.14s/it, Written=2, Skipped=0]
# Augmenting train:   0%|          | 3/7752 [00:21<12:53:05,  5.99s/it, Written=2, Skipped=0]
# Augmenting train:   0%|          | 3/7752 [00:25<12:53:05,  5.99s/it, Written=3, Skipped=0]
# Augmenting train:   0%|          | 8/7752 [00:25<5:02:50,  2.35s/it, Written=3, Skipped=0]
# Augmenting train:   0%|          | 8/7752 [00:39<5:02:50,  2.35s/it, Written=3, Skipped=1]
# Augmenting train:   0%|          | 33/7752 [00:39<1:48:03,  1.19it/s, Written=3, Skipped=1]
# Augmenting train:   0%|          | 33/7752 [00:55<1:48:03,  1.19it/s, Written=4, Skipped=1]
# Augmenting train:   0%|          | 36/7752 [00:55<3:02:05,  1.42s/it, Written=4, Skipped=1]
# Augmenting train:   0%|          | 36/7752 [01:02<3:02:05,  1.42s/it, Written=5, Skipped=1]
# Augmenting train:   0%|          | 37/7752 [01:02<3:36:53,  1.69s/it, Written=5, Skipped=1]
# Augmenting train:   0%|          | 37/7752 [01:07<3:36:53,  1.69s/it, Written=6, Skipped=1]
# Augmenting train:   1%|          | 41/7752 [01:07<3:24:07,  1.59s/it, Written=6, Skipped=1]
# Augmenting train:   1%|          | 41/7752 [01:12<3:24:07,  1.59s/it, Written=7, Skipped=1]
# Augmenting train:   1%|          | 46/7752 [01:12<3:04:20,  1.44s/it, Written=7, Skipped=1]
# Augmenting train:   1%|          | 46/7752 [01:17<3:04:20,  1.44s/it, Written=8, Skipped=1]
# Augmenting train:   1%|          | 48/7752 [01:17<3:22:31,  1.58s/it, Written=8, Skipped=1]
# Augmenting train:   1%|          | 48/7752 [01:23<3:22:31,  1.58s/it, Written=9, Skipped=1]
# Augmenting train:   1%|          | 58/7752 [01:23<2:16:59,  1.07s/it, Written=9, Skipped=1]
# Augmenting train:   1%|          | 58/7752 [01:37<2:16:59,  1.07s/it, Written=10, Skipped=1]
# Augmenting train:   1%|          | 62/7752 [01:37<3:29:23,  1.63s/it, Written=10, Skipped=1]
# Augmenting train:   1%|          | 62/7752 [01:53<3:29:23,  1.63s/it, Written=10, Skipped=2]
# Augmenting train:   1%|          | 65/7752 [01:53<5:01:50,  2.36s/it, Written=10, Skipped=2]
# Augmenting train:   1%|          | 65/7752 [01:57<5:01:50,  2.36s/it, Written=11, Skipped=2]
# Augmenting train:   1%|          | 67/7752 [01:57<4:58:17,  2.33s/it, Written=11, Skipped=2]
# Augmenting train:   1%|          | 67/7752 [02:03<4:58:17,  2.33s/it, Written=12, Skipped=2]
# Augmenting train:   1%|          | 68/7752 [02:03<5:35:48,  2.62s/it, Written=12, Skipped=2]
# Augmenting train:   1%|          | 68/7752 [02:14<5:35:48,  2.62s/it, Written=12, Skipped=3]
# Augmenting train:   1%|          | 69/7752 [02:14<7:55:27,  3.71s/it, Written=12, Skipped=3]
# Augmenting train:   1%|          | 69/7752 [02:29<7:55:27,  3.71s/it, Written=12, Skipped=4]
# Augmenting train:   1%|          | 71/7752 [02:29<10:01:20,  4.70s/it, Written=12, Skipped=4]
# Augmenting train:   1%|          | 71/7752 [02:34<10:01:20,  4.70s/it, Written=13, Skipped=4]
# Augmenting train:   1%|          | 73/7752 [02:34<8:43:31,  4.09s/it, Written=13, Skipped=4]
# Augmenting train:   1%|          | 73/7752 [02:50<8:43:31,  4.09s/it, Written=13, Skipped=5]
# Augmenting train:   1%|          | 79/7752 [02:50<7:07:24,  3.34s/it, Written=13, Skipped=5]
# Augmenting train:   1%|          | 79/7752 [02:53<7:07:24,  3.34s/it, Written=14, Skipped=5]
# Augmenting train:   1%|          | 85/7752 [02:53<4:32:00,  2.13s/it, Written=14, Skipped=5]
# Augmenting train:   1%|          | 85/7752 [03:09<4:32:00,  2.13s/it, Written=14, Skipped=6]
# Augmenting train:   1%|          | 92/7752 [03:09<4:36:02,  2.16s/it, Written=14, Skipped=6]
# Augmenting train:   1%|          | 92/7752 [03:16<4:36:02,  2.16s/it, Written=15, Skipped=6]
# Augmenting train:   1%|▏         | 97/7752 [03:16<4:09:27,  1.96s/it, Written=15, Skipped=6]
# Augmenting train:   1%|▏         | 97/7752 [03:21<4:09:27,  1.96s/it, Written=16, Skipped=6]
# Augmenting train:   1%|▏         | 100/7752 [03:21<4:04:03,  1.91s/it, Written=16, Skipped=6]
# Augmenting train:   1%|▏         | 100/7752 [03:38<4:04:03,  1.91s/it, Written=16, Skipped=7]
# Augmenting train:   1%|▏         | 105/7752 [03:38<4:58:44,  2.34s/it, Written=16, Skipped=7]
# Augmenting train:   1%|▏         | 105/7752 [03:52<4:58:44,  2.34s/it, Written=16, Skipped=8]
# Augmenting train:   1%|▏         | 108/7752 [03:52<6:04:48,  2.86s/it, Written=16, Skipped=8]
# Augmenting train:   1%|▏         | 108/7752 [04:06<6:04:48,  2.86s/it, Written=16, Skipped=9]
# Augmenting train:   1%|▏         | 115/7752 [04:06<5:24:24,  2.55s/it, Written=16, Skipped=9]
# Augmenting train:   1%|▏         | 115/7752 [04:12<5:24:24,  2.55s/it, Written=17, Skipped=9]
# Augmenting train:   2%|▏         | 121/7752 [04:12<4:11:08,  1.97s/it, Written=17, Skipped=9]
# Augmenting train:   2%|▏         | 121/7752 [04:29<4:11:08,  1.97s/it, Written=17, Skipped=10]
# Augmenting train:   2%|▏         | 123/7752 [04:29<6:07:44,  2.89s/it, Written=17, Skipped=10]
# Augmenting train:   2%|▏         | 123/7752 [04:46<6:07:44,  2.89s/it, Written=18, Skipped=10]
# Augmenting train:   2%|▏         | 124/7752 [04:46<8:58:00,  4.23s/it, Written=18, Skipped=10]
# Augmenting train:   2%|▏         | 124/7752 [04:59<8:58:00,  4.23s/it, Written=18, Skipped=11]
# Augmenting train:   2%|▏         | 128/7752 [04:59<8:14:25,  3.89s/it, Written=18, Skipped=11]
# Augmenting train:   2%|▏         | 128/7752 [05:04<8:14:25,  3.89s/it, Written=19, Skipped=11]
# Augmenting train:   2%|▏         | 138/7752 [05:04<4:13:33,  2.00s/it, Written=19, Skipped=11]
# Augmenting train:   2%|▏         | 138/7752 [05:19<4:13:33,  2.00s/it, Written=19, Skipped=12]
# Augmenting train:   2%|▏         | 139/7752 [05:19<6:16:25,  2.97s/it, Written=19, Skipped=12]
# Augmenting train:   2%|▏         | 139/7752 [05:25<6:16:25,  2.97s/it, Written=20, Skipped=12]
# Augmenting train:   2%|▏         | 140/7752 [05:25<6:53:58,  3.26s/it, Written=20, Skipped=12]
# Augmenting train:   2%|▏         | 140/7752 [05:41<6:53:58,  3.26s/it, Written=20, Skipped=13]
# Augmenting train:   2%|▏         | 145/7752 [05:41<6:45:44,  3.20s/it, Written=20, Skipped=13]
# Augmenting train:   2%|▏         | 145/7752 [05:48<6:45:44,  3.20s/it, Written=21, Skipped=13]
# Augmenting train:   2%|▏         | 146/7752 [05:48<7:40:47,  3.63s/it, Written=21, Skipped=13]
# Augmenting train:   2%|▏         | 146/7752 [05:53<7:40:47,  3.63s/it, Written=22, Skipped=13]
# Augmenting train:   2%|▏         | 147/7752 [05:53<8:07:08,  3.84s/it, Written=22, Skipped=13]
# Augmenting train:   2%|▏         | 147/7752 [05:58<8:07:08,  3.84s/it, Written=23, Skipped=13]
# Augmenting train:   2%|▏         | 149/7752 [05:58<7:13:45,  3.42s/it, Written=23, Skipped=13]
# Augmenting train:   2%|▏         | 149/7752 [06:18<7:13:45,  3.42s/it, Written=23, Skipped=14]
# Augmenting train:   2%|▏         | 151/7752 [06:18<11:00:23,  5.21s/it, Written=23, Skipped=14]
# Augmenting train:   2%|▏         | 151/7752 [06:23<11:00:23,  5.21s/it, Written=24, Skipped=14]
# Augmenting train:   2%|▏         | 153/7752 [06:23<9:25:20,  4.46s/it, Written=24, Skipped=14]
# Augmenting train:   2%|▏         | 153/7752 [06:28<9:25:20,  4.46s/it, Written=25, Skipped=14]
# Augmenting train:   2%|▏         | 155/7752 [06:28<8:09:01,  3.86s/it, Written=25, Skipped=14]
# Augmenting train:   2%|▏         | 155/7752 [06:43<8:09:01,  3.86s/it, Written=25, Skipped=15]
# Augmenting train:   2%|▏         | 156/7752 [06:43<12:06:25,  5.74s/it, Written=25, Skipped=15]
# Augmenting train:   2%|▏         | 156/7752 [06:47<12:06:25,  5.74s/it, Written=26, Skipped=15]
# Augmenting train:   2%|▏         | 161/7752 [06:47<6:28:34,  3.07s/it, Written=26, Skipped=15]
# Augmenting train:   2%|▏         | 161/7752 [07:01<6:28:34,  3.07s/it, Written=26, Skipped=16]
# Augmenting train:   2%|▏         | 163/7752 [07:01<8:30:22,  4.04s/it, Written=26, Skipped=16]
# Augmenting train:   2%|▏         | 163/7752 [07:17<8:30:22,  4.04s/it, Written=26, Skipped=17]
# Augmenting train:   2%|▏         | 165/7752 [07:17<10:28:52,  4.97s/it, Written=26, Skipped=17]
# Augmenting train:   2%|▏         | 165/7752 [07:33<10:28:52,  4.97s/it, Written=26, Skipped=18]
# Augmenting train:   2%|▏         | 167/7752 [07:33<12:25:20,  5.90s/it, Written=26, Skipped=18]
# Augmenting train:   2%|▏         | 167/7752 [07:48<12:25:20,  5.90s/it, Written=26, Skipped=19]
# Augmenting train:   2%|▏         | 170/7752 [07:48<11:40:56,  5.55s/it, Written=26, Skipped=19]
# Augmenting train:   2%|▏         | 170/7752 [07:56<11:40:56,  5.55s/it, Written=27, Skipped=19]
# Augmenting train:   2%|▏         | 175/7752 [07:56<7:45:43,  3.69s/it, Written=27, Skipped=19]
# Augmenting train:   2%|▏         | 175/7752 [08:02<7:45:43,  3.69s/it, Written=28, Skipped=19]
# Augmenting train:   2%|▏         | 180/7752 [08:02<5:37:19,  2.67s/it, Written=28, Skipped=19]
# Augmenting train:   2%|▏         | 180/7752 [08:06<5:37:19,  2.67s/it, Written=29, Skipped=19]
# Augmenting train:   2%|▏         | 182/7752 [08:06<5:29:39,  2.61s/it, Written=29, Skipped=19]
# Augmenting train:   2%|▏         | 182/7752 [08:12<5:29:39,  2.61s/it, Written=30, Skipped=19]
# Augmenting train:   2%|▏         | 183/7752 [08:12<6:13:12,  2.96s/it, Written=30, Skipped=19]
# Augmenting train:   2%|▏         | 183/7752 [08:27<6:13:12,  2.96s/it, Written=30, Skipped=20]
# Augmenting train:   2%|▏         | 187/7752 [08:27<6:47:45,  3.23s/it, Written=30, Skipped=20]
# Augmenting train:   2%|▏         | 187/7752 [08:40<6:47:45,  3.23s/it, Written=30, Skipped=21]
# Augmenting train:   2%|▏         | 188/7752 [08:40<9:30:15,  4.52s/it, Written=30, Skipped=21]
# Augmenting train:   2%|▏         | 188/7752 [08:44<9:30:15,  4.52s/it, Written=31, Skipped=21]
# Augmenting train:   3%|▎         | 195/7752 [08:44<4:56:42,  2.36s/it, Written=31, Skipped=21]
# Augmenting train:   3%|▎         | 195/7752 [09:00<4:56:42,  2.36s/it, Written=31, Skipped=22]
# Augmenting train:   3%|▎         | 199/7752 [09:00<5:57:16,  2.84s/it, Written=31, Skipped=22]
# Augmenting train:   3%|▎         | 199/7752 [09:15<5:57:16,  2.84s/it, Written=31, Skipped=23]
# Augmenting train:   3%|▎         | 200/7752 [09:15<8:32:47,  4.07s/it, Written=31, Skipped=23]
# Augmenting train:   3%|▎         | 200/7752 [09:27<8:32:47,  4.07s/it, Written=31, Skipped=24]
# Augmenting train:   3%|▎         | 206/7752 [09:27<6:34:33,  3.14s/it, Written=31, Skipped=24]
# Augmenting train:   3%|▎         | 206/7752 [09:33<6:34:33,  3.14s/it, Written=32, Skipped=24]
# Augmenting train:   3%|▎         | 212/7752 [09:33<4:46:11,  2.28s/it, Written=32, Skipped=24]
# Augmenting train:   3%|▎         | 212/7752 [09:48<4:46:11,  2.28s/it, Written=32, Skipped=25]
# Augmenting train:   3%|▎         | 216/7752 [09:48<5:36:24,  2.68s/it, Written=32, Skipped=25]
# Augmenting train:   3%|▎         | 216/7752 [10:04<5:36:24,  2.68s/it, Written=32, Skipped=26]
# Augmenting train:   3%|▎         | 218/7752 [10:04<7:20:49,  3.51s/it, Written=32, Skipped=26]
# Augmenting train:   3%|▎         | 218/7752 [10:09<7:20:49,  3.51s/it, Written=33, Skipped=26]
# Augmenting train:   3%|▎         | 223/7752 [10:09<5:30:29,  2.63s/it, Written=33, Skipped=26]
# Augmenting train:   3%|▎         | 223/7752 [10:25<5:30:29,  2.63s/it, Written=33, Skipped=27]
# Augmenting train:   3%|▎         | 224/7752 [10:25<8:03:04,  3.85s/it, Written=33, Skipped=27]
# Augmenting train:   3%|▎         | 224/7752 [10:29<8:03:04,  3.85s/it, Written=34, Skipped=27]
# Augmenting train:   3%|▎         | 226/7752 [10:29<7:21:25,  3.52s/it, Written=34, Skipped=27]
# Augmenting train:   3%|▎         | 226/7752 [10:34<7:21:25,  3.52s/it, Written=35, Skipped=27]
# Augmenting train:   3%|▎         | 229/7752 [10:34<6:05:08,  2.91s/it, Written=35, Skipped=27]
# Augmenting train:   3%|▎         | 229/7752 [10:49<6:05:08,  2.91s/it, Written=35, Skipped=28]
# Augmenting train:   3%|▎         | 232/7752 [10:49<7:19:47,  3.51s/it, Written=35, Skipped=28]
# Augmenting train:   3%|▎         | 232/7752 [11:06<7:19:47,  3.51s/it, Written=36, Skipped=28]
# Augmenting train:   3%|▎         | 235/7752 [11:06<8:47:57,  4.21s/it, Written=36, Skipped=28]
# Augmenting train:   3%|▎         | 235/7752 [11:21<8:47:57,  4.21s/it, Written=36, Skipped=29]
# Augmenting train:   3%|▎         | 236/7752 [11:21<11:33:06,  5.53s/it, Written=36, Skipped=29]
# Augmenting train:   3%|▎         | 236/7752 [11:35<11:33:06,  5.53s/it, Written=36, Skipped=30]
# Augmenting train:   3%|▎         | 243/7752 [11:35<7:27:22,  3.57s/it, Written=36, Skipped=30]
# Augmenting train:   3%|▎         | 243/7752 [11:48<7:27:22,  3.57s/it, Written=36, Skipped=31]
# Augmenting train:   3%|▎         | 244/7752 [11:48<9:26:42,  4.53s/it, Written=36, Skipped=31]
# Augmenting train:   3%|▎         | 244/7752 [11:54<9:26:42,  4.53s/it, Written=37, Skipped=31]
# Augmenting train:   3%|▎         | 245/7752 [11:54<9:57:41,  4.78s/it, Written=37, Skipped=31]
# Augmenting train:   3%|▎         | 245/7752 [11:59<9:57:41,  4.78s/it, Written=38, Skipped=31]
# Augmenting train:   3%|▎         | 247/7752 [11:59<8:41:28,  4.17s/it, Written=38, Skipped=31]
# Augmenting train:   3%|▎         | 247/7752 [12:13<8:41:28,  4.17s/it, Written=38, Skipped=32]
# Augmenting train:   3%|▎         | 250/7752 [12:13<8:53:05,  4.26s/it, Written=38, Skipped=32]
# Augmenting train:   3%|▎         | 250/7752 [12:27<8:53:05,  4.26s/it, Written=38, Skipped=33]
# Augmenting train:   3%|▎         | 252/7752 [12:27<10:22:53,  4.98s/it, Written=38, Skipped=33]
# Augmenting train:   3%|▎         | 252/7752 [12:33<10:22:53,  4.98s/it, Written=39, Skipped=33]
# Augmenting train:   3%|▎         | 257/7752 [12:33<6:37:25,  3.18s/it, Written=39, Skipped=33]
# Augmenting train:   3%|▎         | 257/7752 [12:48<6:37:25,  3.18s/it, Written=39, Skipped=34]
# Augmenting train:   3%|▎         | 261/7752 [12:48<7:08:38,  3.43s/it, Written=39, Skipped=34]
# Augmenting train:   3%|▎         | 261/7752 [13:04<7:08:38,  3.43s/it, Written=40, Skipped=34]
# Augmenting train:   3%|▎         | 263/7752 [13:04<8:55:25,  4.29s/it, Written=40, Skipped=34]
# Augmenting train:   3%|▎         | 263/7752 [13:18<8:55:25,  4.29s/it, Written=40, Skipped=35]
# Augmenting train:   3%|▎         | 268/7752 [13:18<7:35:58,  3.66s/it, Written=40, Skipped=35]
# Augmenting train:   3%|▎         | 268/7752 [13:24<7:35:58,  3.66s/it, Written=41, Skipped=35]
# Augmenting train:   4%|▎         | 279/7752 [13:24<3:54:46,  1.88s/it, Written=41, Skipped=35]
# Augmenting train:   4%|▎         | 279/7752 [13:30<3:54:46,  1.88s/it, Written=42, Skipped=35]
# Augmenting train:   4%|▎         | 280/7752 [13:30<4:32:18,  2.19s/it, Written=42, Skipped=35]
# Augmenting train:   4%|▎         | 280/7752 [13:37<4:32:18,  2.19s/it, Written=43, Skipped=35]
# Augmenting train:   4%|▎         | 281/7752 [13:38<5:32:55,  2.67s/it, Written=43, Skipped=35]
# Augmenting train:   4%|▎         | 281/7752 [13:53<5:32:55,  2.67s/it, Written=43, Skipped=36]
# Augmenting train:   4%|▎         | 282/7752 [13:53<8:38:58,  4.17s/it, Written=43, Skipped=36]
# Augmenting train:   4%|▎         | 282/7752 [13:58<8:38:58,  4.17s/it, Written=44, Skipped=36]
# Augmenting train:   4%|▎         | 289/7752 [13:58<4:49:24,  2.33s/it, Written=44, Skipped=36]
# Augmenting train:   4%|▎         | 289/7752 [14:03<4:49:24,  2.33s/it, Written=45, Skipped=36]
# Augmenting train:   4%|▍         | 293/7752 [14:03<4:08:43,  2.00s/it, Written=45, Skipped=36]
# Augmenting train:   4%|▍         | 293/7752 [14:09<4:08:43,  2.00s/it, Written=46, Skipped=36]
# Augmenting train:   4%|▍         | 297/7752 [14:09<3:49:34,  1.85s/it, Written=46, Skipped=36]
# Augmenting train:   4%|▍         | 297/7752 [14:23<3:49:34,  1.85s/it, Written=46, Skipped=37]
# Augmenting train:   4%|▍         | 298/7752 [14:23<6:08:17,  2.96s/it, Written=46, Skipped=37]
# Augmenting train:   4%|▍         | 298/7752 [14:39<6:08:17,  2.96s/it, Written=46, Skipped=38]
# Augmenting train:   4%|▍         | 300/7752 [14:39<8:35:11,  4.15s/it, Written=46, Skipped=38]
# Augmenting train:   4%|▍         | 300/7752 [14:57<8:35:11,  4.15s/it, Written=46, Skipped=39]
# Augmenting train:   4%|▍         | 303/7752 [14:57<9:40:04,  4.67s/it, Written=46, Skipped=39]
# Augmenting train:   4%|▍         | 303/7752 [15:04<9:40:04,  4.67s/it, Written=47, Skipped=39]
# Augmenting train:   4%|▍         | 308/7752 [15:04<6:45:13,  3.27s/it, Written=47, Skipped=39]
# Augmenting train:   4%|▍         | 308/7752 [15:19<6:45:13,  3.27s/it, Written=47, Skipped=40]
# Augmenting train:   4%|▍         | 323/7752 [15:19<3:42:12,  1.79s/it, Written=47, Skipped=40]
# Augmenting train:   4%|▍         | 323/7752 [15:33<3:42:12,  1.79s/it, Written=47, Skipped=41]
# Augmenting train:   4%|▍         | 325/7752 [15:33<4:56:53,  2.40s/it, Written=47, Skipped=41]
# Augmenting train:   4%|▍         | 325/7752 [15:38<4:56:53,  2.40s/it, Written=48, Skipped=41]
# Augmenting train:   4%|▍         | 326/7752 [15:38<5:14:03,  2.54s/it, Written=48, Skipped=41]
# Augmenting train:   4%|▍         | 326/7752 [15:53<5:14:03,  2.54s/it, Written=48, Skipped=42]
# Augmenting train:   4%|▍         | 334/7752 [15:53<4:41:41,  2.28s/it, Written=48, Skipped=42]
# Augmenting train:   4%|▍         | 334/7752 [16:09<4:41:41,  2.28s/it, Written=48, Skipped=43]
# Augmenting train:   4%|▍         | 340/7752 [16:09<4:52:57,  2.37s/it, Written=48, Skipped=43]
# Augmenting train:   4%|▍         | 340/7752 [16:15<4:52:57,  2.37s/it, Written=49, Skipped=43]
# Augmenting train:   4%|▍         | 342/7752 [16:15<5:07:16,  2.49s/it, Written=49, Skipped=43]
# Augmenting train:   4%|▍         | 342/7752 [16:21<5:07:16,  2.49s/it, Written=50, Skipped=43]
# Augmenting train:   4%|▍         | 343/7752 [16:21<5:37:47,  2.74s/it, Written=50, Skipped=43]
# Augmenting train:   4%|▍         | 343/7752 [16:30<5:37:47,  2.74s/it, Written=51, Skipped=43]
# Augmenting train:   4%|▍         | 344/7752 [16:30<7:08:37,  3.47s/it, Written=51, Skipped=43]
# Augmenting train:   4%|▍         | 344/7752 [16:44<7:08:37,  3.47s/it, Written=51, Skipped=44]
# Augmenting train:   4%|▍         | 345/7752 [16:44<10:05:33,  4.91s/it, Written=51, Skipped=44]
# Augmenting train:   4%|▍         | 345/7752 [16:58<10:05:33,  4.91s/it, Written=51, Skipped=45]
# Augmenting train:   4%|▍         | 347/7752 [16:58<11:24:56,  5.55s/it, Written=51, Skipped=45]
# Augmenting train:   4%|▍         | 347/7752 [17:15<11:24:56,  5.55s/it, Written=51, Skipped=46]
# Augmenting train:   5%|▍         | 353/7752 [17:15<8:18:12,  4.04s/it, Written=51, Skipped=46]
# Augmenting train:   5%|▍         | 353/7752 [17:21<8:18:12,  4.04s/it, Written=52, Skipped=46]
# Augmenting train:   5%|▍         | 354/7752 [17:21<8:48:47,  4.29s/it, Written=52, Skipped=46]
# Augmenting train:   5%|▍         | 354/7752 [17:27<8:48:47,  4.29s/it, Written=53, Skipped=46]
# Augmenting train:   5%|▍         | 355/7752 [17:27<9:18:46,  4.53s/it, Written=53, Skipped=46]
# Augmenting train:   5%|▍         | 355/7752 [17:42<9:18:46,  4.53s/it, Written=53, Skipped=47]
# Augmenting train:   5%|▍         | 358/7752 [17:42<9:37:20,  4.69s/it, Written=53, Skipped=47]
# Augmenting train:   5%|▍         | 358/7752 [17:49<9:37:20,  4.69s/it, Written=54, Skipped=47]
# Augmenting train:   5%|▍         | 359/7752 [17:49<10:22:03,  5.05s/it, Written=54, Skipped=47]
# Augmenting train:   5%|▍         | 359/7752 [17:54<10:22:03,  5.05s/it, Written=55, Skipped=47]
# Augmenting train:   5%|▍         | 360/7752 [17:54<10:23:58,  5.06s/it, Written=55, Skipped=47]
# Augmenting train:   5%|▍         | 360/7752 [18:08<10:23:58,  5.06s/it, Written=55, Skipped=48]
# Augmenting train:   5%|▍         | 362/7752 [18:08<11:37:15,  5.66s/it, Written=55, Skipped=48]
# Augmenting train:   5%|▍         | 362/7752 [18:23<11:37:15,  5.66s/it, Written=55, Skipped=49]
# Augmenting train:   5%|▍         | 368/7752 [18:23<7:45:35,  3.78s/it, Written=55, Skipped=49]
# Augmenting train:   5%|▍         | 368/7752 [18:29<7:45:35,  3.78s/it, Written=56, Skipped=49]
# Augmenting train:   5%|▍         | 371/7752 [18:29<6:43:40,  3.28s/it, Written=56, Skipped=49]
# Augmenting train:   5%|▍         | 371/7752 [18:36<6:43:40,  3.28s/it, Written=57, Skipped=49]
# Augmenting train:   5%|▍         | 376/7752 [18:36<5:09:38,  2.52s/it, Written=57, Skipped=49]
# Augmenting train:   5%|▍         | 376/7752 [18:41<5:09:38,  2.52s/it, Written=58, Skipped=49]
# Augmenting train:   5%|▍         | 380/7752 [18:41<4:16:11,  2.09s/it, Written=58, Skipped=49]
# Augmenting train:   5%|▍         | 380/7752 [18:55<4:16:11,  2.09s/it, Written=58, Skipped=50]
# Augmenting train:   5%|▍         | 381/7752 [18:55<6:43:52,  3.29s/it, Written=58, Skipped=50]
# Augmenting train:   5%|▍         | 381/7752 [19:00<6:43:52,  3.29s/it, Written=59, Skipped=50]
# Augmenting train:   5%|▍         | 382/7752 [19:00<7:21:48,  3.60s/it, Written=59, Skipped=50]
# Augmenting train:   5%|▍         | 382/7752 [19:06<7:21:48,  3.60s/it, Written=60, Skipped=50]
# Augmenting train:   5%|▍         | 384/7752 [19:06<7:01:57,  3.44s/it, Written=60, Skipped=50]
# Augmenting train:   5%|▍         | 384/7752 [19:24<7:01:57,  3.44s/it, Written=60, Skipped=51]
# Augmenting train:   5%|▌         | 388/7752 [19:24<7:55:00,  3.87s/it, Written=60, Skipped=51]
# Augmenting train:   5%|▌         | 388/7752 [19:29<7:55:00,  3.87s/it, Written=61, Skipped=51]
# Augmenting train:   5%|▌         | 389/7752 [19:29<8:11:40,  4.01s/it, Written=61, Skipped=51]
# Augmenting train:   5%|▌         | 389/7752 [19:35<8:11:40,  4.01s/it, Written=62, Skipped=51]
# Augmenting train:   5%|▌         | 402/7752 [19:35<2:58:47,  1.46s/it, Written=62, Skipped=51]
# Augmenting train:   5%|▌         | 402/7752 [19:43<2:58:47,  1.46s/it, Written=63, Skipped=51]
# Augmenting train:   5%|▌         | 403/7752 [19:43<3:57:50,  1.94s/it, Written=63, Skipped=51]
# Augmenting train:   5%|▌         | 403/7752 [19:58<3:57:50,  1.94s/it, Written=64, Skipped=51]
# Augmenting train:   5%|▌         | 408/7752 [19:58<4:44:07,  2.32s/it, Written=64, Skipped=51]
# Augmenting train:   5%|▌         | 408/7752 [20:14<4:44:07,  2.32s/it, Written=64, Skipped=52]
# Augmenting train:   5%|▌         | 418/7752 [20:14<3:57:20,  1.94s/it, Written=64, Skipped=52]
# Augmenting train:   5%|▌         | 418/7752 [20:27<3:57:20,  1.94s/it, Written=64, Skipped=53]
# Augmenting train:   5%|▌         | 419/7752 [20:27<5:32:32,  2.72s/it, Written=64, Skipped=53]
# Augmenting train:   5%|▌         | 419/7752 [20:41<5:32:32,  2.72s/it, Written=64, Skipped=54]
# Augmenting train:   5%|▌         | 423/7752 [20:41<5:56:15,  2.92s/it, Written=64, Skipped=54]
# Augmenting train:   5%|▌         | 423/7752 [20:46<5:56:15,  2.92s/it, Written=65, Skipped=54]
# Augmenting train:   5%|▌         | 426/7752 [20:46<5:20:13,  2.62s/it, Written=65, Skipped=54]
# Augmenting train:   5%|▌         | 426/7752 [21:03<5:20:13,  2.62s/it, Written=65, Skipped=55]
# Augmenting train:   6%|▌         | 428/7752 [21:03<7:25:38,  3.65s/it, Written=65, Skipped=55]
# Augmenting train:   6%|▌         | 428/7752 [21:20<7:25:38,  3.65s/it, Written=65, Skipped=56]
# Augmenting train:   6%|▌         | 429/7752 [21:20<10:36:19,  5.21s/it, Written=65, Skipped=56]
# Augmenting train:   6%|▌         | 429/7752 [21:33<10:36:19,  5.21s/it, Written=65, Skipped=57]
# Augmenting train:   6%|▌         | 431/7752 [21:33<11:12:48,  5.51s/it, Written=65, Skipped=57]
# Augmenting train:   6%|▌         | 431/7752 [21:48<11:12:48,  5.51s/it, Written=65, Skipped=58]
# Augmenting train:   6%|▌         | 433/7752 [21:48<12:14:22,  6.02s/it, Written=65, Skipped=58]
# Augmenting train:   6%|▌         | 433/7752 [21:53<12:14:22,  6.02s/it, Written=66, Skipped=58]
# Augmenting train:   6%|▌         | 436/7752 [21:53<8:59:41,  4.43s/it, Written=66, Skipped=58]
# Augmenting train:   6%|▌         | 436/7752 [22:10<8:59:41,  4.43s/it, Written=66, Skipped=59]
# Augmenting train:   6%|▌         | 437/7752 [22:10<12:49:56,  6.32s/it, Written=66, Skipped=59]
# Augmenting train:   6%|▌         | 437/7752 [22:14<12:49:56,  6.32s/it, Written=67, Skipped=59]
# Augmenting train:   6%|▌         | 440/7752 [22:14<8:59:25,  4.43s/it, Written=67, Skipped=59]
# Augmenting train:   6%|▌         | 440/7752 [22:19<8:59:25,  4.43s/it, Written=68, Skipped=59]
# Augmenting train:   6%|▌         | 444/7752 [22:19<6:10:38,  3.04s/it, Written=68, Skipped=59]
# Augmenting train:   6%|▌         | 444/7752 [22:33<6:10:38,  3.04s/it, Written=68, Skipped=60]
# Augmenting train:   6%|▌         | 445/7752 [22:33<9:04:56,  4.47s/it, Written=68, Skipped=60]
# Augmenting train:   6%|▌         | 445/7752 [22:47<9:04:56,  4.47s/it, Written=68, Skipped=61]
# Augmenting train:   6%|▌         | 446/7752 [22:47<12:05:27,  5.96s/it, Written=68, Skipped=61]
# Augmenting train:   6%|▌         | 446/7752 [23:01<12:05:27,  5.96s/it, Written=68, Skipped=62]
# Augmenting train:   6%|▌         | 449/7752 [23:01<11:08:55,  5.50s/it, Written=68, Skipped=62]
# Augmenting train:   6%|▌         | 449/7752 [23:19<11:08:55,  5.50s/it, Written=68, Skipped=63]
# Augmenting train:   6%|▌         | 453/7752 [23:19<10:17:29,  5.08s/it, Written=68, Skipped=63]
# Augmenting train:   6%|▌         | 453/7752 [23:24<10:17:29,  5.08s/it, Written=69, Skipped=63]
# Augmenting train:   6%|▌         | 454/7752 [23:24<10:12:35,  5.04s/it, Written=69, Skipped=63]
# Augmenting train:   6%|▌         | 454/7752 [23:28<10:12:35,  5.04s/it, Written=70, Skipped=63]
# Augmenting train:   6%|▌         | 455/7752 [23:28<9:56:22,  4.90s/it, Written=70, Skipped=63]
# Augmenting train:   6%|▌         | 455/7752 [23:41<9:56:22,  4.90s/it, Written=70, Skipped=64]
# Augmenting train:   6%|▌         | 459/7752 [23:41<8:14:02,  4.06s/it, Written=70, Skipped=64]
# Augmenting train:   6%|▌         | 459/7752 [23:46<8:14:02,  4.06s/it, Written=71, Skipped=64]
# Augmenting train:   6%|▌         | 462/7752 [23:46<6:34:42,  3.25s/it, Written=71, Skipped=64]
# Augmenting train:   6%|▌         | 462/7752 [24:00<6:34:42,  3.25s/it, Written=71, Skipped=65]
# Augmenting train:   6%|▌         | 464/7752 [24:00<8:26:57,  4.17s/it, Written=71, Skipped=65]
# Augmenting train:   6%|▌         | 464/7752 [24:15<8:26:57,  4.17s/it, Written=71, Skipped=66]
# Augmenting train:   6%|▌         | 467/7752 [24:15<8:55:41,  4.41s/it, Written=71, Skipped=66]
# Augmenting train:   6%|▌         | 467/7752 [24:29<8:55:41,  4.41s/it, Written=71, Skipped=67]
# Augmenting train:   6%|▌         | 468/7752 [24:29<11:51:17,  5.86s/it, Written=71, Skipped=67]
# Augmenting train:   6%|▌         | 468/7752 [24:34<11:51:17,  5.86s/it, Written=72, Skipped=67]
# Augmenting train:   6%|▌         | 474/7752 [24:34<6:19:14,  3.13s/it, Written=72, Skipped=67]
# Augmenting train:   6%|▌         | 474/7752 [24:50<6:19:14,  3.13s/it, Written=72, Skipped=68]
# Augmenting train:   6%|▌         | 476/7752 [24:50<8:17:33,  4.10s/it, Written=72, Skipped=68]
# Augmenting train:   6%|▌         | 476/7752 [25:07<8:17:33,  4.10s/it, Written=73, Skipped=68]
# Augmenting train:   6%|▌         | 477/7752 [25:07<11:27:42,  5.67s/it, Written=73, Skipped=68]
# Augmenting train:   6%|▌         | 477/7752 [25:22<11:27:42,  5.67s/it, Written=73, Skipped=69]
# Augmenting train:   6%|▌         | 484/7752 [25:22<7:30:56,  3.72s/it, Written=73, Skipped=69]
# Augmenting train:   6%|▌         | 484/7752 [25:28<7:30:56,  3.72s/it, Written=74, Skipped=69]
# Augmenting train:   6%|▋         | 485/7752 [25:28<7:56:40,  3.94s/it, Written=74, Skipped=69]
# Augmenting train:   6%|▋         | 485/7752 [25:34<7:56:40,  3.94s/it, Written=75, Skipped=69]
# Augmenting train:   6%|▋         | 489/7752 [25:34<6:06:26,  3.03s/it, Written=75, Skipped=69]
# Augmenting train:   6%|▋         | 489/7752 [25:40<6:06:26,  3.03s/it, Written=76, Skipped=69]
# Augmenting train:   6%|▋         | 494/7752 [25:40<4:40:40,  2.32s/it, Written=76, Skipped=69]
# Augmenting train:   6%|▋         | 494/7752 [25:55<4:40:40,  2.32s/it, Written=76, Skipped=70]
# Augmenting train:   6%|▋         | 495/7752 [25:55<7:20:36,  3.64s/it, Written=76, Skipped=70]
# Augmenting train:   6%|▋         | 495/7752 [26:05<7:20:36,  3.64s/it, Written=77, Skipped=70]
# Augmenting train:   6%|▋         | 496/7752 [26:05<9:02:25,  4.49s/it, Written=77, Skipped=70]
# Augmenting train:   6%|▋         | 496/7752 [26:11<9:02:25,  4.49s/it, Written=78, Skipped=70]
# Augmenting train:   6%|▋         | 497/7752 [26:11<9:17:14,  4.61s/it, Written=78, Skipped=70]
# Augmenting train:   6%|▋         | 497/7752 [26:17<9:17:14,  4.61s/it, Written=79, Skipped=70]
# Augmenting train:   6%|▋         | 502/7752 [26:17<5:38:37,  2.80s/it, Written=79, Skipped=70]
# Augmenting train:   6%|▋         | 502/7752 [26:21<5:38:37,  2.80s/it, Written=80, Skipped=70]
# Augmenting train:   7%|▋         | 504/7752 [26:21<5:15:52,  2.61s/it, Written=80, Skipped=70]
# Augmenting train:   7%|▋         | 504/7752 [26:34<5:15:52,  2.61s/it, Written=80, Skipped=71]
# Augmenting train:   7%|▋         | 507/7752 [26:34<6:27:25,  3.21s/it, Written=80, Skipped=71]
# Augmenting train:   7%|▋         | 507/7752 [26:48<6:27:25,  3.21s/it, Written=80, Skipped=72]
# Augmenting train:   7%|▋         | 511/7752 [26:48<6:39:21,  3.31s/it, Written=80, Skipped=72]
# Augmenting train:   7%|▋         | 511/7752 [26:52<6:39:21,  3.31s/it, Written=81, Skipped=72]
# Augmenting train:   7%|▋         | 516/7752 [26:52<4:40:32,  2.33s/it, Written=81, Skipped=72]
# Augmenting train:   7%|▋         | 516/7752 [26:59<4:40:32,  2.33s/it, Written=82, Skipped=72]
# Augmenting train:   7%|▋         | 517/7752 [26:59<5:40:39,  2.83s/it, Written=82, Skipped=72]
# Augmenting train:   7%|▋         | 517/7752 [27:10<5:40:39,  2.83s/it, Written=82, Skipped=73]
# Augmenting train:   7%|▋         | 520/7752 [27:10<6:14:33,  3.11s/it, Written=82, Skipped=73]
# Augmenting train:   7%|▋         | 520/7752 [27:15<6:14:33,  3.11s/it, Written=83, Skipped=73]
# Augmenting train:   7%|▋         | 524/7752 [27:15<4:47:02,  2.38s/it, Written=83, Skipped=73]
# Augmenting train:   7%|▋         | 524/7752 [27:30<4:47:02,  2.38s/it, Written=83, Skipped=74]
# Augmenting train:   7%|▋         | 525/7752 [27:30<7:48:23,  3.89s/it, Written=83, Skipped=74]
# Augmenting train:   7%|▋         | 525/7752 [27:46<7:48:23,  3.89s/it, Written=83, Skipped=75]
# Augmenting train:   7%|▋         | 526/7752 [27:46<11:12:19,  5.58s/it, Written=83, Skipped=75]
# Augmenting train:   7%|▋         | 526/7752 [28:03<11:12:19,  5.58s/it, Written=83, Skipped=76]
# Augmenting train:   7%|▋         | 527/7752 [28:03<15:01:21,  7.49s/it, Written=83, Skipped=76]
# Augmenting train:   7%|▋         | 527/7752 [28:08<15:01:21,  7.49s/it, Written=84, Skipped=76]
# Augmenting train:   7%|▋         | 532/7752 [28:08<7:58:31,  3.98s/it, Written=84, Skipped=76]
# Augmenting train:   7%|▋         | 532/7752 [28:12<7:58:31,  3.98s/it, Written=85, Skipped=76]
# Augmenting train:   7%|▋         | 533/7752 [28:12<8:00:44,  4.00s/it, Written=85, Skipped=76]
# Augmenting train:   7%|▋         | 533/7752 [28:17<8:00:44,  4.00s/it, Written=86, Skipped=76]
# Augmenting train:   7%|▋         | 544/7752 [28:17<3:04:52,  1.54s/it, Written=86, Skipped=76]
# Augmenting train:   7%|▋         | 544/7752 [28:21<3:04:52,  1.54s/it, Written=87, Skipped=76]
# Augmenting train:   7%|▋         | 546/7752 [28:21<3:17:55,  1.65s/it, Written=87, Skipped=76]
# Augmenting train:   7%|▋         | 546/7752 [28:30<3:17:55,  1.65s/it, Written=88, Skipped=76]
# Augmenting train:   7%|▋         | 552/7752 [28:30<3:09:12,  1.58s/it, Written=88, Skipped=76]
# Augmenting train:   7%|▋         | 552/7752 [28:49<3:09:12,  1.58s/it, Written=89, Skipped=76]
# Augmenting train:   7%|▋         | 560/7752 [28:49<3:47:53,  1.90s/it, Written=89, Skipped=76]
# Augmenting train:   7%|▋         | 560/7752 [28:55<3:47:53,  1.90s/it, Written=90, Skipped=76]
# Augmenting train:   7%|▋         | 565/7752 [28:55<3:28:17,  1.74s/it, Written=90, Skipped=76]
# Augmenting train:   7%|▋         | 565/7752 [29:16<3:28:17,  1.74s/it, Written=90, Skipped=77]
# Augmenting train:   7%|▋         | 566/7752 [29:16<6:13:18,  3.12s/it, Written=90, Skipped=77]
# Augmenting train:   7%|▋         | 566/7752 [29:21<6:13:18,  3.12s/it, Written=91, Skipped=77]
# Augmenting train:   7%|▋         | 567/7752 [29:21<6:36:14,  3.31s/it, Written=91, Skipped=77]
# Augmenting train:   7%|▋         | 567/7752 [29:35<6:36:14,  3.31s/it, Written=91, Skipped=78]
# Augmenting train:   7%|▋         | 568/7752 [29:35<9:10:59,  4.60s/it, Written=91, Skipped=78]
# Augmenting train:   7%|▋         | 568/7752 [29:39<9:10:59,  4.60s/it, Written=92, Skipped=78]
# Augmenting train:   7%|▋         | 571/7752 [29:39<7:01:34,  3.52s/it, Written=92, Skipped=78]
# Augmenting train:   7%|▋         | 571/7752 [29:52<7:01:34,  3.52s/it, Written=92, Skipped=79]
# Augmenting train:   7%|▋         | 579/7752 [29:52<4:52:22,  2.45s/it, Written=92, Skipped=79]
# Augmenting train:   7%|▋         | 579/7752 [30:07<4:52:22,  2.45s/it, Written=92, Skipped=80]
# Augmenting train:   8%|▊         | 590/7752 [30:07<3:43:46,  1.87s/it, Written=92, Skipped=80]
# Augmenting train:   8%|▊         | 590/7752 [30:22<3:43:46,  1.87s/it, Written=92, Skipped=81]
# Augmenting train:   8%|▊         | 600/7752 [30:22<3:26:35,  1.73s/it, Written=92, Skipped=81]
# Augmenting train:   8%|▊         | 600/7752 [30:30<3:26:35,  1.73s/it, Written=93, Skipped=81]
# Augmenting train:   8%|▊         | 602/7752 [30:30<3:54:06,  1.96s/it, Written=93, Skipped=81]
# Augmenting train:   8%|▊         | 602/7752 [30:38<3:54:06,  1.96s/it, Written=94, Skipped=81]
# Augmenting train:   8%|▊         | 609/7752 [30:38<3:21:13,  1.69s/it, Written=94, Skipped=81]
# Augmenting train:   8%|▊         | 609/7752 [30:56<3:21:13,  1.69s/it, Written=94, Skipped=82]
# Augmenting train:   8%|▊         | 611/7752 [30:56<5:03:04,  2.55s/it, Written=94, Skipped=82]
# Augmenting train:   8%|▊         | 611/7752 [31:02<5:03:04,  2.55s/it, Written=95, Skipped=82]
# Augmenting train:   8%|▊         | 619/7752 [31:02<3:35:55,  1.82s/it, Written=95, Skipped=82]
# Augmenting train:   8%|▊         | 619/7752 [31:17<3:35:55,  1.82s/it, Written=95, Skipped=83]
# Augmenting train:   8%|▊         | 624/7752 [31:17<4:13:13,  2.13s/it, Written=95, Skipped=83]
# Augmenting train:   8%|▊         | 624/7752 [31:22<4:13:13,  2.13s/it, Written=96, Skipped=83]
# Augmenting train:   8%|▊         | 630/7752 [31:22<3:25:32,  1.73s/it, Written=96, Skipped=83]
# Augmenting train:   8%|▊         | 630/7752 [31:37<3:25:32,  1.73s/it, Written=96, Skipped=84]
# Augmenting train:   8%|▊         | 637/7752 [31:37<3:40:03,  1.86s/it, Written=96, Skipped=84]
# Augmenting train:   8%|▊         | 637/7752 [31:50<3:40:03,  1.86s/it, Written=96, Skipped=85]
# Augmenting train:   8%|▊         | 639/7752 [31:50<4:49:53,  2.45s/it, Written=96, Skipped=85]
# Augmenting train:   8%|▊         | 639/7752 [32:00<4:49:53,  2.45s/it, Written=97, Skipped=85]
# Augmenting train:   8%|▊         | 643/7752 [32:00<4:47:53,  2.43s/it, Written=97, Skipped=85]
# Augmenting train:   8%|▊         | 643/7752 [32:15<4:47:53,  2.43s/it, Written=97, Skipped=86]
# Augmenting train:   8%|▊         | 645/7752 [32:15<6:25:33,  3.26s/it, Written=97, Skipped=86]
# Augmenting train:   8%|▊         | 645/7752 [32:19<6:25:33,  3.26s/it, Written=98, Skipped=86]
# Augmenting train:   8%|▊         | 647/7752 [32:19<5:56:47,  3.01s/it, Written=98, Skipped=86]
# Augmenting train:   8%|▊         | 647/7752 [32:25<5:56:47,  3.01s/it, Written=99, Skipped=86]
# Augmenting train:   8%|▊         | 654/7752 [32:25<3:54:07,  1.98s/it, Written=99, Skipped=86]
# Augmenting train:   8%|▊         | 654/7752 [32:33<3:54:07,  1.98s/it, Written=100, Skipped=86]
# Augmenting train:   8%|▊         | 658/7752 [32:33<3:55:33,  1.99s/it, Written=100, Skipped=86]
# Augmenting train:   8%|▊         | 658/7752 [32:49<3:55:33,  1.99s/it, Written=100, Skipped=87]
# Augmenting train:   9%|▊         | 660/7752 [32:49<5:50:33,  2.97s/it, Written=100, Skipped=87]
# Augmenting train:   9%|▊         | 660/7752 [33:06<5:50:33,  2.97s/it, Written=100, Skipped=88]
# Augmenting train:   9%|▊         | 661/7752 [33:06<8:48:58,  4.48s/it, Written=100, Skipped=88]
# Augmenting train:   9%|▊         | 661/7752 [33:22<8:48:58,  4.48s/it, Written=100, Skipped=89]
# Augmenting train:   9%|▊         | 662/7752 [33:22<11:55:13,  6.05s/it, Written=100, Skipped=89]
# Augmenting train:   9%|▊         | 662/7752 [33:36<11:55:13,  6.05s/it, Written=100, Skipped=90]
# Augmenting train:   9%|▊         | 668/7752 [33:36<8:00:19,  4.07s/it, Written=100, Skipped=90]
# Augmenting train:   9%|▊         | 668/7752 [33:49<8:00:19,  4.07s/it, Written=100, Skipped=91]
# Augmenting train:   9%|▊         | 669/7752 [33:49<9:58:48,  5.07s/it, Written=100, Skipped=91]
# Augmenting train:   9%|▊         | 669/7752 [34:05<9:58:48,  5.07s/it, Written=100, Skipped=92]
# Augmenting train:   9%|▊         | 670/7752 [34:05<12:58:30,  6.60s/it, Written=100, Skipped=92]
# Augmenting train:   9%|▊         | 670/7752 [34:10<12:58:30,  6.60s/it, Written=101, Skipped=92]
# Augmenting train:   9%|▉         | 680/7752 [34:10<4:58:19,  2.53s/it, Written=101, Skipped=92]
# Augmenting train:   9%|▉         | 680/7752 [34:25<4:58:19,  2.53s/it, Written=101, Skipped=93]
# Augmenting train:   9%|▉         | 686/7752 [34:25<4:58:00,  2.53s/it, Written=101, Skipped=93]
# Augmenting train:   9%|▉         | 686/7752 [34:30<4:58:00,  2.53s/it, Written=102, Skipped=93]
# Augmenting train:   9%|▉         | 688/7752 [34:30<4:58:14,  2.53s/it, Written=102, Skipped=93]
# Augmenting train:   9%|▉         | 688/7752 [34:46<4:58:14,  2.53s/it, Written=102, Skipped=94]
# Augmenting train:   9%|▉         | 689/7752 [34:46<7:24:19,  3.77s/it, Written=102, Skipped=94]
# Augmenting train:   9%|▉         | 689/7752 [35:00<7:24:19,  3.77s/it, Written=103, Skipped=94]
# Augmenting train:   9%|▉         | 695/7752 [35:00<6:11:34,  3.16s/it, Written=103, Skipped=94]
# Augmenting train:   9%|▉         | 695/7752 [35:18<6:11:34,  3.16s/it, Written=103, Skipped=95]
# Augmenting train:   9%|▉         | 698/7752 [35:18<7:36:31,  3.88s/it, Written=103, Skipped=95]
# Augmenting train:   9%|▉         | 698/7752 [35:23<7:36:31,  3.88s/it, Written=104, Skipped=95]
# Augmenting train:   9%|▉         | 707/7752 [35:23<4:14:28,  2.17s/it, Written=104, Skipped=95]
# Augmenting train:   9%|▉         | 707/7752 [35:41<4:14:28,  2.17s/it, Written=104, Skipped=96]
# Augmenting train:   9%|▉         | 708/7752 [35:41<6:29:08,  3.31s/it, Written=104, Skipped=96]
# Augmenting train:   9%|▉         | 708/7752 [35:45<6:29:08,  3.31s/it, Written=105, Skipped=96]
# Augmenting train:   9%|▉         | 711/7752 [35:45<5:36:08,  2.86s/it, Written=105, Skipped=96]
# Augmenting train:   9%|▉         | 711/7752 [35:59<5:36:08,  2.86s/it, Written=105, Skipped=97]
# Augmenting train:   9%|▉         | 713/7752 [35:59<7:05:31,  3.63s/it, Written=105, Skipped=97]
# Augmenting train:   9%|▉         | 713/7752 [36:14<7:05:31,  3.63s/it, Written=105, Skipped=98]
# Augmenting train:   9%|▉         | 715/7752 [36:14<8:46:42,  4.49s/it, Written=105, Skipped=98]
# Augmenting train:   9%|▉         | 715/7752 [36:26<8:46:42,  4.49s/it, Written=105, Skipped=99]
# Augmenting train:   9%|▉         | 718/7752 [36:26<8:29:48,  4.35s/it, Written=105, Skipped=99]
# Augmenting train:   9%|▉         | 718/7752 [36:31<8:29:48,  4.35s/it, Written=106, Skipped=99]
# Augmenting train:   9%|▉         | 726/7752 [36:31<4:27:43,  2.29s/it, Written=106, Skipped=99]
# Augmenting train:   9%|▉         | 726/7752 [36:35<4:27:43,  2.29s/it, Written=107, Skipped=99]
# Augmenting train:   9%|▉         | 727/7752 [36:35<4:46:21,  2.45s/it, Written=107, Skipped=99]
# Augmenting train:   9%|▉         | 727/7752 [36:40<4:46:21,  2.45s/it, Written=108, Skipped=99]
# Augmenting train:   9%|▉         | 730/7752 [36:40<4:23:27,  2.25s/it, Written=108, Skipped=99]
# Augmenting train:   9%|▉         | 730/7752 [36:56<4:23:27,  2.25s/it, Written=109, Skipped=99]
# Augmenting train:   9%|▉         | 734/7752 [36:56<5:32:04,  2.84s/it, Written=109, Skipped=99]
# Augmenting train:   9%|▉         | 734/7752 [37:00<5:32:04,  2.84s/it, Written=110, Skipped=99]
# Augmenting train:  10%|▉         | 740/7752 [37:00<3:45:46,  1.93s/it, Written=110, Skipped=99]
# Augmenting train:  10%|▉         | 740/7752 [37:06<3:45:46,  1.93s/it, Written=111, Skipped=99]
# Augmenting train:  10%|▉         | 748/7752 [37:06<2:40:33,  1.38s/it, Written=111, Skipped=99]
# Augmenting train:  10%|▉         | 748/7752 [37:10<2:40:33,  1.38s/it, Written=112, Skipped=99]
# Augmenting train:  10%|▉         | 753/7752 [37:10<2:22:54,  1.23s/it, Written=112, Skipped=99]
# Augmenting train:  10%|▉         | 753/7752 [37:25<2:22:54,  1.23s/it, Written=112, Skipped=100]
# Augmenting train:  10%|▉         | 757/7752 [37:25<3:34:57,  1.84s/it, Written=112, Skipped=100]
# Augmenting train:  10%|▉         | 757/7752 [37:36<3:34:57,  1.84s/it, Written=113, Skipped=100]
# Augmenting train:  10%|▉         | 760/7752 [37:36<4:21:32,  2.24s/it, Written=113, Skipped=100]
# Augmenting train:  10%|▉         | 760/7752 [37:42<4:21:32,  2.24s/it, Written=114, Skipped=100]
# Augmenting train:  10%|▉         | 762/7752 [37:42<4:33:19,  2.35s/it, Written=114, Skipped=100]
# Augmenting train:  10%|▉         | 762/7752 [37:56<4:33:19,  2.35s/it, Written=114, Skipped=101]
# Augmenting train:  10%|▉         | 764/7752 [37:56<6:22:43,  3.29s/it, Written=114, Skipped=101]
# Augmenting train:  10%|▉         | 764/7752 [38:11<6:22:43,  3.29s/it, Written=114, Skipped=102]
# Augmenting train:  10%|▉         | 768/7752 [38:11<6:35:10,  3.40s/it, Written=114, Skipped=102]
# Augmenting train:  10%|▉         | 768/7752 [38:17<6:35:10,  3.40s/it, Written=115, Skipped=102]
# Augmenting train:  10%|▉         | 770/7752 [38:17<6:30:36,  3.36s/it, Written=115, Skipped=102]
# Augmenting train:  10%|▉         | 770/7752 [38:34<6:30:36,  3.36s/it, Written=116, Skipped=102]
# Augmenting train:  10%|▉         | 772/7752 [38:34<8:36:15,  4.44s/it, Written=116, Skipped=102]
# Augmenting train:  10%|▉         | 772/7752 [38:50<8:36:15,  4.44s/it, Written=116, Skipped=103]
# Augmenting train:  10%|▉         | 775/7752 [38:50<9:11:10,  4.74s/it, Written=116, Skipped=103]
# Augmenting train:  10%|▉         | 775/7752 [38:54<9:11:10,  4.74s/it, Written=117, Skipped=103]
# Augmenting train:  10%|█         | 776/7752 [38:54<9:10:40,  4.74s/it, Written=117, Skipped=103]
# Augmenting train:  10%|█         | 776/7752 [39:10<9:10:40,  4.74s/it, Written=117, Skipped=104]
# Augmenting train:  10%|█         | 778/7752 [39:10<10:55:57,  5.64s/it, Written=117, Skipped=104]
# Augmenting train:  10%|█         | 778/7752 [39:17<10:55:57,  5.64s/it, Written=118, Skipped=104]
# Augmenting train:  10%|█         | 786/7752 [39:17<5:10:10,  2.67s/it, Written=118, Skipped=104]
# Augmenting train:  10%|█         | 786/7752 [39:33<5:10:10,  2.67s/it, Written=118, Skipped=105]
# Augmenting train:  10%|█         | 791/7752 [39:33<5:34:40,  2.88s/it, Written=118, Skipped=105]
# Augmenting train:  10%|█         | 791/7752 [39:39<5:34:40,  2.88s/it, Written=119, Skipped=105]
# Augmenting train:  10%|█         | 793/7752 [39:39<5:36:17,  2.90s/it, Written=119, Skipped=105]
# Augmenting train:  10%|█         | 793/7752 [39:53<5:36:17,  2.90s/it, Written=119, Skipped=106]
# Augmenting train:  10%|█         | 800/7752 [39:53<4:50:54,  2.51s/it, Written=119, Skipped=106]
# Augmenting train:  10%|█         | 800/7752 [40:08<4:50:54,  2.51s/it, Written=119, Skipped=107]
# Augmenting train:  10%|█         | 804/7752 [40:08<5:27:55,  2.83s/it, Written=119, Skipped=107]
# Augmenting train:  10%|█         | 804/7752 [40:25<5:27:55,  2.83s/it, Written=119, Skipped=108]
# Augmenting train:  10%|█         | 806/7752 [40:25<7:13:29,  3.74s/it, Written=119, Skipped=108]
# Augmenting train:  10%|█         | 806/7752 [40:38<7:13:29,  3.74s/it, Written=119, Skipped=109]
# Augmenting train:  10%|█         | 808/7752 [40:38<8:13:51,  4.27s/it, Written=119, Skipped=109]
# Augmenting train:  10%|█         | 808/7752 [40:56<8:13:51,  4.27s/it, Written=120, Skipped=109]
# Augmenting train:  10%|█         | 812/7752 [40:56<8:19:27,  4.32s/it, Written=120, Skipped=109]
# Augmenting train:  10%|█         | 812/7752 [41:01<8:19:27,  4.32s/it, Written=121, Skipped=109]
# Augmenting train:  11%|█         | 814/7752 [41:01<7:35:16,  3.94s/it, Written=121, Skipped=109]
# Augmenting train:  11%|█         | 814/7752 [41:05<7:35:16,  3.94s/it, Written=122, Skipped=109]
# Augmenting train:  11%|█         | 816/7752 [41:05<6:50:26,  3.55s/it, Written=122, Skipped=109]
# Augmenting train:  11%|█         | 816/7752 [41:09<6:50:26,  3.55s/it, Written=123, Skipped=109]
# Augmenting train:  11%|█         | 820/7752 [41:09<4:59:14,  2.59s/it, Written=123, Skipped=109]
# Augmenting train:  11%|█         | 820/7752 [41:15<4:59:14,  2.59s/it, Written=124, Skipped=109]
# Augmenting train:  11%|█         | 821/7752 [41:15<5:42:01,  2.96s/it, Written=124, Skipped=109]
# Augmenting train:  11%|█         | 821/7752 [41:30<5:42:01,  2.96s/it, Written=124, Skipped=110]
# Augmenting train:  11%|█         | 827/7752 [41:30<5:16:37,  2.74s/it, Written=124, Skipped=110]
# Augmenting train:  11%|█         | 827/7752 [41:43<5:16:37,  2.74s/it, Written=124, Skipped=111]
# Augmenting train:  11%|█         | 829/7752 [41:43<6:38:15,  3.45s/it, Written=124, Skipped=111]
# Augmenting train:  11%|█         | 829/7752 [41:47<6:38:15,  3.45s/it, Written=125, Skipped=111]
# Augmenting train:  11%|█         | 830/7752 [41:47<6:51:01,  3.56s/it, Written=125, Skipped=111]
# Augmenting train:  11%|█         | 830/7752 [42:03<6:51:01,  3.56s/it, Written=125, Skipped=112]
# Augmenting train:  11%|█         | 847/7752 [42:03<3:02:29,  1.59s/it, Written=125, Skipped=112]
# Augmenting train:  11%|█         | 847/7752 [42:17<3:02:29,  1.59s/it, Written=126, Skipped=112]
# Augmenting train:  11%|█         | 848/7752 [42:17<4:28:11,  2.33s/it, Written=126, Skipped=112]
# Augmenting train:  11%|█         | 848/7752 [42:27<4:28:11,  2.33s/it, Written=127, Skipped=112]
# Augmenting train:  11%|█         | 855/7752 [42:27<3:51:57,  2.02s/it, Written=127, Skipped=112]
# Augmenting train:  11%|█         | 855/7752 [42:34<3:51:57,  2.02s/it, Written=128, Skipped=112]
# Augmenting train:  11%|█         | 863/7752 [42:34<2:57:54,  1.55s/it, Written=128, Skipped=112]
# Augmenting train:  11%|█         | 863/7752 [42:40<2:57:54,  1.55s/it, Written=129, Skipped=112]
# Augmenting train:  11%|█         | 864/7752 [42:40<3:29:15,  1.82s/it, Written=129, Skipped=112]
# Augmenting train:  11%|█         | 864/7752 [42:54<3:29:15,  1.82s/it, Written=129, Skipped=113]
# Augmenting train:  11%|█         | 866/7752 [42:54<5:01:14,  2.62s/it, Written=129, Skipped=113]
# Augmenting train:  11%|█         | 866/7752 [43:09<5:01:14,  2.62s/it, Written=129, Skipped=114]
# Augmenting train:  11%|█         | 867/7752 [43:09<7:23:30,  3.86s/it, Written=129, Skipped=114]
# Augmenting train:  11%|█         | 867/7752 [43:24<7:23:30,  3.86s/it, Written=129, Skipped=115]
# Augmenting train:  11%|█         | 868/7752 [43:24<10:03:53,  5.26s/it, Written=129, Skipped=115]
# Augmenting train:  11%|█         | 868/7752 [43:29<10:03:53,  5.26s/it, Written=130, Skipped=115]
# Augmenting train:  11%|█         | 872/7752 [43:29<6:46:41,  3.55s/it, Written=130, Skipped=115]
# Augmenting train:  11%|█         | 872/7752 [43:38<6:46:41,  3.55s/it, Written=131, Skipped=115]
# Augmenting train:  11%|█▏        | 877/7752 [43:38<5:21:29,  2.81s/it, Written=131, Skipped=115]
# Augmenting train:  11%|█▏        | 877/7752 [43:52<5:21:29,  2.81s/it, Written=131, Skipped=116]
# ...
# Augmenting train:  98%|█████████▊| 7595/7752 [5:52:44<14:10,  5.42s/it, Written=1240, Skipped=867]
# Augmenting train:  98%|█████████▊| 7599/7752 [5:52:44<11:10,  4.38s/it, Written=1240, Skipped=867]
# Augmenting train:  98%|█████████▊| 7599/7752 [5:52:50<11:10,  4.38s/it, Written=1241, Skipped=867]
# Augmenting train:  98%|█████████▊| 7610/7752 [5:52:50<04:24,  1.86s/it, Written=1241, Skipped=867]
# Augmenting train:  98%|█████████▊| 7610/7752 [5:52:56<04:24,  1.86s/it, Written=1242, Skipped=867]
# Augmenting train:  98%|█████████▊| 7611/7752 [5:52:56<05:05,  2.17s/it, Written=1242, Skipped=867]
# Augmenting train:  98%|█████████▊| 7611/7752 [5:53:09<05:05,  2.17s/it, Written=1243, Skipped=867]
# Augmenting train:  98%|█████████▊| 7613/7752 [5:53:09<06:48,  2.94s/it, Written=1243, Skipped=867]
# Augmenting train:  98%|█████████▊| 7613/7752 [5:53:13<06:48,  2.94s/it, Written=1244, Skipped=867]
# Augmenting train:  98%|█████████▊| 7618/7752 [5:53:13<04:42,  2.11s/it, Written=1244, Skipped=867]
# Augmenting train:  98%|█████████▊| 7618/7752 [5:53:20<04:42,  2.11s/it, Written=1245, Skipped=867]
# Augmenting train:  98%|█████████▊| 7619/7752 [5:53:20<05:51,  2.65s/it, Written=1245, Skipped=867]
# Augmenting train:  98%|█████████▊| 7619/7752 [5:53:36<05:51,  2.65s/it, Written=1245, Skipped=868]
# Augmenting train:  98%|█████████▊| 7623/7752 [5:53:36<06:38,  3.09s/it, Written=1245, Skipped=868]
# Augmenting train:  98%|█████████▊| 7623/7752 [5:53:52<06:38,  3.09s/it, Written=1245, Skipped=869]
# Augmenting train:  98%|█████████▊| 7625/7752 [5:53:52<08:50,  4.18s/it, Written=1245, Skipped=869]
# Augmenting train:  98%|█████████▊| 7625/7752 [5:53:57<08:50,  4.18s/it, Written=1246, Skipped=869]
# Augmenting train:  98%|█████████▊| 7629/7752 [5:53:57<06:12,  3.03s/it, Written=1246, Skipped=869]
# Augmenting train:  98%|█████████▊| 7629/7752 [5:54:15<06:12,  3.03s/it, Written=1246, Skipped=870]
# Augmenting train:  98%|█████████▊| 7630/7752 [5:54:15<09:50,  4.84s/it, Written=1246, Skipped=870]
# Augmenting train:  98%|█████████▊| 7630/7752 [5:54:20<09:50,  4.84s/it, Written=1247, Skipped=870]
# Augmenting train:  98%|█████████▊| 7634/7752 [5:54:20<06:36,  3.36s/it, Written=1247, Skipped=870]
# Augmenting train:  98%|█████████▊| 7634/7752 [5:54:37<06:36,  3.36s/it, Written=1247, Skipped=871]
# Augmenting train:  99%|█████████▊| 7639/7752 [5:54:37<06:27,  3.43s/it, Written=1247, Skipped=871]
# Augmenting train:  99%|█████████▊| 7639/7752 [5:54:48<06:27,  3.43s/it, Written=1248, Skipped=871]
# Augmenting train:  99%|█████████▊| 7645/7752 [5:54:48<04:55,  2.76s/it, Written=1248, Skipped=871]
# Augmenting train:  99%|█████████▊| 7645/7752 [5:55:03<04:55,  2.76s/it, Written=1248, Skipped=872]
# Augmenting train:  99%|█████████▊| 7650/7752 [5:55:03<04:48,  2.83s/it, Written=1248, Skipped=872]
# Augmenting train:  99%|█████████▊| 7650/7752 [5:55:08<04:48,  2.83s/it, Written=1249, Skipped=872]
# Augmenting train:  99%|█████████▉| 7658/7752 [5:55:08<02:58,  1.89s/it, Written=1249, Skipped=872]
# Augmenting train:  99%|█████████▉| 7658/7752 [5:55:15<02:58,  1.89s/it, Written=1250, Skipped=872]
# Augmenting train:  99%|█████████▉| 7663/7752 [5:55:15<02:32,  1.71s/it, Written=1250, Skipped=872]
# Augmenting train:  99%|█████████▉| 7663/7752 [5:55:20<02:32,  1.71s/it, Written=1251, Skipped=872]
# Augmenting train:  99%|█████████▉| 7664/7752 [5:55:20<02:56,  2.00s/it, Written=1251, Skipped=872]
# Augmenting train:  99%|█████████▉| 7664/7752 [5:55:25<02:56,  2.00s/it, Written=1252, Skipped=872]
# Augmenting train:  99%|█████████▉| 7667/7752 [5:55:25<02:39,  1.88s/it, Written=1252, Skipped=872]
# Augmenting train:  99%|█████████▉| 7667/7752 [5:55:32<02:39,  1.88s/it, Written=1253, Skipped=872]
# Augmenting train:  99%|█████████▉| 7668/7752 [5:55:32<03:19,  2.38s/it, Written=1253, Skipped=872]
# Augmenting train:  99%|█████████▉| 7668/7752 [5:55:36<03:19,  2.38s/it, Written=1254, Skipped=872]
# Augmenting train:  99%|█████████▉| 7672/7752 [5:55:36<02:32,  1.91s/it, Written=1254, Skipped=872]
# Augmenting train:  99%|█████████▉| 7672/7752 [5:55:50<02:32,  1.91s/it, Written=1254, Skipped=873]
# Augmenting train:  99%|█████████▉| 7676/7752 [5:55:50<03:08,  2.48s/it, Written=1254, Skipped=873]
# Augmenting train:  99%|█████████▉| 7676/7752 [5:55:57<03:08,  2.48s/it, Written=1255, Skipped=873]
# Augmenting train:  99%|█████████▉| 7680/7752 [5:55:57<02:38,  2.21s/it, Written=1255, Skipped=873]
# Augmenting train:  99%|█████████▉| 7680/7752 [5:56:09<02:38,  2.21s/it, Written=1255, Skipped=874]
# Augmenting train:  99%|█████████▉| 7681/7752 [5:56:09<03:50,  3.24s/it, Written=1255, Skipped=874]
# Augmenting train:  99%|█████████▉| 7681/7752 [5:56:23<03:50,  3.24s/it, Written=1255, Skipped=875]
# Augmenting train:  99%|█████████▉| 7685/7752 [5:56:23<03:44,  3.35s/it, Written=1255, Skipped=875]
# Augmenting train:  99%|█████████▉| 7685/7752 [5:56:29<03:44,  3.35s/it, Written=1256, Skipped=875]
# Augmenting train:  99%|█████████▉| 7688/7752 [5:56:29<03:12,  3.01s/it, Written=1256, Skipped=875]
# Augmenting train:  99%|█████████▉| 7688/7752 [5:56:45<03:12,  3.01s/it, Written=1256, Skipped=876]
# Augmenting train:  99%|█████████▉| 7694/7752 [5:56:45<02:44,  2.84s/it, Written=1256, Skipped=876]
# Augmenting train:  99%|█████████▉| 7694/7752 [5:57:00<02:44,  2.84s/it, Written=1256, Skipped=877]
# Augmenting train:  99%|█████████▉| 7695/7752 [5:57:00<03:49,  4.02s/it, Written=1256, Skipped=877]
# Augmenting train:  99%|█████████▉| 7695/7752 [5:57:04<03:49,  4.02s/it, Written=1257, Skipped=877]
# Augmenting train:  99%|█████████▉| 7698/7752 [5:57:04<02:54,  3.22s/it, Written=1257, Skipped=877]
# Augmenting train:  99%|█████████▉| 7698/7752 [5:57:15<02:54,  3.22s/it, Written=1258, Skipped=877]
# Augmenting train:  99%|█████████▉| 7703/7752 [5:57:15<02:18,  2.83s/it, Written=1258, Skipped=877]
# Augmenting train:  99%|█████████▉| 7703/7752 [5:57:22<02:18,  2.83s/it, Written=1259, Skipped=877]
# Augmenting train:  99%|█████████▉| 7704/7752 [5:57:22<02:34,  3.23s/it, Written=1259, Skipped=877]
# Augmenting train:  99%|█████████▉| 7704/7752 [5:57:29<02:34,  3.23s/it, Written=1260, Skipped=877]
# Augmenting train:  99%|█████████▉| 7705/7752 [5:57:29<02:52,  3.67s/it, Written=1260, Skipped=877]
# Augmenting train:  99%|█████████▉| 7705/7752 [5:57:36<02:52,  3.67s/it, Written=1261, Skipped=877]
# Augmenting train:  99%|█████████▉| 7706/7752 [5:57:36<03:14,  4.23s/it, Written=1261, Skipped=877]
# Augmenting train:  99%|█████████▉| 7706/7752 [5:57:57<03:14,  4.23s/it, Written=1261, Skipped=878]
# Augmenting train:  99%|█████████▉| 7707/7752 [5:57:57<05:31,  7.36s/it, Written=1261, Skipped=878]
# Augmenting train:  99%|█████████▉| 7707/7752 [5:58:10<05:31,  7.36s/it, Written=1261, Skipped=879]
# Augmenting train:  99%|█████████▉| 7708/7752 [5:58:10<06:14,  8.52s/it, Written=1261, Skipped=879]
# Augmenting train:  99%|█████████▉| 7708/7752 [5:58:18<06:14,  8.52s/it, Written=1262, Skipped=879]
# Augmenting train:  99%|█████████▉| 7709/7752 [5:58:18<06:00,  8.38s/it, Written=1262, Skipped=879]
# Augmenting train:  99%|█████████▉| 7709/7752 [5:58:25<06:00,  8.38s/it, Written=1263, Skipped=879]
# Augmenting train:  99%|█████████▉| 7710/7752 [5:58:25<05:39,  8.09s/it, Written=1263, Skipped=879]
# Augmenting train:  99%|█████████▉| 7710/7752 [5:58:32<05:39,  8.09s/it, Written=1264, Skipped=879]
# Augmenting train:  99%|█████████▉| 7711/7752 [5:58:32<05:20,  7.81s/it, Written=1264, Skipped=879]
# Augmenting train:  99%|█████████▉| 7711/7752 [5:58:38<05:20,  7.81s/it, Written=1265, Skipped=879]
# Augmenting train:  99%|█████████▉| 7712/7752 [5:58:38<04:52,  7.32s/it, Written=1265, Skipped=879]
# Augmenting train:  99%|█████████▉| 7712/7752 [5:58:46<04:52,  7.32s/it, Written=1266, Skipped=879]
# Augmenting train:  99%|█████████▉| 7713/7752 [5:58:46<04:53,  7.52s/it, Written=1266, Skipped=879]
# Augmenting train:  99%|█████████▉| 7713/7752 [5:58:52<04:53,  7.52s/it, Written=1267, Skipped=879]
# Augmenting train: 100%|█████████▉| 7714/7752 [5:58:52<04:26,  7.00s/it, Written=1267, Skipped=879]
# Augmenting train: 100%|█████████▉| 7714/7752 [5:58:58<04:26,  7.00s/it, Written=1268, Skipped=879]
# Augmenting train: 100%|█████████▉| 7715/7752 [5:58:58<04:04,  6.60s/it, Written=1268, Skipped=879]
# Augmenting train: 100%|█████████▉| 7715/7752 [5:59:05<04:04,  6.60s/it, Written=1269, Skipped=879]
# Augmenting train: 100%|█████████▉| 7716/7752 [5:59:05<04:05,  6.83s/it, Written=1269, Skipped=879]
# Augmenting train: 100%|█████████▉| 7716/7752 [5:59:11<04:05,  6.83s/it, Written=1270, Skipped=879]
# Augmenting train: 100%|█████████▉| 7717/7752 [5:59:11<03:51,  6.60s/it, Written=1270, Skipped=879]
# Augmenting train: 100%|█████████▉| 7717/7752 [5:59:16<03:51,  6.60s/it, Written=1271, Skipped=879]
# Augmenting train: 100%|█████████▉| 7718/7752 [5:59:16<03:26,  6.08s/it, Written=1271, Skipped=879]
# Augmenting train: 100%|█████████▉| 7718/7752 [5:59:20<03:26,  6.08s/it, Written=1272, Skipped=879]
# Augmenting train: 100%|█████████▉| 7719/7752 [5:59:20<03:04,  5.58s/it, Written=1272, Skipped=879]
# Augmenting train: 100%|█████████▉| 7719/7752 [5:59:27<03:04,  5.58s/it, Written=1273, Skipped=879]
# Augmenting train: 100%|█████████▉| 7720/7752 [5:59:27<03:10,  5.94s/it, Written=1273, Skipped=879]
# Augmenting train: 100%|█████████▉| 7720/7752 [5:59:42<03:10,  5.94s/it, Written=1273, Skipped=880]
# Augmenting train: 100%|█████████▉| 7721/7752 [5:59:42<04:27,  8.64s/it, Written=1273, Skipped=880]
# Augmenting train: 100%|█████████▉| 7721/7752 [5:59:50<04:27,  8.64s/it, Written=1274, Skipped=880]
# Augmenting train: 100%|█████████▉| 7722/7752 [5:59:50<04:15,  8.52s/it, Written=1274, Skipped=880]
# Augmenting train: 100%|█████████▉| 7722/7752 [5:59:57<04:15,  8.52s/it, Written=1275, Skipped=880]
# Augmenting train: 100%|█████████▉| 7723/7752 [5:59:57<03:48,  7.88s/it, Written=1275, Skipped=880]
# Augmenting train: 100%|█████████▉| 7723/7752 [6:00:05<03:48,  7.88s/it, Written=1276, Skipped=880]
# Augmenting train: 100%|█████████▉| 7724/7752 [6:00:05<03:45,  8.06s/it, Written=1276, Skipped=880]
# Augmenting train: 100%|█████████▉| 7724/7752 [6:00:11<03:45,  8.06s/it, Written=1277, Skipped=880]
# Augmenting train: 100%|█████████▉| 7725/7752 [6:00:11<03:20,  7.42s/it, Written=1277, Skipped=880]
# Augmenting train: 100%|█████████▉| 7725/7752 [6:00:27<03:20,  7.42s/it, Written=1277, Skipped=881]
# Augmenting train: 100%|█████████▉| 7726/7752 [6:00:27<04:17,  9.89s/it, Written=1277, Skipped=881]
# Augmenting train: 100%|█████████▉| 7726/7752 [6:00:33<04:17,  9.89s/it, Written=1278, Skipped=881]
# Augmenting train: 100%|█████████▉| 7727/7752 [6:00:33<03:43,  8.94s/it, Written=1278, Skipped=881]
# Augmenting train: 100%|█████████▉| 7727/7752 [6:00:40<03:43,  8.94s/it, Written=1279, Skipped=881]
# Augmenting train: 100%|█████████▉| 7728/7752 [6:00:40<03:18,  8.28s/it, Written=1279, Skipped=881]
# Augmenting train: 100%|█████████▉| 7728/7752 [6:00:45<03:18,  8.28s/it, Written=1280, Skipped=881]
# Augmenting train: 100%|█████████▉| 7729/7752 [6:00:45<02:48,  7.33s/it, Written=1280, Skipped=881]
# Augmenting train: 100%|█████████▉| 7729/7752 [6:00:58<02:48,  7.33s/it, Written=1281, Skipped=881]
# Augmenting train: 100%|█████████▉| 7730/7752 [6:00:58<03:15,  8.87s/it, Written=1281, Skipped=881]
# Augmenting train: 100%|█████████▉| 7730/7752 [6:01:04<03:15,  8.87s/it, Written=1282, Skipped=881]
# Augmenting train: 100%|█████████▉| 7731/7752 [6:01:04<02:49,  8.08s/it, Written=1282, Skipped=881]
# Augmenting train: 100%|█████████▉| 7731/7752 [6:01:21<02:49,  8.08s/it, Written=1282, Skipped=882]
# Augmenting train: 100%|█████████▉| 7732/7752 [6:01:21<03:32, 10.63s/it, Written=1282, Skipped=882]
# Augmenting train: 100%|█████████▉| 7732/7752 [6:01:37<03:32, 10.63s/it, Written=1282, Skipped=883]
# Augmenting train: 100%|█████████▉| 7733/7752 [6:01:37<03:52, 12.24s/it, Written=1282, Skipped=883]
# Augmenting train: 100%|█████████▉| 7733/7752 [6:01:42<03:52, 12.24s/it, Written=1283, Skipped=883]
# Augmenting train: 100%|█████████▉| 7734/7752 [6:01:42<03:02, 10.14s/it, Written=1283, Skipped=883]
# Augmenting train: 100%|█████████▉| 7734/7752 [6:01:51<03:02, 10.14s/it, Written=1284, Skipped=883]
# Augmenting train: 100%|█████████▉| 7735/7752 [6:01:51<02:46,  9.82s/it, Written=1284, Skipped=883]
# Augmenting train: 100%|█████████▉| 7735/7752 [6:01:56<02:46,  9.82s/it, Written=1285, Skipped=883]
# Augmenting train: 100%|█████████▉| 7736/7752 [6:01:56<02:16,  8.53s/it, Written=1285, Skipped=883]
# Augmenting train: 100%|█████████▉| 7736/7752 [6:02:01<02:16,  8.53s/it, Written=1286, Skipped=883]
# Augmenting train: 100%|█████████▉| 7737/7752 [6:02:01<01:49,  7.27s/it, Written=1286, Skipped=883]
# Augmenting train: 100%|█████████▉| 7737/7752 [6:02:08<01:49,  7.27s/it, Written=1287, Skipped=883]
# Augmenting train: 100%|█████████▉| 7738/7752 [6:02:08<01:43,  7.39s/it, Written=1287, Skipped=883]
# Augmenting train: 100%|█████████▉| 7738/7752 [6:02:14<01:43,  7.39s/it, Written=1288, Skipped=883]
# Augmenting train: 100%|█████████▉| 7739/7752 [6:02:14<01:30,  6.93s/it, Written=1288, Skipped=883]
# Augmenting train: 100%|█████████▉| 7739/7752 [6:02:23<01:30,  6.93s/it, Written=1289, Skipped=883]
# Augmenting train: 100%|█████████▉| 7740/7752 [6:02:23<01:30,  7.51s/it, Written=1289, Skipped=883]
# Augmenting train: 100%|█████████▉| 7740/7752 [6:02:29<01:30,  7.51s/it, Written=1290, Skipped=883]
# Augmenting train: 100%|█████████▉| 7741/7752 [6:02:29<01:17,  7.04s/it, Written=1290, Skipped=883]
# Augmenting train: 100%|█████████▉| 7741/7752 [6:02:46<01:17,  7.04s/it, Written=1290, Skipped=884]
# Augmenting train: 100%|█████████▉| 7742/7752 [6:02:46<01:38,  9.86s/it, Written=1290, Skipped=884]
# Augmenting train: 100%|█████████▉| 7742/7752 [6:02:52<01:38,  9.86s/it, Written=1291, Skipped=884]
# Augmenting train: 100%|█████████▉| 7743/7752 [6:02:52<01:20,  8.93s/it, Written=1291, Skipped=884]
# Augmenting train: 100%|█████████▉| 7743/7752 [6:02:58<01:20,  8.93s/it, Written=1292, Skipped=884]
# Augmenting train: 100%|█████████▉| 7744/7752 [6:02:58<01:04,  8.09s/it, Written=1292, Skipped=884]
# Augmenting train: 100%|█████████▉| 7744/7752 [6:03:06<01:04,  8.09s/it, Written=1293, Skipped=884]
# Augmenting train: 100%|█████████▉| 7745/7752 [6:03:06<00:54,  7.81s/it, Written=1293, Skipped=884]
# Augmenting train: 100%|█████████▉| 7745/7752 [6:03:21<00:54,  7.81s/it, Written=1293, Skipped=885]
# Augmenting train: 100%|█████████▉| 7746/7752 [6:03:21<01:00, 10.13s/it, Written=1293, Skipped=885]
# Augmenting train: 100%|█████████▉| 7746/7752 [6:03:28<01:00, 10.13s/it, Written=1294, Skipped=885]
# Augmenting train: 100%|█████████▉| 7747/7752 [6:03:28<00:45,  9.19s/it, Written=1294, Skipped=885]
# Augmenting train: 100%|█████████▉| 7747/7752 [6:03:38<00:45,  9.19s/it, Written=1295, Skipped=885]
# Augmenting train: 100%|█████████▉| 7747/7752 [6:03:45<00:45,  9.19s/it, Written=1296, Skipped=885]
# Augmenting train: 100%|█████████▉| 7748/7752 [6:03:45<00:46, 11.54s/it, Written=1296, Skipped=885]
# Augmenting train: 100%|█████████▉| 7748/7752 [6:03:53<00:46, 11.54s/it, Written=1297, Skipped=885]
# Augmenting train: 100%|█████████▉| 7749/7752 [6:03:53<00:31, 10.43s/it, Written=1297, Skipped=885]
# Augmenting train: 100%|█████████▉| 7749/7752 [6:04:09<00:31, 10.43s/it, Written=1298, Skipped=885]
# Augmenting train: 100%|█████████▉| 7750/7752 [6:04:09<00:24, 12.15s/it, Written=1298, Skipped=885]
# Augmenting train: 100%|█████████▉| 7750/7752 [6:04:17<00:24, 12.15s/it, Written=1299, Skipped=885]
# Augmenting train: 100%|█████████▉| 7751/7752 [6:04:17<00:10, 10.75s/it, Written=1299, Skipped=885]
# Augmenting train: 100%|█████████▉| 7751/7752 [6:04:22<00:10, 10.75s/it, Written=1300, Skipped=885]
# Augmenting train: 100%|██████████| 7752/7752 [6:04:22<00:00,  2.82s/it, Written=1300, Skipped=885]
# ✅  train done
#     Written : 1300
#     Skipped : 885
#     Saved   : /kaggle/working/augmented/all_acts_train_augmented.jsonl
#
# ============================================================
# 🏁  AUGMENTATION COMPLETE
#     Total written : 1300
#     Total skipped : 885
#     Output dir    : /kaggle/working/augmented
# ============================================================
