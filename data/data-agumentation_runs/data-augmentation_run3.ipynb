# %%
# !pip install jsonschema transformers accelerate sentencepiece bitsandbytes tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 30.5 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
"""
==============================================================
Nyaya-LLM  —  Phase 2 Dataset Augmentation (Kaggle / P100)
==============================================================
Augments all three splits (train, val, test) using a
HuggingFace model loaded directly on the P100 GPU.

Long sections (>3000 chars) are chunked at subsection
boundaries so every part of the statute gets covered.
==============================================================
"""

import json
import re
import os
import time
import torch
import shutil
import gc
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from jsonschema import validate, ValidationError

# ==============================
# ⚙️  CONFIG
# ==============================
MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"

# ── Paths ───────────────────────────────────────────────────
INPUT_DIR  = "/kaggle/input/datasets/shreyashgaur221/nyaya-llm-processed"
OUTPUT_DIR = "/kaggle/working/augmented"
WIP_DATASET_PATH = "/kaggle/input/datasets/shreyashgaur221/nyaya-augmented-wip" # For Run 2+

SPLITS = {
    "train": "all_acts_train.jsonl",
    "val":   "all_acts_val.jsonl",
    "test":  "all_acts_test.jsonl",
}

# ── Processing Limits ───────────────────────────────────────
CHUNK_SIZE  = 3000    
RETRY_LIMIT = 3       
MAX_RUNTIME_HOURS = 11.75

# ==============================
# 📦  JSON SCHEMA
# ==============================
AUGMENT_SCHEMA = {
    "type": "object",
    "properties": {
        "instruction": {"type": "string"},
        "input":       {"type": "string"},
        "output":      {"type": "string"}
    },
    "required": ["instruction", "input", "output"]
}

# ==============================
# 💬  PROMPT (CHAT TEMPLATE)
# ==============================
SYSTEM_PROMPT = """You are a strict Indian legal dataset generator.

RULES:
1. Only use the provided statute text. Do NOT add outside legal knowledge.
2. Do NOT invent punishments, sections, or acts not mentioned in the text.
3. Output STRICT JSON only. No markdown, no explanation, no preamble.
4. Return exactly ONE valid JSON object.
5. The instruction must be a realistic question a layperson or law student would ask.
6. The output must apply or explain the statute — not just quote it verbatim."""

def build_messages(original_instruction: str, chunk: str) -> list:
    user_msg = f"""ORIGINAL INSTRUCTION:
{original_instruction}

STATUTE TEXT:
{chunk}

---
Generate a new, enriched training example that:
- Asks a reasoning or application question about this statute text
- Answers it using ONLY the information in the statute text above
- Does NOT reference sections or provisions outside the text above

Respond ONLY with this JSON format, nothing else:
{{
  "instruction": "...",
  "input": "",
  "output": "..."
}}"""

    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg}
    ]

# ==============================
# ✂️  CHUNKER
# ==============================
def chunk_text(text: str, max_chars: int = CHUNK_SIZE) -> list:
    if len(text) <= max_chars:
        return [text]

    parts   = text.split("\n\n")
    chunks  = []
    current = ""

    for part in parts:
        if len(part) > max_chars:
            if current:
                chunks.append(current.strip())
                current = ""
            sentences = re.split(r'(?<=[.;])\s+', part)
            for sentence in sentences:
                if len(current) + len(sentence) <= max_chars:
                    current += " " + sentence
                else:
                    if current:
                        chunks.append(current.strip())
                    current = sentence
        elif len(current) + len(part) + 2 <= max_chars:
            current += "\n\n" + part
        else:
            if current:
                chunks.append(current.strip())
            current = part

    if current:
        chunks.append(current.strip())

    return [c for c in chunks if len(c) >= 50]

# ==============================
# 🤖  MODEL LOADING
# ==============================
def load_model():
    print(f"Loading {MODEL_NAME} in 4-bit on GPU...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16, 
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.float16,
        trust_remote_code=True
    )
    model.eval()
    print("Model loaded.\n")
    return model, tokenizer

# ==============================
# 🔁  GENERATION (WITH OOM KILLER)
# ==============================
def generate(model, tokenizer, messages: list) -> str:
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.2,
            do_sample=True,
            top_p=0.8,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id
        )

    new_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    result = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    
    del inputs
    del outputs
    del new_tokens
    torch.cuda.empty_cache()
    gc.collect()
    
    return result

# ==============================
# 🔍  JSON EXTRACTION
# ==============================
def extract_json(text: str):
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        return None
    try:
        return json.loads(match.group())
    except Exception:
        return None

# ==============================
# 🛡️  HALLUCINATION GUARD (FIXED)
# ==============================
def hallucination_guard(original_text: str, generated_output: str) -> bool:
    out_lower  = generated_output.lower()
    orig_lower = original_text.lower()

    # Lexical overlap only — remove the strict act/section requirement
    orig_words  = set(orig_lower.split())
    gen_words   = set(out_lower.split())
    overlap     = len(orig_words & gen_words)

    # Just needs reasonable overlap with source text
    return overlap > 10

# ==============================
# 💾  CHECKPOINT HELPER
# ==============================
def load_processed_keys(output_path: str) -> set:
    processed = set()
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    key = (obj.get("source_instruction", ""), obj.get("chunk_index", 0))
                    processed.add(key)
                except Exception:
                    pass
    return processed

# ==============================
# 🚀  MAIN
# ==============================
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # --- RUN 2 RESTORATION LOGIC ---
    if os.path.exists(WIP_DATASET_PATH):
        print("Restoring previous progress from WIP dataset...")
        for filename in os.listdir(WIP_DATASET_PATH):
            if filename.endswith(".jsonl"):
                src = os.path.join(WIP_DATASET_PATH, filename)
                dst = os.path.join(OUTPUT_DIR, filename)
                shutil.copy2(src, dst)
                print(f"✅ Restored: {filename}")
        print("Ready to resume!\n")
    # -------------------------------
    
    START_TIME = time.time()
    MAX_RUNTIME_SEC = MAX_RUNTIME_HOURS * 3600 

    model, tokenizer = load_model()

    total_written = 0
    total_skipped = 0

    for split_name, filename in SPLITS.items():
        input_path  = os.path.join(INPUT_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, f"all_acts_{split_name}_augmented.jsonl")

        if not os.path.exists(input_path):
            print(f"⚠️  {input_path} not found — skipping {split_name}")
            continue

        with open(input_path, "r", encoding="utf-8") as f:
            data = [json.loads(line) for line in f]

        processed_keys = load_processed_keys(output_path)
        total_chunks = sum(len(chunk_text(d["output"])) for d in data)

        print(f"\n{'='*60}")
        print(f"📂  Split         : {split_name.upper()}")
        print(f"    Samples       : {len(data)}")
        print(f"    Total chunks  : {total_chunks}")
        print(f"    Already done  : {len(processed_keys)}")
        print(f"    Remaining     : {total_chunks - len(processed_keys)}")
        print(f"{'='*60}\n")

        split_written = 0
        split_skipped = 0

        pbar = tqdm(data, desc=f"Augmenting {split_name}")
        with open(output_path, "a", encoding="utf-8") as outfile:
            for example in pbar:
                instruction = example["instruction"]
                chunks      = chunk_text(example["output"])

                for chunk_idx, chunk in enumerate(chunks):
                    
                    if time.time() - START_TIME > MAX_RUNTIME_SEC:
                        print(f"\n⚠️ REACHED {MAX_RUNTIME_HOURS} HOURS. GRACEFULLY STOPPING.")
                        print(f"📊 Stats this run -> Written: {split_written} | Skipped: {split_skipped}")
                        print(f"💾 Files safely saved to: {OUTPUT_DIR}")
                        return 
                    
                    key = (instruction, chunk_idx)

                    if key in processed_keys:
                        continue

                    retries = 0
                    success = False

                    while retries < RETRY_LIMIT and not success:
                        try:
                            messages = build_messages(instruction, chunk)
                            raw      = generate(model, tokenizer, messages)
                            parsed   = extract_json(raw)

                            if parsed is None:
                                raise ValueError("No JSON found")

                            validate(instance=parsed, schema=AUGMENT_SCHEMA)

                            if not hallucination_guard(chunk, parsed["output"]):
                                raise ValueError("Hallucination guard failed")

                            parsed["source_instruction"] = instruction
                            parsed["chunk_index"]        = chunk_idx
                            parsed["total_chunks"]       = len(chunks)
                            parsed["split"]              = split_name

                            outfile.write(json.dumps(parsed, ensure_ascii=False) + "\n")
                            outfile.flush()
                            success       = True
                            split_written += 1

                        except (ValidationError, ValueError):
                            retries += 1
                            time.sleep(0.5)
                        except Exception as e:
                            print(f"\n❌ Unexpected error: {e}")
                            retries += 1
                            time.sleep(1)

                    if not success:
                        split_skipped += 1
                        
                    # LIVE TRACKER: Updates the progress bar with real-time stats!
                    pbar.set_postfix({"Written": split_written, "Skipped": split_skipped})

        total_written += split_written
        total_skipped += split_skipped

        print(f"\n✅  {split_name} done")
        print(f"    Written : {split_written}")
        print(f"    Skipped : {split_skipped}")
        print(f"    Saved   : {output_path}")

    print(f"\n{'='*60}")
    print(f"🏁  AUGMENTATION COMPLETE")
    print(f"    Total written : {total_written}")
    print(f"    Total skipped : {total_skipped}")
    print(f"    Output dir    : {OUTPUT_DIR}")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# Restoring previous progress from WIP dataset...
# ✅ Restored: all_acts_train_augmented.jsonl
# Ready to resume!
#
# Loading Qwen/Qwen2.5-7B-Instruct in 4-bit on GPU...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded.
#
#
# ============================================================
# 📂  Split         : TRAIN
#     Samples       : 7752
#     Total chunks  : 7935
#     Already done  : 1824
#     Remaining     : 6111
# ============================================================
# Augmenting train:   0%|          | 0/7752 [00:00<?, ?it/s]
# Augmenting train:   0%|          | 0/7752 [00:16<?, ?it/s, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:16<35:45:12, 16.61s/it, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:32<35:45:12, 16.61s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:32<21:49:08, 10.14s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:48<21:49:08, 10.14s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [00:48<10:56:16,  5.08s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [00:55<10:56:16,  5.08s/it, Written=1, Skipped=3]
# Augmenting train:   0%|          | 23/7752 [00:55<3:29:23,  1.63s/it, Written=1, Skipped=3]
# Augmenting train:   0%|          | 23/7752 [01:10<3:29:23,  1.63s/it, Written=1, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [01:10<3:20:43,  1.56s/it, Written=1, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [01:29<3:20:43,  1.56s/it, Written=1, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:29<4:54:25,  2.29s/it, Written=1, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:52<4:54:25,  2.29s/it, Written=1, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [01:52<7:54:40,  3.69s/it, Written=1, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [02:10<7:54:40,  3.69s/it, Written=1, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [02:10<8:20:33,  3.89s/it, Written=1, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [02:27<8:20:33,  3.89s/it, Written=1, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:27<8:03:21,  3.76s/it, Written=1, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:43<8:03:21,  3.76s/it, Written=1, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:43<9:27:27,  4.42s/it, Written=1, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:49<9:27:27,  4.42s/it, Written=2, Skipped=9]
# Augmenting train:   1%|          | 49/7752 [02:49<9:46:45,  4.57s/it, Written=2, Skipped=9]
# Augmenting train:   1%|          | 49/7752 [03:08<9:46:45,  4.57s/it, Written=2, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [03:08<6:47:15,  3.18s/it, Written=2, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [03:23<6:47:15,  3.18s/it, Written=2, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [03:23<7:05:06,  3.32s/it, Written=2, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [03:39<7:05:06,  3.32s/it, Written=2, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:39<8:05:13,  3.79s/it, Written=2, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:54<8:05:13,  3.79s/it, Written=2, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [03:54<9:29:12,  4.44s/it, Written=2, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [04:09<9:29:12,  4.44s/it, Written=2, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [04:09<11:48:51,  5.54s/it, Written=2, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [04:22<11:48:51,  5.54s/it, Written=2, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [04:22<14:01:02,  6.57s/it, Written=2, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [04:38<14:01:02,  6.57s/it, Written=2, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:38<14:47:56,  6.94s/it, Written=2, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:54<14:47:56,  6.94s/it, Written=2, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [04:54<15:29:38,  7.26s/it, Written=2, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [05:11<15:29:38,  7.26s/it, Written=2, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [05:11<10:16:10,  4.82s/it, Written=2, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [05:22<10:16:10,  4.82s/it, Written=2, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [05:22<7:33:43,  3.55s/it, Written=2, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [05:38<7:33:43,  3.55s/it, Written=2, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [05:38<6:26:30,  3.03s/it, Written=2, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [06:01<6:26:30,  3.03s/it, Written=2, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [06:01<7:20:56,  3.46s/it, Written=2, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [06:18<7:20:56,  3.46s/it, Written=2, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [06:18<8:25:11,  3.96s/it, Written=2, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [06:35<8:25:11,  3.96s/it, Written=2, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [06:35<7:54:30,  3.72s/it, Written=2, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [06:51<7:54:30,  3.72s/it, Written=3, Skipped=23]
# Augmenting train:   1%|▏         | 106/7752 [06:51<10:15:20,  4.83s/it, Written=3, Skipped=23]
# Augmenting train:   1%|▏         | 106/7752 [07:06<10:15:20,  4.83s/it, Written=3, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [07:06<11:19:26,  5.33s/it, Written=3, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [07:21<11:19:26,  5.33s/it, Written=3, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [07:21<8:01:20,  3.78s/it, Written=3, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [07:44<8:01:20,  3.78s/it, Written=3, Skipped=26]
# Augmenting train:   2%|▏         | 119/7752 [07:44<9:12:04,  4.34s/it, Written=3, Skipped=26]
# Augmenting train:   2%|▏         | 119/7752 [08:02<9:12:04,  4.34s/it, Written=3, Skipped=27]
# Augmenting train:   2%|▏         | 121/7752 [08:02<10:44:36,  5.07s/it, Written=3, Skipped=27]
# Augmenting train:   2%|▏         | 121/7752 [08:19<10:44:36,  5.07s/it, Written=3, Skipped=28]
# Augmenting train:   2%|▏         | 123/7752 [08:19<12:15:33,  5.78s/it, Written=3, Skipped=28]
# Augmenting train:   2%|▏         | 123/7752 [08:48<12:15:33,  5.78s/it, Written=3, Skipped=29]
# Augmenting train:   2%|▏         | 124/7752 [08:48<18:09:55,  8.57s/it, Written=3, Skipped=29]
# Augmenting train:   2%|▏         | 124/7752 [09:04<18:09:55,  8.57s/it, Written=3, Skipped=30]
# Augmenting train:   2%|▏         | 126/7752 [09:04<18:06:37,  8.55s/it, Written=3, Skipped=30]
# Augmenting train:   2%|▏         | 126/7752 [09:19<18:06:37,  8.55s/it, Written=3, Skipped=31]
# Augmenting train:   2%|▏         | 128/7752 [09:19<17:16:44,  8.16s/it, Written=3, Skipped=31]
# Augmenting train:   2%|▏         | 128/7752 [09:35<17:16:44,  8.16s/it, Written=4, Skipped=31]
# Augmenting train:   2%|▏         | 130/7752 [09:35<17:08:02,  8.09s/it, Written=4, Skipped=31]
# Augmenting train:   2%|▏         | 130/7752 [09:50<17:08:02,  8.09s/it, Written=4, Skipped=32]
# Augmenting train:   2%|▏         | 138/7752 [09:50<9:08:34,  4.32s/it, Written=4, Skipped=32]
# Augmenting train:   2%|▏         | 138/7752 [10:06<9:08:34,  4.32s/it, Written=4, Skipped=33]
# Augmenting train:   2%|▏         | 139/7752 [10:06<11:35:11,  5.48s/it, Written=4, Skipped=33]
# Augmenting train:   2%|▏         | 139/7752 [10:26<11:35:11,  5.48s/it, Written=4, Skipped=34]
# Augmenting train:   2%|▏         | 140/7752 [10:26<15:13:02,  7.20s/it, Written=4, Skipped=34]
# Augmenting train:   2%|▏         | 140/7752 [10:41<15:13:02,  7.20s/it, Written=4, Skipped=35]
# Augmenting train:   2%|▏         | 145/7752 [10:41<11:03:34,  5.23s/it, Written=4, Skipped=35]
# Augmenting train:   2%|▏         | 145/7752 [11:03<11:03:34,  5.23s/it, Written=4, Skipped=36]
# Augmenting train:   2%|▏         | 146/7752 [11:03<15:26:16,  7.31s/it, Written=4, Skipped=36]
# Augmenting train:   2%|▏         | 146/7752 [11:21<15:26:16,  7.31s/it, Written=4, Skipped=37]
# Augmenting train:   2%|▏         | 147/7752 [11:21<18:31:39,  8.77s/it, Written=4, Skipped=37]
# Augmenting train:   2%|▏         | 147/7752 [11:36<18:31:39,  8.77s/it, Written=4, Skipped=38]
# Augmenting train:   2%|▏         | 149/7752 [11:36<17:50:45,  8.45s/it, Written=4, Skipped=38]
# Augmenting train:   2%|▏         | 149/7752 [11:57<17:50:45,  8.45s/it, Written=4, Skipped=39]
# Augmenting train:   2%|▏         | 151/7752 [11:57<18:54:19,  8.95s/it, Written=4, Skipped=39]
# Augmenting train:   2%|▏         | 151/7752 [12:13<18:54:19,  8.95s/it, Written=4, Skipped=40]
# Augmenting train:   2%|▏         | 153/7752 [12:13<18:30:16,  8.77s/it, Written=4, Skipped=40]
# Augmenting train:   2%|▏         | 153/7752 [12:28<18:30:16,  8.77s/it, Written=4, Skipped=41]
# Augmenting train:   2%|▏         | 155/7752 [12:28<17:46:10,  8.42s/it, Written=4, Skipped=41]
# Augmenting train:   2%|▏         | 155/7752 [12:44<17:46:10,  8.42s/it, Written=4, Skipped=42]
# Augmenting train:   2%|▏         | 156/7752 [12:44<20:26:28,  9.69s/it, Written=4, Skipped=42]
# Augmenting train:   2%|▏         | 156/7752 [13:04<20:26:28,  9.69s/it, Written=4, Skipped=43]
# Augmenting train:   2%|▏         | 157/7752 [13:04<24:42:12, 11.71s/it, Written=4, Skipped=43]
# Augmenting train:   2%|▏         | 157/7752 [13:19<24:42:12, 11.71s/it, Written=4, Skipped=44]
# Augmenting train:   2%|▏         | 161/7752 [13:19<15:39:29,  7.43s/it, Written=4, Skipped=44]
# Augmenting train:   2%|▏         | 161/7752 [13:33<15:39:29,  7.43s/it, Written=4, Skipped=45]
# Augmenting train:   2%|▏         | 163/7752 [13:33<15:40:13,  7.43s/it, Written=4, Skipped=45]
# Augmenting train:   2%|▏         | 163/7752 [13:49<15:40:13,  7.43s/it, Written=4, Skipped=46]
# Augmenting train:   2%|▏         | 165/7752 [13:49<15:51:15,  7.52s/it, Written=4, Skipped=46]
# Augmenting train:   2%|▏         | 165/7752 [14:06<15:51:15,  7.52s/it, Written=4, Skipped=47]
# Augmenting train:   2%|▏         | 167/7752 [14:06<16:36:39,  7.88s/it, Written=4, Skipped=47]
# Augmenting train:   2%|▏         | 167/7752 [14:22<16:36:39,  7.88s/it, Written=4, Skipped=48]
# Augmenting train:   2%|▏         | 170/7752 [14:22<14:25:52,  6.85s/it, Written=4, Skipped=48]
# Augmenting train:   2%|▏         | 170/7752 [14:45<14:25:52,  6.85s/it, Written=4, Skipped=49]
# Augmenting train:   2%|▏         | 175/7752 [14:45<12:08:27,  5.77s/it, Written=4, Skipped=49]
# Augmenting train:   2%|▏         | 175/7752 [15:01<12:08:27,  5.77s/it, Written=4, Skipped=50]
# Augmenting train:   2%|▏         | 180/7752 [15:01<9:58:19,  4.74s/it, Written=4, Skipped=50]
# Augmenting train:   2%|▏         | 180/7752 [15:17<9:58:19,  4.74s/it, Written=4, Skipped=51]
# Augmenting train:   2%|▏         | 182/7752 [15:17<11:11:19,  5.32s/it, Written=4, Skipped=51]
# Augmenting train:   2%|▏         | 182/7752 [15:34<11:11:19,  5.32s/it, Written=4, Skipped=52]
# Augmenting train:   2%|▏         | 183/7752 [15:34<14:08:30,  6.73s/it, Written=4, Skipped=52]
# Augmenting train:   2%|▏         | 183/7752 [15:48<14:08:30,  6.73s/it, Written=5, Skipped=52]
# Augmenting train:   2%|▏         | 184/7752 [15:48<16:15:45,  7.74s/it, Written=5, Skipped=52]
# Augmenting train:   2%|▏         | 184/7752 [16:03<16:15:45,  7.74s/it, Written=5, Skipped=53]
# Augmenting train:   2%|▏         | 187/7752 [16:03<14:07:22,  6.72s/it, Written=5, Skipped=53]
# Augmenting train:   2%|▏         | 187/7752 [16:17<14:07:22,  6.72s/it, Written=5, Skipped=54]
# Augmenting train:   2%|▏         | 188/7752 [16:17<16:37:00,  7.91s/it, Written=5, Skipped=54]
# Augmenting train:   2%|▏         | 188/7752 [16:31<16:37:00,  7.91s/it, Written=5, Skipped=55]
# Augmenting train:   3%|▎         | 195/7752 [16:31<9:05:15,  4.33s/it, Written=5, Skipped=55]
# Augmenting train:   3%|▎         | 195/7752 [16:48<9:05:15,  4.33s/it, Written=5, Skipped=56]
# Augmenting train:   3%|▎         | 199/7752 [16:48<8:57:22,  4.27s/it, Written=5, Skipped=56]
# Augmenting train:   3%|▎         | 199/7752 [17:04<8:57:22,  4.27s/it, Written=5, Skipped=57]
# Augmenting train:   3%|▎         | 200/7752 [17:04<11:31:32,  5.49s/it, Written=5, Skipped=57]
# Augmenting train:   3%|▎         | 200/7752 [17:19<11:31:32,  5.49s/it, Written=6, Skipped=57]
# Augmenting train:   3%|▎         | 203/7752 [17:19<11:14:50,  5.36s/it, Written=6, Skipped=57]
# Augmenting train:   3%|▎         | 203/7752 [17:32<11:14:50,  5.36s/it, Written=6, Skipped=58]
# Augmenting train:   3%|▎         | 206/7752 [17:32<10:35:44,  5.05s/it, Written=6, Skipped=58]
# Augmenting train:   3%|▎         | 206/7752 [17:51<10:35:44,  5.05s/it, Written=6, Skipped=59]
# Augmenting train:   3%|▎         | 212/7752 [17:51<8:43:14,  4.16s/it, Written=6, Skipped=59]
# Augmenting train:   3%|▎         | 212/7752 [18:09<8:43:14,  4.16s/it, Written=6, Skipped=60]
# Augmenting train:   3%|▎         | 214/7752 [18:09<10:28:22,  5.00s/it, Written=6, Skipped=60]
# Augmenting train:   3%|▎         | 214/7752 [18:24<10:28:22,  5.00s/it, Written=6, Skipped=61]
# Augmenting train:   3%|▎         | 216/7752 [18:24<11:43:14,  5.60s/it, Written=6, Skipped=61]
# Augmenting train:   3%|▎         | 216/7752 [18:40<11:43:14,  5.60s/it, Written=6, Skipped=62]
# Augmenting train:   3%|▎         | 218/7752 [18:40<12:54:24,  6.17s/it, Written=6, Skipped=62]
# Augmenting train:   3%|▎         | 218/7752 [19:04<12:54:24,  6.17s/it, Written=6, Skipped=63]
# Augmenting train:   3%|▎         | 222/7752 [19:04<12:44:39,  6.09s/it, Written=6, Skipped=63]
# Augmenting train:   3%|▎         | 222/7752 [19:22<12:44:39,  6.09s/it, Written=6, Skipped=64]
# Augmenting train:   3%|▎         | 223/7752 [19:22<15:49:33,  7.57s/it, Written=6, Skipped=64]
# Augmenting train:   3%|▎         | 223/7752 [19:39<15:49:33,  7.57s/it, Written=6, Skipped=65]
# Augmenting train:   3%|▎         | 224/7752 [19:39<18:32:47,  8.87s/it, Written=6, Skipped=65]
# Augmenting train:   3%|▎         | 224/7752 [19:55<18:32:47,  8.87s/it, Written=6, Skipped=66]
# Augmenting train:   3%|▎         | 226/7752 [19:55<18:00:39,  8.62s/it, Written=6, Skipped=66]
# Augmenting train:   3%|▎         | 226/7752 [20:13<18:00:39,  8.62s/it, Written=6, Skipped=67]
# Augmenting train:   3%|▎         | 229/7752 [20:13<15:55:41,  7.62s/it, Written=6, Skipped=67]
# Augmenting train:   3%|▎         | 229/7752 [20:30<15:55:41,  7.62s/it, Written=6, Skipped=68]
# Augmenting train:   3%|▎         | 232/7752 [20:30<14:32:39,  6.96s/it, Written=6, Skipped=68]
# Augmenting train:   3%|▎         | 232/7752 [20:52<14:32:39,  6.96s/it, Written=6, Skipped=69]
# Augmenting train:   3%|▎         | 235/7752 [20:52<14:50:38,  7.11s/it, Written=6, Skipped=69]
# Augmenting train:   3%|▎         | 235/7752 [21:08<14:50:38,  7.11s/it, Written=6, Skipped=70]
# Augmenting train:   3%|▎         | 236/7752 [21:08<17:19:48,  8.30s/it, Written=6, Skipped=70]
# Augmenting train:   3%|▎         | 236/7752 [21:26<17:19:48,  8.30s/it, Written=7, Skipped=70]
# Augmenting train:   3%|▎         | 239/7752 [21:26<15:24:48,  7.39s/it, Written=7, Skipped=70]
# Augmenting train:   3%|▎         | 239/7752 [21:41<15:24:48,  7.39s/it, Written=7, Skipped=71]
# Augmenting train:   3%|▎         | 243/7752 [21:41<12:12:51,  5.86s/it, Written=7, Skipped=71]
# Augmenting train:   3%|▎         | 243/7752 [21:54<12:12:51,  5.86s/it, Written=7, Skipped=72]
# Augmenting train:   3%|▎         | 244/7752 [21:54<14:22:39,  6.89s/it, Written=7, Skipped=72]
# Augmenting train:   3%|▎         | 244/7752 [22:09<14:22:39,  6.89s/it, Written=7, Skipped=73]
# Augmenting train:   3%|▎         | 245/7752 [22:09<17:01:08,  8.16s/it, Written=7, Skipped=73]
# Augmenting train:   3%|▎         | 245/7752 [22:25<17:01:08,  8.16s/it, Written=7, Skipped=74]
# Augmenting train:   3%|▎         | 247/7752 [22:25<16:54:58,  8.11s/it, Written=7, Skipped=74]
# Augmenting train:   3%|▎         | 247/7752 [22:41<16:54:58,  8.11s/it, Written=7, Skipped=75]
# Augmenting train:   3%|▎         | 250/7752 [22:41<14:28:16,  6.94s/it, Written=7, Skipped=75]
# Augmenting train:   3%|▎         | 250/7752 [22:56<14:28:16,  6.94s/it, Written=7, Skipped=76]
# Augmenting train:   3%|▎         | 252/7752 [22:56<14:43:46,  7.07s/it, Written=7, Skipped=76]
# Augmenting train:   3%|▎         | 252/7752 [23:15<14:43:46,  7.07s/it, Written=7, Skipped=77]
# Augmenting train:   3%|▎         | 253/7752 [23:15<18:46:53,  9.02s/it, Written=7, Skipped=77]
# Augmenting train:   3%|▎         | 253/7752 [23:26<18:46:53,  9.02s/it, Written=8, Skipped=77]
# Augmenting train:   3%|▎         | 254/7752 [23:26<19:38:35,  9.43s/it, Written=8, Skipped=77]
# Augmenting train:   3%|▎         | 254/7752 [23:45<19:38:35,  9.43s/it, Written=8, Skipped=78]
# Augmenting train:   3%|▎         | 257/7752 [23:45<16:52:48,  8.11s/it, Written=8, Skipped=78]
# Augmenting train:   3%|▎         | 257/7752 [24:02<16:52:48,  8.11s/it, Written=8, Skipped=79]
# Augmenting train:   3%|▎         | 259/7752 [24:02<16:56:04,  8.14s/it, Written=8, Skipped=79]
# Augmenting train:   3%|▎         | 259/7752 [24:18<16:56:04,  8.14s/it, Written=8, Skipped=80]
# Augmenting train:   3%|▎         | 261/7752 [24:18<16:57:02,  8.15s/it, Written=8, Skipped=80]
# Augmenting train:   3%|▎         | 261/7752 [24:25<16:57:02,  8.15s/it, Written=9, Skipped=80]
# Augmenting train:   3%|▎         | 262/7752 [24:25<16:21:28,  7.86s/it, Written=9, Skipped=80]
# Augmenting train:   3%|▎         | 262/7752 [24:48<16:21:28,  7.86s/it, Written=9, Skipped=81]
# Augmenting train:   3%|▎         | 263/7752 [24:48<22:40:22, 10.90s/it, Written=9, Skipped=81]
# Augmenting train:   3%|▎         | 263/7752 [25:02<22:40:22, 10.90s/it, Written=9, Skipped=82]
# Augmenting train:   3%|▎         | 268/7752 [25:02<12:52:45,  6.20s/it, Written=9, Skipped=82]
# Augmenting train:   3%|▎         | 268/7752 [25:21<12:52:45,  6.20s/it, Written=9, Skipped=83]
# Augmenting train:   4%|▎         | 279/7752 [25:21<6:50:00,  3.29s/it, Written=9, Skipped=83]
# Augmenting train:   4%|▎         | 279/7752 [25:40<6:50:00,  3.29s/it, Written=9, Skipped=84]
# Augmenting train:   4%|▎         | 280/7752 [25:40<9:21:12,  4.51s/it, Written=9, Skipped=84]
# Augmenting train:   4%|▎         | 280/7752 [25:58<9:21:12,  4.51s/it, Written=9, Skipped=85]
# Augmenting train:   4%|▎         | 281/7752 [25:58<12:13:00,  5.89s/it, Written=9, Skipped=85]
# Augmenting train:   4%|▎         | 281/7752 [26:15<12:13:00,  5.89s/it, Written=9, Skipped=86]
# Augmenting train:   4%|▎         | 282/7752 [26:15<14:58:36,  7.22s/it, Written=9, Skipped=86]
# Augmenting train:   4%|▎         | 282/7752 [26:31<14:58:36,  7.22s/it, Written=9, Skipped=87]
# Augmenting train:   4%|▎         | 289/7752 [26:31<9:16:51,  4.48s/it, Written=9, Skipped=87]
# Augmenting train:   4%|▎         | 289/7752 [26:46<9:16:51,  4.48s/it, Written=10, Skipped=87]
# Augmenting train:   4%|▍         | 292/7752 [26:46<9:28:42,  4.57s/it, Written=10, Skipped=87]
# Augmenting train:   4%|▍         | 292/7752 [27:05<9:28:42,  4.57s/it, Written=10, Skipped=88]
# Augmenting train:   4%|▍         | 293/7752 [27:05<12:43:37,  6.14s/it, Written=10, Skipped=88]
# Augmenting train:   4%|▍         | 293/7752 [27:24<12:43:37,  6.14s/it, Written=10, Skipped=89]
# Augmenting train:   4%|▍         | 297/7752 [27:24<11:39:24,  5.63s/it, Written=10, Skipped=89]
# Augmenting train:   4%|▍         | 297/7752 [27:38<11:39:24,  5.63s/it, Written=10, Skipped=90]
# Augmenting train:   4%|▍         | 298/7752 [27:38<13:44:18,  6.64s/it, Written=10, Skipped=90]
# Augmenting train:   4%|▍         | 298/7752 [27:55<13:44:18,  6.64s/it, Written=10, Skipped=91]
# Augmenting train:   4%|▍         | 300/7752 [27:55<14:50:50,  7.17s/it, Written=10, Skipped=91]
# Augmenting train:   4%|▍         | 300/7752 [28:13<14:50:50,  7.17s/it, Written=10, Skipped=92]
# Augmenting train:   4%|▍         | 303/7752 [28:13<13:52:55,  6.71s/it, Written=10, Skipped=92]
# Augmenting train:   4%|▍         | 303/7752 [28:35<13:52:55,  6.71s/it, Written=10, Skipped=93]
# Augmenting train:   4%|▍         | 308/7752 [28:35<11:42:09,  5.66s/it, Written=10, Skipped=93]
# Augmenting train:   4%|▍         | 308/7752 [28:55<11:42:09,  5.66s/it, Written=11, Skipped=93]
# Augmenting train:   4%|▍         | 317/7752 [28:55<7:48:28,  3.78s/it, Written=11, Skipped=93]
# Augmenting train:   4%|▍         | 317/7752 [29:12<7:48:28,  3.78s/it, Written=12, Skipped=93]
# Augmenting train:   4%|▍         | 319/7752 [29:12<9:18:28,  4.51s/it, Written=12, Skipped=93]
# Augmenting train:   4%|▍         | 319/7752 [29:28<9:18:28,  4.51s/it, Written=12, Skipped=94]
# Augmenting train:   4%|▍         | 323/7752 [29:28<8:56:11,  4.33s/it, Written=12, Skipped=94]
# Augmenting train:   4%|▍         | 323/7752 [29:43<8:56:11,  4.33s/it, Written=12, Skipped=95]
# Augmenting train:   4%|▍         | 325/7752 [29:43<10:10:07,  4.93s/it, Written=12, Skipped=95]
# Augmenting train:   4%|▍         | 325/7752 [29:57<10:10:07,  4.93s/it, Written=12, Skipped=96]
# Augmenting train:   4%|▍         | 326/7752 [29:57<12:11:38,  5.91s/it, Written=12, Skipped=96]
# Augmenting train:   4%|▍         | 326/7752 [30:13<12:11:38,  5.91s/it, Written=12, Skipped=97]
# Augmenting train:   4%|▍         | 334/7752 [30:13<7:41:25,  3.73s/it, Written=12, Skipped=97]
# Augmenting train:   4%|▍         | 334/7752 [30:29<7:41:25,  3.73s/it, Written=12, Skipped=98]
# Augmenting train:   4%|▍         | 340/7752 [30:29<6:51:04,  3.33s/it, Written=12, Skipped=98]
# Augmenting train:   4%|▍         | 340/7752 [30:50<6:51:04,  3.33s/it, Written=12, Skipped=99]
# Augmenting train:   4%|▍         | 342/7752 [30:50<9:00:18,  4.38s/it, Written=12, Skipped=99]
# Augmenting train:   4%|▍         | 342/7752 [31:06<9:00:18,  4.38s/it, Written=12, Skipped=100]
# Augmenting train:   4%|▍         | 343/7752 [31:06<11:28:39,  5.58s/it, Written=12, Skipped=100]
# Augmenting train:   4%|▍         | 343/7752 [31:22<11:28:39,  5.58s/it, Written=12, Skipped=101]
# Augmenting train:   4%|▍         | 344/7752 [31:22<14:01:04,  6.81s/it, Written=12, Skipped=101]
# Augmenting train:   4%|▍         | 344/7752 [31:37<14:01:04,  6.81s/it, Written=12, Skipped=102]
# Augmenting train:   4%|▍         | 345/7752 [31:37<16:26:49,  7.99s/it, Written=12, Skipped=102]
# Augmenting train:   4%|▍         | 345/7752 [31:52<16:26:49,  7.99s/it, Written=12, Skipped=103]
# Augmenting train:   4%|▍         | 347/7752 [31:52<16:12:44,  7.88s/it, Written=12, Skipped=103]
# Augmenting train:   4%|▍         | 347/7752 [32:00<16:12:44,  7.88s/it, Written=13, Skipped=103]
# Augmenting train:   5%|▍         | 350/7752 [32:00<12:00:13,  5.84s/it, Written=13, Skipped=103]
# Augmenting train:   5%|▍         | 350/7752 [32:17<12:00:13,  5.84s/it, Written=14, Skipped=103]
# Augmenting train:   5%|▍         | 351/7752 [32:17<15:33:58,  7.57s/it, Written=14, Skipped=103]
# Augmenting train:   5%|▍         | 351/7752 [32:30<15:33:58,  7.57s/it, Written=15, Skipped=103]
# Augmenting train:   5%|▍         | 352/7752 [32:30<17:34:09,  8.55s/it, Written=15, Skipped=103]
# Augmenting train:   5%|▍         | 352/7752 [32:47<17:34:09,  8.55s/it, Written=15, Skipped=104]
# Augmenting train:   5%|▍         | 353/7752 [32:47<21:17:21, 10.36s/it, Written=15, Skipped=104]
# Augmenting train:   5%|▍         | 353/7752 [33:07<21:17:21, 10.36s/it, Written=15, Skipped=105]
# Augmenting train:   5%|▍         | 354/7752 [33:07<25:36:48, 12.46s/it, Written=15, Skipped=105]
# Augmenting train:   5%|▍         | 354/7752 [33:22<25:36:48, 12.46s/it, Written=15, Skipped=106]
# Augmenting train:   5%|▍         | 355/7752 [33:22<26:52:09, 13.08s/it, Written=15, Skipped=106]
# Augmenting train:   5%|▍         | 355/7752 [33:37<26:52:09, 13.08s/it, Written=15, Skipped=107]
# Augmenting train:   5%|▍         | 358/7752 [33:37<18:29:36,  9.00s/it, Written=15, Skipped=107]
# Augmenting train:   5%|▍         | 358/7752 [34:01<18:29:36,  9.00s/it, Written=15, Skipped=108]
# Augmenting train:   5%|▍         | 359/7752 [34:01<24:22:09, 11.87s/it, Written=15, Skipped=108]
# Augmenting train:   5%|▍         | 359/7752 [34:15<24:22:09, 11.87s/it, Written=15, Skipped=109]
# Augmenting train:   5%|▍         | 360/7752 [34:15<25:19:51, 12.34s/it, Written=15, Skipped=109]
# Augmenting train:   5%|▍         | 360/7752 [34:29<25:19:51, 12.34s/it, Written=15, Skipped=110]
# Augmenting train:   5%|▍         | 362/7752 [34:29<21:10:21, 10.31s/it, Written=15, Skipped=110]
# Augmenting train:   5%|▍         | 362/7752 [34:48<21:10:21, 10.31s/it, Written=15, Skipped=111]
# Augmenting train:   5%|▍         | 365/7752 [34:48<17:30:24,  8.53s/it, Written=15, Skipped=111]
# Augmenting train:   5%|▍         | 365/7752 [35:03<17:30:24,  8.53s/it, Written=15, Skipped=112]
# Augmenting train:   5%|▍         | 368/7752 [35:03<14:48:11,  7.22s/it, Written=15, Skipped=112]
# Augmenting train:   5%|▍         | 368/7752 [35:23<14:48:11,  7.22s/it, Written=15, Skipped=113]
# Augmenting train:   5%|▍         | 371/7752 [35:23<14:24:10,  7.02s/it, Written=15, Skipped=113]
# Augmenting train:   5%|▍         | 371/7752 [35:47<14:24:10,  7.02s/it, Written=15, Skipped=114]
# Augmenting train:   5%|▍         | 375/7752 [35:47<13:31:03,  6.60s/it, Written=15, Skipped=114]
# Augmenting train:   5%|▍         | 375/7752 [36:06<13:31:03,  6.60s/it, Written=15, Skipped=115]
# Augmenting train:   5%|▍         | 376/7752 [36:06<16:47:14,  8.19s/it, Written=15, Skipped=115]
# Augmenting train:   5%|▍         | 376/7752 [36:22<16:47:14,  8.19s/it, Written=15, Skipped=116]
# Augmenting train:   5%|▍         | 380/7752 [36:22<13:03:31,  6.38s/it, Written=15, Skipped=116]
# Augmenting train:   5%|▍         | 380/7752 [36:36<13:03:31,  6.38s/it, Written=15, Skipped=117]
# Augmenting train:   5%|▍         | 381/7752 [36:36<15:12:13,  7.43s/it, Written=15, Skipped=117]
# Augmenting train:   5%|▍         | 381/7752 [36:54<15:12:13,  7.43s/it, Written=15, Skipped=118]
# Augmenting train:   5%|▍         | 382/7752 [36:54<18:38:48,  9.11s/it, Written=15, Skipped=118]
# Augmenting train:   5%|▍         | 382/7752 [37:11<18:38:48,  9.11s/it, Written=15, Skipped=119]
# Augmenting train:   5%|▍         | 384/7752 [37:11<17:58:33,  8.78s/it, Written=15, Skipped=119]
# Augmenting train:   5%|▍         | 384/7752 [37:28<17:58:33,  8.78s/it, Written=15, Skipped=120]
# Augmenting train:   5%|▌         | 388/7752 [37:28<13:44:14,  6.72s/it, Written=15, Skipped=120]
# Augmenting train:   5%|▌         | 388/7752 [37:44<13:44:14,  6.72s/it, Written=15, Skipped=121]
# Augmenting train:   5%|▌         | 389/7752 [37:44<16:25:52,  8.03s/it, Written=15, Skipped=121]
# Augmenting train:   5%|▌         | 389/7752 [38:00<16:25:52,  8.03s/it, Written=15, Skipped=122]
# Augmenting train:   5%|▌         | 400/7752 [38:00<7:03:17,  3.45s/it, Written=15, Skipped=122]
# Augmenting train:   5%|▌         | 400/7752 [38:17<7:03:17,  3.45s/it, Written=15, Skipped=123]
# Augmenting train:   5%|▌         | 402/7752 [38:17<8:42:00,  4.26s/it, Written=15, Skipped=123]
# Augmenting train:   5%|▌         | 402/7752 [38:42<8:42:00,  4.26s/it, Written=15, Skipped=124]
# Augmenting train:   5%|▌         | 403/7752 [38:42<12:46:44,  6.26s/it, Written=15, Skipped=124]
# Augmenting train:   5%|▌         | 403/7752 [38:58<12:46:44,  6.26s/it, Written=15, Skipped=125]
# Augmenting train:   5%|▌         | 408/7752 [38:58<10:16:24,  5.04s/it, Written=15, Skipped=125]
# Augmenting train:   5%|▌         | 408/7752 [39:04<10:16:24,  5.04s/it, Written=16, Skipped=125]
# Augmenting train:   5%|▌         | 412/7752 [39:04<7:57:43,  3.91s/it, Written=16, Skipped=125]
# Augmenting train:   5%|▌         | 412/7752 [39:20<7:57:43,  3.91s/it, Written=16, Skipped=126]
# Augmenting train:   5%|▌         | 418/7752 [39:20<6:52:48,  3.38s/it, Written=16, Skipped=126]
# Augmenting train:   5%|▌         | 418/7752 [39:34<6:52:48,  3.38s/it, Written=16, Skipped=127]
# Augmenting train:   5%|▌         | 419/7752 [39:34<8:51:52,  4.35s/it, Written=16, Skipped=127]
# Augmenting train:   5%|▌         | 419/7752 [39:49<8:51:52,  4.35s/it, Written=16, Skipped=128]
# Augmenting train:   5%|▌         | 423/7752 [39:49<8:21:00,  4.10s/it, Written=16, Skipped=128]
# Augmenting train:   5%|▌         | 423/7752 [40:05<8:21:00,  4.10s/it, Written=16, Skipped=129]
# Augmenting train:   5%|▌         | 426/7752 [40:05<9:06:45,  4.48s/it, Written=16, Skipped=129]
# Augmenting train:   5%|▌         | 426/7752 [40:23<9:06:45,  4.48s/it, Written=16, Skipped=130]
# Augmenting train:   6%|▌         | 428/7752 [40:23<10:48:25,  5.31s/it, Written=16, Skipped=130]
# Augmenting train:   6%|▌         | 428/7752 [40:41<10:48:25,  5.31s/it, Written=16, Skipped=131]
# Augmenting train:   6%|▌         | 429/7752 [40:41<14:05:45,  6.93s/it, Written=16, Skipped=131]
# Augmenting train:   6%|▌         | 429/7752 [40:54<14:05:45,  6.93s/it, Written=16, Skipped=132]
# Augmenting train:   6%|▌         | 431/7752 [40:54<14:01:57,  6.90s/it, Written=16, Skipped=132]
# Augmenting train:   6%|▌         | 431/7752 [41:10<14:01:57,  6.90s/it, Written=16, Skipped=133]
# Augmenting train:   6%|▌         | 433/7752 [41:10<14:34:04,  7.17s/it, Written=16, Skipped=133]
# Augmenting train:   6%|▌         | 433/7752 [41:25<14:34:04,  7.17s/it, Written=16, Skipped=134]
# Augmenting train:   6%|▌         | 436/7752 [41:25<12:57:14,  6.37s/it, Written=16, Skipped=134]
# Augmenting train:   6%|▌         | 436/7752 [41:43<12:57:14,  6.37s/it, Written=16, Skipped=135]
# Augmenting train:   6%|▌         | 437/7752 [41:43<16:26:25,  8.09s/it, Written=16, Skipped=135]
# Augmenting train:   6%|▌         | 437/7752 [41:57<16:26:25,  8.09s/it, Written=16, Skipped=136]
# Augmenting train:   6%|▌         | 440/7752 [41:57<13:40:00,  6.73s/it, Written=16, Skipped=136]
# Augmenting train:   6%|▌         | 440/7752 [42:12<13:40:00,  6.73s/it, Written=16, Skipped=137]
# Augmenting train:   6%|▌         | 444/7752 [42:12<11:07:26,  5.48s/it, Written=16, Skipped=137]
# Augmenting train:   6%|▌         | 444/7752 [42:27<11:07:26,  5.48s/it, Written=16, Skipped=138]
# Augmenting train:   6%|▌         | 445/7752 [42:27<13:43:51,  6.77s/it, Written=16, Skipped=138]
# Augmenting train:   6%|▌         | 445/7752 [42:42<13:43:51,  6.77s/it, Written=16, Skipped=139]
# Augmenting train:   6%|▌         | 446/7752 [42:42<16:16:21,  8.02s/it, Written=16, Skipped=139]
# Augmenting train:   6%|▌         | 446/7752 [42:57<16:16:21,  8.02s/it, Written=16, Skipped=140]
# Augmenting train:   6%|▌         | 449/7752 [42:57<13:48:49,  6.81s/it, Written=16, Skipped=140]
# Augmenting train:   6%|▌         | 449/7752 [43:16<13:48:49,  6.81s/it, Written=16, Skipped=141]
# Augmenting train:   6%|▌         | 453/7752 [43:16<11:54:57,  5.88s/it, Written=16, Skipped=141]
# Augmenting train:   6%|▌         | 453/7752 [43:31<11:54:57,  5.88s/it, Written=16, Skipped=142]
# Augmenting train:   6%|▌         | 454/7752 [43:31<14:33:59,  7.19s/it, Written=16, Skipped=142]
# Augmenting train:   6%|▌         | 454/7752 [43:46<14:33:59,  7.19s/it, Written=16, Skipped=143]
# Augmenting train:   6%|▌         | 455/7752 [43:46<16:51:48,  8.32s/it, Written=16, Skipped=143]
# Augmenting train:   6%|▌         | 455/7752 [44:00<16:51:48,  8.32s/it, Written=16, Skipped=144]
# Augmenting train:   6%|▌         | 459/7752 [44:00<12:15:16,  6.05s/it, Written=16, Skipped=144]
# Augmenting train:   6%|▌         | 459/7752 [44:14<12:15:16,  6.05s/it, Written=16, Skipped=145]
# Augmenting train:   6%|▌         | 462/7752 [44:14<11:24:14,  5.63s/it, Written=16, Skipped=145]
# Augmenting train:   6%|▌         | 462/7752 [44:29<11:24:14,  5.63s/it, Written=16, Skipped=146]
# Augmenting train:   6%|▌         | 464/7752 [44:29<12:19:48,  6.09s/it, Written=16, Skipped=146]
# Augmenting train:   6%|▌         | 464/7752 [44:45<12:19:48,  6.09s/it, Written=16, Skipped=147]
# Augmenting train:   6%|▌         | 467/7752 [44:45<11:37:59,  5.75s/it, Written=16, Skipped=147]
# Augmenting train:   6%|▌         | 467/7752 [45:00<11:37:59,  5.75s/it, Written=16, Skipped=148]
# Augmenting train:   6%|▌         | 468/7752 [45:00<14:27:20,  7.14s/it, Written=16, Skipped=148]
# Augmenting train:   6%|▌         | 468/7752 [45:23<14:27:20,  7.14s/it, Written=16, Skipped=149]
# Augmenting train:   6%|▌         | 470/7752 [45:23<16:48:35,  8.31s/it, Written=16, Skipped=149]
# Augmenting train:   6%|▌         | 470/7752 [45:39<16:48:35,  8.31s/it, Written=16, Skipped=150]
# Augmenting train:   6%|▌         | 474/7752 [45:39<13:01:29,  6.44s/it, Written=16, Skipped=150]
# Augmenting train:   6%|▌         | 474/7752 [45:56<13:01:29,  6.44s/it, Written=16, Skipped=151]
# Augmenting train:   6%|▌         | 476/7752 [45:56<13:51:36,  6.86s/it, Written=16, Skipped=151]
# Augmenting train:   6%|▌         | 476/7752 [46:13<13:51:36,  6.86s/it, Written=16, Skipped=152]
# Augmenting train:   6%|▌         | 477/7752 [46:13<16:59:18,  8.41s/it, Written=16, Skipped=152]
# Augmenting train:   6%|▌         | 477/7752 [46:28<16:59:18,  8.41s/it, Written=16, Skipped=153]
# Augmenting train:   6%|▌         | 484/7752 [46:28<9:25:53,  4.67s/it, Written=16, Skipped=153]
# Augmenting train:   6%|▌         | 484/7752 [46:46<9:25:53,  4.67s/it, Written=16, Skipped=154]
# Augmenting train:   6%|▋         | 485/7752 [46:46<12:24:18,  6.15s/it, Written=16, Skipped=154]
# Augmenting train:   6%|▋         | 485/7752 [47:05<12:24:18,  6.15s/it, Written=16, Skipped=155]
# Augmenting train:   6%|▋         | 489/7752 [47:05<11:20:35,  5.62s/it, Written=16, Skipped=155]
# Augmenting train:   6%|▋         | 489/7752 [47:23<11:20:35,  5.62s/it, Written=16, Skipped=156]
# Augmenting train:   6%|▋         | 491/7752 [47:23<12:47:18,  6.34s/it, Written=16, Skipped=156]
# Augmenting train:   6%|▋         | 491/7752 [47:35<12:47:18,  6.34s/it, Written=17, Skipped=156]
# Augmenting train:   6%|▋         | 492/7752 [47:35<14:18:40,  7.10s/it, Written=17, Skipped=156]
# Augmenting train:   6%|▋         | 492/7752 [47:55<14:18:40,  7.10s/it, Written=17, Skipped=157]
# Augmenting train:   6%|▋         | 494/7752 [47:55<15:54:09,  7.89s/it, Written=17, Skipped=157]
# Augmenting train:   6%|▋         | 494/7752 [48:11<15:54:09,  7.89s/it, Written=17, Skipped=158]
# Augmenting train:   6%|▋         | 495/7752 [48:11<18:30:42,  9.18s/it, Written=17, Skipped=158]
# Augmenting train:   6%|▋         | 495/7752 [48:28<18:30:42,  9.18s/it, Written=17, Skipped=159]
# Augmenting train:   6%|▋         | 496/7752 [48:28<21:24:21, 10.62s/it, Written=17, Skipped=159]
# Augmenting train:   6%|▋         | 496/7752 [48:45<21:24:21, 10.62s/it, Written=17, Skipped=160]
# Augmenting train:   6%|▋         | 497/7752 [48:45<24:08:47, 11.98s/it, Written=17, Skipped=160]
# Augmenting train:   6%|▋         | 497/7752 [49:06<24:08:47, 11.98s/it, Written=18, Skipped=160]
# Augmenting train:   6%|▋         | 498/7752 [49:06<28:23:24, 14.09s/it, Written=18, Skipped=160]
# Augmenting train:   6%|▋         | 498/7752 [49:21<28:23:24, 14.09s/it, Written=18, Skipped=161]
# Augmenting train:   6%|▋         | 499/7752 [49:21<29:02:27, 14.41s/it, Written=18, Skipped=161]
# Augmenting train:   6%|▋         | 499/7752 [49:39<29:02:27, 14.41s/it, Written=18, Skipped=162]
# Augmenting train:   6%|▋         | 502/7752 [49:39<20:07:13,  9.99s/it, Written=18, Skipped=162]
# Augmenting train:   6%|▋         | 502/7752 [49:57<20:07:13,  9.99s/it, Written=18, Skipped=163]
# Augmenting train:   6%|▋         | 503/7752 [49:57<23:15:26, 11.55s/it, Written=18, Skipped=163]
# Augmenting train:   6%|▋         | 503/7752 [50:09<23:15:26, 11.55s/it, Written=18, Skipped=164]
# Augmenting train:   7%|▋         | 504/7752 [50:09<23:40:07, 11.76s/it, Written=18, Skipped=164]
# Augmenting train:   7%|▋         | 504/7752 [50:23<23:40:07, 11.76s/it, Written=18, Skipped=165]
# Augmenting train:   7%|▋         | 507/7752 [50:23<16:47:22,  8.34s/it, Written=18, Skipped=165]
# Augmenting train:   7%|▋         | 507/7752 [50:38<16:47:22,  8.34s/it, Written=19, Skipped=165]
# Augmenting train:   7%|▋         | 509/7752 [50:38<16:12:17,  8.05s/it, Written=19, Skipped=165]
# Augmenting train:   7%|▋         | 509/7752 [50:53<16:12:17,  8.05s/it, Written=19, Skipped=166]
# Augmenting train:   7%|▋         | 511/7752 [50:53<15:46:46,  7.85s/it, Written=19, Skipped=166]
# Augmenting train:   7%|▋         | 511/7752 [51:08<15:46:46,  7.85s/it, Written=19, Skipped=167]
# Augmenting train:   7%|▋         | 516/7752 [51:08<10:34:48,  5.26s/it, Written=19, Skipped=167]
# Augmenting train:   7%|▋         | 516/7752 [51:27<10:34:48,  5.26s/it, Written=19, Skipped=168]
# Augmenting train:   7%|▋         | 517/7752 [51:27<14:10:20,  7.05s/it, Written=19, Skipped=168]
# Augmenting train:   7%|▋         | 517/7752 [51:40<14:10:20,  7.05s/it, Written=19, Skipped=169]
# Augmenting train:   7%|▋         | 520/7752 [51:40<12:24:24,  6.18s/it, Written=19, Skipped=169]
# Augmenting train:   7%|▋         | 520/7752 [51:56<12:24:24,  6.18s/it, Written=19, Skipped=170]
# Augmenting train:   7%|▋         | 524/7752 [51:56<10:26:51,  5.20s/it, Written=19, Skipped=170]
# Augmenting train:   7%|▋         | 524/7752 [52:12<10:26:51,  5.20s/it, Written=19, Skipped=171]
# Augmenting train:   7%|▋         | 525/7752 [52:12<13:13:54,  6.59s/it, Written=19, Skipped=171]
# Augmenting train:   7%|▋         | 525/7752 [52:28<13:13:54,  6.59s/it, Written=19, Skipped=172]
# Augmenting train:   7%|▋         | 526/7752 [52:28<16:09:28,  8.05s/it, Written=19, Skipped=172]
# Augmenting train:   7%|▋         | 526/7752 [52:44<16:09:28,  8.05s/it, Written=19, Skipped=173]
# Augmenting train:   7%|▋         | 527/7752 [52:44<19:14:53,  9.59s/it, Written=19, Skipped=173]
# Augmenting train:   7%|▋         | 527/7752 [53:06<19:14:53,  9.59s/it, Written=19, Skipped=174]
# Augmenting train:   7%|▋         | 529/7752 [53:06<20:10:31, 10.06s/it, Written=19, Skipped=174]
# Augmenting train:   7%|▋         | 529/7752 [53:25<20:10:31, 10.06s/it, Written=19, Skipped=175]
# Augmenting train:   7%|▋         | 532/7752 [53:25<16:50:35,  8.40s/it, Written=19, Skipped=175]
# Augmenting train:   7%|▋         | 532/7752 [53:38<16:50:35,  8.40s/it, Written=19, Skipped=176]
# Augmenting train:   7%|▋         | 533/7752 [53:38<18:37:49,  9.29s/it, Written=19, Skipped=176]
# Augmenting train:   7%|▋         | 533/7752 [54:01<18:37:49,  9.29s/it, Written=19, Skipped=177]
# Augmenting train:   7%|▋         | 536/7752 [54:01<17:09:13,  8.56s/it, Written=19, Skipped=177]
# Augmenting train:   7%|▋         | 536/7752 [54:18<17:09:13,  8.56s/it, Written=19, Skipped=178]
# Augmenting train:   7%|▋         | 538/7752 [54:18<16:57:40,  8.46s/it, Written=19, Skipped=178]
# Augmenting train:   7%|▋         | 538/7752 [54:36<16:57:40,  8.46s/it, Written=19, Skipped=179]
# Augmenting train:   7%|▋         | 541/7752 [54:36<15:19:20,  7.65s/it, Written=19, Skipped=179]
# Augmenting train:   7%|▋         | 541/7752 [54:51<15:19:20,  7.65s/it, Written=19, Skipped=180]
# Augmenting train:   7%|▋         | 544/7752 [54:51<13:15:02,  6.62s/it, Written=19, Skipped=180]
# Augmenting train:   7%|▋         | 544/7752 [55:06<13:15:02,  6.62s/it, Written=19, Skipped=181]
# Augmenting train:   7%|▋         | 546/7752 [55:06<13:40:41,  6.83s/it, Written=19, Skipped=181]
# Augmenting train:   7%|▋         | 546/7752 [55:21<13:40:41,  6.83s/it, Written=19, Skipped=182]
# Augmenting train:   7%|▋         | 552/7752 [55:21<9:13:12,  4.61s/it, Written=19, Skipped=182]
# Augmenting train:   7%|▋         | 552/7752 [55:40<9:13:12,  4.61s/it, Written=19, Skipped=183]
# Augmenting train:   7%|▋         | 558/7752 [55:40<8:03:25,  4.03s/it, Written=19, Skipped=183]
# Augmenting train:   7%|▋         | 558/7752 [56:39<8:03:25,  4.03s/it, Written=19, Skipped=184]
# Augmenting train:   7%|▋         | 560/7752 [56:39<16:35:29,  8.30s/it, Written=19, Skipped=184]
# Augmenting train:   7%|▋         | 560/7752 [57:02<16:35:29,  8.30s/it, Written=19, Skipped=185]
# Augmenting train:   7%|▋         | 565/7752 [57:02<13:42:34,  6.87s/it, Written=19, Skipped=185]
# Augmenting train:   7%|▋         | 565/7752 [57:22<13:42:34,  6.87s/it, Written=19, Skipped=186]
# Augmenting train:   7%|▋         | 566/7752 [57:22<16:22:56,  8.21s/it, Written=19, Skipped=186]
# Augmenting train:   7%|▋         | 566/7752 [57:38<16:22:56,  8.21s/it, Written=19, Skipped=187]
# Augmenting train:   7%|▋         | 567/7752 [57:38<18:15:30,  9.15s/it, Written=19, Skipped=187]
# Augmenting train:   7%|▋         | 567/7752 [57:53<18:15:30,  9.15s/it, Written=19, Skipped=188]
# Augmenting train:   7%|▋         | 568/7752 [57:53<19:59:59, 10.02s/it, Written=19, Skipped=188]
# Augmenting train:   7%|▋         | 568/7752 [58:07<19:59:59, 10.02s/it, Written=19, Skipped=189]
# Augmenting train:   7%|▋         | 571/7752 [58:07<15:54:46,  7.98s/it, Written=19, Skipped=189]
# Augmenting train:   7%|▋         | 571/7752 [58:14<15:54:46,  7.98s/it, Written=20, Skipped=189]
# Augmenting train:   7%|▋         | 573/7752 [58:14<13:16:56,  6.66s/it, Written=20, Skipped=189]
# Augmenting train:   7%|▋         | 573/7752 [58:28<13:16:56,  6.66s/it, Written=20, Skipped=190]
# Augmenting train:   7%|▋         | 579/7752 [58:28<8:42:49,  4.37s/it, Written=20, Skipped=190]
# Augmenting train:   7%|▋         | 579/7752 [58:48<8:42:49,  4.37s/it, Written=20, Skipped=191]
# Augmenting train:   8%|▊         | 583/7752 [58:48<9:09:06,  4.60s/it, Written=20, Skipped=191]
# Augmenting train:   8%|▊         | 583/7752 [59:04<9:09:06,  4.60s/it, Written=20, Skipped=192]
# Augmenting train:   8%|▊         | 590/7752 [59:04<7:03:06,  3.54s/it, Written=20, Skipped=192]
# Augmenting train:   8%|▊         | 590/7752 [59:25<7:03:06,  3.54s/it, Written=20, Skipped=193]
# Augmenting train:   8%|▊         | 593/7752 [59:25<8:27:43,  4.26s/it, Written=20, Skipped=193]
# Augmenting train:   8%|▊         | 593/7752 [59:41<8:27:43,  4.26s/it, Written=20, Skipped=194]
# Augmenting train:   8%|▊         | 600/7752 [59:41<6:47:23,  3.42s/it, Written=20, Skipped=194]
# Augmenting train:   8%|▊         | 600/7752 [1:00:04<6:47:23,  3.42s/it, Written=20, Skipped=195]
# Augmenting train:   8%|▊         | 602/7752 [1:00:04<9:11:31,  4.63s/it, Written=20, Skipped=195]
# Augmenting train:   8%|▊         | 602/7752 [1:00:26<9:11:31,  4.63s/it, Written=20, Skipped=196]
# Augmenting train:   8%|▊         | 609/7752 [1:00:26<7:58:22,  4.02s/it, Written=20, Skipped=196]
# Augmenting train:   8%|▊         | 609/7752 [1:00:44<7:58:22,  4.02s/it, Written=20, Skipped=197]
# Augmenting train:   8%|▊         | 611/7752 [1:00:44<9:24:49,  4.75s/it, Written=20, Skipped=197]
# Augmenting train:   8%|▊         | 611/7752 [1:01:04<9:24:49,  4.75s/it, Written=20, Skipped=198]
# Augmenting train:   8%|▊         | 619/7752 [1:01:04<7:21:19,  3.71s/it, Written=20, Skipped=198]
# Augmenting train:   8%|▊         | 619/7752 [1:01:20<7:21:19,  3.71s/it, Written=20, Skipped=199]
# Augmenting train:   8%|▊         | 624/7752 [1:01:20<7:01:47,  3.55s/it, Written=20, Skipped=199]
# Augmenting train:   8%|▊         | 624/7752 [1:01:36<7:01:47,  3.55s/it, Written=20, Skipped=200]
# Augmenting train:   8%|▊         | 630/7752 [1:01:36<6:27:59,  3.27s/it, Written=20, Skipped=200]
# Augmenting train:   8%|▊         | 630/7752 [1:02:01<6:27:59,  3.27s/it, Written=20, Skipped=201]
# Augmenting train:   8%|▊         | 636/7752 [1:02:01<7:02:22,  3.56s/it, Written=20, Skipped=201]
# Augmenting train:   8%|▊         | 636/7752 [1:02:16<7:02:22,  3.56s/it, Written=20, Skipped=202]
# Augmenting train:   8%|▊         | 637/7752 [1:02:16<8:36:25,  4.35s/it, Written=20, Skipped=202]
# Augmenting train:   8%|▊         | 637/7752 [1:02:30<8:36:25,  4.35s/it, Written=20, Skipped=203]
# Augmenting train:   8%|▊         | 639/7752 [1:02:30<9:30:36,  4.81s/it, Written=20, Skipped=203]
# Augmenting train:   8%|▊         | 639/7752 [1:02:45<9:30:36,  4.81s/it, Written=20, Skipped=204]
# Augmenting train:   8%|▊         | 643/7752 [1:02:45<8:53:48,  4.51s/it, Written=20, Skipped=204]
# Augmenting train:   8%|▊         | 643/7752 [1:03:02<8:53:48,  4.51s/it, Written=20, Skipped=205]
# Augmenting train:   8%|▊         | 645/7752 [1:03:02<10:16:26,  5.20s/it, Written=20, Skipped=205]
# Augmenting train:   8%|▊         | 645/7752 [1:03:15<10:16:26,  5.20s/it, Written=20, Skipped=206]
# Augmenting train:   8%|▊         | 647/7752 [1:03:15<10:50:24,  5.49s/it, Written=20, Skipped=206]
# Augmenting train:   8%|▊         | 647/7752 [1:03:34<10:50:24,  5.49s/it, Written=20, Skipped=207]
# Augmenting train:   8%|▊         | 654/7752 [1:03:34<8:03:03,  4.08s/it, Written=20, Skipped=207]
# Augmenting train:   8%|▊         | 654/7752 [1:03:59<8:03:03,  4.08s/it, Written=20, Skipped=208]
# Augmenting train:   8%|▊         | 658/7752 [1:03:59<9:17:23,  4.71s/it, Written=20, Skipped=208]
# Augmenting train:   8%|▊         | 658/7752 [1:04:15<9:17:23,  4.71s/it, Written=20, Skipped=209]
# Augmenting train:   9%|▊         | 660/7752 [1:04:15<10:21:53,  5.26s/it, Written=20, Skipped=209]
# Augmenting train:   9%|▊         | 660/7752 [1:04:33<10:21:53,  5.26s/it, Written=20, Skipped=210]
# Augmenting train:   9%|▊         | 661/7752 [1:04:33<13:06:28,  6.65s/it, Written=20, Skipped=210]
# Augmenting train:   9%|▊         | 661/7752 [1:04:51<13:06:28,  6.65s/it, Written=20, Skipped=211]
# Augmenting train:   9%|▊         | 662/7752 [1:04:51<16:11:58,  8.23s/it, Written=20, Skipped=211]
# Augmenting train:   9%|▊         | 662/7752 [1:05:05<16:11:58,  8.23s/it, Written=20, Skipped=212]
# Augmenting train:   9%|▊         | 668/7752 [1:05:05<10:04:11,  5.12s/it, Written=20, Skipped=212]
# Augmenting train:   9%|▊         | 668/7752 [1:05:19<10:04:11,  5.12s/it, Written=20, Skipped=213]
# Augmenting train:   9%|▊         | 669/7752 [1:05:19<12:03:27,  6.13s/it, Written=20, Skipped=213]
# Augmenting train:   9%|▊         | 669/7752 [1:05:37<12:03:27,  6.13s/it, Written=20, Skipped=214]
# Augmenting train:   9%|▊         | 670/7752 [1:05:37<15:04:46,  7.67s/it, Written=20, Skipped=214]
# Augmenting train:   9%|▊         | 670/7752 [1:05:46<15:04:46,  7.67s/it, Written=21, Skipped=214]
# Augmenting train:   9%|▊         | 671/7752 [1:05:46<15:45:21,  8.01s/it, Written=21, Skipped=214]
# Augmenting train:   9%|▊         | 671/7752 [1:06:01<15:45:21,  8.01s/it, Written=21, Skipped=215]
# Augmenting train:   9%|▉         | 680/7752 [1:06:01<7:14:03,  3.68s/it, Written=21, Skipped=215]
# Augmenting train:   9%|▉         | 680/7752 [1:06:12<7:14:03,  3.68s/it, Written=22, Skipped=215]
# Augmenting train:   9%|▉         | 682/7752 [1:06:12<7:44:45,  3.94s/it, Written=22, Skipped=215]
# Augmenting train:   9%|▉         | 682/7752 [1:06:28<7:44:45,  3.94s/it, Written=22, Skipped=216]
# Augmenting train:   9%|▉         | 686/7752 [1:06:28<7:46:22,  3.96s/it, Written=22, Skipped=216]
# Augmenting train:   9%|▉         | 686/7752 [1:06:35<7:46:22,  3.96s/it, Written=23, Skipped=216]
# Augmenting train:   9%|▉         | 687/7752 [1:06:35<8:28:55,  4.32s/it, Written=23, Skipped=216]
# Augmenting train:   9%|▉         | 687/7752 [1:06:51<8:28:55,  4.32s/it, Written=23, Skipped=217]
# Augmenting train:   9%|▉         | 688/7752 [1:06:51<11:37:55,  5.93s/it, Written=23, Skipped=217]
# Augmenting train:   9%|▉         | 688/7752 [1:07:07<11:37:55,  5.93s/it, Written=23, Skipped=218]
# Augmenting train:   9%|▉         | 689/7752 [1:07:07<14:39:17,  7.47s/it, Written=23, Skipped=218]
# Augmenting train:   9%|▉         | 689/7752 [1:07:22<14:39:17,  7.47s/it, Written=23, Skipped=219]
# Augmenting train:   9%|▉         | 695/7752 [1:07:22<8:58:54,  4.58s/it, Written=23, Skipped=219]
# Augmenting train:   9%|▉         | 695/7752 [1:07:41<8:58:54,  4.58s/it, Written=23, Skipped=220]
# Augmenting train:   9%|▉         | 698/7752 [1:07:41<9:59:17,  5.10s/it, Written=23, Skipped=220]
# Augmenting train:   9%|▉         | 698/7752 [1:07:52<9:59:17,  5.10s/it, Written=24, Skipped=220]
# Augmenting train:   9%|▉         | 700/7752 [1:07:52<10:12:45,  5.21s/it, Written=24, Skipped=220]
# Augmenting train:   9%|▉         | 700/7752 [1:08:07<10:12:45,  5.21s/it, Written=24, Skipped=221]
# ...
# Augmenting train:  64%|██████▍   | 4974/7752 [11:27:35<10:05:01, 13.07s/it, Written=1695, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4974/7752 [11:27:44<10:05:01, 13.07s/it, Written=1696, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4975/7752 [11:27:44<9:08:24, 11.85s/it, Written=1696, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4975/7752 [11:27:51<9:08:24, 11.85s/it, Written=1697, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4976/7752 [11:27:51<8:09:37, 10.58s/it, Written=1697, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4976/7752 [11:28:00<8:09:37, 10.58s/it, Written=1698, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4977/7752 [11:28:00<7:38:56,  9.92s/it, Written=1698, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4977/7752 [11:28:08<7:38:56,  9.92s/it, Written=1699, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4978/7752 [11:28:08<7:11:51,  9.34s/it, Written=1699, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4978/7752 [11:28:22<7:11:51,  9.34s/it, Written=1700, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4979/7752 [11:28:22<8:22:24, 10.87s/it, Written=1700, Skipped=1561]
# Augmenting train:  64%|██████▍   | 4979/7752 [11:28:44<8:22:24, 10.87s/it, Written=1700, Skipped=1562]
# Augmenting train:  64%|██████▍   | 4980/7752 [11:28:44<10:50:32, 14.08s/it, Written=1700, Skipped=1562]
# Augmenting train:  64%|██████▍   | 4980/7752 [11:29:01<10:50:32, 14.08s/it, Written=1700, Skipped=1563]
# Augmenting train:  64%|██████▍   | 4981/7752 [11:29:01<11:39:50, 15.15s/it, Written=1700, Skipped=1563]
# Augmenting train:  64%|██████▍   | 4981/7752 [11:29:09<11:39:50, 15.15s/it, Written=1701, Skipped=1563]
# Augmenting train:  64%|██████▍   | 4982/7752 [11:29:09<9:55:09, 12.89s/it, Written=1701, Skipped=1563]
# Augmenting train:  64%|██████▍   | 4982/7752 [11:29:28<9:55:09, 12.89s/it, Written=1701, Skipped=1564]
# Augmenting train:  64%|██████▍   | 4983/7752 [11:29:28<11:15:34, 14.64s/it, Written=1701, Skipped=1564]
# Augmenting train:  64%|██████▍   | 4983/7752 [11:29:44<11:15:34, 14.64s/it, Written=1701, Skipped=1565]
# Augmenting train:  64%|██████▍   | 4984/7752 [11:29:44<11:35:01, 15.07s/it, Written=1701, Skipped=1565]
# Augmenting train:  64%|██████▍   | 4984/7752 [11:30:03<11:35:01, 15.07s/it, Written=1701, Skipped=1566]
# Augmenting train:  64%|██████▍   | 4985/7752 [11:30:03<12:25:09, 16.16s/it, Written=1701, Skipped=1566]
# Augmenting train:  64%|██████▍   | 4985/7752 [11:30:18<12:25:09, 16.16s/it, Written=1701, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4986/7752 [11:30:18<12:14:40, 15.94s/it, Written=1701, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4986/7752 [11:30:24<12:14:40, 15.94s/it, Written=1702, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4987/7752 [11:30:24<10:02:53, 13.08s/it, Written=1702, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4987/7752 [11:30:39<10:02:53, 13.08s/it, Written=1703, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4988/7752 [11:30:39<10:24:36, 13.56s/it, Written=1703, Skipped=1567]
# Augmenting train:  64%|██████▍   | 4988/7752 [11:30:56<10:24:36, 13.56s/it, Written=1703, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4989/7752 [11:30:56<11:16:12, 14.68s/it, Written=1703, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4989/7752 [11:31:06<11:16:12, 14.68s/it, Written=1704, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4990/7752 [11:31:06<10:02:45, 13.09s/it, Written=1704, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4990/7752 [11:31:12<10:02:45, 13.09s/it, Written=1705, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4991/7752 [11:31:12<8:30:18, 11.09s/it, Written=1705, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4991/7752 [11:31:17<8:30:18, 11.09s/it, Written=1706, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4992/7752 [11:31:17<7:09:29,  9.34s/it, Written=1706, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4992/7752 [11:31:30<7:09:29,  9.34s/it, Written=1707, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:31:30<7:52:32, 10.28s/it, Written=1707, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:31:36<7:52:32, 10.28s/it, Written=1708, Skipped=1568]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:31:55<7:52:32, 10.28s/it, Written=1708, Skipped=1569]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:32:07<7:52:32, 10.28s/it, Written=1708, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:32:27<7:52:32, 10.28s/it, Written=1709, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4993/7752 [11:32:34<7:52:32, 10.28s/it, Written=1710, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4994/7752 [11:32:34<20:08:33, 26.29s/it, Written=1710, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4994/7752 [11:32:40<20:08:33, 26.29s/it, Written=1711, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4995/7752 [11:32:40<15:39:47, 20.45s/it, Written=1711, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4995/7752 [11:32:45<15:39:47, 20.45s/it, Written=1712, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4996/7752 [11:32:45<12:07:37, 15.84s/it, Written=1712, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4996/7752 [11:32:56<12:07:37, 15.84s/it, Written=1713, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4997/7752 [11:32:56<10:47:35, 14.10s/it, Written=1713, Skipped=1570]
# Augmenting train:  64%|██████▍   | 4997/7752 [11:33:12<10:47:35, 14.10s/it, Written=1713, Skipped=1571]
# Augmenting train:  64%|██████▍   | 4998/7752 [11:33:12<11:23:27, 14.89s/it, Written=1713, Skipped=1571]
# Augmenting train:  64%|██████▍   | 4998/7752 [11:33:20<11:23:27, 14.89s/it, Written=1714, Skipped=1571]
# Augmenting train:  64%|██████▍   | 4999/7752 [11:33:20<9:41:43, 12.68s/it, Written=1714, Skipped=1571]
# Augmenting train:  64%|██████▍   | 4999/7752 [11:33:26<9:41:43, 12.68s/it, Written=1715, Skipped=1571]
# Augmenting train:  64%|██████▍   | 5000/7752 [11:33:26<8:10:26, 10.69s/it, Written=1715, Skipped=1571]
# Augmenting train:  64%|██████▍   | 5000/7752 [11:33:33<8:10:26, 10.69s/it, Written=1716, Skipped=1571]
# Augmenting train:  65%|██████▍   | 5001/7752 [11:33:33<7:20:25,  9.61s/it, Written=1716, Skipped=1571]
# Augmenting train:  65%|██████▍   | 5001/7752 [11:33:48<7:20:25,  9.61s/it, Written=1716, Skipped=1572]
# Augmenting train:  65%|██████▍   | 5002/7752 [11:33:48<8:41:56, 11.39s/it, Written=1716, Skipped=1572]
# Augmenting train:  65%|██████▍   | 5002/7752 [11:34:07<8:41:56, 11.39s/it, Written=1716, Skipped=1573]
# Augmenting train:  65%|██████▍   | 5003/7752 [11:34:07<10:21:36, 13.57s/it, Written=1716, Skipped=1573]
# Augmenting train:  65%|██████▍   | 5003/7752 [11:34:24<10:21:36, 13.57s/it, Written=1716, Skipped=1574]
# Augmenting train:  65%|██████▍   | 5004/7752 [11:34:24<11:11:07, 14.65s/it, Written=1716, Skipped=1574]
# Augmenting train:  65%|██████▍   | 5004/7752 [11:34:42<11:11:07, 14.65s/it, Written=1716, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5005/7752 [11:34:42<11:52:50, 15.57s/it, Written=1716, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5005/7752 [11:34:49<11:52:50, 15.57s/it, Written=1717, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5006/7752 [11:34:49<10:00:49, 13.13s/it, Written=1717, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5006/7752 [11:34:56<10:00:49, 13.13s/it, Written=1718, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5007/7752 [11:34:56<8:25:40, 11.05s/it, Written=1718, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5007/7752 [11:35:02<8:25:40, 11.05s/it, Written=1719, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5008/7752 [11:35:02<7:15:03,  9.51s/it, Written=1719, Skipped=1575]
# Augmenting train:  65%|██████▍   | 5008/7752 [11:35:17<7:15:03,  9.51s/it, Written=1719, Skipped=1576]
# Augmenting train:  65%|██████▍   | 5009/7752 [11:35:17<8:39:20, 11.36s/it, Written=1719, Skipped=1576]
# Augmenting train:  65%|██████▍   | 5009/7752 [11:35:37<8:39:20, 11.36s/it, Written=1719, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5010/7752 [11:35:37<10:28:58, 13.76s/it, Written=1719, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5010/7752 [11:35:50<10:28:58, 13.76s/it, Written=1720, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5011/7752 [11:35:50<10:17:51, 13.52s/it, Written=1720, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5011/7752 [11:35:55<10:17:51, 13.52s/it, Written=1721, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5012/7752 [11:35:55<8:26:10, 11.08s/it, Written=1721, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5012/7752 [11:36:02<8:26:10, 11.08s/it, Written=1722, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5013/7752 [11:36:02<7:25:33,  9.76s/it, Written=1722, Skipped=1577]
# Augmenting train:  65%|██████▍   | 5013/7752 [11:36:18<7:25:33,  9.76s/it, Written=1722, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5014/7752 [11:36:18<8:49:37, 11.61s/it, Written=1722, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5014/7752 [11:36:25<8:49:37, 11.61s/it, Written=1723, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5015/7752 [11:36:25<7:52:20, 10.35s/it, Written=1723, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5015/7752 [11:36:30<7:52:20, 10.35s/it, Written=1724, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5016/7752 [11:36:30<6:46:12,  8.91s/it, Written=1724, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5016/7752 [11:36:37<6:46:12,  8.91s/it, Written=1725, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5017/7752 [11:36:37<6:17:45,  8.29s/it, Written=1725, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5017/7752 [11:36:44<6:17:45,  8.29s/it, Written=1726, Skipped=1578]
# Augmenting train:  65%|██████▍   | 5017/7752 [11:37:02<6:17:45,  8.29s/it, Written=1726, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5018/7752 [11:37:02<9:54:46, 13.05s/it, Written=1726, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5018/7752 [11:37:27<9:54:46, 13.05s/it, Written=1727, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5019/7752 [11:37:27<12:40:14, 16.69s/it, Written=1727, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5019/7752 [11:37:42<12:40:14, 16.69s/it, Written=1728, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5020/7752 [11:37:42<12:19:48, 16.25s/it, Written=1728, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5020/7752 [11:37:50<12:19:48, 16.25s/it, Written=1729, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5020/7752 [11:37:57<12:19:48, 16.25s/it, Written=1730, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5021/7752 [11:37:57<12:07:20, 15.98s/it, Written=1730, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5021/7752 [11:38:05<12:07:20, 15.98s/it, Written=1731, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5022/7752 [11:38:05<10:08:09, 13.37s/it, Written=1731, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5022/7752 [11:38:12<10:08:09, 13.37s/it, Written=1732, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5023/7752 [11:38:12<8:44:06, 11.52s/it, Written=1732, Skipped=1579]
# Augmenting train:  65%|██████▍   | 5023/7752 [11:38:38<8:44:06, 11.52s/it, Written=1732, Skipped=1580]
# Augmenting train:  65%|██████▍   | 5024/7752 [11:38:38<12:08:58, 16.03s/it, Written=1732, Skipped=1580]
# Augmenting train:  65%|██████▍   | 5024/7752 [11:38:58<12:08:58, 16.03s/it, Written=1732, Skipped=1581]
# Augmenting train:  65%|██████▍   | 5025/7752 [11:38:58<12:58:15, 17.12s/it, Written=1732, Skipped=1581]
# Augmenting train:  65%|██████▍   | 5025/7752 [11:39:03<12:58:15, 17.12s/it, Written=1733, Skipped=1581]
# Augmenting train:  65%|██████▍   | 5026/7752 [11:39:03<10:18:51, 13.62s/it, Written=1733, Skipped=1581]
# Augmenting train:  65%|██████▍   | 5026/7752 [11:39:21<10:18:51, 13.62s/it, Written=1733, Skipped=1582]
# Augmenting train:  65%|██████▍   | 5027/7752 [11:39:21<11:14:51, 14.86s/it, Written=1733, Skipped=1582]
# Augmenting train:  65%|██████▍   | 5027/7752 [11:39:37<11:14:51, 14.86s/it, Written=1733, Skipped=1583]
# Augmenting train:  65%|██████▍   | 5028/7752 [11:39:37<11:27:04, 15.13s/it, Written=1733, Skipped=1583]
# Augmenting train:  65%|██████▍   | 5028/7752 [11:39:53<11:27:04, 15.13s/it, Written=1733, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5029/7752 [11:39:53<11:44:57, 15.53s/it, Written=1733, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5029/7752 [11:40:00<11:44:57, 15.53s/it, Written=1734, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5030/7752 [11:40:00<9:43:25, 12.86s/it, Written=1734, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5030/7752 [11:40:07<9:43:25, 12.86s/it, Written=1735, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5031/7752 [11:40:07<8:21:27, 11.06s/it, Written=1735, Skipped=1584]
# Augmenting train:  65%|██████▍   | 5031/7752 [11:40:31<8:21:27, 11.06s/it, Written=1735, Skipped=1585]
# Augmenting train:  65%|██████▍   | 5032/7752 [11:40:31<11:15:56, 14.91s/it, Written=1735, Skipped=1585]
# Augmenting train:  65%|██████▍   | 5032/7752 [11:40:51<11:15:56, 14.91s/it, Written=1735, Skipped=1586]
# Augmenting train:  65%|██████▍   | 5033/7752 [11:40:51<12:29:07, 16.53s/it, Written=1735, Skipped=1586]
# Augmenting train:  65%|██████▍   | 5033/7752 [11:41:11<12:29:07, 16.53s/it, Written=1735, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5034/7752 [11:41:11<13:14:13, 17.53s/it, Written=1735, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5034/7752 [11:41:23<13:14:13, 17.53s/it, Written=1736, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5035/7752 [11:41:23<12:04:51, 16.01s/it, Written=1736, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5035/7752 [11:41:30<12:04:51, 16.01s/it, Written=1737, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5036/7752 [11:41:30<9:52:25, 13.09s/it, Written=1737, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5036/7752 [11:41:38<9:52:25, 13.09s/it, Written=1738, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5037/7752 [11:41:38<8:45:02, 11.60s/it, Written=1738, Skipped=1587]
# Augmenting train:  65%|██████▍   | 5037/7752 [11:42:02<8:45:02, 11.60s/it, Written=1738, Skipped=1588]
# Augmenting train:  65%|██████▍   | 5038/7752 [11:42:02<11:30:31, 15.27s/it, Written=1738, Skipped=1588]
# Augmenting train:  65%|██████▍   | 5038/7752 [11:42:08<11:30:31, 15.27s/it, Written=1739, Skipped=1588]
# Augmenting train:  65%|██████▌   | 5039/7752 [11:42:08<9:34:13, 12.70s/it, Written=1739, Skipped=1588]
# Augmenting train:  65%|██████▌   | 5039/7752 [11:42:29<9:34:13, 12.70s/it, Written=1739, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5040/7752 [11:42:29<11:20:03, 15.05s/it, Written=1739, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5040/7752 [11:42:34<11:20:03, 15.05s/it, Written=1740, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5041/7752 [11:42:34<9:06:41, 12.10s/it, Written=1740, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5041/7752 [11:42:42<9:06:41, 12.10s/it, Written=1741, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5042/7752 [11:42:42<8:03:26, 10.70s/it, Written=1741, Skipped=1589]
# Augmenting train:  65%|██████▌   | 5042/7752 [11:42:57<8:03:26, 10.70s/it, Written=1741, Skipped=1590]
# Augmenting train:  65%|██████▌   | 5043/7752 [11:42:57<9:09:03, 12.16s/it, Written=1741, Skipped=1590]
# Augmenting train:  65%|██████▌   | 5043/7752 [11:43:04<9:09:03, 12.16s/it, Written=1742, Skipped=1590]
# Augmenting train:  65%|██████▌   | 5044/7752 [11:43:04<8:02:17, 10.69s/it, Written=1742, Skipped=1590]
# Augmenting train:  65%|██████▌   | 5044/7752 [11:43:21<8:02:17, 10.69s/it, Written=1742, Skipped=1591]
# Augmenting train:  65%|██████▌   | 5045/7752 [11:43:21<9:16:56, 12.34s/it, Written=1742, Skipped=1591]
# Augmenting train:  65%|██████▌   | 5045/7752 [11:43:38<9:16:56, 12.34s/it, Written=1742, Skipped=1592]
# Augmenting train:  65%|██████▌   | 5046/7752 [11:43:38<10:20:21, 13.76s/it, Written=1742, Skipped=1592]
# Augmenting train:  65%|██████▌   | 5046/7752 [11:43:57<10:20:21, 13.76s/it, Written=1743, Skipped=1592]
# Augmenting train:  65%|██████▌   | 5047/7752 [11:43:57<6:17:17,  8.37s/it, Written=1743, Skipped=1592]
# ⚠️ REACHED 11.75 HOURS. GRACEFULLY STOPPING.
# 📊 Stats this run -> Written: 1743 | Skipped: 1592
# 💾 Files safely saved to: /kaggle/working/augmented
