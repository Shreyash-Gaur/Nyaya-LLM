# %%
# !pip install jsonschema transformers accelerate sentencepiece bitsandbytes tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.9 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
"""
==============================================================
Nyaya-LLM  —  Phase 2 Dataset Augmentation (Kaggle / P100)
==============================================================
Augments all three splits (train, val, test) using a
HuggingFace model loaded directly on the P100 GPU.

Long sections (>3000 chars) are chunked at subsection
boundaries so every part of the statute gets covered.
==============================================================
"""

import json
import re
import os
import time
import torch
import shutil
import gc
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from jsonschema import validate, ValidationError

# ==============================
# ⚙️  CONFIG
# ==============================
MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"

# ── Paths ───────────────────────────────────────────────────
INPUT_DIR  = "/kaggle/input/datasets/shreyashgaur221/nyaya-llm-processed"
OUTPUT_DIR = "/kaggle/working/augmented"
WIP_DATASET_PATH = "/kaggle/input/datasets/shreyashgaur221/nyaya-augmented-wip" # For Run 2+

SPLITS = {
    "train": "all_acts_train.jsonl",
    "val":   "all_acts_val.jsonl",
    "test":  "all_acts_test.jsonl",
}

# ── Processing Limits ───────────────────────────────────────
CHUNK_SIZE  = 3000    
RETRY_LIMIT = 3       
MAX_RUNTIME_HOURS = 7.9

# ==============================
# 📦  JSON SCHEMA
# ==============================
AUGMENT_SCHEMA = {
    "type": "object",
    "properties": {
        "instruction": {"type": "string"},
        "input":       {"type": "string"},
        "output":      {"type": "string"}
    },
    "required": ["instruction", "input", "output"]
}

# ==============================
# 💬  PROMPT (CHAT TEMPLATE)
# ==============================
SYSTEM_PROMPT = """You are a strict Indian legal dataset generator.

RULES:
1. Only use the provided statute text. Do NOT add outside legal knowledge.
2. Do NOT invent punishments, sections, or acts not mentioned in the text.
3. Output STRICT JSON only. No markdown, no explanation, no preamble.
4. Return exactly ONE valid JSON object.
5. The instruction must be a realistic question a layperson or law student would ask.
6. The output must apply or explain the statute — not just quote it verbatim."""

def build_messages(original_instruction: str, chunk: str) -> list:
    user_msg = f"""ORIGINAL INSTRUCTION:
{original_instruction}

STATUTE TEXT:
{chunk}

---
Generate a new, enriched training example that:
- Asks a reasoning or application question about this statute text
- Answers it using ONLY the information in the statute text above
- Does NOT reference sections or provisions outside the text above

Respond ONLY with this JSON format, nothing else:
{{
  "instruction": "...",
  "input": "",
  "output": "..."
}}"""

    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg}
    ]

# ==============================
# ✂️  CHUNKER
# ==============================
def chunk_text(text: str, max_chars: int = CHUNK_SIZE) -> list:
    if len(text) <= max_chars:
        return [text]

    parts   = text.split("\n\n")
    chunks  = []
    current = ""

    for part in parts:
        if len(part) > max_chars:
            if current:
                chunks.append(current.strip())
                current = ""
            sentences = re.split(r'(?<=[.;])\s+', part)
            for sentence in sentences:
                if len(current) + len(sentence) <= max_chars:
                    current += " " + sentence
                else:
                    if current:
                        chunks.append(current.strip())
                    current = sentence
        elif len(current) + len(part) + 2 <= max_chars:
            current += "\n\n" + part
        else:
            if current:
                chunks.append(current.strip())
            current = part

    if current:
        chunks.append(current.strip())

    return [c for c in chunks if len(c) >= 50]

# ==============================
# 🤖  MODEL LOADING
# ==============================
def load_model():
    print(f"Loading {MODEL_NAME} in 4-bit on GPU...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16, 
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.float16,
        trust_remote_code=True
    )
    model.eval()
    print("Model loaded.\n")
    return model, tokenizer

# ==============================
# 🔁  GENERATION (WITH OOM KILLER)
# ==============================
def generate(model, tokenizer, messages: list) -> str:
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.2,
            do_sample=True,
            top_p=0.8,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id
        )

    new_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    result = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    
    del inputs
    del outputs
    del new_tokens
    torch.cuda.empty_cache()
    gc.collect()
    
    return result

# ==============================
# 🔍  JSON EXTRACTION
# ==============================
def extract_json(text: str):
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        return None
    try:
        return json.loads(match.group())
    except Exception:
        return None

# ==============================
# 🛡️  HALLUCINATION GUARD (FIXED)
# ==============================
def hallucination_guard(original_text: str, generated_output: str) -> bool:
    out_lower  = generated_output.lower()
    orig_lower = original_text.lower()

    # Lexical overlap only — remove the strict act/section requirement
    orig_words  = set(orig_lower.split())
    gen_words   = set(out_lower.split())
    overlap     = len(orig_words & gen_words)

    # Just needs reasonable overlap with source text
    return overlap > 10

# ==============================
# 💾  CHECKPOINT HELPER
# ==============================
def load_processed_keys(output_path: str) -> set:
    processed = set()
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    key = (obj.get("source_instruction", ""), obj.get("chunk_index", 0))
                    processed.add(key)
                except Exception:
                    pass
    return processed

# ==============================
# 🚀  MAIN
# ==============================
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # --- RUN 2 RESTORATION LOGIC ---
    if os.path.exists(WIP_DATASET_PATH):
        print("Restoring previous progress from WIP dataset...")
        for filename in os.listdir(WIP_DATASET_PATH):
            if filename.endswith(".jsonl"):
                src = os.path.join(WIP_DATASET_PATH, filename)
                dst = os.path.join(OUTPUT_DIR, filename)
                shutil.copy2(src, dst)
                print(f"✅ Restored: {filename}")
        print("Ready to resume!\n")
    # -------------------------------
    
    START_TIME = time.time()
    MAX_RUNTIME_SEC = MAX_RUNTIME_HOURS * 3600 

    model, tokenizer = load_model()

    total_written = 0
    total_skipped = 0

    for split_name, filename in SPLITS.items():
        input_path  = os.path.join(INPUT_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, f"all_acts_{split_name}_augmented.jsonl")

        if not os.path.exists(input_path):
            print(f"⚠️  {input_path} not found — skipping {split_name}")
            continue

        with open(input_path, "r", encoding="utf-8") as f:
            data = [json.loads(line) for line in f]

        processed_keys = load_processed_keys(output_path)
        total_chunks = sum(len(chunk_text(d["output"])) for d in data)

        print(f"\n{'='*60}")
        print(f"📂  Split         : {split_name.upper()}")
        print(f"    Samples       : {len(data)}")
        print(f"    Total chunks  : {total_chunks}")
        print(f"    Already done  : {len(processed_keys)}")
        print(f"    Remaining     : {total_chunks - len(processed_keys)}")
        print(f"{'='*60}\n")

        split_written = 0
        split_skipped = 0

        pbar = tqdm(data, desc=f"Augmenting {split_name}")
        with open(output_path, "a", encoding="utf-8") as outfile:
            for example in pbar:
                instruction = example["instruction"]
                chunks      = chunk_text(example["output"])

                for chunk_idx, chunk in enumerate(chunks):
                    
                    if time.time() - START_TIME > MAX_RUNTIME_SEC:
                        print(f"\n⚠️ REACHED {MAX_RUNTIME_HOURS} HOURS. GRACEFULLY STOPPING.")
                        print(f"📊 Stats this run -> Written: {split_written} | Skipped: {split_skipped}")
                        print(f"💾 Files safely saved to: {OUTPUT_DIR}")
                        return 
                    
                    key = (instruction, chunk_idx)

                    if key in processed_keys:
                        continue

                    retries = 0
                    success = False

                    while retries < RETRY_LIMIT and not success:
                        try:
                            messages = build_messages(instruction, chunk)
                            raw      = generate(model, tokenizer, messages)
                            parsed   = extract_json(raw)

                            if parsed is None:
                                raise ValueError("No JSON found")

                            validate(instance=parsed, schema=AUGMENT_SCHEMA)

                            if not hallucination_guard(chunk, parsed["output"]):
                                raise ValueError("Hallucination guard failed")

                            parsed["source_instruction"] = instruction
                            parsed["chunk_index"]        = chunk_idx
                            parsed["total_chunks"]       = len(chunks)
                            parsed["split"]              = split_name

                            outfile.write(json.dumps(parsed, ensure_ascii=False) + "\n")
                            outfile.flush()
                            success       = True
                            split_written += 1

                        except (ValidationError, ValueError):
                            retries += 1
                            time.sleep(0.5)
                        except Exception as e:
                            print(f"\n❌ Unexpected error: {e}")
                            retries += 1
                            time.sleep(1)

                    if not success:
                        split_skipped += 1
                        
                    # LIVE TRACKER: Updates the progress bar with real-time stats!
                    pbar.set_postfix({"Written": split_written, "Skipped": split_skipped})

        total_written += split_written
        total_skipped += split_skipped

        print(f"\n✅  {split_name} done")
        print(f"    Written : {split_written}")
        print(f"    Skipped : {split_skipped}")
        print(f"    Saved   : {output_path}")

    print(f"\n{'='*60}")
    print(f"🏁  AUGMENTATION COMPLETE")
    print(f"    Total written : {total_written}")
    print(f"    Total skipped : {total_skipped}")
    print(f"    Output dir    : {OUTPUT_DIR}")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# Restoring previous progress from WIP dataset...
# ✅ Restored: all_acts_train_augmented.jsonl
# Ready to resume!
#
# Loading Qwen/Qwen2.5-7B-Instruct in 4-bit on GPU...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded.
#
#
# ============================================================
# 📂  Split         : TRAIN
#     Samples       : 7752
#     Total chunks  : 7935
#     Already done  : 173
#     Remaining     : 7762
# ============================================================
# Augmenting train:   0%|          | 0/7752 [00:00<?, ?it/s]
# Augmenting train:   0%|          | 0/7752 [00:17<?, ?it/s, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:17<38:30:16, 17.88s/it, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:38<38:30:16, 17.88s/it, Written=1, Skipped=1]
# Augmenting train:   0%|          | 2/7752 [00:38<41:34:31, 19.31s/it, Written=1, Skipped=1]
# Augmenting train:   0%|          | 2/7752 [00:53<41:34:31, 19.31s/it, Written=1, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:53<37:56:30, 17.63s/it, Written=1, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [01:01<37:56:30, 17.63s/it, Written=2, Skipped=2]
# Augmenting train:   0%|          | 4/7752 [01:01<29:33:33, 13.73s/it, Written=2, Skipped=2]
# Augmenting train:   0%|          | 4/7752 [01:21<29:33:33, 13.73s/it, Written=3, Skipped=2]
# Augmenting train:   0%|          | 5/7752 [01:21<34:29:05, 16.02s/it, Written=3, Skipped=2]
# Augmenting train:   0%|          | 5/7752 [01:26<34:29:05, 16.02s/it, Written=4, Skipped=2]
# Augmenting train:   0%|          | 6/7752 [01:26<26:24:52, 12.28s/it, Written=4, Skipped=2]
# Augmenting train:   0%|          | 6/7752 [01:32<26:24:52, 12.28s/it, Written=5, Skipped=2]
# Augmenting train:   0%|          | 7/7752 [01:32<22:06:33, 10.28s/it, Written=5, Skipped=2]
# Augmenting train:   0%|          | 7/7752 [01:49<22:06:33, 10.28s/it, Written=5, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [01:49<26:21:38, 12.25s/it, Written=5, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [01:55<26:21:38, 12.25s/it, Written=6, Skipped=3]
# Augmenting train:   0%|          | 9/7752 [01:55<22:30:42, 10.47s/it, Written=6, Skipped=3]
# Augmenting train:   0%|          | 9/7752 [02:05<22:30:42, 10.47s/it, Written=7, Skipped=3]
# Augmenting train:   0%|          | 11/7752 [02:05<16:34:38,  7.71s/it, Written=7, Skipped=3]
# Augmenting train:   0%|          | 11/7752 [02:11<16:34:38,  7.71s/it, Written=8, Skipped=3]
# Augmenting train:   0%|          | 12/7752 [02:11<15:48:40,  7.35s/it, Written=8, Skipped=3]
# Augmenting train:   0%|          | 12/7752 [02:17<15:48:40,  7.35s/it, Written=9, Skipped=3]
# Augmenting train:   0%|          | 13/7752 [02:17<14:52:40,  6.92s/it, Written=9, Skipped=3]
# Augmenting train:   0%|          | 13/7752 [02:24<14:52:40,  6.92s/it, Written=10, Skipped=3]
# Augmenting train:   0%|          | 14/7752 [02:24<14:58:13,  6.96s/it, Written=10, Skipped=3]
# Augmenting train:   0%|          | 14/7752 [02:30<14:58:13,  6.96s/it, Written=11, Skipped=3]
# Augmenting train:   0%|          | 15/7752 [02:30<14:43:24,  6.85s/it, Written=11, Skipped=3]
# Augmenting train:   0%|          | 15/7752 [02:37<14:43:24,  6.85s/it, Written=12, Skipped=3]
# Augmenting train:   0%|          | 16/7752 [02:37<14:34:25,  6.78s/it, Written=12, Skipped=3]
# Augmenting train:   0%|          | 16/7752 [02:44<14:34:25,  6.78s/it, Written=13, Skipped=3]
# Augmenting train:   0%|          | 18/7752 [02:44<11:37:47,  5.41s/it, Written=13, Skipped=3]
# Augmenting train:   0%|          | 18/7752 [02:53<11:37:47,  5.41s/it, Written=14, Skipped=3]
# Augmenting train:   0%|          | 20/7752 [02:53<10:30:24,  4.89s/it, Written=14, Skipped=3]
# Augmenting train:   0%|          | 20/7752 [02:59<10:30:24,  4.89s/it, Written=15, Skipped=3]
# Augmenting train:   0%|          | 21/7752 [02:59<11:25:22,  5.32s/it, Written=15, Skipped=3]
# Augmenting train:   0%|          | 21/7752 [03:15<11:25:22,  5.32s/it, Written=16, Skipped=3]
# Augmenting train:   0%|          | 22/7752 [03:15<16:34:47,  7.72s/it, Written=16, Skipped=3]
# Augmenting train:   0%|          | 22/7752 [03:36<16:34:47,  7.72s/it, Written=16, Skipped=4]
# Augmenting train:   0%|          | 23/7752 [03:36<23:40:13, 11.03s/it, Written=16, Skipped=4]
# Augmenting train:   0%|          | 23/7752 [03:44<23:40:13, 11.03s/it, Written=17, Skipped=4]
# Augmenting train:   0%|          | 24/7752 [03:44<21:56:41, 10.22s/it, Written=17, Skipped=4]
# Augmenting train:   0%|          | 24/7752 [03:50<21:56:41, 10.22s/it, Written=18, Skipped=4]
# Augmenting train:   0%|          | 25/7752 [03:50<19:39:13,  9.16s/it, Written=18, Skipped=4]
# Augmenting train:   0%|          | 25/7752 [03:56<19:39:13,  9.16s/it, Written=19, Skipped=4]
# Augmenting train:   0%|          | 26/7752 [03:56<17:40:54,  8.24s/it, Written=19, Skipped=4]
# Augmenting train:   0%|          | 26/7752 [04:02<17:40:54,  8.24s/it, Written=20, Skipped=4]
# Augmenting train:   0%|          | 27/7752 [04:02<16:30:40,  7.69s/it, Written=20, Skipped=4]
# Augmenting train:   0%|          | 27/7752 [04:07<16:30:40,  7.69s/it, Written=21, Skipped=4]
# Augmenting train:   0%|          | 28/7752 [04:07<15:02:13,  7.01s/it, Written=21, Skipped=4]
# Augmenting train:   0%|          | 28/7752 [04:21<15:02:13,  7.01s/it, Written=22, Skipped=4]
# Augmenting train:   0%|          | 29/7752 [04:21<19:14:52,  8.97s/it, Written=22, Skipped=4]
# Augmenting train:   0%|          | 29/7752 [04:29<19:14:52,  8.97s/it, Written=23, Skipped=4]
# Augmenting train:   0%|          | 30/7752 [04:29<18:37:17,  8.68s/it, Written=23, Skipped=4]
# Augmenting train:   0%|          | 30/7752 [04:38<18:37:17,  8.68s/it, Written=24, Skipped=4]
# Augmenting train:   0%|          | 31/7752 [04:38<18:34:28,  8.66s/it, Written=24, Skipped=4]
# Augmenting train:   0%|          | 31/7752 [04:52<18:34:28,  8.66s/it, Written=24, Skipped=5]
# Augmenting train:   0%|          | 33/7752 [04:52<17:10:12,  8.01s/it, Written=24, Skipped=5]
# Augmenting train:   0%|          | 33/7752 [04:59<17:10:12,  8.01s/it, Written=25, Skipped=5]
# Augmenting train:   0%|          | 34/7752 [04:59<16:34:31,  7.73s/it, Written=25, Skipped=5]
# Augmenting train:   0%|          | 34/7752 [05:05<16:34:31,  7.73s/it, Written=26, Skipped=5]
# Augmenting train:   0%|          | 35/7752 [05:05<15:47:22,  7.37s/it, Written=26, Skipped=5]
# Augmenting train:   0%|          | 35/7752 [05:24<15:47:22,  7.37s/it, Written=26, Skipped=6]
# Augmenting train:   0%|          | 36/7752 [05:24<22:32:42, 10.52s/it, Written=26, Skipped=6]
# Augmenting train:   0%|          | 36/7752 [05:50<22:32:42, 10.52s/it, Written=26, Skipped=7]
# Augmenting train:   0%|          | 37/7752 [05:50<31:29:40, 14.70s/it, Written=26, Skipped=7]
# Augmenting train:   0%|          | 37/7752 [05:56<31:29:40, 14.70s/it, Written=27, Skipped=7]
# Augmenting train:   0%|          | 38/7752 [05:56<26:29:03, 12.36s/it, Written=27, Skipped=7]
# Augmenting train:   0%|          | 38/7752 [06:02<26:29:03, 12.36s/it, Written=28, Skipped=7]
# Augmenting train:   1%|          | 39/7752 [06:02<22:32:52, 10.52s/it, Written=28, Skipped=7]
# Augmenting train:   1%|          | 39/7752 [06:20<22:32:52, 10.52s/it, Written=28, Skipped=8]
# Augmenting train:   1%|          | 41/7752 [06:20<20:39:20,  9.64s/it, Written=28, Skipped=8]
# Augmenting train:   1%|          | 41/7752 [06:26<20:39:20,  9.64s/it, Written=29, Skipped=8]
# Augmenting train:   1%|          | 42/7752 [06:26<19:06:02,  8.92s/it, Written=29, Skipped=8]
# Augmenting train:   1%|          | 42/7752 [06:33<19:06:02,  8.92s/it, Written=30, Skipped=8]
# Augmenting train:   1%|          | 43/7752 [06:33<17:46:36,  8.30s/it, Written=30, Skipped=8]
# Augmenting train:   1%|          | 43/7752 [06:43<17:46:36,  8.30s/it, Written=31, Skipped=8]
# Augmenting train:   1%|          | 44/7752 [06:43<18:56:16,  8.84s/it, Written=31, Skipped=8]
# Augmenting train:   1%|          | 44/7752 [06:50<18:56:16,  8.84s/it, Written=32, Skipped=8]
# Augmenting train:   1%|          | 45/7752 [06:50<17:30:52,  8.18s/it, Written=32, Skipped=8]
# Augmenting train:   1%|          | 45/7752 [07:07<17:30:52,  8.18s/it, Written=32, Skipped=9]
# Augmenting train:   1%|          | 46/7752 [07:07<23:08:10, 10.81s/it, Written=32, Skipped=9]
# Augmenting train:   1%|          | 46/7752 [07:26<23:08:10, 10.81s/it, Written=33, Skipped=9]
# Augmenting train:   1%|          | 46/7752 [07:33<23:08:10, 10.81s/it, Written=34, Skipped=9]
# Augmenting train:   1%|          | 46/7752 [07:45<23:08:10, 10.81s/it, Written=35, Skipped=9]
# Augmenting train:   1%|          | 47/7752 [07:45<40:06:43, 18.74s/it, Written=35, Skipped=9]
# Augmenting train:   1%|          | 47/7752 [08:01<40:06:43, 18.74s/it, Written=35, Skipped=10]
# Augmenting train:   1%|          | 48/7752 [08:01<38:12:25, 17.85s/it, Written=35, Skipped=10]
# Augmenting train:   1%|          | 48/7752 [08:20<38:12:25, 17.85s/it, Written=35, Skipped=11]
# Augmenting train:   1%|          | 49/7752 [08:20<38:44:15, 18.10s/it, Written=35, Skipped=11]
# Augmenting train:   1%|          | 49/7752 [08:34<38:44:15, 18.10s/it, Written=36, Skipped=11]
# Augmenting train:   1%|          | 50/7752 [08:34<36:15:22, 16.95s/it, Written=36, Skipped=11]
# Augmenting train:   1%|          | 50/7752 [08:40<36:15:22, 16.95s/it, Written=37, Skipped=11]
# Augmenting train:   1%|          | 51/7752 [08:40<29:26:54, 13.77s/it, Written=37, Skipped=11]
# Augmenting train:   1%|          | 51/7752 [08:46<29:26:54, 13.77s/it, Written=38, Skipped=11]
# Augmenting train:   1%|          | 52/7752 [08:46<24:28:05, 11.44s/it, Written=38, Skipped=11]
# Augmenting train:   1%|          | 52/7752 [08:54<24:28:05, 11.44s/it, Written=39, Skipped=11]
# Augmenting train:   1%|          | 53/7752 [08:54<22:05:46, 10.33s/it, Written=39, Skipped=11]
# Augmenting train:   1%|          | 53/7752 [09:00<22:05:46, 10.33s/it, Written=40, Skipped=11]
# Augmenting train:   1%|          | 54/7752 [09:00<19:34:45,  9.16s/it, Written=40, Skipped=11]
# Augmenting train:   1%|          | 54/7752 [09:07<19:34:45,  9.16s/it, Written=41, Skipped=11]
# Augmenting train:   1%|          | 55/7752 [09:07<18:06:19,  8.47s/it, Written=41, Skipped=11]
# Augmenting train:   1%|          | 55/7752 [09:13<18:06:19,  8.47s/it, Written=42, Skipped=11]
# Augmenting train:   1%|          | 56/7752 [09:13<16:15:13,  7.60s/it, Written=42, Skipped=11]
# Augmenting train:   1%|          | 56/7752 [09:18<16:15:13,  7.60s/it, Written=43, Skipped=11]
# Augmenting train:   1%|          | 57/7752 [09:18<14:49:31,  6.94s/it, Written=43, Skipped=11]
# Augmenting train:   1%|          | 57/7752 [09:36<14:49:31,  6.94s/it, Written=43, Skipped=12]
# Augmenting train:   1%|          | 58/7752 [09:36<21:39:26, 10.13s/it, Written=43, Skipped=12]
# Augmenting train:   1%|          | 58/7752 [09:42<21:39:26, 10.13s/it, Written=44, Skipped=12]
# Augmenting train:   1%|          | 59/7752 [09:42<19:31:50,  9.14s/it, Written=44, Skipped=12]
# Augmenting train:   1%|          | 59/7752 [09:51<19:31:50,  9.14s/it, Written=45, Skipped=12]
# Augmenting train:   1%|          | 60/7752 [09:51<19:09:20,  8.97s/it, Written=45, Skipped=12]
# Augmenting train:   1%|          | 60/7752 [09:59<19:09:20,  8.97s/it, Written=46, Skipped=12]
# Augmenting train:   1%|          | 61/7752 [09:59<18:41:27,  8.75s/it, Written=46, Skipped=12]
# Augmenting train:   1%|          | 61/7752 [10:15<18:41:27,  8.75s/it, Written=46, Skipped=13]
# Augmenting train:   1%|          | 62/7752 [10:15<23:00:05, 10.77s/it, Written=46, Skipped=13]
# Augmenting train:   1%|          | 62/7752 [10:20<23:00:05, 10.77s/it, Written=47, Skipped=13]
# Augmenting train:   1%|          | 63/7752 [10:20<19:27:44,  9.11s/it, Written=47, Skipped=13]
# Augmenting train:   1%|          | 63/7752 [10:26<19:27:44,  9.11s/it, Written=48, Skipped=13]
# Augmenting train:   1%|          | 64/7752 [10:26<17:20:55,  8.12s/it, Written=48, Skipped=13]
# Augmenting train:   1%|          | 64/7752 [10:42<17:20:55,  8.12s/it, Written=48, Skipped=14]
# Augmenting train:   1%|          | 65/7752 [10:42<22:38:05, 10.60s/it, Written=48, Skipped=14]
# Augmenting train:   1%|          | 65/7752 [10:49<22:38:05, 10.60s/it, Written=49, Skipped=14]
# Augmenting train:   1%|          | 66/7752 [10:49<20:00:44,  9.37s/it, Written=49, Skipped=14]
# Augmenting train:   1%|          | 66/7752 [11:03<20:00:44,  9.37s/it, Written=49, Skipped=15]
# Augmenting train:   1%|          | 67/7752 [11:03<23:25:25, 10.97s/it, Written=49, Skipped=15]
# Augmenting train:   1%|          | 67/7752 [11:18<23:25:25, 10.97s/it, Written=49, Skipped=16]
# Augmenting train:   1%|          | 68/7752 [11:18<25:55:14, 12.14s/it, Written=49, Skipped=16]
# Augmenting train:   1%|          | 68/7752 [11:31<25:55:14, 12.14s/it, Written=49, Skipped=17]
# Augmenting train:   1%|          | 69/7752 [11:31<26:12:45, 12.28s/it, Written=49, Skipped=17]
# Augmenting train:   1%|          | 69/7752 [11:47<26:12:45, 12.28s/it, Written=49, Skipped=18]
# Augmenting train:   1%|          | 71/7752 [11:47<21:49:53, 10.23s/it, Written=49, Skipped=18]
# Augmenting train:   1%|          | 71/7752 [11:56<21:49:53, 10.23s/it, Written=50, Skipped=18]
# Augmenting train:   1%|          | 72/7752 [11:56<21:31:35, 10.09s/it, Written=50, Skipped=18]
# Augmenting train:   1%|          | 72/7752 [12:13<21:31:35, 10.09s/it, Written=50, Skipped=19]
# Augmenting train:   1%|          | 73/7752 [12:13<25:27:09, 11.93s/it, Written=50, Skipped=19]
# Augmenting train:   1%|          | 73/7752 [12:19<25:27:09, 11.93s/it, Written=51, Skipped=19]
# Augmenting train:   1%|          | 74/7752 [12:19<21:42:24, 10.18s/it, Written=51, Skipped=19]
# Augmenting train:   1%|          | 74/7752 [12:27<21:42:24, 10.18s/it, Written=52, Skipped=19]
# Augmenting train:   1%|          | 76/7752 [12:27<15:59:28,  7.50s/it, Written=52, Skipped=19]
# Augmenting train:   1%|          | 76/7752 [12:35<15:59:28,  7.50s/it, Written=53, Skipped=19]
# Augmenting train:   1%|          | 77/7752 [12:35<16:25:07,  7.70s/it, Written=53, Skipped=19]
# Augmenting train:   1%|          | 77/7752 [12:53<16:25:07,  7.70s/it, Written=53, Skipped=20]
# Augmenting train:   1%|          | 79/7752 [12:53<17:12:04,  8.07s/it, Written=53, Skipped=20]
# Augmenting train:   1%|          | 79/7752 [13:12<17:12:04,  8.07s/it, Written=54, Skipped=20]
# Augmenting train:   1%|          | 80/7752 [13:12<22:41:56, 10.65s/it, Written=54, Skipped=20]
# Augmenting train:   1%|          | 80/7752 [13:18<22:41:56, 10.65s/it, Written=55, Skipped=20]
# Augmenting train:   1%|          | 81/7752 [13:18<20:19:30,  9.54s/it, Written=55, Skipped=20]
# Augmenting train:   1%|          | 81/7752 [13:25<20:19:30,  9.54s/it, Written=56, Skipped=20]
# Augmenting train:   1%|          | 83/7752 [13:25<14:50:00,  6.96s/it, Written=56, Skipped=20]
# Augmenting train:   1%|          | 83/7752 [13:31<14:50:00,  6.96s/it, Written=57, Skipped=20]
# Augmenting train:   1%|          | 84/7752 [13:31<14:27:31,  6.79s/it, Written=57, Skipped=20]
# Augmenting train:   1%|          | 84/7752 [13:42<14:27:31,  6.79s/it, Written=57, Skipped=21]
# Augmenting train:   1%|          | 85/7752 [13:42<16:53:14,  7.93s/it, Written=57, Skipped=21]
# Augmenting train:   1%|          | 85/7752 [13:50<16:53:14,  7.93s/it, Written=58, Skipped=21]
# Augmenting train:   1%|          | 86/7752 [13:50<16:40:36,  7.83s/it, Written=58, Skipped=21]
# Augmenting train:   1%|          | 86/7752 [13:56<16:40:36,  7.83s/it, Written=59, Skipped=21]
# Augmenting train:   1%|          | 87/7752 [13:56<15:39:46,  7.36s/it, Written=59, Skipped=21]
# Augmenting train:   1%|          | 87/7752 [14:04<15:39:46,  7.36s/it, Written=60, Skipped=21]
# Augmenting train:   1%|          | 88/7752 [14:04<16:12:58,  7.62s/it, Written=60, Skipped=21]
# Augmenting train:   1%|          | 88/7752 [14:10<16:12:58,  7.62s/it, Written=61, Skipped=21]
# Augmenting train:   1%|          | 89/7752 [14:10<15:13:08,  7.15s/it, Written=61, Skipped=21]
# Augmenting train:   1%|          | 89/7752 [14:18<15:13:08,  7.15s/it, Written=62, Skipped=21]
# Augmenting train:   1%|          | 91/7752 [14:18<12:00:53,  5.65s/it, Written=62, Skipped=21]
# Augmenting train:   1%|          | 91/7752 [14:34<12:00:53,  5.65s/it, Written=62, Skipped=22]
# Augmenting train:   1%|          | 92/7752 [14:34<17:21:59,  8.16s/it, Written=62, Skipped=22]
# Augmenting train:   1%|          | 92/7752 [14:41<17:21:59,  8.16s/it, Written=63, Skipped=22]
# Augmenting train:   1%|          | 93/7752 [14:41<16:34:33,  7.79s/it, Written=63, Skipped=22]
# Augmenting train:   1%|          | 93/7752 [14:46<16:34:33,  7.79s/it, Written=64, Skipped=22]
# Augmenting train:   1%|          | 94/7752 [14:46<14:59:14,  7.05s/it, Written=64, Skipped=22]
# Augmenting train:   1%|          | 94/7752 [14:57<14:59:14,  7.05s/it, Written=65, Skipped=22]
# Augmenting train:   1%|          | 96/7752 [14:57<13:42:54,  6.45s/it, Written=65, Skipped=22]
# Augmenting train:   1%|          | 96/7752 [15:19<13:42:54,  6.45s/it, Written=65, Skipped=23]
# Augmenting train:   1%|▏         | 97/7752 [15:19<21:43:53, 10.22s/it, Written=65, Skipped=23]
# Augmenting train:   1%|▏         | 97/7752 [15:26<21:43:53, 10.22s/it, Written=66, Skipped=23]
# Augmenting train:   1%|▏         | 98/7752 [15:26<19:49:47,  9.33s/it, Written=66, Skipped=23]
# Augmenting train:   1%|▏         | 98/7752 [15:34<19:49:47,  9.33s/it, Written=67, Skipped=23]
# Augmenting train:   1%|▏         | 99/7752 [15:34<19:01:17,  8.95s/it, Written=67, Skipped=23]
# Augmenting train:   1%|▏         | 99/7752 [15:52<19:01:17,  8.95s/it, Written=67, Skipped=24]
# Augmenting train:   1%|▏         | 100/7752 [15:52<24:27:49, 11.51s/it, Written=67, Skipped=24]
# Augmenting train:   1%|▏         | 100/7752 [15:59<24:27:49, 11.51s/it, Written=68, Skipped=24]
# Augmenting train:   1%|▏         | 101/7752 [15:59<21:42:13, 10.21s/it, Written=68, Skipped=24]
# Augmenting train:   1%|▏         | 101/7752 [16:10<21:42:13, 10.21s/it, Written=69, Skipped=24]
# Augmenting train:   1%|▏         | 102/7752 [16:10<22:18:45, 10.50s/it, Written=69, Skipped=24]
# Augmenting train:   1%|▏         | 102/7752 [16:18<22:18:45, 10.50s/it, Written=70, Skipped=24]
# Augmenting train:   1%|▏         | 103/7752 [16:18<20:22:08,  9.59s/it, Written=70, Skipped=24]
# Augmenting train:   1%|▏         | 103/7752 [16:25<20:22:08,  9.59s/it, Written=71, Skipped=24]
# Augmenting train:   1%|▏         | 104/7752 [16:25<19:03:02,  8.97s/it, Written=71, Skipped=24]
# Augmenting train:   1%|▏         | 104/7752 [16:42<19:03:02,  8.97s/it, Written=71, Skipped=25]
# Augmenting train:   1%|▏         | 105/7752 [16:42<23:57:18, 11.28s/it, Written=71, Skipped=25]
# Augmenting train:   1%|▏         | 105/7752 [16:57<23:57:18, 11.28s/it, Written=71, Skipped=26]
# Augmenting train:   1%|▏         | 106/7752 [16:57<26:41:01, 12.56s/it, Written=71, Skipped=26]
# Augmenting train:   1%|▏         | 106/7752 [17:13<26:41:01, 12.56s/it, Written=71, Skipped=27]
# Augmenting train:   1%|▏         | 108/7752 [17:13<21:45:50, 10.25s/it, Written=71, Skipped=27]
# Augmenting train:   1%|▏         | 108/7752 [17:19<21:45:50, 10.25s/it, Written=72, Skipped=27]
# Augmenting train:   1%|▏         | 109/7752 [17:19<20:01:25,  9.43s/it, Written=72, Skipped=27]
# Augmenting train:   1%|▏         | 109/7752 [17:26<20:01:25,  9.43s/it, Written=73, Skipped=27]
# Augmenting train:   1%|▏         | 110/7752 [17:26<18:21:10,  8.65s/it, Written=73, Skipped=27]
# Augmenting train:   1%|▏         | 110/7752 [17:32<18:21:10,  8.65s/it, Written=74, Skipped=27]
# Augmenting train:   1%|▏         | 111/7752 [17:32<16:50:40,  7.94s/it, Written=74, Skipped=27]
# Augmenting train:   1%|▏         | 111/7752 [17:39<16:50:40,  7.94s/it, Written=75, Skipped=27]
# Augmenting train:   1%|▏         | 112/7752 [17:39<16:04:59,  7.58s/it, Written=75, Skipped=27]
# Augmenting train:   1%|▏         | 112/7752 [17:45<16:04:59,  7.58s/it, Written=76, Skipped=27]
# Augmenting train:   1%|▏         | 113/7752 [17:45<15:33:51,  7.33s/it, Written=76, Skipped=27]
# Augmenting train:   1%|▏         | 113/7752 [17:54<15:33:51,  7.33s/it, Written=77, Skipped=27]
# Augmenting train:   1%|▏         | 114/7752 [17:54<16:18:03,  7.68s/it, Written=77, Skipped=27]
# Augmenting train:   1%|▏         | 114/7752 [18:09<16:18:03,  7.68s/it, Written=77, Skipped=28]
# Augmenting train:   1%|▏         | 115/7752 [18:09<21:01:42,  9.91s/it, Written=77, Skipped=28]
# Augmenting train:   1%|▏         | 115/7752 [18:14<21:01:42,  9.91s/it, Written=78, Skipped=28]
# Augmenting train:   1%|▏         | 116/7752 [18:14<17:58:42,  8.48s/it, Written=78, Skipped=28]
# Augmenting train:   1%|▏         | 116/7752 [18:21<17:58:42,  8.48s/it, Written=79, Skipped=28]
# Augmenting train:   2%|▏         | 117/7752 [18:21<17:15:58,  8.14s/it, Written=79, Skipped=28]
# Augmenting train:   2%|▏         | 117/7752 [18:28<17:15:58,  8.14s/it, Written=80, Skipped=28]
# Augmenting train:   2%|▏         | 118/7752 [18:28<16:16:37,  7.68s/it, Written=80, Skipped=28]
# Augmenting train:   2%|▏         | 118/7752 [18:45<16:16:37,  7.68s/it, Written=80, Skipped=29]
# Augmenting train:   2%|▏         | 119/7752 [18:45<22:18:17, 10.52s/it, Written=80, Skipped=29]
# Augmenting train:   2%|▏         | 119/7752 [18:52<22:18:17, 10.52s/it, Written=81, Skipped=29]
# Augmenting train:   2%|▏         | 120/7752 [18:52<19:49:29,  9.35s/it, Written=81, Skipped=29]
# Augmenting train:   2%|▏         | 120/7752 [19:09<19:49:29,  9.35s/it, Written=81, Skipped=30]
# Augmenting train:   2%|▏         | 121/7752 [19:09<24:56:35, 11.77s/it, Written=81, Skipped=30]
# Augmenting train:   2%|▏         | 121/7752 [19:17<24:56:35, 11.77s/it, Written=82, Skipped=30]
# Augmenting train:   2%|▏         | 122/7752 [19:17<22:18:32, 10.53s/it, Written=82, Skipped=30]
# Augmenting train:   2%|▏         | 122/7752 [19:35<22:18:32, 10.53s/it, Written=82, Skipped=31]
# Augmenting train:   2%|▏         | 123/7752 [19:35<27:02:46, 12.76s/it, Written=82, Skipped=31]
# Augmenting train:   2%|▏         | 123/7752 [20:00<27:02:46, 12.76s/it, Written=82, Skipped=32]
# Augmenting train:   2%|▏         | 124/7752 [20:00<34:35:37, 16.33s/it, Written=82, Skipped=32]
# Augmenting train:   2%|▏         | 124/7752 [20:06<34:35:37, 16.33s/it, Written=83, Skipped=32]
# Augmenting train:   2%|▏         | 125/7752 [20:06<28:30:42, 13.46s/it, Written=83, Skipped=32]
# Augmenting train:   2%|▏         | 125/7752 [20:23<28:30:42, 13.46s/it, Written=83, Skipped=33]
# Augmenting train:   2%|▏         | 126/7752 [20:23<30:47:52, 14.54s/it, Written=83, Skipped=33]
# Augmenting train:   2%|▏         | 126/7752 [20:29<30:47:52, 14.54s/it, Written=84, Skipped=33]
# Augmenting train:   2%|▏         | 127/7752 [20:29<25:22:16, 11.98s/it, Written=84, Skipped=33]
# Augmenting train:   2%|▏         | 127/7752 [20:43<25:22:16, 11.98s/it, Written=84, Skipped=34]
# Augmenting train:   2%|▏         | 128/7752 [20:43<26:05:44, 12.32s/it, Written=84, Skipped=34]
# Augmenting train:   2%|▏         | 128/7752 [20:49<26:05:44, 12.32s/it, Written=85, Skipped=34]
# Augmenting train:   2%|▏         | 129/7752 [20:49<22:09:57, 10.47s/it, Written=85, Skipped=34]
# Augmenting train:   2%|▏         | 129/7752 [21:08<22:09:57, 10.47s/it, Written=85, Skipped=35]
# Augmenting train:   2%|▏         | 130/7752 [21:08<28:05:33, 13.27s/it, Written=85, Skipped=35]
# Augmenting train:   2%|▏         | 130/7752 [21:14<28:05:33, 13.27s/it, Written=86, Skipped=35]
# Augmenting train:   2%|▏         | 131/7752 [21:14<23:12:13, 10.96s/it, Written=86, Skipped=35]
# Augmenting train:   2%|▏         | 131/7752 [21:21<23:12:13, 10.96s/it, Written=87, Skipped=35]
# Augmenting train:   2%|▏         | 132/7752 [21:21<20:28:28,  9.67s/it, Written=87, Skipped=35]
# Augmenting train:   2%|▏         | 132/7752 [21:28<20:28:28,  9.67s/it, Written=88, Skipped=35]
# Augmenting train:   2%|▏         | 133/7752 [21:28<18:47:25,  8.88s/it, Written=88, Skipped=35]
# Augmenting train:   2%|▏         | 133/7752 [21:34<18:47:25,  8.88s/it, Written=89, Skipped=35]
# Augmenting train:   2%|▏         | 134/7752 [21:34<17:17:09,  8.17s/it, Written=89, Skipped=35]
# Augmenting train:   2%|▏         | 134/7752 [21:42<17:17:09,  8.17s/it, Written=90, Skipped=35]
# Augmenting train:   2%|▏         | 135/7752 [21:42<16:57:07,  8.01s/it, Written=90, Skipped=35]
# Augmenting train:   2%|▏         | 135/7752 [22:03<16:57:07,  8.01s/it, Written=91, Skipped=35]
# Augmenting train:   2%|▏         | 136/7752 [22:03<25:04:59, 11.86s/it, Written=91, Skipped=35]
# Augmenting train:   2%|▏         | 136/7752 [22:19<25:04:59, 11.86s/it, Written=91, Skipped=36]
# Augmenting train:   2%|▏         | 138/7752 [22:19<21:12:45, 10.03s/it, Written=91, Skipped=36]
# Augmenting train:   2%|▏         | 138/7752 [22:34<21:12:45, 10.03s/it, Written=91, Skipped=37]
# Augmenting train:   2%|▏         | 139/7752 [22:34<24:17:46, 11.49s/it, Written=91, Skipped=37]
# Augmenting train:   2%|▏         | 139/7752 [22:54<24:17:46, 11.49s/it, Written=91, Skipped=38]
# Augmenting train:   2%|▏         | 140/7752 [22:54<28:34:33, 13.51s/it, Written=91, Skipped=38]
# Augmenting train:   2%|▏         | 140/7752 [23:00<28:34:33, 13.51s/it, Written=92, Skipped=38]
# Augmenting train:   2%|▏         | 141/7752 [23:00<24:24:20, 11.54s/it, Written=92, Skipped=38]
# Augmenting train:   2%|▏         | 141/7752 [23:07<24:24:20, 11.54s/it, Written=93, Skipped=38]
# Augmenting train:   2%|▏         | 142/7752 [23:07<21:49:35, 10.33s/it, Written=93, Skipped=38]
# Augmenting train:   2%|▏         | 142/7752 [23:13<21:49:35, 10.33s/it, Written=94, Skipped=38]
# Augmenting train:   2%|▏         | 143/7752 [23:13<19:02:11,  9.01s/it, Written=94, Skipped=38]
# Augmenting train:   2%|▏         | 143/7752 [23:19<19:02:11,  9.01s/it, Written=95, Skipped=38]
# Augmenting train:   2%|▏         | 144/7752 [23:19<17:17:07,  8.18s/it, Written=95, Skipped=38]
# Augmenting train:   2%|▏         | 144/7752 [23:35<17:17:07,  8.18s/it, Written=95, Skipped=39]
# Augmenting train:   2%|▏         | 145/7752 [23:35<22:12:25, 10.51s/it, Written=95, Skipped=39]
# Augmenting train:   2%|▏         | 145/7752 [23:58<22:12:25, 10.51s/it, Written=95, Skipped=40]
# Augmenting train:   2%|▏         | 145/7752 [24:19<22:12:25, 10.51s/it, Written=96, Skipped=40]
# Augmenting train:   2%|▏         | 145/7752 [24:31<22:12:25, 10.51s/it, Written=97, Skipped=40]
# Augmenting train:   2%|▏         | 146/7752 [24:31<50:12:20, 23.76s/it, Written=97, Skipped=40]
# Augmenting train:   2%|▏         | 146/7752 [24:48<50:12:20, 23.76s/it, Written=97, Skipped=41]
# Augmenting train:   2%|▏         | 147/7752 [24:48<46:31:32, 22.02s/it, Written=97, Skipped=41]
# Augmenting train:   2%|▏         | 147/7752 [24:58<46:31:32, 22.02s/it, Written=98, Skipped=41]
# Augmenting train:   2%|▏         | 148/7752 [24:58<38:51:23, 18.40s/it, Written=98, Skipped=41]
# Augmenting train:   2%|▏         | 148/7752 [25:13<38:51:23, 18.40s/it, Written=98, Skipped=42]
# Augmenting train:   2%|▏         | 149/7752 [25:13<36:46:06, 17.41s/it, Written=98, Skipped=42]
# Augmenting train:   2%|▏         | 149/7752 [25:20<36:46:06, 17.41s/it, Written=99, Skipped=42]
# Augmenting train:   2%|▏         | 150/7752 [25:20<29:50:40, 14.13s/it, Written=99, Skipped=42]
# Augmenting train:   2%|▏         | 150/7752 [25:41<29:50:40, 14.13s/it, Written=99, Skipped=43]
# Augmenting train:   2%|▏         | 151/7752 [25:41<34:24:30, 16.30s/it, Written=99, Skipped=43]
# Augmenting train:   2%|▏         | 151/7752 [25:49<34:24:30, 16.30s/it, Written=100, Skipped=43]
# Augmenting train:   2%|▏         | 152/7752 [25:49<29:06:17, 13.79s/it, Written=100, Skipped=43]
# Augmenting train:   2%|▏         | 152/7752 [26:03<29:06:17, 13.79s/it, Written=101, Skipped=43]
# Augmenting train:   2%|▏         | 152/7752 [26:10<29:06:17, 13.79s/it, Written=102, Skipped=43]
# Augmenting train:   2%|▏         | 152/7752 [26:27<29:06:17, 13.79s/it, Written=102, Skipped=44]
# Augmenting train:   2%|▏         | 153/7752 [26:27<44:19:38, 21.00s/it, Written=102, Skipped=44]
# Augmenting train:   2%|▏         | 153/7752 [26:36<44:19:38, 21.00s/it, Written=103, Skipped=44]
# Augmenting train:   2%|▏         | 154/7752 [26:36<36:49:56, 17.45s/it, Written=103, Skipped=44]
# Augmenting train:   2%|▏         | 154/7752 [26:51<36:49:56, 17.45s/it, Written=103, Skipped=45]
# Augmenting train:   2%|▏         | 155/7752 [26:51<35:02:02, 16.60s/it, Written=103, Skipped=45]
# Augmenting train:   2%|▏         | 155/7752 [27:06<35:02:02, 16.60s/it, Written=103, Skipped=46]
# Augmenting train:   2%|▏         | 156/7752 [27:06<34:22:43, 16.29s/it, Written=103, Skipped=46]
# Augmenting train:   2%|▏         | 156/7752 [27:24<34:22:43, 16.29s/it, Written=103, Skipped=47]
# Augmenting train:   2%|▏         | 157/7752 [27:24<35:25:38, 16.79s/it, Written=103, Skipped=47]
# Augmenting train:   2%|▏         | 157/7752 [27:30<35:25:38, 16.79s/it, Written=104, Skipped=47]
# Augmenting train:   2%|▏         | 158/7752 [27:30<28:39:52, 13.59s/it, Written=104, Skipped=47]
# Augmenting train:   2%|▏         | 158/7752 [27:36<28:39:52, 13.59s/it, Written=105, Skipped=47]
# Augmenting train:   2%|▏         | 159/7752 [27:36<23:52:58, 11.32s/it, Written=105, Skipped=47]
# Augmenting train:   2%|▏         | 159/7752 [27:43<23:52:58, 11.32s/it, Written=106, Skipped=47]
# Augmenting train:   2%|▏         | 160/7752 [27:43<20:54:03,  9.91s/it, Written=106, Skipped=47]
# Augmenting train:   2%|▏         | 160/7752 [27:58<20:54:03,  9.91s/it, Written=106, Skipped=48]
# Augmenting train:   2%|▏         | 161/7752 [27:58<23:47:27, 11.28s/it, Written=106, Skipped=48]
# Augmenting train:   2%|▏         | 161/7752 [28:06<23:47:27, 11.28s/it, Written=107, Skipped=48]
# Augmenting train:   2%|▏         | 162/7752 [28:06<22:03:02, 10.46s/it, Written=107, Skipped=48]
# Augmenting train:   2%|▏         | 162/7752 [28:21<22:03:02, 10.46s/it, Written=107, Skipped=49]
# Augmenting train:   2%|▏         | 163/7752 [28:21<24:44:05, 11.73s/it, Written=107, Skipped=49]
# Augmenting train:   2%|▏         | 163/7752 [28:30<24:44:05, 11.73s/it, Written=108, Skipped=49]
# Augmenting train:   2%|▏         | 164/7752 [28:30<23:21:17, 11.08s/it, Written=108, Skipped=49]
# Augmenting train:   2%|▏         | 164/7752 [28:45<23:21:17, 11.08s/it, Written=108, Skipped=50]
# Augmenting train:   2%|▏         | 165/7752 [28:45<25:52:45, 12.28s/it, Written=108, Skipped=50]
# Augmenting train:   2%|▏         | 165/7752 [28:51<25:52:45, 12.28s/it, Written=109, Skipped=50]
# Augmenting train:   2%|▏         | 166/7752 [28:51<21:47:10, 10.34s/it, Written=109, Skipped=50]
# Augmenting train:   2%|▏         | 166/7752 [29:09<21:47:10, 10.34s/it, Written=109, Skipped=51]
# Augmenting train:   2%|▏         | 167/7752 [29:09<26:14:53, 12.46s/it, Written=109, Skipped=51]
# Augmenting train:   2%|▏         | 167/7752 [29:15<26:14:53, 12.46s/it, Written=110, Skipped=51]
# Augmenting train:   2%|▏         | 168/7752 [29:15<22:24:03, 10.63s/it, Written=110, Skipped=51]
# Augmenting train:   2%|▏         | 168/7752 [29:31<22:24:03, 10.63s/it, Written=110, Skipped=52]
# Augmenting train:   2%|▏         | 170/7752 [29:31<19:51:13,  9.43s/it, Written=110, Skipped=52]
# Augmenting train:   2%|▏         | 170/7752 [29:38<19:51:13,  9.43s/it, Written=111, Skipped=52]
# Augmenting train:   2%|▏         | 171/7752 [29:38<18:36:41,  8.84s/it, Written=111, Skipped=52]
# Augmenting train:   2%|▏         | 171/7752 [29:48<18:36:41,  8.84s/it, Written=112, Skipped=52]
# Augmenting train:   2%|▏         | 172/7752 [29:48<18:59:39,  9.02s/it, Written=112, Skipped=52]
# Augmenting train:   2%|▏         | 172/7752 [30:03<18:59:39,  9.02s/it, Written=113, Skipped=52]
# Augmenting train:   2%|▏         | 173/7752 [30:03<22:21:05, 10.62s/it, Written=113, Skipped=52]
# Augmenting train:   2%|▏         | 173/7752 [30:09<22:21:05, 10.62s/it, Written=114, Skipped=52]
# Augmenting train:   2%|▏         | 174/7752 [30:09<19:40:24,  9.35s/it, Written=114, Skipped=52]
# Augmenting train:   2%|▏         | 174/7752 [30:30<19:40:24,  9.35s/it, Written=114, Skipped=53]
# Augmenting train:   2%|▏         | 175/7752 [30:30<26:50:33, 12.75s/it, Written=114, Skipped=53]
# Augmenting train:   2%|▏         | 175/7752 [30:36<26:50:33, 12.75s/it, Written=115, Skipped=53]
# Augmenting train:   2%|▏         | 176/7752 [30:36<22:36:43, 10.74s/it, Written=115, Skipped=53]
# Augmenting train:   2%|▏         | 176/7752 [30:41<22:36:43, 10.74s/it, Written=116, Skipped=53]
# Augmenting train:   2%|▏         | 177/7752 [30:41<19:31:53,  9.28s/it, Written=116, Skipped=53]
# Augmenting train:   2%|▏         | 177/7752 [30:50<19:31:53,  9.28s/it, Written=117, Skipped=53]
# Augmenting train:   2%|▏         | 179/7752 [30:50<14:53:33,  7.08s/it, Written=117, Skipped=53]
# Augmenting train:   2%|▏         | 179/7752 [31:11<14:53:33,  7.08s/it, Written=117, Skipped=54]
# Augmenting train:   2%|▏         | 180/7752 [31:11<21:39:33, 10.30s/it, Written=117, Skipped=54]
# Augmenting train:   2%|▏         | 180/7752 [31:18<21:39:33, 10.30s/it, Written=118, Skipped=54]
# Augmenting train:   2%|▏         | 181/7752 [31:18<20:02:20,  9.53s/it, Written=118, Skipped=54]
# Augmenting train:   2%|▏         | 181/7752 [31:33<20:02:20,  9.53s/it, Written=118, Skipped=55]
# Augmenting train:   2%|▏         | 182/7752 [31:33<23:19:11, 11.09s/it, Written=118, Skipped=55]
# Augmenting train:   2%|▏         | 182/7752 [31:50<23:19:11, 11.09s/it, Written=118, Skipped=56]
# Augmenting train:   2%|▏         | 183/7752 [31:50<26:23:33, 12.55s/it, Written=118, Skipped=56]
# Augmenting train:   2%|▏         | 183/7752 [32:07<26:23:33, 12.55s/it, Written=118, Skipped=57]
# Augmenting train:   2%|▏         | 184/7752 [32:07<29:30:35, 14.04s/it, Written=118, Skipped=57]
# Augmenting train:   2%|▏         | 184/7752 [32:24<29:30:35, 14.04s/it, Written=119, Skipped=57]
# Augmenting train:   2%|▏         | 185/7752 [32:24<31:17:44, 14.89s/it, Written=119, Skipped=57]
# Augmenting train:   2%|▏         | 185/7752 [32:30<31:17:44, 14.89s/it, Written=120, Skipped=57]
# Augmenting train:   2%|▏         | 186/7752 [32:30<25:39:46, 12.21s/it, Written=120, Skipped=57]
# Augmenting train:   2%|▏         | 186/7752 [32:45<25:39:46, 12.21s/it, Written=120, Skipped=58]
# Augmenting train:   2%|▏         | 187/7752 [32:45<27:18:35, 13.00s/it, Written=120, Skipped=58]
# Augmenting train:   2%|▏         | 187/7752 [32:59<27:18:35, 13.00s/it, Written=120, Skipped=59]
# Augmenting train:   2%|▏         | 188/7752 [32:59<27:57:33, 13.31s/it, Written=120, Skipped=59]
# Augmenting train:   2%|▏         | 188/7752 [33:06<27:57:33, 13.31s/it, Written=121, Skipped=59]
# Augmenting train:   2%|▏         | 189/7752 [33:06<24:18:02, 11.57s/it, Written=121, Skipped=59]
# Augmenting train:   2%|▏         | 189/7752 [33:19<24:18:02, 11.57s/it, Written=122, Skipped=59]
# Augmenting train:   2%|▏         | 189/7752 [33:27<24:18:02, 11.57s/it, Written=123, Skipped=59]
# Augmenting train:   2%|▏         | 190/7752 [33:27<29:50:03, 14.20s/it, Written=123, Skipped=59]
# Augmenting train:   2%|▏         | 190/7752 [33:32<29:50:03, 14.20s/it, Written=124, Skipped=59]
# Augmenting train:   2%|▏         | 191/7752 [33:32<24:03:17, 11.45s/it, Written=124, Skipped=59]
# Augmenting train:   2%|▏         | 191/7752 [33:37<24:03:17, 11.45s/it, Written=125, Skipped=59]
# Augmenting train:   2%|▏         | 192/7752 [33:37<20:14:24,  9.64s/it, Written=125, Skipped=59]
# Augmenting train:   2%|▏         | 192/7752 [33:43<20:14:24,  9.64s/it, Written=126, Skipped=59]
# Augmenting train:   3%|▎         | 194/7752 [33:43<13:42:35,  6.53s/it, Written=126, Skipped=59]
# Augmenting train:   3%|▎         | 194/7752 [33:57<13:42:35,  6.53s/it, Written=126, Skipped=60]
# Augmenting train:   3%|▎         | 195/7752 [33:57<17:30:30,  8.34s/it, Written=126, Skipped=60]
# Augmenting train:   3%|▎         | 195/7752 [34:05<17:30:30,  8.34s/it, Written=127, Skipped=60]
# Augmenting train:   3%|▎         | 196/7752 [34:05<17:16:29,  8.23s/it, Written=127, Skipped=60]
# Augmenting train:   3%|▎         | 196/7752 [34:14<17:16:29,  8.23s/it, Written=128, Skipped=60]
# Augmenting train:   3%|▎         | 197/7752 [34:14<17:55:18,  8.54s/it, Written=128, Skipped=60]
# Augmenting train:   3%|▎         | 197/7752 [34:20<17:55:18,  8.54s/it, Written=129, Skipped=60]
# Augmenting train:   3%|▎         | 198/7752 [34:20<16:29:42,  7.86s/it, Written=129, Skipped=60]
# Augmenting train:   3%|▎         | 198/7752 [34:36<16:29:42,  7.86s/it, Written=129, Skipped=61]
# Augmenting train:   3%|▎         | 199/7752 [34:36<21:26:12, 10.22s/it, Written=129, Skipped=61]
# Augmenting train:   3%|▎         | 199/7752 [34:52<21:26:12, 10.22s/it, Written=129, Skipped=62]
# Augmenting train:   3%|▎         | 200/7752 [34:52<24:38:31, 11.75s/it, Written=129, Skipped=62]
# Augmenting train:   3%|▎         | 200/7752 [34:58<24:38:31, 11.75s/it, Written=130, Skipped=62]
# Augmenting train:   3%|▎         | 201/7752 [34:58<21:25:26, 10.21s/it, Written=130, Skipped=62]
# Augmenting train:   3%|▎         | 201/7752 [35:04<21:25:26, 10.21s/it, Written=131, Skipped=62]
# Augmenting train:   3%|▎         | 202/7752 [35:04<18:40:00,  8.90s/it, Written=131, Skipped=62]
# Augmenting train:   3%|▎         | 202/7752 [35:28<18:40:00,  8.90s/it, Written=131, Skipped=63]
# Augmenting train:   3%|▎         | 203/7752 [35:28<27:52:45, 13.30s/it, Written=131, Skipped=63]
# Augmenting train:   3%|▎         | 203/7752 [35:35<27:52:45, 13.30s/it, Written=132, Skipped=63]
# Augmenting train:   3%|▎         | 204/7752 [35:35<24:10:33, 11.53s/it, Written=132, Skipped=63]
# Augmenting train:   3%|▎         | 204/7752 [35:41<24:10:33, 11.53s/it, Written=133, Skipped=63]
# Augmenting train:   3%|▎         | 205/7752 [35:41<20:52:05,  9.95s/it, Written=133, Skipped=63]
# Augmenting train:   3%|▎         | 205/7752 [35:54<20:52:05,  9.95s/it, Written=133, Skipped=64]
# Augmenting train:   3%|▎         | 206/7752 [35:54<22:46:29, 10.87s/it, Written=133, Skipped=64]
# Augmenting train:   3%|▎         | 206/7752 [36:00<22:46:29, 10.87s/it, Written=134, Skipped=64]
# Augmenting train:   3%|▎         | 207/7752 [36:00<19:25:38,  9.27s/it, Written=134, Skipped=64]
# Augmenting train:   3%|▎         | 207/7752 [36:07<19:25:38,  9.27s/it, Written=135, Skipped=64]
# Augmenting train:   3%|▎         | 208/7752 [36:07<18:15:08,  8.71s/it, Written=135, Skipped=64]
# Augmenting train:   3%|▎         | 208/7752 [36:14<18:15:08,  8.71s/it, Written=136, Skipped=64]
# Augmenting train:   3%|▎         | 209/7752 [36:14<17:03:04,  8.14s/it, Written=136, Skipped=64]
# Augmenting train:   3%|▎         | 209/7752 [36:29<17:03:04,  8.14s/it, Written=137, Skipped=64]
# Augmenting train:   3%|▎         | 210/7752 [36:29<21:14:47, 10.14s/it, Written=137, Skipped=64]
# Augmenting train:   3%|▎         | 210/7752 [36:36<21:14:47, 10.14s/it, Written=138, Skipped=64]
# Augmenting train:   3%|▎         | 211/7752 [36:36<19:24:36,  9.27s/it, Written=138, Skipped=64]
# Augmenting train:   3%|▎         | 211/7752 [36:55<19:24:36,  9.27s/it, Written=138, Skipped=65]
# Augmenting train:   3%|▎         | 212/7752 [36:55<25:20:31, 12.10s/it, Written=138, Skipped=65]
# Augmenting train:   3%|▎         | 212/7752 [37:01<25:20:31, 12.10s/it, Written=139, Skipped=65]
# Augmenting train:   3%|▎         | 213/7752 [37:01<21:29:49, 10.27s/it, Written=139, Skipped=65]
# Augmenting train:   3%|▎         | 213/7752 [37:18<21:29:49, 10.27s/it, Written=139, Skipped=66]
# Augmenting train:   3%|▎         | 214/7752 [37:18<25:51:18, 12.35s/it, Written=139, Skipped=66]
# Augmenting train:   3%|▎         | 214/7752 [37:26<25:51:18, 12.35s/it, Written=140, Skipped=66]
# Augmenting train:   3%|▎         | 215/7752 [37:26<23:02:06, 11.00s/it, Written=140, Skipped=66]
# Augmenting train:   3%|▎         | 215/7752 [37:41<23:02:06, 11.00s/it, Written=140, Skipped=67]
# Augmenting train:   3%|▎         | 216/7752 [37:41<25:52:33, 12.36s/it, Written=140, Skipped=67]
# Augmenting train:   3%|▎         | 216/7752 [37:49<25:52:33, 12.36s/it, Written=141, Skipped=67]
# Augmenting train:   3%|▎         | 217/7752 [37:49<22:32:33, 10.77s/it, Written=141, Skipped=67]
# Augmenting train:   3%|▎         | 217/7752 [38:04<22:32:33, 10.77s/it, Written=141, Skipped=68]
# Augmenting train:   3%|▎         | 218/7752 [38:04<25:47:48, 12.33s/it, Written=141, Skipped=68]
# Augmenting train:   3%|▎         | 218/7752 [38:11<25:47:48, 12.33s/it, Written=142, Skipped=68]
# Augmenting train:   3%|▎         | 221/7752 [38:11<13:39:00,  6.53s/it, Written=142, Skipped=68]
# Augmenting train:   3%|▎         | 221/7752 [38:34<13:39:00,  6.53s/it, Written=142, Skipped=69]
# Augmenting train:   3%|▎         | 222/7752 [38:34<21:06:18, 10.09s/it, Written=142, Skipped=69]
# Augmenting train:   3%|▎         | 222/7752 [38:52<21:06:18, 10.09s/it, Written=142, Skipped=70]
# Augmenting train:   3%|▎         | 223/7752 [38:52<24:55:49, 11.92s/it, Written=142, Skipped=70]
# Augmenting train:   3%|▎         | 223/7752 [39:08<24:55:49, 11.92s/it, Written=142, Skipped=71]
# Augmenting train:   3%|▎         | 224/7752 [39:08<27:16:50, 13.05s/it, Written=142, Skipped=71]
# Augmenting train:   3%|▎         | 224/7752 [39:17<27:16:50, 13.05s/it, Written=143, Skipped=71]
# Augmenting train:   3%|▎         | 224/7752 [39:24<27:16:50, 13.05s/it, Written=144, Skipped=71]
# Augmenting train:   3%|▎         | 225/7752 [39:24<28:31:32, 13.64s/it, Written=144, Skipped=71]
# Augmenting train:   3%|▎         | 225/7752 [39:39<28:31:32, 13.64s/it, Written=144, Skipped=72]
# Augmenting train:   3%|▎         | 226/7752 [39:39<29:33:26, 14.14s/it, Written=144, Skipped=72]
# Augmenting train:   3%|▎         | 226/7752 [39:45<29:33:26, 14.14s/it, Written=145, Skipped=72]
# Augmenting train:   3%|▎         | 227/7752 [39:45<24:52:05, 11.90s/it, Written=145, Skipped=72]
# Augmenting train:   3%|▎         | 227/7752 [39:52<24:52:05, 11.90s/it, Written=146, Skipped=72]
# Augmenting train:   3%|▎         | 228/7752 [39:52<21:45:30, 10.41s/it, Written=146, Skipped=72]
# Augmenting train:   3%|▎         | 228/7752 [40:09<21:45:30, 10.41s/it, Written=146, Skipped=73]
# Augmenting train:   3%|▎         | 229/7752 [40:09<25:46:49, 12.34s/it, Written=146, Skipped=73]
# Augmenting train:   3%|▎         | 229/7752 [40:15<25:46:49, 12.34s/it, Written=147, Skipped=73]
# Augmenting train:   3%|▎         | 230/7752 [40:15<22:06:16, 10.58s/it, Written=147, Skipped=73]
# Augmenting train:   3%|▎         | 230/7752 [40:24<22:06:16, 10.58s/it, Written=148, Skipped=73]
# Augmenting train:   3%|▎         | 231/7752 [40:24<20:45:35,  9.94s/it, Written=148, Skipped=73]
# Augmenting train:   3%|▎         | 231/7752 [40:40<20:45:35,  9.94s/it, Written=148, Skipped=74]
# Augmenting train:   3%|▎         | 232/7752 [40:40<24:31:36, 11.74s/it, Written=148, Skipped=74]
# Augmenting train:   3%|▎         | 232/7752 [40:46<24:31:36, 11.74s/it, Written=149, Skipped=74]
# Augmenting train:   3%|▎         | 233/7752 [40:46<21:06:28, 10.11s/it, Written=149, Skipped=74]
# Augmenting train:   3%|▎         | 233/7752 [40:55<21:06:28, 10.11s/it, Written=150, Skipped=74]
# Augmenting train:   3%|▎         | 234/7752 [40:55<20:12:35,  9.68s/it, Written=150, Skipped=74]
# Augmenting train:   3%|▎         | 234/7752 [41:16<20:12:35,  9.68s/it, Written=150, Skipped=75]
# Augmenting train:   3%|▎         | 235/7752 [41:16<27:21:16, 13.10s/it, Written=150, Skipped=75]
# Augmenting train:   3%|▎         | 235/7752 [41:31<27:21:16, 13.10s/it, Written=150, Skipped=76]
# Augmenting train:   3%|▎         | 236/7752 [41:31<28:36:12, 13.70s/it, Written=150, Skipped=76]
# Augmenting train:   3%|▎         | 236/7752 [41:38<28:36:12, 13.70s/it, Written=151, Skipped=76]
# Augmenting train:   3%|▎         | 237/7752 [41:38<24:38:27, 11.80s/it, Written=151, Skipped=76]
# Augmenting train:   3%|▎         | 237/7752 [41:49<24:38:27, 11.80s/it, Written=152, Skipped=76]
# Augmenting train:   3%|▎         | 238/7752 [41:49<23:40:47, 11.35s/it, Written=152, Skipped=76]
# Augmenting train:   3%|▎         | 238/7752 [42:09<23:40:47, 11.35s/it, Written=152, Skipped=77]
# Augmenting train:   3%|▎         | 239/7752 [42:09<29:31:54, 14.15s/it, Written=152, Skipped=77]
# Augmenting train:   3%|▎         | 239/7752 [42:17<29:31:54, 14.15s/it, Written=153, Skipped=77]
# Augmenting train:   3%|▎         | 240/7752 [42:17<25:12:55, 12.08s/it, Written=153, Skipped=77]
# Augmenting train:   3%|▎         | 240/7752 [42:24<25:12:55, 12.08s/it, Written=154, Skipped=77]
# Augmenting train:   3%|▎         | 242/7752 [42:24<17:20:27,  8.31s/it, Written=154, Skipped=77]
# Augmenting train:   3%|▎         | 242/7752 [42:39<17:20:27,  8.31s/it, Written=154, Skipped=78]
# Augmenting train:   3%|▎         | 243/7752 [42:39<20:37:31,  9.89s/it, Written=154, Skipped=78]
# Augmenting train:   3%|▎         | 243/7752 [42:53<20:37:31,  9.89s/it, Written=154, Skipped=79]
# Augmenting train:   3%|▎         | 244/7752 [42:53<22:45:55, 10.92s/it, Written=154, Skipped=79]
# Augmenting train:   3%|▎         | 244/7752 [43:11<22:45:55, 10.92s/it, Written=154, Skipped=80]
# Augmenting train:   3%|▎         | 245/7752 [43:11<26:43:22, 12.81s/it, Written=154, Skipped=80]
# Augmenting train:   3%|▎         | 245/7752 [43:18<26:43:22, 12.81s/it, Written=155, Skipped=80]
# Augmenting train:   3%|▎         | 246/7752 [43:18<23:23:48, 11.22s/it, Written=155, Skipped=80]
# Augmenting train:   3%|▎         | 246/7752 [43:34<23:23:48, 11.22s/it, Written=155, Skipped=81]
# Augmenting train:   3%|▎         | 247/7752 [43:34<26:12:20, 12.57s/it, Written=155, Skipped=81]
# Augmenting train:   3%|▎         | 247/7752 [43:43<26:12:20, 12.57s/it, Written=156, Skipped=81]
# Augmenting train:   3%|▎         | 248/7752 [43:43<23:51:17, 11.44s/it, Written=156, Skipped=81]
# Augmenting train:   3%|▎         | 248/7752 [43:58<23:51:17, 11.44s/it, Written=156, Skipped=82]
# Augmenting train:   3%|▎         | 250/7752 [43:58<20:19:19,  9.75s/it, Written=156, Skipped=82]
# Augmenting train:   3%|▎         | 250/7752 [44:03<20:19:19,  9.75s/it, Written=157, Skipped=82]
# Augmenting train:   3%|▎         | 251/7752 [44:03<18:10:59,  8.73s/it, Written=157, Skipped=82]
# Augmenting train:   3%|▎         | 251/7752 [44:18<18:10:59,  8.73s/it, Written=157, Skipped=83]
# Augmenting train:   3%|▎         | 252/7752 [44:18<21:18:45, 10.23s/it, Written=157, Skipped=83]
# Augmenting train:   3%|▎         | 252/7752 [44:37<21:18:45, 10.23s/it, Written=157, Skipped=84]
# Augmenting train:   3%|▎         | 253/7752 [44:37<26:19:21, 12.64s/it, Written=157, Skipped=84]
# Augmenting train:   3%|▎         | 253/7752 [44:54<26:19:21, 12.64s/it, Written=157, Skipped=85]
# Augmenting train:   3%|▎         | 254/7752 [44:54<28:51:58, 13.86s/it, Written=157, Skipped=85]
# Augmenting train:   3%|▎         | 254/7752 [45:07<28:51:58, 13.86s/it, Written=158, Skipped=85]
# Augmenting train:   3%|▎         | 255/7752 [45:07<28:05:21, 13.49s/it, Written=158, Skipped=85]
# Augmenting train:   3%|▎         | 255/7752 [45:13<28:05:21, 13.49s/it, Written=159, Skipped=85]
# Augmenting train:   3%|▎         | 256/7752 [45:13<23:47:42, 11.43s/it, Written=159, Skipped=85]
# Augmenting train:   3%|▎         | 256/7752 [45:32<23:47:42, 11.43s/it, Written=159, Skipped=86]
# Augmenting train:   3%|▎         | 257/7752 [45:32<28:35:39, 13.73s/it, Written=159, Skipped=86]
# Augmenting train:   3%|▎         | 257/7752 [45:40<28:35:39, 13.73s/it, Written=160, Skipped=86]
# Augmenting train:   3%|▎         | 258/7752 [45:40<24:32:10, 11.79s/it, Written=160, Skipped=86]
# Augmenting train:   3%|▎         | 258/7752 [45:56<24:32:10, 11.79s/it, Written=160, Skipped=87]
# Augmenting train:   3%|▎         | 259/7752 [45:56<27:25:18, 13.17s/it, Written=160, Skipped=87]
# Augmenting train:   3%|▎         | 259/7752 [46:12<27:25:18, 13.17s/it, Written=160, Skipped=88]
# Augmenting train:   3%|▎         | 261/7752 [46:12<22:25:16, 10.78s/it, Written=160, Skipped=88]
# Augmenting train:   3%|▎         | 261/7752 [46:29<22:25:16, 10.78s/it, Written=160, Skipped=89]
# Augmenting train:   3%|▎         | 262/7752 [46:29<25:35:35, 12.30s/it, Written=160, Skipped=89]
# ...
# Augmenting train:  33%|███▎      | 2581/7752 [7:38:58<13:46:56,  9.60s/it, Written=1601, Skipped=864]
# Augmenting train:  33%|███▎      | 2581/7752 [7:39:14<13:46:56,  9.60s/it, Written=1601, Skipped=865]
# Augmenting train:  33%|███▎      | 2582/7752 [7:39:14<16:32:48, 11.52s/it, Written=1601, Skipped=865]
# Augmenting train:  33%|███▎      | 2582/7752 [7:39:32<16:32:48, 11.52s/it, Written=1601, Skipped=866]
# Augmenting train:  33%|███▎      | 2583/7752 [7:39:32<19:08:10, 13.33s/it, Written=1601, Skipped=866]
# Augmenting train:  33%|███▎      | 2583/7752 [7:39:49<19:08:10, 13.33s/it, Written=1601, Skipped=867]
# Augmenting train:  33%|███▎      | 2584/7752 [7:39:49<20:57:46, 14.60s/it, Written=1601, Skipped=867]
# Augmenting train:  33%|███▎      | 2584/7752 [7:40:08<20:57:46, 14.60s/it, Written=1602, Skipped=867]
# Augmenting train:  33%|███▎      | 2585/7752 [7:40:08<22:39:53, 15.79s/it, Written=1602, Skipped=867]
# Augmenting train:  33%|███▎      | 2585/7752 [7:40:13<22:39:53, 15.79s/it, Written=1603, Skipped=867]
# Augmenting train:  33%|███▎      | 2586/7752 [7:40:13<17:56:21, 12.50s/it, Written=1603, Skipped=867]
# Augmenting train:  33%|███▎      | 2586/7752 [7:40:32<17:56:21, 12.50s/it, Written=1603, Skipped=868]
# Augmenting train:  33%|███▎      | 2587/7752 [7:40:32<20:39:52, 14.40s/it, Written=1603, Skipped=868]
# Augmenting train:  33%|███▎      | 2587/7752 [7:40:38<20:39:52, 14.40s/it, Written=1604, Skipped=868]
# Augmenting train:  33%|███▎      | 2588/7752 [7:40:38<17:07:33, 11.94s/it, Written=1604, Skipped=868]
# Augmenting train:  33%|███▎      | 2588/7752 [7:40:44<17:07:33, 11.94s/it, Written=1605, Skipped=868]
# Augmenting train:  33%|███▎      | 2589/7752 [7:40:44<14:49:25, 10.34s/it, Written=1605, Skipped=868]
# Augmenting train:  33%|███▎      | 2589/7752 [7:40:52<14:49:25, 10.34s/it, Written=1606, Skipped=868]
# Augmenting train:  33%|███▎      | 2590/7752 [7:40:52<13:41:17,  9.55s/it, Written=1606, Skipped=868]
# Augmenting train:  33%|███▎      | 2590/7752 [7:40:59<13:41:17,  9.55s/it, Written=1607, Skipped=868]
# Augmenting train:  33%|███▎      | 2591/7752 [7:40:59<12:22:07,  8.63s/it, Written=1607, Skipped=868]
# Augmenting train:  33%|███▎      | 2591/7752 [7:41:15<12:22:07,  8.63s/it, Written=1607, Skipped=869]
# Augmenting train:  33%|███▎      | 2592/7752 [7:41:15<15:41:09, 10.94s/it, Written=1607, Skipped=869]
# Augmenting train:  33%|███▎      | 2592/7752 [7:41:22<15:41:09, 10.94s/it, Written=1608, Skipped=869]
# Augmenting train:  33%|███▎      | 2593/7752 [7:41:22<14:01:07,  9.78s/it, Written=1608, Skipped=869]
# Augmenting train:  33%|███▎      | 2593/7752 [7:41:28<14:01:07,  9.78s/it, Written=1609, Skipped=869]
# Augmenting train:  33%|███▎      | 2594/7752 [7:41:28<12:13:00,  8.53s/it, Written=1609, Skipped=869]
# Augmenting train:  33%|███▎      | 2594/7752 [7:41:34<12:13:00,  8.53s/it, Written=1610, Skipped=869]
# Augmenting train:  33%|███▎      | 2595/7752 [7:41:34<11:16:02,  7.87s/it, Written=1610, Skipped=869]
# Augmenting train:  33%|███▎      | 2595/7752 [7:41:45<11:16:02,  7.87s/it, Written=1611, Skipped=869]
# Augmenting train:  33%|███▎      | 2596/7752 [7:41:45<12:25:38,  8.68s/it, Written=1611, Skipped=869]
# Augmenting train:  33%|███▎      | 2596/7752 [7:41:51<12:25:38,  8.68s/it, Written=1612, Skipped=869]
# Augmenting train:  34%|███▎      | 2597/7752 [7:41:51<11:31:37,  8.05s/it, Written=1612, Skipped=869]
# Augmenting train:  34%|███▎      | 2597/7752 [7:41:58<11:31:37,  8.05s/it, Written=1613, Skipped=869]
# Augmenting train:  34%|███▎      | 2598/7752 [7:41:58<11:10:36,  7.81s/it, Written=1613, Skipped=869]
# Augmenting train:  34%|███▎      | 2598/7752 [7:42:05<11:10:36,  7.81s/it, Written=1614, Skipped=869]
# Augmenting train:  34%|███▎      | 2599/7752 [7:42:05<10:38:32,  7.44s/it, Written=1614, Skipped=869]
# Augmenting train:  34%|███▎      | 2599/7752 [7:42:10<10:38:32,  7.44s/it, Written=1615, Skipped=869]
# Augmenting train:  34%|███▎      | 2600/7752 [7:42:10<9:44:46,  6.81s/it, Written=1615, Skipped=869]
# Augmenting train:  34%|███▎      | 2600/7752 [7:42:18<9:44:46,  6.81s/it, Written=1616, Skipped=869]
# Augmenting train:  34%|███▎      | 2601/7752 [7:42:18<10:06:37,  7.07s/it, Written=1616, Skipped=869]
# Augmenting train:  34%|███▎      | 2601/7752 [7:42:25<10:06:37,  7.07s/it, Written=1617, Skipped=869]
# Augmenting train:  34%|███▎      | 2602/7752 [7:42:25<10:01:58,  7.01s/it, Written=1617, Skipped=869]
# Augmenting train:  34%|███▎      | 2602/7752 [7:42:43<10:01:58,  7.01s/it, Written=1617, Skipped=870]
# Augmenting train:  34%|███▎      | 2603/7752 [7:42:43<14:56:34, 10.45s/it, Written=1617, Skipped=870]
# Augmenting train:  34%|███▎      | 2603/7752 [7:42:51<14:56:34, 10.45s/it, Written=1618, Skipped=870]
# Augmenting train:  34%|███▎      | 2604/7752 [7:42:51<13:34:27,  9.49s/it, Written=1618, Skipped=870]
# Augmenting train:  34%|███▎      | 2604/7752 [7:43:06<13:34:27,  9.49s/it, Written=1618, Skipped=871]
# Augmenting train:  34%|███▎      | 2605/7752 [7:43:06<16:00:20, 11.20s/it, Written=1618, Skipped=871]
# Augmenting train:  34%|███▎      | 2605/7752 [7:43:12<16:00:20, 11.20s/it, Written=1619, Skipped=871]
# Augmenting train:  34%|███▎      | 2606/7752 [7:43:12<13:55:26,  9.74s/it, Written=1619, Skipped=871]
# Augmenting train:  34%|███▎      | 2606/7752 [7:43:19<13:55:26,  9.74s/it, Written=1620, Skipped=871]
# Augmenting train:  34%|███▎      | 2607/7752 [7:43:19<12:44:06,  8.91s/it, Written=1620, Skipped=871]
# Augmenting train:  34%|███▎      | 2607/7752 [7:43:36<12:44:06,  8.91s/it, Written=1620, Skipped=872]
# Augmenting train:  34%|███▎      | 2608/7752 [7:43:36<16:07:55, 11.29s/it, Written=1620, Skipped=872]
# Augmenting train:  34%|███▎      | 2608/7752 [7:43:54<16:07:55, 11.29s/it, Written=1620, Skipped=873]
# Augmenting train:  34%|███▎      | 2609/7752 [7:43:54<19:14:50, 13.47s/it, Written=1620, Skipped=873]
# Augmenting train:  34%|███▎      | 2609/7752 [7:44:00<19:14:50, 13.47s/it, Written=1621, Skipped=873]
# Augmenting train:  34%|███▎      | 2610/7752 [7:44:00<15:57:36, 11.17s/it, Written=1621, Skipped=873]
# Augmenting train:  34%|███▎      | 2610/7752 [7:44:07<15:57:36, 11.17s/it, Written=1622, Skipped=873]
# Augmenting train:  34%|███▎      | 2611/7752 [7:44:07<14:05:15,  9.86s/it, Written=1622, Skipped=873]
# Augmenting train:  34%|███▎      | 2611/7752 [7:44:23<14:05:15,  9.86s/it, Written=1622, Skipped=874]
# Augmenting train:  34%|███▎      | 2612/7752 [7:44:23<16:30:11, 11.56s/it, Written=1622, Skipped=874]
# Augmenting train:  34%|███▎      | 2612/7752 [7:44:30<16:30:11, 11.56s/it, Written=1623, Skipped=874]
# Augmenting train:  34%|███▎      | 2613/7752 [7:44:30<14:37:47, 10.25s/it, Written=1623, Skipped=874]
# Augmenting train:  34%|███▎      | 2613/7752 [7:44:42<14:37:47, 10.25s/it, Written=1623, Skipped=875]
# Augmenting train:  34%|███▎      | 2614/7752 [7:44:42<15:27:49, 10.83s/it, Written=1623, Skipped=875]
# Augmenting train:  34%|███▎      | 2614/7752 [7:45:07<15:27:49, 10.83s/it, Written=1623, Skipped=876]
# Augmenting train:  34%|███▎      | 2615/7752 [7:45:07<21:39:52, 15.18s/it, Written=1623, Skipped=876]
# Augmenting train:  34%|███▎      | 2615/7752 [7:45:22<21:39:52, 15.18s/it, Written=1623, Skipped=877]
# Augmenting train:  34%|███▎      | 2616/7752 [7:45:22<21:34:47, 15.13s/it, Written=1623, Skipped=877]
# Augmenting train:  34%|███▎      | 2616/7752 [7:45:33<21:34:47, 15.13s/it, Written=1624, Skipped=877]
# Augmenting train:  34%|███▍      | 2617/7752 [7:45:33<19:49:45, 13.90s/it, Written=1624, Skipped=877]
# Augmenting train:  34%|███▍      | 2617/7752 [7:45:40<19:49:45, 13.90s/it, Written=1625, Skipped=877]
# Augmenting train:  34%|███▍      | 2618/7752 [7:45:40<16:36:48, 11.65s/it, Written=1625, Skipped=877]
# Augmenting train:  34%|███▍      | 2618/7752 [7:45:48<16:36:48, 11.65s/it, Written=1626, Skipped=877]
# Augmenting train:  34%|███▍      | 2619/7752 [7:45:48<15:15:59, 10.71s/it, Written=1626, Skipped=877]
# Augmenting train:  34%|███▍      | 2619/7752 [7:46:08<15:15:59, 10.71s/it, Written=1626, Skipped=878]
# Augmenting train:  34%|███▍      | 2620/7752 [7:46:08<18:57:03, 13.29s/it, Written=1626, Skipped=878]
# Augmenting train:  34%|███▍      | 2620/7752 [7:46:17<18:57:03, 13.29s/it, Written=1627, Skipped=878]
# Augmenting train:  34%|███▍      | 2621/7752 [7:46:17<17:29:10, 12.27s/it, Written=1627, Skipped=878]
# Augmenting train:  34%|███▍      | 2621/7752 [7:46:33<17:29:10, 12.27s/it, Written=1627, Skipped=879]
# Augmenting train:  34%|███▍      | 2622/7752 [7:46:33<18:45:26, 13.16s/it, Written=1627, Skipped=879]
# Augmenting train:  34%|███▍      | 2622/7752 [7:46:41<18:45:26, 13.16s/it, Written=1628, Skipped=879]
# Augmenting train:  34%|███▍      | 2623/7752 [7:46:41<16:51:12, 11.83s/it, Written=1628, Skipped=879]
# Augmenting train:  34%|███▍      | 2623/7752 [7:46:49<16:51:12, 11.83s/it, Written=1629, Skipped=879]
# Augmenting train:  34%|███▍      | 2624/7752 [7:46:49<15:06:42, 10.61s/it, Written=1629, Skipped=879]
# Augmenting train:  34%|███▍      | 2624/7752 [7:46:58<15:06:42, 10.61s/it, Written=1630, Skipped=879]
# Augmenting train:  34%|███▍      | 2625/7752 [7:46:58<14:10:58,  9.96s/it, Written=1630, Skipped=879]
# Augmenting train:  34%|███▍      | 2625/7752 [7:47:05<14:10:58,  9.96s/it, Written=1631, Skipped=879]
# Augmenting train:  34%|███▍      | 2626/7752 [7:47:05<12:54:22,  9.06s/it, Written=1631, Skipped=879]
# Augmenting train:  34%|███▍      | 2626/7752 [7:47:21<12:54:22,  9.06s/it, Written=1631, Skipped=880]
# Augmenting train:  34%|███▍      | 2627/7752 [7:47:21<16:05:00, 11.30s/it, Written=1631, Skipped=880]
# Augmenting train:  34%|███▍      | 2627/7752 [7:47:40<16:05:00, 11.30s/it, Written=1631, Skipped=881]
# Augmenting train:  34%|███▍      | 2628/7752 [7:47:40<19:26:55, 13.66s/it, Written=1631, Skipped=881]
# Augmenting train:  34%|███▍      | 2628/7752 [7:47:54<19:26:55, 13.66s/it, Written=1632, Skipped=881]
# Augmenting train:  34%|███▍      | 2629/7752 [7:47:54<19:20:30, 13.59s/it, Written=1632, Skipped=881]
# Augmenting train:  34%|███▍      | 2629/7752 [7:48:01<19:20:30, 13.59s/it, Written=1633, Skipped=881]
# Augmenting train:  34%|███▍      | 2630/7752 [7:48:01<16:41:13, 11.73s/it, Written=1633, Skipped=881]
# Augmenting train:  34%|███▍      | 2630/7752 [7:48:07<16:41:13, 11.73s/it, Written=1634, Skipped=881]
# Augmenting train:  34%|███▍      | 2631/7752 [7:48:07<14:22:29, 10.11s/it, Written=1634, Skipped=881]
# Augmenting train:  34%|███▍      | 2631/7752 [7:48:23<14:22:29, 10.11s/it, Written=1634, Skipped=882]
# Augmenting train:  34%|███▍      | 2632/7752 [7:48:23<16:53:39, 11.88s/it, Written=1634, Skipped=882]
# Augmenting train:  34%|███▍      | 2632/7752 [7:48:29<16:53:39, 11.88s/it, Written=1635, Skipped=882]
# Augmenting train:  34%|███▍      | 2633/7752 [7:48:29<14:21:06, 10.09s/it, Written=1635, Skipped=882]
# Augmenting train:  34%|███▍      | 2633/7752 [7:48:37<14:21:06, 10.09s/it, Written=1636, Skipped=882]
# Augmenting train:  34%|███▍      | 2634/7752 [7:48:37<13:06:12,  9.22s/it, Written=1636, Skipped=882]
# Augmenting train:  34%|███▍      | 2634/7752 [7:48:44<13:06:12,  9.22s/it, Written=1637, Skipped=882]
# Augmenting train:  34%|███▍      | 2635/7752 [7:48:44<12:22:43,  8.71s/it, Written=1637, Skipped=882]
# Augmenting train:  34%|███▍      | 2635/7752 [7:49:00<12:22:43,  8.71s/it, Written=1637, Skipped=883]
# Augmenting train:  34%|███▍      | 2636/7752 [7:49:00<15:17:40, 10.76s/it, Written=1637, Skipped=883]
# Augmenting train:  34%|███▍      | 2636/7752 [7:49:14<15:17:40, 10.76s/it, Written=1637, Skipped=884]
# Augmenting train:  34%|███▍      | 2637/7752 [7:49:14<16:46:57, 11.81s/it, Written=1637, Skipped=884]
# Augmenting train:  34%|███▍      | 2637/7752 [7:49:21<16:46:57, 11.81s/it, Written=1638, Skipped=884]
# Augmenting train:  34%|███▍      | 2638/7752 [7:49:21<14:36:31, 10.28s/it, Written=1638, Skipped=884]
# Augmenting train:  34%|███▍      | 2638/7752 [7:49:29<14:36:31, 10.28s/it, Written=1639, Skipped=884]
# Augmenting train:  34%|███▍      | 2639/7752 [7:49:29<13:53:13,  9.78s/it, Written=1639, Skipped=884]
# Augmenting train:  34%|███▍      | 2639/7752 [7:49:49<13:53:13,  9.78s/it, Written=1639, Skipped=885]
# Augmenting train:  34%|███▍      | 2640/7752 [7:49:49<18:03:47, 12.72s/it, Written=1639, Skipped=885]
# Augmenting train:  34%|███▍      | 2640/7752 [7:49:55<18:03:47, 12.72s/it, Written=1640, Skipped=885]
# Augmenting train:  34%|███▍      | 2641/7752 [7:49:55<15:26:10, 10.87s/it, Written=1640, Skipped=885]
# Augmenting train:  34%|███▍      | 2641/7752 [7:50:02<15:26:10, 10.87s/it, Written=1641, Skipped=885]
# Augmenting train:  34%|███▍      | 2642/7752 [7:50:02<13:29:27,  9.50s/it, Written=1641, Skipped=885]
# Augmenting train:  34%|███▍      | 2642/7752 [7:50:16<13:29:27,  9.50s/it, Written=1641, Skipped=886]
# Augmenting train:  34%|███▍      | 2643/7752 [7:50:16<15:41:24, 11.06s/it, Written=1641, Skipped=886]
# Augmenting train:  34%|███▍      | 2643/7752 [7:50:25<15:41:24, 11.06s/it, Written=1642, Skipped=886]
# Augmenting train:  34%|███▍      | 2644/7752 [7:50:25<14:39:09, 10.33s/it, Written=1642, Skipped=886]
# Augmenting train:  34%|███▍      | 2644/7752 [7:50:32<14:39:09, 10.33s/it, Written=1643, Skipped=886]
# Augmenting train:  34%|███▍      | 2645/7752 [7:50:32<13:05:09,  9.22s/it, Written=1643, Skipped=886]
# Augmenting train:  34%|███▍      | 2645/7752 [7:50:40<13:05:09,  9.22s/it, Written=1644, Skipped=886]
# Augmenting train:  34%|███▍      | 2646/7752 [7:50:40<12:43:51,  8.98s/it, Written=1644, Skipped=886]
# Augmenting train:  34%|███▍      | 2646/7752 [7:50:45<12:43:51,  8.98s/it, Written=1645, Skipped=886]
# Augmenting train:  34%|███▍      | 2647/7752 [7:50:45<11:09:12,  7.87s/it, Written=1645, Skipped=886]
# Augmenting train:  34%|███▍      | 2647/7752 [7:50:51<11:09:12,  7.87s/it, Written=1646, Skipped=886]
# Augmenting train:  34%|███▍      | 2648/7752 [7:50:51<10:10:42,  7.18s/it, Written=1646, Skipped=886]
# Augmenting train:  34%|███▍      | 2648/7752 [7:51:07<10:10:42,  7.18s/it, Written=1646, Skipped=887]
# Augmenting train:  34%|███▍      | 2649/7752 [7:51:07<13:53:31,  9.80s/it, Written=1646, Skipped=887]
# Augmenting train:  34%|███▍      | 2649/7752 [7:51:23<13:53:31,  9.80s/it, Written=1646, Skipped=888]
# Augmenting train:  34%|███▍      | 2650/7752 [7:51:23<16:49:27, 11.87s/it, Written=1646, Skipped=888]
# Augmenting train:  34%|███▍      | 2650/7752 [7:51:30<16:49:27, 11.87s/it, Written=1647, Skipped=888]
# Augmenting train:  34%|███▍      | 2651/7752 [7:51:30<14:31:43, 10.25s/it, Written=1647, Skipped=888]
# Augmenting train:  34%|███▍      | 2651/7752 [7:51:45<14:31:43, 10.25s/it, Written=1647, Skipped=889]
# Augmenting train:  34%|███▍      | 2652/7752 [7:51:45<16:35:05, 11.71s/it, Written=1647, Skipped=889]
# Augmenting train:  34%|███▍      | 2652/7752 [7:52:00<16:35:05, 11.71s/it, Written=1647, Skipped=890]
# Augmenting train:  34%|███▍      | 2653/7752 [7:52:00<18:00:34, 12.72s/it, Written=1647, Skipped=890]
# Augmenting train:  34%|███▍      | 2653/7752 [7:52:07<18:00:34, 12.72s/it, Written=1648, Skipped=890]
# Augmenting train:  34%|███▍      | 2654/7752 [7:52:07<15:33:41, 10.99s/it, Written=1648, Skipped=890]
# Augmenting train:  34%|███▍      | 2654/7752 [7:52:20<15:33:41, 10.99s/it, Written=1649, Skipped=890]
# Augmenting train:  34%|███▍      | 2655/7752 [7:52:20<16:21:47, 11.56s/it, Written=1649, Skipped=890]
# Augmenting train:  34%|███▍      | 2655/7752 [7:52:27<16:21:47, 11.56s/it, Written=1650, Skipped=890]
# Augmenting train:  34%|███▍      | 2656/7752 [7:52:27<14:21:34, 10.14s/it, Written=1650, Skipped=890]
# Augmenting train:  34%|███▍      | 2656/7752 [7:52:36<14:21:34, 10.14s/it, Written=1651, Skipped=890]
# Augmenting train:  34%|███▍      | 2657/7752 [7:52:36<13:58:35,  9.88s/it, Written=1651, Skipped=890]
# Augmenting train:  34%|███▍      | 2657/7752 [7:52:55<13:58:35,  9.88s/it, Written=1651, Skipped=891]
# Augmenting train:  34%|███▍      | 2658/7752 [7:52:55<15:06:20, 10.68s/it, Written=1651, Skipped=891]
# ⚠️ REACHED 7.9 HOURS. GRACEFULLY STOPPING.
# 📊 Stats this run -> Written: 1651 | Skipped: 891
# 💾 Files safely saved to: /kaggle/working/augmented
