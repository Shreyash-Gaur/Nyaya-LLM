# %%
# !pip install jsonschema transformers accelerate sentencepiece bitsandbytes tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.3 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
"""
==============================================================
Nyaya-LLM  —  Phase 2 Dataset Augmentation (Kaggle / P100)
==============================================================
Augments all three splits (train, val, test) using a
HuggingFace model loaded directly on the P100 GPU.

Long sections (>3000 chars) are chunked at subsection
boundaries so every part of the statute gets covered.
==============================================================
"""

import json
import re
import os
import time
import torch
import shutil
import gc
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from jsonschema import validate, ValidationError

# ==============================
# ⚙️  CONFIG
# ==============================
MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"

# ── Paths ───────────────────────────────────────────────────
INPUT_DIR  = "/kaggle/input/datasets/shreyashgaurgla/nyaya-llm-dataset"
OUTPUT_DIR = "/kaggle/working/augmented"
WIP_DATASET_PATH = "/kaggle/input/datasets/shreyashgaurgla/nyaya-augmented-wip" # For Run 2+

SPLITS = {
    "train": "all_acts_train.jsonl"
}

# ── Processing Limits ───────────────────────────────────────
CHUNK_SIZE  = 3000    
RETRY_LIMIT = 3       
MAX_RUNTIME_HOURS = 11.85

# ==============================
# 📦  JSON SCHEMA
# ==============================
AUGMENT_SCHEMA = {
    "type": "object",
    "properties": {
        "instruction": {"type": "string"},
        "input":       {"type": "string"},
        "output":      {"type": "string"}
    },
    "required": ["instruction", "input", "output"]
}

# ==============================
# 💬  PROMPT (CHAT TEMPLATE)
# ==============================
SYSTEM_PROMPT = """You are a strict Indian legal dataset generator.

RULES:
1. Only use the provided statute text. Do NOT add outside legal knowledge.
2. Do NOT invent punishments, sections, or acts not mentioned in the text.
3. Output STRICT JSON only. No markdown, no explanation, no preamble.
4. Return exactly ONE valid JSON object.
5. The instruction must be a realistic question a layperson or law student would ask.
6. The output must apply or explain the statute — not just quote it verbatim."""

def build_messages(original_instruction: str, chunk: str) -> list:
    user_msg = f"""ORIGINAL INSTRUCTION:
{original_instruction}

STATUTE TEXT:
{chunk}

---
Generate a new, enriched training example that:
- Asks a reasoning or application question about this statute text
- Answers it using ONLY the information in the statute text above
- Does NOT reference sections or provisions outside the text above

Respond ONLY with this JSON format, nothing else:
{{
  "instruction": "...",
  "input": "",
  "output": "..."
}}"""

    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg}
    ]

# ==============================
# ✂️  CHUNKER
# ==============================
def chunk_text(text: str, max_chars: int = CHUNK_SIZE) -> list:
    if len(text) <= max_chars:
        return [text]

    parts   = text.split("\n\n")
    chunks  = []
    current = ""

    for part in parts:
        if len(part) > max_chars:
            if current:
                chunks.append(current.strip())
                current = ""
            sentences = re.split(r'(?<=[.;])\s+', part)
            for sentence in sentences:
                if len(current) + len(sentence) <= max_chars:
                    current += " " + sentence
                else:
                    if current:
                        chunks.append(current.strip())
                    current = sentence
        elif len(current) + len(part) + 2 <= max_chars:
            current += "\n\n" + part
        else:
            if current:
                chunks.append(current.strip())
            current = part

    if current:
        chunks.append(current.strip())

    return [c for c in chunks if len(c) >= 50]

# ==============================
# 🤖  MODEL LOADING
# ==============================
def load_model():
    print(f"Loading {MODEL_NAME} in 4-bit on GPU...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16, 
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.float16,
        trust_remote_code=True
    )
    model.eval()
    print("Model loaded.\n")
    return model, tokenizer

# ==============================
# 🔁  GENERATION (WITH OOM KILLER)
# ==============================
def generate(model, tokenizer, messages: list) -> str:
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.2,
            do_sample=True,
            top_p=0.8,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id
        )

    new_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    result = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    
    del inputs
    del outputs
    del new_tokens
    torch.cuda.empty_cache()
    gc.collect()
    
    return result

# ==============================
# 🔍  JSON EXTRACTION
# ==============================
def extract_json(text: str):
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        return None
    try:
        return json.loads(match.group())
    except Exception:
        return None

# ==============================
# 🛡️  HALLUCINATION GUARD (FIXED)
# ==============================
def hallucination_guard(original_text: str, generated_output: str) -> bool:
    out_lower  = generated_output.lower()
    orig_lower = original_text.lower()

    # Lexical overlap only — remove the strict act/section requirement
    orig_words  = set(orig_lower.split())
    gen_words   = set(out_lower.split())
    overlap     = len(orig_words & gen_words)

    # Just needs reasonable overlap with source text
    return overlap > 10

# ==============================
# 💾  CHECKPOINT HELPER
# ==============================
def load_processed_keys(output_path: str) -> set:
    processed = set()
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    key = (obj.get("source_instruction", ""), obj.get("chunk_index", 0))
                    processed.add(key)
                except Exception:
                    pass
    return processed

# ==============================
# 🚀  MAIN
# ==============================
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # --- RUN 2 RESTORATION LOGIC ---
    if os.path.exists(WIP_DATASET_PATH):
        print("Restoring previous progress from WIP dataset...")
        for filename in os.listdir(WIP_DATASET_PATH):
            if filename.endswith(".jsonl"):
                src = os.path.join(WIP_DATASET_PATH, filename)
                dst = os.path.join(OUTPUT_DIR, filename)
                shutil.copy2(src, dst)
                print(f"✅ Restored: {filename}")
        print("Ready to resume!\n")
    # -------------------------------
    
    START_TIME = time.time()
    MAX_RUNTIME_SEC = MAX_RUNTIME_HOURS * 3600 

    model, tokenizer = load_model()

    total_written = 0
    total_skipped = 0

    for split_name, filename in SPLITS.items():
        input_path  = os.path.join(INPUT_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, f"all_acts_{split_name}_augmented.jsonl")

        if not os.path.exists(input_path):
            print(f"⚠️  {input_path} not found — skipping {split_name}")
            continue

        with open(input_path, "r", encoding="utf-8") as f:
            data = [json.loads(line) for line in f]

        processed_keys = load_processed_keys(output_path)
        total_chunks = sum(len(chunk_text(d["output"])) for d in data)

        print(f"\n{'='*60}")
        print(f"📂  Split         : {split_name.upper()}")
        print(f"    Samples       : {len(data)}")
        print(f"    Total chunks  : {total_chunks}")
        print(f"    Already done  : {len(processed_keys)}")
        print(f"    Remaining     : {total_chunks - len(processed_keys)}")
        print(f"{'='*60}\n")

        split_written = 0
        split_skipped = 0

        pbar = tqdm(data, desc=f"Augmenting {split_name}")
        with open(output_path, "a", encoding="utf-8") as outfile:
            for example in pbar:
                instruction = example["instruction"]
                chunks      = chunk_text(example["output"])

                for chunk_idx, chunk in enumerate(chunks):
                    
                    if time.time() - START_TIME > MAX_RUNTIME_SEC:
                        print(f"\n⚠️ REACHED {MAX_RUNTIME_HOURS} HOURS. GRACEFULLY STOPPING.")
                        print(f"📊 Stats this run -> Written: {split_written} | Skipped: {split_skipped}")
                        print(f"💾 Files safely saved to: {OUTPUT_DIR}")
                        return 
                    
                    key = (instruction, chunk_idx)

                    if key in processed_keys:
                        continue

                    retries = 0
                    success = False

                    while retries < RETRY_LIMIT and not success:
                        try:
                            messages = build_messages(instruction, chunk)
                            raw      = generate(model, tokenizer, messages)
                            parsed   = extract_json(raw)

                            if parsed is None:
                                raise ValueError("No JSON found")

                            validate(instance=parsed, schema=AUGMENT_SCHEMA)

                            if not hallucination_guard(chunk, parsed["output"]):
                                raise ValueError("Hallucination guard failed")

                            parsed["source_instruction"] = instruction
                            parsed["chunk_index"]        = chunk_idx
                            parsed["total_chunks"]       = len(chunks)
                            parsed["split"]              = split_name

                            outfile.write(json.dumps(parsed, ensure_ascii=False) + "\n")
                            outfile.flush()
                            success       = True
                            split_written += 1

                        except (ValidationError, ValueError):
                            retries += 1
                            time.sleep(0.2)
                        except Exception as e:
                            print(f"\n❌ Unexpected error: {e}")
                            retries += 1
                            time.sleep(1)

                    if not success:
                        split_skipped += 1
                        
                    # LIVE TRACKER: Updates the progress bar with real-time stats!
                    pbar.set_postfix({"Written": split_written, "Skipped": split_skipped})

        total_written += split_written
        total_skipped += split_skipped

        print(f"\n✅  {split_name} done")
        print(f"    Written : {split_written}")
        print(f"    Skipped : {split_skipped}")
        print(f"    Saved   : {output_path}")

    print(f"\n{'='*60}")
    print(f"🏁  AUGMENTATION COMPLETE")
    print(f"    Total written : {total_written}")
    print(f"    Total skipped : {total_skipped}")
    print(f"    Output dir    : {OUTPUT_DIR}")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# Restoring previous progress from WIP dataset...
# ✅ Restored: all_acts_train_augmented.jsonl
# Ready to resume!
#
# Loading Qwen/Qwen2.5-7B-Instruct in 4-bit on GPU...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded.
#
#
# ============================================================
# 📂  Split         : TRAIN
#     Samples       : 7752
#     Total chunks  : 7935
#     Already done  : 4754
#     Remaining     : 3181
# ============================================================
# Augmenting train:   0%|          | 0/7752 [00:00<?, ?it/s]
# Augmenting train:   0%|          | 0/7752 [00:15<?, ?it/s, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:15<32:45:26, 15.21s/it, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:29<32:45:26, 15.21s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:29<20:09:19,  9.36s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:45<20:09:19,  9.36s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [00:45<10:24:19,  4.84s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [00:58<10:24:19,  4.84s/it, Written=0, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [00:58<2:38:32,  1.23s/it, Written=0, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [01:14<2:38:32,  1.23s/it, Written=0, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:14<3:41:06,  1.72s/it, Written=0, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:38<3:41:06,  1.72s/it, Written=0, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [01:38<6:21:18,  2.97s/it, Written=0, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [01:55<6:21:18,  2.97s/it, Written=0, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [01:55<7:01:17,  3.28s/it, Written=0, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [02:11<7:01:17,  3.28s/it, Written=0, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:11<7:01:33,  3.28s/it, Written=0, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:26<7:01:33,  3.28s/it, Written=0, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:26<8:19:15,  3.89s/it, Written=0, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:43<8:19:15,  3.89s/it, Written=0, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [02:43<5:53:32,  2.76s/it, Written=0, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [02:56<5:53:32,  2.76s/it, Written=0, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [02:56<6:12:44,  2.91s/it, Written=0, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [03:12<6:12:44,  2.91s/it, Written=0, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:12<7:11:58,  3.37s/it, Written=0, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:26<7:11:58,  3.37s/it, Written=0, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [03:26<8:28:40,  3.97s/it, Written=0, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [03:39<8:28:40,  3.97s/it, Written=0, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [03:39<10:19:48,  4.84s/it, Written=0, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [03:50<10:19:48,  4.84s/it, Written=0, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [03:50<12:04:01,  5.65s/it, Written=0, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [04:05<12:04:01,  5.65s/it, Written=0, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:05<12:56:17,  6.06s/it, Written=0, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:19<12:56:17,  6.06s/it, Written=0, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [04:19<13:35:08,  6.37s/it, Written=0, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [04:35<13:35:08,  6.37s/it, Written=0, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [04:35<9:20:40,  4.38s/it, Written=0, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [04:46<9:20:40,  4.38s/it, Written=0, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [04:46<6:52:44,  3.23s/it, Written=0, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [05:01<6:52:44,  3.23s/it, Written=0, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [05:01<5:54:27,  2.78s/it, Written=0, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [05:22<5:54:27,  2.78s/it, Written=0, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [05:22<6:50:49,  3.22s/it, Written=0, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [05:39<6:50:49,  3.22s/it, Written=0, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [05:39<7:53:30,  3.71s/it, Written=0, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [05:54<7:53:30,  3.71s/it, Written=0, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [05:54<7:27:00,  3.51s/it, Written=0, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [06:09<7:27:00,  3.51s/it, Written=0, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [06:09<8:06:05,  3.82s/it, Written=0, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [06:23<8:06:05,  3.82s/it, Written=0, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [06:23<6:29:49,  3.06s/it, Written=0, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [06:39<6:29:49,  3.06s/it, Written=0, Skipped=26]
# Augmenting train:   2%|▏         | 121/7752 [06:39<6:13:05,  2.93s/it, Written=0, Skipped=26]
# Augmenting train:   2%|▏         | 121/7752 [06:56<6:13:05,  2.93s/it, Written=0, Skipped=27]
# Augmenting train:   2%|▏         | 123/7752 [06:56<7:45:32,  3.66s/it, Written=0, Skipped=27]
# Augmenting train:   2%|▏         | 123/7752 [07:18<7:45:32,  3.66s/it, Written=0, Skipped=28]
# Augmenting train:   2%|▏         | 124/7752 [07:18<11:24:33,  5.38s/it, Written=0, Skipped=28]
# Augmenting train:   2%|▏         | 124/7752 [07:32<11:24:33,  5.38s/it, Written=0, Skipped=29]
# Augmenting train:   2%|▏         | 128/7752 [07:32<10:02:10,  4.74s/it, Written=0, Skipped=29]
# Augmenting train:   2%|▏         | 128/7752 [07:47<10:02:10,  4.74s/it, Written=0, Skipped=30]
# Augmenting train:   2%|▏         | 138/7752 [07:47<6:10:53,  2.92s/it, Written=0, Skipped=30]
# Augmenting train:   2%|▏         | 138/7752 [08:01<6:10:53,  2.92s/it, Written=0, Skipped=31]
# Augmenting train:   2%|▏         | 139/7752 [08:01<7:58:38,  3.77s/it, Written=0, Skipped=31]
# Augmenting train:   2%|▏         | 139/7752 [08:19<7:58:38,  3.77s/it, Written=0, Skipped=32]
# Augmenting train:   2%|▏         | 140/7752 [08:19<10:50:19,  5.13s/it, Written=0, Skipped=32]
# Augmenting train:   2%|▏         | 140/7752 [08:33<10:50:19,  5.13s/it, Written=0, Skipped=33]
# Augmenting train:   2%|▏         | 145/7752 [08:33<8:51:07,  4.19s/it, Written=0, Skipped=33]
# Augmenting train:   2%|▏         | 145/7752 [08:56<8:51:07,  4.19s/it, Written=0, Skipped=34]
# Augmenting train:   2%|▏         | 146/7752 [08:56<12:50:48,  6.08s/it, Written=0, Skipped=34]
# Augmenting train:   2%|▏         | 146/7752 [09:12<12:50:48,  6.08s/it, Written=0, Skipped=35]
# Augmenting train:   2%|▏         | 147/7752 [09:12<15:27:08,  7.31s/it, Written=0, Skipped=35]
# Augmenting train:   2%|▏         | 147/7752 [09:26<15:27:08,  7.31s/it, Written=0, Skipped=36]
# Augmenting train:   2%|▏         | 149/7752 [09:26<15:15:30,  7.22s/it, Written=0, Skipped=36]
# Augmenting train:   2%|▏         | 149/7752 [09:44<15:15:30,  7.22s/it, Written=0, Skipped=37]
# Augmenting train:   2%|▏         | 151/7752 [09:44<16:24:42,  7.77s/it, Written=0, Skipped=37]
# Augmenting train:   2%|▏         | 151/7752 [10:00<16:24:42,  7.77s/it, Written=0, Skipped=38]
# Augmenting train:   2%|▏         | 153/7752 [10:00<16:23:21,  7.76s/it, Written=0, Skipped=38]
# Augmenting train:   2%|▏         | 153/7752 [10:14<16:23:21,  7.76s/it, Written=0, Skipped=39]
# Augmenting train:   2%|▏         | 155/7752 [10:14<16:02:45,  7.60s/it, Written=0, Skipped=39]
# Augmenting train:   2%|▏         | 155/7752 [10:28<16:02:45,  7.60s/it, Written=0, Skipped=40]
# Augmenting train:   2%|▏         | 156/7752 [10:28<18:30:56,  8.78s/it, Written=0, Skipped=40]
# Augmenting train:   2%|▏         | 156/7752 [10:42<18:30:56,  8.78s/it, Written=0, Skipped=41]
# Augmenting train:   2%|▏         | 161/7752 [10:42<11:28:48,  5.44s/it, Written=0, Skipped=41]
# Augmenting train:   2%|▏         | 161/7752 [10:56<11:28:48,  5.44s/it, Written=0, Skipped=42]
# Augmenting train:   2%|▏         | 163/7752 [10:56<12:12:22,  5.79s/it, Written=0, Skipped=42]
# Augmenting train:   2%|▏         | 163/7752 [11:10<12:12:22,  5.79s/it, Written=0, Skipped=43]
# Augmenting train:   2%|▏         | 165/7752 [11:10<12:55:22,  6.13s/it, Written=0, Skipped=43]
# Augmenting train:   2%|▏         | 165/7752 [11:26<12:55:22,  6.13s/it, Written=0, Skipped=44]
# Augmenting train:   2%|▏         | 167/7752 [11:26<14:05:11,  6.69s/it, Written=0, Skipped=44]
# Augmenting train:   2%|▏         | 167/7752 [11:41<14:05:11,  6.69s/it, Written=0, Skipped=45]
# Augmenting train:   2%|▏         | 170/7752 [11:41<12:47:24,  6.07s/it, Written=0, Skipped=45]
# Augmenting train:   2%|▏         | 170/7752 [12:03<12:47:24,  6.07s/it, Written=0, Skipped=46]
# Augmenting train:   2%|▏         | 175/7752 [12:03<11:05:33,  5.27s/it, Written=0, Skipped=46]
# Augmenting train:   2%|▏         | 175/7752 [12:18<11:05:33,  5.27s/it, Written=0, Skipped=47]
# Augmenting train:   2%|▏         | 180/7752 [12:18<9:04:28,  4.31s/it, Written=0, Skipped=47]
# Augmenting train:   2%|▏         | 180/7752 [12:32<9:04:28,  4.31s/it, Written=0, Skipped=48]
# Augmenting train:   2%|▏         | 182/7752 [12:32<10:11:03,  4.84s/it, Written=0, Skipped=48]
# Augmenting train:   2%|▏         | 182/7752 [12:48<10:11:03,  4.84s/it, Written=0, Skipped=49]
# Augmenting train:   2%|▏         | 183/7752 [12:48<13:04:28,  6.22s/it, Written=0, Skipped=49]
# Augmenting train:   2%|▏         | 183/7752 [13:03<13:04:28,  6.22s/it, Written=0, Skipped=50]
# Augmenting train:   2%|▏         | 187/7752 [13:03<10:50:36,  5.16s/it, Written=0, Skipped=50]
# Augmenting train:   2%|▏         | 187/7752 [13:16<10:50:36,  5.16s/it, Written=0, Skipped=51]
# Augmenting train:   2%|▏         | 188/7752 [13:16<12:58:17,  6.17s/it, Written=0, Skipped=51]
# Augmenting train:   2%|▏         | 188/7752 [13:29<12:58:17,  6.17s/it, Written=0, Skipped=52]
# Augmenting train:   3%|▎         | 195/7752 [13:29<7:54:31,  3.77s/it, Written=0, Skipped=52]
# Augmenting train:   3%|▎         | 195/7752 [13:44<7:54:31,  3.77s/it, Written=0, Skipped=53]
# Augmenting train:   3%|▎         | 199/7752 [13:44<7:56:21,  3.78s/it, Written=0, Skipped=53]
# Augmenting train:   3%|▎         | 199/7752 [13:59<7:56:21,  3.78s/it, Written=0, Skipped=54]
# Augmenting train:   3%|▎         | 200/7752 [13:59<10:13:59,  4.88s/it, Written=0, Skipped=54]
# Augmenting train:   3%|▎         | 200/7752 [14:11<10:13:59,  4.88s/it, Written=0, Skipped=55]
# Augmenting train:   3%|▎         | 206/7752 [14:11<7:26:43,  3.55s/it, Written=0, Skipped=55]
# Augmenting train:   3%|▎         | 206/7752 [14:29<7:26:43,  3.55s/it, Written=0, Skipped=56]
# Augmenting train:   3%|▎         | 212/7752 [14:29<6:55:59,  3.31s/it, Written=0, Skipped=56]
# Augmenting train:   3%|▎         | 212/7752 [14:43<6:55:59,  3.31s/it, Written=0, Skipped=57]
# Augmenting train:   3%|▎         | 216/7752 [14:43<7:06:10,  3.39s/it, Written=0, Skipped=57]
# Augmenting train:   3%|▎         | 216/7752 [14:58<7:06:10,  3.39s/it, Written=0, Skipped=58]
# Augmenting train:   3%|▎         | 218/7752 [14:58<8:31:38,  4.07s/it, Written=0, Skipped=58]
# Augmenting train:   3%|▎         | 218/7752 [15:21<8:31:38,  4.07s/it, Written=1, Skipped=58]
# Augmenting train:   3%|▎         | 222/7752 [15:21<9:35:00,  4.58s/it, Written=1, Skipped=58]
# Augmenting train:   3%|▎         | 222/7752 [15:38<9:35:00,  4.58s/it, Written=1, Skipped=59]
# Augmenting train:   3%|▎         | 223/7752 [15:38<12:17:39,  5.88s/it, Written=1, Skipped=59]
# Augmenting train:   3%|▎         | 223/7752 [15:53<12:17:39,  5.88s/it, Written=1, Skipped=60]
# Augmenting train:   3%|▎         | 224/7752 [15:53<14:43:54,  7.05s/it, Written=1, Skipped=60]
# Augmenting train:   3%|▎         | 224/7752 [16:08<14:43:54,  7.05s/it, Written=1, Skipped=61]
# Augmenting train:   3%|▎         | 226/7752 [16:08<14:54:37,  7.13s/it, Written=1, Skipped=61]
# Augmenting train:   3%|▎         | 226/7752 [16:23<14:54:37,  7.13s/it, Written=1, Skipped=62]
# Augmenting train:   3%|▎         | 229/7752 [16:23<13:22:43,  6.40s/it, Written=1, Skipped=62]
# Augmenting train:   3%|▎         | 229/7752 [16:38<13:22:43,  6.40s/it, Written=1, Skipped=63]
# Augmenting train:   3%|▎         | 232/7752 [16:38<12:20:31,  5.91s/it, Written=1, Skipped=63]
# Augmenting train:   3%|▎         | 232/7752 [16:55<12:20:31,  5.91s/it, Written=1, Skipped=64]
# Augmenting train:   3%|▎         | 235/7752 [16:55<12:11:19,  5.84s/it, Written=1, Skipped=64]
# Augmenting train:   3%|▎         | 235/7752 [17:09<12:11:19,  5.84s/it, Written=1, Skipped=65]
# Augmenting train:   3%|▎         | 236/7752 [17:09<14:34:09,  6.98s/it, Written=1, Skipped=65]
# Augmenting train:   3%|▎         | 236/7752 [17:24<14:34:09,  6.98s/it, Written=1, Skipped=66]
# Augmenting train:   3%|▎         | 243/7752 [17:24<8:38:41,  4.14s/it, Written=1, Skipped=66]
# Augmenting train:   3%|▎         | 243/7752 [17:37<8:38:41,  4.14s/it, Written=1, Skipped=67]
# Augmenting train:   3%|▎         | 244/7752 [17:37<10:35:03,  5.07s/it, Written=1, Skipped=67]
# Augmenting train:   3%|▎         | 244/7752 [17:51<10:35:03,  5.07s/it, Written=1, Skipped=68]
# Augmenting train:   3%|▎         | 245/7752 [17:51<12:59:15,  6.23s/it, Written=1, Skipped=68]
# Augmenting train:   3%|▎         | 245/7752 [18:06<12:59:15,  6.23s/it, Written=1, Skipped=69]
# Augmenting train:   3%|▎         | 247/7752 [18:06<13:45:31,  6.60s/it, Written=1, Skipped=69]
# Augmenting train:   3%|▎         | 247/7752 [18:20<13:45:31,  6.60s/it, Written=1, Skipped=70]
# Augmenting train:   3%|▎         | 250/7752 [18:20<12:23:02,  5.94s/it, Written=1, Skipped=70]
# Augmenting train:   3%|▎         | 250/7752 [18:34<12:23:02,  5.94s/it, Written=1, Skipped=71]
# Augmenting train:   3%|▎         | 252/7752 [18:34<12:56:24,  6.21s/it, Written=1, Skipped=71]
# Augmenting train:   3%|▎         | 252/7752 [18:53<12:56:24,  6.21s/it, Written=2, Skipped=71]
# Augmenting train:   3%|▎         | 253/7752 [18:53<16:54:16,  8.12s/it, Written=2, Skipped=71]
# Augmenting train:   3%|▎         | 253/7752 [19:11<16:54:16,  8.12s/it, Written=2, Skipped=72]
# Augmenting train:   3%|▎         | 257/7752 [19:11<13:26:48,  6.46s/it, Written=2, Skipped=72]
# Augmenting train:   3%|▎         | 257/7752 [19:26<13:26:48,  6.46s/it, Written=2, Skipped=73]
# Augmenting train:   3%|▎         | 261/7752 [19:26<11:05:22,  5.33s/it, Written=2, Skipped=73]
# Augmenting train:   3%|▎         | 261/7752 [19:50<11:05:22,  5.33s/it, Written=2, Skipped=74]
# Augmenting train:   3%|▎         | 263/7752 [19:50<14:09:04,  6.80s/it, Written=2, Skipped=74]
# Augmenting train:   3%|▎         | 263/7752 [20:03<14:09:04,  6.80s/it, Written=2, Skipped=75]
# Augmenting train:   3%|▎         | 268/7752 [20:03<10:22:18,  4.99s/it, Written=2, Skipped=75]
# Augmenting train:   3%|▎         | 268/7752 [20:21<10:22:18,  4.99s/it, Written=2, Skipped=76]
# Augmenting train:   4%|▎         | 279/7752 [20:21<6:18:40,  3.04s/it, Written=2, Skipped=76]
# Augmenting train:   4%|▎         | 279/7752 [20:40<6:18:40,  3.04s/it, Written=2, Skipped=77]
# Augmenting train:   4%|▎         | 280/7752 [20:40<8:37:02,  4.15s/it, Written=2, Skipped=77]
# Augmenting train:   4%|▎         | 280/7752 [21:00<8:37:02,  4.15s/it, Written=2, Skipped=78]
# Augmenting train:   4%|▎         | 281/7752 [21:00<11:34:33,  5.58s/it, Written=2, Skipped=78]
# Augmenting train:   4%|▎         | 281/7752 [21:16<11:34:33,  5.58s/it, Written=2, Skipped=79]
# Augmenting train:   4%|▎         | 282/7752 [21:16<14:00:16,  6.75s/it, Written=2, Skipped=79]
# Augmenting train:   4%|▎         | 282/7752 [21:31<14:00:16,  6.75s/it, Written=2, Skipped=80]
# Augmenting train:   4%|▎         | 289/7752 [21:31<8:52:53,  4.28s/it, Written=2, Skipped=80]
# Augmenting train:   4%|▎         | 289/7752 [21:49<8:52:53,  4.28s/it, Written=2, Skipped=81]
# Augmenting train:   4%|▍         | 293/7752 [21:49<9:00:21,  4.35s/it, Written=2, Skipped=81]
# Augmenting train:   4%|▍         | 293/7752 [22:07<9:00:21,  4.35s/it, Written=2, Skipped=82]
# Augmenting train:   4%|▍         | 297/7752 [22:07<9:08:39,  4.42s/it, Written=2, Skipped=82]
# Augmenting train:   4%|▍         | 297/7752 [22:20<9:08:39,  4.42s/it, Written=2, Skipped=83]
# Augmenting train:   4%|▍         | 298/7752 [22:20<10:53:27,  5.26s/it, Written=2, Skipped=83]
# Augmenting train:   4%|▍         | 298/7752 [22:36<10:53:27,  5.26s/it, Written=2, Skipped=84]
# Augmenting train:   4%|▍         | 300/7752 [22:36<12:13:40,  5.91s/it, Written=2, Skipped=84]
# Augmenting train:   4%|▍         | 300/7752 [22:53<12:13:40,  5.91s/it, Written=2, Skipped=85]
# Augmenting train:   4%|▍         | 303/7752 [22:53<12:01:31,  5.81s/it, Written=2, Skipped=85]
# Augmenting train:   4%|▍         | 303/7752 [23:13<12:01:31,  5.81s/it, Written=2, Skipped=86]
# Augmenting train:   4%|▍         | 308/7752 [23:13<10:26:38,  5.05s/it, Written=2, Skipped=86]
# Augmenting train:   4%|▍         | 308/7752 [23:28<10:26:38,  5.05s/it, Written=2, Skipped=87]
# Augmenting train:   4%|▍         | 323/7752 [23:28<4:58:12,  2.41s/it, Written=2, Skipped=87]
# Augmenting train:   4%|▍         | 323/7752 [23:42<4:58:12,  2.41s/it, Written=2, Skipped=88]
# Augmenting train:   4%|▍         | 325/7752 [23:42<6:03:05,  2.93s/it, Written=2, Skipped=88]
# Augmenting train:   4%|▍         | 325/7752 [23:55<6:03:05,  2.93s/it, Written=2, Skipped=89]
# Augmenting train:   4%|▍         | 326/7752 [23:55<7:33:12,  3.66s/it, Written=2, Skipped=89]
# Augmenting train:   4%|▍         | 326/7752 [24:10<7:33:12,  3.66s/it, Written=2, Skipped=90]
# Augmenting train:   4%|▍         | 334/7752 [24:10<5:51:10,  2.84s/it, Written=2, Skipped=90]
# Augmenting train:   4%|▍         | 334/7752 [24:25<5:51:10,  2.84s/it, Written=2, Skipped=91]
# Augmenting train:   4%|▍         | 340/7752 [24:25<5:37:09,  2.73s/it, Written=2, Skipped=91]
# Augmenting train:   4%|▍         | 340/7752 [24:46<5:37:09,  2.73s/it, Written=2, Skipped=92]
# Augmenting train:   4%|▍         | 342/7752 [24:46<7:44:53,  3.76s/it, Written=2, Skipped=92]
# Augmenting train:   4%|▍         | 342/7752 [25:02<7:44:53,  3.76s/it, Written=2, Skipped=93]
# Augmenting train:   4%|▍         | 343/7752 [25:02<9:56:34,  4.83s/it, Written=2, Skipped=93]
# Augmenting train:   4%|▍         | 343/7752 [25:16<9:56:34,  4.83s/it, Written=2, Skipped=94]
# Augmenting train:   4%|▍         | 344/7752 [25:16<12:06:36,  5.89s/it, Written=2, Skipped=94]
# Augmenting train:   4%|▍         | 344/7752 [25:30<12:06:36,  5.89s/it, Written=2, Skipped=95]
# Augmenting train:   4%|▍         | 345/7752 [25:30<14:19:15,  6.96s/it, Written=2, Skipped=95]
# Augmenting train:   4%|▍         | 345/7752 [25:44<14:19:15,  6.96s/it, Written=2, Skipped=96]
# Augmenting train:   4%|▍         | 347/7752 [25:44<14:20:12,  6.97s/it, Written=2, Skipped=96]
# Augmenting train:   4%|▍         | 347/7752 [26:00<14:20:12,  6.97s/it, Written=2, Skipped=97]
# Augmenting train:   5%|▍         | 353/7752 [26:00<9:34:00,  4.65s/it, Written=2, Skipped=97]
# Augmenting train:   5%|▍         | 353/7752 [26:18<9:34:00,  4.65s/it, Written=2, Skipped=98]
# Augmenting train:   5%|▍         | 354/7752 [26:18<12:39:35,  6.16s/it, Written=2, Skipped=98]
# Augmenting train:   5%|▍         | 354/7752 [26:32<12:39:35,  6.16s/it, Written=2, Skipped=99]
# Augmenting train:   5%|▍         | 355/7752 [26:32<14:50:27,  7.22s/it, Written=2, Skipped=99]
# Augmenting train:   5%|▍         | 355/7752 [26:46<14:50:27,  7.22s/it, Written=2, Skipped=100]
# Augmenting train:   5%|▍         | 358/7752 [26:46<12:56:57,  6.30s/it, Written=2, Skipped=100]
# Augmenting train:   5%|▍         | 358/7752 [27:07<12:56:57,  6.30s/it, Written=2, Skipped=101]
# Augmenting train:   5%|▍         | 359/7752 [27:07<17:33:05,  8.55s/it, Written=2, Skipped=101]
# Augmenting train:   5%|▍         | 359/7752 [27:21<17:33:05,  8.55s/it, Written=2, Skipped=102]
# Augmenting train:   5%|▍         | 360/7752 [27:21<19:34:30,  9.53s/it, Written=2, Skipped=102]
# Augmenting train:   5%|▍         | 360/7752 [27:34<19:34:30,  9.53s/it, Written=2, Skipped=103]
# Augmenting train:   5%|▍         | 362/7752 [27:34<17:31:57,  8.54s/it, Written=2, Skipped=103]
# Augmenting train:   5%|▍         | 362/7752 [27:41<17:31:57,  8.54s/it, Written=3, Skipped=103]
# Augmenting train:   5%|▍         | 365/7752 [27:41<12:10:09,  5.93s/it, Written=3, Skipped=103]
# Augmenting train:   5%|▍         | 365/7752 [27:56<12:10:09,  5.93s/it, Written=3, Skipped=104]
# Augmenting train:   5%|▍         | 368/7752 [27:56<11:13:57,  5.48s/it, Written=3, Skipped=104]
# Augmenting train:   5%|▍         | 368/7752 [28:15<11:13:57,  5.48s/it, Written=3, Skipped=105]
# Augmenting train:   5%|▍         | 371/7752 [28:15<11:53:12,  5.80s/it, Written=3, Skipped=105]
# Augmenting train:   5%|▍         | 371/7752 [28:34<11:53:12,  5.80s/it, Written=3, Skipped=106]
# Augmenting train:   5%|▍         | 376/7752 [28:34<10:07:55,  4.95s/it, Written=3, Skipped=106]
# Augmenting train:   5%|▍         | 376/7752 [28:49<10:07:55,  4.95s/it, Written=3, Skipped=107]
# Augmenting train:   5%|▍         | 380/7752 [28:49<9:12:58,  4.50s/it, Written=3, Skipped=107]
# Augmenting train:   5%|▍         | 380/7752 [29:02<9:12:58,  4.50s/it, Written=3, Skipped=108]
# Augmenting train:   5%|▍         | 381/7752 [29:02<11:12:26,  5.47s/it, Written=3, Skipped=108]
# Augmenting train:   5%|▍         | 381/7752 [29:20<11:12:26,  5.47s/it, Written=3, Skipped=109]
# Augmenting train:   5%|▍         | 382/7752 [29:20<14:25:47,  7.05s/it, Written=3, Skipped=109]
# Augmenting train:   5%|▍         | 382/7752 [29:37<14:25:47,  7.05s/it, Written=3, Skipped=110]
# Augmenting train:   5%|▍         | 384/7752 [29:37<15:28:54,  7.56s/it, Written=3, Skipped=110]
# Augmenting train:   5%|▍         | 384/7752 [29:53<15:28:54,  7.56s/it, Written=3, Skipped=111]
# Augmenting train:   5%|▌         | 388/7752 [29:53<12:04:49,  5.91s/it, Written=3, Skipped=111]
# Augmenting train:   5%|▌         | 388/7752 [30:07<12:04:49,  5.91s/it, Written=3, Skipped=112]
# Augmenting train:   5%|▌         | 389/7752 [30:07<14:28:48,  7.08s/it, Written=3, Skipped=112]
# Augmenting train:   5%|▌         | 389/7752 [30:23<14:28:48,  7.08s/it, Written=3, Skipped=113]
# Augmenting train:   5%|▌         | 402/7752 [30:23<5:55:29,  2.90s/it, Written=3, Skipped=113]
# Augmenting train:   5%|▌         | 402/7752 [30:45<5:55:29,  2.90s/it, Written=3, Skipped=114]
# Augmenting train:   5%|▌         | 403/7752 [30:45<8:44:32,  4.28s/it, Written=3, Skipped=114]
# Augmenting train:   5%|▌         | 403/7752 [31:00<8:44:32,  4.28s/it, Written=3, Skipped=115]
# Augmenting train:   5%|▌         | 408/7752 [31:00<7:51:42,  3.85s/it, Written=3, Skipped=115]
# Augmenting train:   5%|▌         | 408/7752 [31:16<7:51:42,  3.85s/it, Written=3, Skipped=116]
# Augmenting train:   5%|▌         | 418/7752 [31:16<5:32:44,  2.72s/it, Written=3, Skipped=116]
# Augmenting train:   5%|▌         | 418/7752 [31:31<5:32:44,  2.72s/it, Written=3, Skipped=117]
# Augmenting train:   5%|▌         | 419/7752 [31:31<7:09:04,  3.51s/it, Written=3, Skipped=117]
# Augmenting train:   5%|▌         | 419/7752 [31:44<7:09:04,  3.51s/it, Written=3, Skipped=118]
# Augmenting train:   5%|▌         | 423/7752 [31:44<7:02:53,  3.46s/it, Written=3, Skipped=118]
# Augmenting train:   5%|▌         | 423/7752 [31:59<7:02:53,  3.46s/it, Written=3, Skipped=119]
# Augmenting train:   5%|▌         | 426/7752 [31:59<7:43:06,  3.79s/it, Written=3, Skipped=119]
# Augmenting train:   5%|▌         | 426/7752 [32:15<7:43:06,  3.79s/it, Written=3, Skipped=120]
# Augmenting train:   6%|▌         | 428/7752 [32:15<9:17:37,  4.57s/it, Written=3, Skipped=120]
# Augmenting train:   6%|▌         | 428/7752 [32:32<9:17:37,  4.57s/it, Written=3, Skipped=121]
# Augmenting train:   6%|▌         | 429/7752 [32:32<12:11:38,  5.99s/it, Written=3, Skipped=121]
# Augmenting train:   6%|▌         | 429/7752 [32:45<12:11:38,  5.99s/it, Written=3, Skipped=122]
# Augmenting train:   6%|▌         | 431/7752 [32:45<12:20:31,  6.07s/it, Written=3, Skipped=122]
# Augmenting train:   6%|▌         | 431/7752 [33:00<12:20:31,  6.07s/it, Written=3, Skipped=123]
# Augmenting train:   6%|▌         | 433/7752 [33:00<13:01:31,  6.41s/it, Written=3, Skipped=123]
# Augmenting train:   6%|▌         | 433/7752 [33:14<13:01:31,  6.41s/it, Written=3, Skipped=124]
# Augmenting train:   6%|▌         | 436/7752 [33:14<11:49:50,  5.82s/it, Written=3, Skipped=124]
# Augmenting train:   6%|▌         | 436/7752 [33:28<11:49:50,  5.82s/it, Written=3, Skipped=125]
# Augmenting train:   6%|▌         | 437/7752 [33:28<14:11:10,  6.98s/it, Written=3, Skipped=125]
# Augmenting train:   6%|▌         | 437/7752 [33:41<14:11:10,  6.98s/it, Written=3, Skipped=126]
# Augmenting train:   6%|▌         | 440/7752 [33:41<12:03:54,  5.94s/it, Written=3, Skipped=126]
# Augmenting train:   6%|▌         | 440/7752 [33:55<12:03:54,  5.94s/it, Written=3, Skipped=127]
# Augmenting train:   6%|▌         | 444/7752 [33:55<9:58:35,  4.91s/it, Written=3, Skipped=127]
# Augmenting train:   6%|▌         | 444/7752 [34:09<9:58:35,  4.91s/it, Written=3, Skipped=128]
# Augmenting train:   6%|▌         | 445/7752 [34:09<12:28:31,  6.15s/it, Written=3, Skipped=128]
# Augmenting train:   6%|▌         | 445/7752 [34:23<12:28:31,  6.15s/it, Written=3, Skipped=129]
# Augmenting train:   6%|▌         | 446/7752 [34:23<14:52:09,  7.33s/it, Written=3, Skipped=129]
# Augmenting train:   6%|▌         | 446/7752 [34:36<14:52:09,  7.33s/it, Written=3, Skipped=130]
# Augmenting train:   6%|▌         | 449/7752 [34:36<12:25:40,  6.13s/it, Written=3, Skipped=130]
# Augmenting train:   6%|▌         | 449/7752 [34:52<12:25:40,  6.13s/it, Written=3, Skipped=131]
# Augmenting train:   6%|▌         | 453/7752 [34:52<10:39:48,  5.26s/it, Written=3, Skipped=131]
# Augmenting train:   6%|▌         | 453/7752 [35:07<10:39:48,  5.26s/it, Written=3, Skipped=132]
# Augmenting train:   6%|▌         | 454/7752 [35:07<13:13:36,  6.52s/it, Written=3, Skipped=132]
# Augmenting train:   6%|▌         | 454/7752 [35:20<13:13:36,  6.52s/it, Written=3, Skipped=133]
# Augmenting train:   6%|▌         | 455/7752 [35:20<15:20:16,  7.57s/it, Written=3, Skipped=133]
# Augmenting train:   6%|▌         | 455/7752 [35:32<15:20:16,  7.57s/it, Written=3, Skipped=134]
# Augmenting train:   6%|▌         | 459/7752 [35:32<10:58:56,  5.42s/it, Written=3, Skipped=134]
# Augmenting train:   6%|▌         | 459/7752 [35:46<10:58:56,  5.42s/it, Written=3, Skipped=135]
# Augmenting train:   6%|▌         | 462/7752 [35:46<10:29:02,  5.18s/it, Written=3, Skipped=135]
# Augmenting train:   6%|▌         | 462/7752 [36:00<10:29:02,  5.18s/it, Written=3, Skipped=136]
# Augmenting train:   6%|▌         | 464/7752 [36:00<11:19:48,  5.60s/it, Written=3, Skipped=136]
# Augmenting train:   6%|▌         | 464/7752 [36:14<11:19:48,  5.60s/it, Written=3, Skipped=137]
# Augmenting train:   6%|▌         | 467/7752 [36:14<10:45:02,  5.31s/it, Written=3, Skipped=137]
# Augmenting train:   6%|▌         | 467/7752 [36:29<10:45:02,  5.31s/it, Written=3, Skipped=138]
# Augmenting train:   6%|▌         | 468/7752 [36:29<13:16:53,  6.56s/it, Written=3, Skipped=138]
# Augmenting train:   6%|▌         | 468/7752 [36:41<13:16:53,  6.56s/it, Written=4, Skipped=138]
# Augmenting train:   6%|▌         | 470/7752 [36:41<13:07:24,  6.49s/it, Written=4, Skipped=138]
# Augmenting train:   6%|▌         | 470/7752 [36:57<13:07:24,  6.49s/it, Written=4, Skipped=139]
# Augmenting train:   6%|▌         | 474/7752 [36:57<10:46:54,  5.33s/it, Written=4, Skipped=139]
# Augmenting train:   6%|▌         | 474/7752 [37:12<10:46:54,  5.33s/it, Written=4, Skipped=140]
# Augmenting train:   6%|▌         | 476/7752 [37:12<11:57:01,  5.91s/it, Written=4, Skipped=140]
# Augmenting train:   6%|▌         | 476/7752 [37:29<11:57:01,  5.91s/it, Written=4, Skipped=141]
# Augmenting train:   6%|▌         | 477/7752 [37:29<15:09:07,  7.50s/it, Written=4, Skipped=141]
# Augmenting train:   6%|▌         | 477/7752 [37:45<15:09:07,  7.50s/it, Written=4, Skipped=142]
# Augmenting train:   6%|▌         | 484/7752 [37:45<8:46:47,  4.35s/it, Written=4, Skipped=142]
# Augmenting train:   6%|▌         | 484/7752 [38:03<8:46:47,  4.35s/it, Written=4, Skipped=143]
# Augmenting train:   6%|▋         | 485/7752 [38:03<11:49:15,  5.86s/it, Written=4, Skipped=143]
# Augmenting train:   6%|▋         | 485/7752 [38:21<11:49:15,  5.86s/it, Written=4, Skipped=144]
# Augmenting train:   6%|▋         | 489/7752 [38:21<10:44:07,  5.32s/it, Written=4, Skipped=144]
# Augmenting train:   6%|▋         | 489/7752 [38:34<10:44:07,  5.32s/it, Written=5, Skipped=144]
# Augmenting train:   6%|▋         | 491/7752 [38:34<11:13:42,  5.57s/it, Written=5, Skipped=144]
# Augmenting train:   6%|▋         | 491/7752 [38:52<11:13:42,  5.57s/it, Written=5, Skipped=145]
# Augmenting train:   6%|▋         | 494/7752 [38:52<11:40:21,  5.79s/it, Written=5, Skipped=145]
# Augmenting train:   6%|▋         | 494/7752 [39:07<11:40:21,  5.79s/it, Written=5, Skipped=146]
# Augmenting train:   6%|▋         | 495/7752 [39:07<14:03:46,  6.98s/it, Written=5, Skipped=146]
# Augmenting train:   6%|▋         | 495/7752 [39:23<14:03:46,  6.98s/it, Written=5, Skipped=147]
# Augmenting train:   6%|▋         | 496/7752 [39:23<16:59:08,  8.43s/it, Written=5, Skipped=147]
# Augmenting train:   6%|▋         | 496/7752 [39:41<16:59:08,  8.43s/it, Written=5, Skipped=148]
# Augmenting train:   6%|▋         | 497/7752 [39:41<20:14:31, 10.04s/it, Written=5, Skipped=148]
# Augmenting train:   6%|▋         | 497/7752 [39:54<20:14:31, 10.04s/it, Written=6, Skipped=148]
# Augmenting train:   6%|▋         | 499/7752 [39:54<17:50:17,  8.85s/it, Written=6, Skipped=148]
# Augmenting train:   6%|▋         | 499/7752 [40:11<17:50:17,  8.85s/it, Written=6, Skipped=149]
# Augmenting train:   6%|▋         | 502/7752 [40:11<15:08:13,  7.52s/it, Written=6, Skipped=149]
# Augmenting train:   6%|▋         | 502/7752 [40:22<15:08:13,  7.52s/it, Written=6, Skipped=150]
# Augmenting train:   7%|▋         | 504/7752 [40:22<14:02:29,  6.97s/it, Written=6, Skipped=150]
# Augmenting train:   7%|▋         | 504/7752 [40:35<14:02:29,  6.97s/it, Written=6, Skipped=151]
# Augmenting train:   7%|▋         | 507/7752 [40:35<12:01:56,  5.98s/it, Written=6, Skipped=151]
# Augmenting train:   7%|▋         | 507/7752 [40:49<12:01:56,  5.98s/it, Written=6, Skipped=152]
# Augmenting train:   7%|▋         | 511/7752 [40:49<9:54:41,  4.93s/it, Written=6, Skipped=152]
# Augmenting train:   7%|▋         | 511/7752 [41:03<9:54:41,  4.93s/it, Written=6, Skipped=153]
# Augmenting train:   7%|▋         | 516/7752 [41:03<7:58:40,  3.97s/it, Written=6, Skipped=153]
# Augmenting train:   7%|▋         | 516/7752 [41:21<7:58:40,  3.97s/it, Written=6, Skipped=154]
# Augmenting train:   7%|▋         | 517/7752 [41:21<11:10:17,  5.56s/it, Written=6, Skipped=154]
# Augmenting train:   7%|▋         | 517/7752 [41:33<11:10:17,  5.56s/it, Written=6, Skipped=155]
# Augmenting train:   7%|▋         | 520/7752 [41:33<10:06:34,  5.03s/it, Written=6, Skipped=155]
# Augmenting train:   7%|▋         | 520/7752 [41:47<10:06:34,  5.03s/it, Written=6, Skipped=156]
# Augmenting train:   7%|▋         | 524/7752 [41:47<8:59:14,  4.48s/it, Written=6, Skipped=156]
# Augmenting train:   7%|▋         | 524/7752 [42:04<8:59:14,  4.48s/it, Written=6, Skipped=157]
# Augmenting train:   7%|▋         | 525/7752 [42:04<11:54:35,  5.93s/it, Written=6, Skipped=157]
# Augmenting train:   7%|▋         | 525/7752 [42:19<11:54:35,  5.93s/it, Written=6, Skipped=158]
# Augmenting train:   7%|▋         | 526/7752 [42:19<14:39:15,  7.30s/it, Written=6, Skipped=158]
# Augmenting train:   7%|▋         | 526/7752 [42:35<14:39:15,  7.30s/it, Written=6, Skipped=159]
# Augmenting train:   7%|▋         | 527/7752 [42:35<17:23:33,  8.67s/it, Written=6, Skipped=159]
# Augmenting train:   7%|▋         | 527/7752 [42:52<17:23:33,  8.67s/it, Written=7, Skipped=159]
# Augmenting train:   7%|▋         | 529/7752 [42:52<17:25:30,  8.68s/it, Written=7, Skipped=159]
# Augmenting train:   7%|▋         | 529/7752 [43:10<17:25:30,  8.68s/it, Written=7, Skipped=160]
# Augmenting train:   7%|▋         | 532/7752 [43:10<15:13:54,  7.59s/it, Written=7, Skipped=160]
# Augmenting train:   7%|▋         | 532/7752 [43:23<15:13:54,  7.59s/it, Written=7, Skipped=161]
# Augmenting train:   7%|▋         | 533/7752 [43:23<16:52:18,  8.41s/it, Written=7, Skipped=161]
# Augmenting train:   7%|▋         | 533/7752 [43:33<16:52:18,  8.41s/it, Written=8, Skipped=161]
# Augmenting train:   7%|▋         | 538/7752 [43:33<10:04:51,  5.03s/it, Written=8, Skipped=161]
# Augmenting train:   7%|▋         | 538/7752 [43:46<10:04:51,  5.03s/it, Written=8, Skipped=162]
# Augmenting train:   7%|▋         | 544/7752 [43:46<7:16:26,  3.63s/it, Written=8, Skipped=162]
# Augmenting train:   7%|▋         | 544/7752 [44:01<7:16:26,  3.63s/it, Written=8, Skipped=163]
# Augmenting train:   7%|▋         | 546/7752 [44:01<8:42:34,  4.35s/it, Written=8, Skipped=163]
# Augmenting train:   7%|▋         | 546/7752 [44:15<8:42:34,  4.35s/it, Written=8, Skipped=164]
# Augmenting train:   7%|▋         | 552/7752 [44:15<6:51:23,  3.43s/it, Written=8, Skipped=164]
# Augmenting train:   7%|▋         | 552/7752 [45:09<6:51:23,  3.43s/it, Written=8, Skipped=165]
# Augmenting train:   7%|▋         | 560/7752 [45:09<9:51:59,  4.94s/it, Written=8, Skipped=165]
# Augmenting train:   7%|▋         | 560/7752 [45:27<9:51:59,  4.94s/it, Written=8, Skipped=166]
# Augmenting train:   7%|▋         | 565/7752 [45:27<9:08:22,  4.58s/it, Written=8, Skipped=166]
# Augmenting train:   7%|▋         | 565/7752 [45:47<9:08:22,  4.58s/it, Written=8, Skipped=167]
# Augmenting train:   7%|▋         | 566/7752 [45:47<11:33:07,  5.79s/it, Written=8, Skipped=167]
# Augmenting train:   7%|▋         | 566/7752 [46:02<11:33:07,  5.79s/it, Written=8, Skipped=168]
# Augmenting train:   7%|▋         | 567/7752 [46:02<13:13:55,  6.63s/it, Written=8, Skipped=168]
# Augmenting train:   7%|▋         | 567/7752 [46:16<13:13:55,  6.63s/it, Written=8, Skipped=169]
# Augmenting train:   7%|▋         | 568/7752 [46:16<15:00:45,  7.52s/it, Written=8, Skipped=169]
# Augmenting train:   7%|▋         | 568/7752 [46:29<15:00:45,  7.52s/it, Written=8, Skipped=170]
# Augmenting train:   7%|▋         | 571/7752 [46:29<12:48:27,  6.42s/it, Written=8, Skipped=170]
# Augmenting train:   7%|▋         | 571/7752 [46:41<12:48:27,  6.42s/it, Written=8, Skipped=171]
# Augmenting train:   7%|▋         | 579/7752 [46:41<7:18:41,  3.67s/it, Written=8, Skipped=171]
# Augmenting train:   7%|▋         | 579/7752 [46:54<7:18:41,  3.67s/it, Written=9, Skipped=171]
# Augmenting train:   8%|▊         | 583/7752 [46:54<7:00:38,  3.52s/it, Written=9, Skipped=171]
# Augmenting train:   8%|▊         | 583/7752 [47:09<7:00:38,  3.52s/it, Written=9, Skipped=172]
# Augmenting train:   8%|▊         | 590/7752 [47:09<5:50:35,  2.94s/it, Written=9, Skipped=172]
# Augmenting train:   8%|▊         | 590/7752 [47:24<5:50:35,  2.94s/it, Written=9, Skipped=173]
# Augmenting train:   8%|▊         | 600/7752 [47:24<4:30:10,  2.27s/it, Written=9, Skipped=173]
# Augmenting train:   8%|▊         | 600/7752 [47:46<4:30:10,  2.27s/it, Written=9, Skipped=174]
# Augmenting train:   8%|▊         | 602/7752 [47:46<6:36:21,  3.33s/it, Written=9, Skipped=174]
# Augmenting train:   8%|▊         | 602/7752 [48:08<6:36:21,  3.33s/it, Written=9, Skipped=175]
# Augmenting train:   8%|▊         | 609/7752 [48:08<6:23:58,  3.23s/it, Written=9, Skipped=175]
# Augmenting train:   8%|▊         | 609/7752 [48:25<6:23:58,  3.23s/it, Written=9, Skipped=176]
# Augmenting train:   8%|▊         | 611/7752 [48:25<7:47:28,  3.93s/it, Written=9, Skipped=176]
# Augmenting train:   8%|▊         | 611/7752 [48:44<7:47:28,  3.93s/it, Written=9, Skipped=177]
# Augmenting train:   8%|▊         | 619/7752 [48:44<6:26:49,  3.25s/it, Written=9, Skipped=177]
# Augmenting train:   8%|▊         | 619/7752 [48:58<6:26:49,  3.25s/it, Written=9, Skipped=178]
# Augmenting train:   8%|▊         | 624/7752 [48:58<6:16:11,  3.17s/it, Written=9, Skipped=178]
# Augmenting train:   8%|▊         | 624/7752 [49:14<6:16:11,  3.17s/it, Written=9, Skipped=179]
# Augmenting train:   8%|▊         | 630/7752 [49:14<5:54:04,  2.98s/it, Written=9, Skipped=179]
# Augmenting train:   8%|▊         | 630/7752 [49:28<5:54:04,  2.98s/it, Written=9, Skipped=180]
# Augmenting train:   8%|▊         | 637/7752 [49:28<5:13:11,  2.64s/it, Written=9, Skipped=180]
# Augmenting train:   8%|▊         | 637/7752 [49:41<5:13:11,  2.64s/it, Written=9, Skipped=181]
# Augmenting train:   8%|▊         | 639/7752 [49:41<6:10:49,  3.13s/it, Written=9, Skipped=181]
# Augmenting train:   8%|▊         | 639/7752 [49:57<6:10:49,  3.13s/it, Written=9, Skipped=182]
# Augmenting train:   8%|▊         | 643/7752 [49:57<6:34:54,  3.33s/it, Written=9, Skipped=182]
# Augmenting train:   8%|▊         | 643/7752 [50:12<6:34:54,  3.33s/it, Written=9, Skipped=183]
# Augmenting train:   8%|▊         | 645/7752 [50:12<7:53:59,  4.00s/it, Written=9, Skipped=183]
# Augmenting train:   8%|▊         | 645/7752 [50:24<7:53:59,  4.00s/it, Written=9, Skipped=184]
# Augmenting train:   8%|▊         | 647/7752 [50:24<8:37:11,  4.37s/it, Written=9, Skipped=184]
# Augmenting train:   8%|▊         | 647/7752 [50:39<8:37:11,  4.37s/it, Written=9, Skipped=185]
# Augmenting train:   8%|▊         | 654/7752 [50:39<6:34:57,  3.34s/it, Written=9, Skipped=185]
# Augmenting train:   8%|▊         | 654/7752 [51:00<6:34:57,  3.34s/it, Written=9, Skipped=186]
# Augmenting train:   8%|▊         | 658/7752 [51:00<7:37:07,  3.87s/it, Written=9, Skipped=186]
# Augmenting train:   8%|▊         | 658/7752 [51:15<7:37:07,  3.87s/it, Written=9, Skipped=187]
# Augmenting train:   9%|▊         | 660/7752 [51:15<8:45:21,  4.44s/it, Written=9, Skipped=187]
# Augmenting train:   9%|▊         | 660/7752 [51:32<8:45:21,  4.44s/it, Written=9, Skipped=188]
# Augmenting train:   9%|▊         | 661/7752 [51:32<11:19:40,  5.75s/it, Written=9, Skipped=188]
# Augmenting train:   9%|▊         | 661/7752 [51:47<11:19:40,  5.75s/it, Written=9, Skipped=189]
# Augmenting train:   9%|▊         | 662/7752 [51:47<13:52:01,  7.04s/it, Written=9, Skipped=189]
# Augmenting train:   9%|▊         | 662/7752 [52:00<13:52:01,  7.04s/it, Written=9, Skipped=190]
# Augmenting train:   9%|▊         | 668/7752 [52:00<8:48:10,  4.47s/it, Written=9, Skipped=190]
# Augmenting train:   9%|▊         | 668/7752 [52:13<8:48:10,  4.47s/it, Written=9, Skipped=191]
# Augmenting train:   9%|▊         | 669/7752 [52:13<10:38:38,  5.41s/it, Written=9, Skipped=191]
# Augmenting train:   9%|▊         | 669/7752 [52:29<10:38:38,  5.41s/it, Written=9, Skipped=192]
# Augmenting train:   9%|▊         | 670/7752 [52:29<13:29:03,  6.85s/it, Written=9, Skipped=192]
# Augmenting train:   9%|▊         | 670/7752 [52:43<13:29:03,  6.85s/it, Written=9, Skipped=193]
# Augmenting train:   9%|▉         | 680/7752 [52:43<6:19:13,  3.22s/it, Written=9, Skipped=193]
# Augmenting train:   9%|▉         | 680/7752 [52:58<6:19:13,  3.22s/it, Written=9, Skipped=194]
# Augmenting train:   9%|▉         | 686/7752 [52:58<5:48:17,  2.96s/it, Written=9, Skipped=194]
# Augmenting train:   9%|▉         | 686/7752 [53:12<5:48:17,  2.96s/it, Written=9, Skipped=195]
# Augmenting train:   9%|▉         | 688/7752 [53:12<7:00:11,  3.57s/it, Written=9, Skipped=195]
# Augmenting train:   9%|▉         | 688/7752 [53:27<7:00:11,  3.57s/it, Written=9, Skipped=196]
# Augmenting train:   9%|▉         | 689/7752 [53:27<9:11:24,  4.68s/it, Written=9, Skipped=196]
# Augmenting train:   9%|▉         | 689/7752 [53:41<9:11:24,  4.68s/it, Written=9, Skipped=197]
# Augmenting train:   9%|▉         | 695/7752 [53:41<7:01:25,  3.58s/it, Written=9, Skipped=197]
# Augmenting train:   9%|▉         | 695/7752 [53:59<7:01:25,  3.58s/it, Written=9, Skipped=198]
# Augmenting train:   9%|▉         | 698/7752 [53:59<8:09:19,  4.16s/it, Written=9, Skipped=198]
# Augmenting train:   9%|▉         | 698/7752 [54:13<8:09:19,  4.16s/it, Written=9, Skipped=199]
# Augmenting train:   9%|▉         | 707/7752 [54:13<5:34:20,  2.85s/it, Written=9, Skipped=199]
# Augmenting train:   9%|▉         | 707/7752 [54:30<5:34:20,  2.85s/it, Written=9, Skipped=200]
# Augmenting train:   9%|▉         | 708/7752 [54:30<7:42:08,  3.94s/it, Written=9, Skipped=200]
# Augmenting train:   9%|▉         | 708/7752 [54:44<7:42:08,  3.94s/it, Written=9, Skipped=201]
# Augmenting train:   9%|▉         | 711/7752 [54:44<7:59:12,  4.08s/it, Written=9, Skipped=201]
# Augmenting train:   9%|▉         | 711/7752 [54:58<7:59:12,  4.08s/it, Written=9, Skipped=202]
# Augmenting train:   9%|▉         | 713/7752 [54:58<9:01:30,  4.62s/it, Written=9, Skipped=202]
# Augmenting train:   9%|▉         | 713/7752 [55:12<9:01:30,  4.62s/it, Written=9, Skipped=203]
# Augmenting train:   9%|▉         | 715/7752 [55:12<10:08:16,  5.19s/it, Written=9, Skipped=203]
# Augmenting train:   9%|▉         | 715/7752 [55:24<10:08:16,  5.19s/it, Written=9, Skipped=204]
# Augmenting train:   9%|▉         | 718/7752 [55:24<9:21:47,  4.79s/it, Written=9, Skipped=204]
# Augmenting train:   9%|▉         | 718/7752 [55:38<9:21:47,  4.79s/it, Written=9, Skipped=205]
# Augmenting train:   9%|▉         | 726/7752 [55:38<6:02:38,  3.10s/it, Written=9, Skipped=205]
# Augmenting train:   9%|▉         | 726/7752 [55:50<6:02:38,  3.10s/it, Written=9, Skipped=206]
# Augmenting train:   9%|▉         | 727/7752 [55:50<7:40:46,  3.94s/it, Written=9, Skipped=206]
# Augmenting train:   9%|▉         | 727/7752 [56:06<7:40:46,  3.94s/it, Written=9, Skipped=207]
# Augmenting train:   9%|▉         | 730/7752 [56:06<8:23:25,  4.30s/it, Written=9, Skipped=207]
# Augmenting train:   9%|▉         | 730/7752 [56:28<8:23:25,  4.30s/it, Written=9, Skipped=208]
# Augmenting train:   9%|▉         | 734/7752 [56:28<9:08:50,  4.69s/it, Written=9, Skipped=208]
# Augmenting train:   9%|▉         | 734/7752 [56:41<9:08:50,  4.69s/it, Written=9, Skipped=209]
# Augmenting train:  10%|▉         | 740/7752 [56:41<7:03:23,  3.62s/it, Written=9, Skipped=209]
# Augmenting train:  10%|▉         | 740/7752 [56:56<7:03:23,  3.62s/it, Written=9, Skipped=210]
# Augmenting train:  10%|▉         | 748/7752 [56:56<5:36:52,  2.89s/it, Written=9, Skipped=210]
# Augmenting train:  10%|▉         | 748/7752 [57:09<5:36:52,  2.89s/it, Written=9, Skipped=211]
# Augmenting train:  10%|▉         | 753/7752 [57:09<5:27:01,  2.80s/it, Written=9, Skipped=211]
# Augmenting train:  10%|▉         | 753/7752 [57:24<5:27:01,  2.80s/it, Written=9, Skipped=212]
# Augmenting train:  10%|▉         | 757/7752 [57:24<5:52:29,  3.02s/it, Written=9, Skipped=212]
# Augmenting train:  10%|▉         | 757/7752 [57:43<5:52:29,  3.02s/it, Written=9, Skipped=213]
# Augmenting train:  10%|▉         | 760/7752 [57:43<7:12:26,  3.71s/it, Written=9, Skipped=213]
# Augmenting train:  10%|▉         | 760/7752 [58:01<7:12:26,  3.71s/it, Written=9, Skipped=214]
# Augmenting train:  10%|▉         | 762/7752 [58:01<8:49:34,  4.55s/it, Written=9, Skipped=214]
# Augmenting train:  10%|▉         | 762/7752 [58:15<8:49:34,  4.55s/it, Written=9, Skipped=215]
# Augmenting train:  10%|▉         | 764/7752 [58:15<9:46:30,  5.04s/it, Written=9, Skipped=215]
# Augmenting train:  10%|▉         | 764/7752 [58:29<9:46:30,  5.04s/it, Written=9, Skipped=216]
# Augmenting train:  10%|▉         | 768/7752 [58:29<8:43:18,  4.50s/it, Written=9, Skipped=216]
# Augmenting train:  10%|▉         | 768/7752 [58:48<8:43:18,  4.50s/it, Written=9, Skipped=217]
# Augmenting train:  10%|▉         | 770/7752 [58:48<10:46:37,  5.56s/it, Written=9, Skipped=217]
# Augmenting train:  10%|▉         | 770/7752 [59:04<10:46:37,  5.56s/it, Written=9, Skipped=218]
# Augmenting train:  10%|▉         | 772/7752 [59:04<11:47:41,  6.08s/it, Written=9, Skipped=218]
# Augmenting train:  10%|▉         | 772/7752 [59:21<11:47:41,  6.08s/it, Written=9, Skipped=219]
# Augmenting train:  10%|▉         | 775/7752 [59:21<11:24:25,  5.89s/it, Written=9, Skipped=219]
# Augmenting train:  10%|▉         | 775/7752 [59:35<11:24:25,  5.89s/it, Written=9, Skipped=220]
# Augmenting train:  10%|█         | 776/7752 [59:35<13:33:38,  7.00s/it, Written=9, Skipped=220]
# Augmenting train:  10%|█         | 776/7752 [59:56<13:33:38,  7.00s/it, Written=10, Skipped=220]
# Augmenting train:  10%|█         | 777/7752 [59:56<17:47:28,  9.18s/it, Written=10, Skipped=220]
# Augmenting train:  10%|█         | 777/7752 [1:00:11<17:47:28,  9.18s/it, Written=10, Skipped=221]
# Augmenting train:  10%|█         | 778/7752 [1:00:11<20:06:43, 10.38s/it, Written=10, Skipped=221]
# Augmenting train:  10%|█         | 778/7752 [1:00:30<20:06:43, 10.38s/it, Written=10, Skipped=222]
# Augmenting train:  10%|█         | 786/7752 [1:00:30<9:27:45,  4.89s/it, Written=10, Skipped=222]
# Augmenting train:  10%|█         | 786/7752 [1:00:46<9:27:45,  4.89s/it, Written=10, Skipped=223]
# Augmenting train:  10%|█         | 791/7752 [1:00:46<8:16:49,  4.28s/it, Written=10, Skipped=223]
# Augmenting train:  10%|█         | 791/7752 [1:01:04<8:16:49,  4.28s/it, Written=10, Skipped=224]
# Augmenting train:  10%|█         | 793/7752 [1:01:04<9:54:04,  5.12s/it, Written=10, Skipped=224]
# Augmenting train:  10%|█         | 793/7752 [1:01:19<9:54:04,  5.12s/it, Written=10, Skipped=225]
# Augmenting train:  10%|█         | 800/7752 [1:01:19<7:07:25,  3.69s/it, Written=10, Skipped=225]
# Augmenting train:  10%|█         | 800/7752 [1:01:34<7:07:25,  3.69s/it, Written=10, Skipped=226]
# Augmenting train:  10%|█         | 804/7752 [1:01:34<7:09:17,  3.71s/it, Written=10, Skipped=226]
# Augmenting train:  10%|█         | 804/7752 [1:01:50<7:09:17,  3.71s/it, Written=10, Skipped=227]
# Augmenting train:  10%|█         | 806/7752 [1:01:50<8:37:07,  4.47s/it, Written=10, Skipped=227]
# Augmenting train:  10%|█         | 806/7752 [1:02:03<8:37:07,  4.47s/it, Written=10, Skipped=228]
# Augmenting train:  10%|█         | 808/7752 [1:02:03<9:19:44,  4.84s/it, Written=10, Skipped=228]
# Augmenting train:  10%|█         | 808/7752 [1:02:21<9:19:44,  4.84s/it, Written=10, Skipped=229]
# Augmenting train:  10%|█         | 812/7752 [1:02:21<9:01:47,  4.68s/it, Written=10, Skipped=229]
# Augmenting train:  10%|█         | 812/7752 [1:02:34<9:01:47,  4.68s/it, Written=10, Skipped=230]
# Augmenting train:  11%|█         | 814/7752 [1:02:34<9:53:24,  5.13s/it, Written=10, Skipped=230]
# Augmenting train:  11%|█         | 814/7752 [1:02:48<9:53:24,  5.13s/it, Written=10, Skipped=231]
# Augmenting train:  11%|█         | 816/7752 [1:02:48<10:39:51,  5.54s/it, Written=10, Skipped=231]
# Augmenting train:  11%|█         | 816/7752 [1:03:02<10:39:51,  5.54s/it, Written=10, Skipped=232]
# Augmenting train:  11%|█         | 820/7752 [1:03:02<9:05:39,  4.72s/it, Written=10, Skipped=232]
# Augmenting train:  11%|█         | 820/7752 [1:03:20<9:05:39,  4.72s/it, Written=10, Skipped=233]
# Augmenting train:  11%|█         | 821/7752 [1:03:20<12:08:30,  6.31s/it, Written=10, Skipped=233]
# Augmenting train:  11%|█         | 821/7752 [1:03:35<12:08:30,  6.31s/it, Written=10, Skipped=234]
# Augmenting train:  11%|█         | 827/7752 [1:03:35<8:23:19,  4.36s/it, Written=10, Skipped=234]
# Augmenting train:  11%|█         | 827/7752 [1:03:47<8:23:19,  4.36s/it, Written=10, Skipped=235]
# Augmenting train:  11%|█         | 829/7752 [1:03:47<9:06:59,  4.74s/it, Written=10, Skipped=235]
# Augmenting train:  11%|█         | 829/7752 [1:04:01<9:06:59,  4.74s/it, Written=10, Skipped=236]
# Augmenting train:  11%|█         | 830/7752 [1:04:01<11:10:33,  5.81s/it, Written=10, Skipped=236]
# Augmenting train:  11%|█         | 830/7752 [1:04:16<11:10:33,  5.81s/it, Written=10, Skipped=237]
# ...
# Augmenting train:  98%|█████████▊| 7624/7752 [11:35:51<26:35, 12.46s/it, Written=934, Skipped=2113]
# Augmenting train:  98%|█████████▊| 7624/7752 [11:36:11<26:35, 12.46s/it, Written=934, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7625/7752 [11:36:11<30:54, 14.60s/it, Written=934, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7625/7752 [11:36:19<30:54, 14.60s/it, Written=935, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7626/7752 [11:36:19<26:36, 12.67s/it, Written=935, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7626/7752 [11:36:26<26:36, 12.67s/it, Written=936, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7627/7752 [11:36:26<22:51, 10.97s/it, Written=936, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7627/7752 [11:36:33<22:51, 10.97s/it, Written=937, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7628/7752 [11:36:33<20:02,  9.70s/it, Written=937, Skipped=2114]
# Augmenting train:  98%|█████████▊| 7628/7752 [11:36:47<20:02,  9.70s/it, Written=937, Skipped=2115]
# Augmenting train:  98%|█████████▊| 7629/7752 [11:36:47<22:39, 11.05s/it, Written=937, Skipped=2115]
# Augmenting train:  98%|█████████▊| 7629/7752 [11:37:04<22:39, 11.05s/it, Written=937, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7630/7752 [11:37:04<26:28, 13.02s/it, Written=937, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7630/7752 [11:37:11<26:28, 13.02s/it, Written=938, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7631/7752 [11:37:11<22:25, 11.12s/it, Written=938, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7631/7752 [11:37:35<22:25, 11.12s/it, Written=939, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7632/7752 [11:37:35<29:49, 14.91s/it, Written=939, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7632/7752 [11:37:41<29:49, 14.91s/it, Written=940, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7633/7752 [11:37:41<24:19, 12.26s/it, Written=940, Skipped=2116]
# Augmenting train:  98%|█████████▊| 7633/7752 [11:37:55<24:19, 12.26s/it, Written=940, Skipped=2117]
# Augmenting train:  98%|█████████▊| 7634/7752 [11:37:55<25:08, 12.79s/it, Written=940, Skipped=2117]
# Augmenting train:  98%|█████████▊| 7634/7752 [11:38:02<25:08, 12.79s/it, Written=941, Skipped=2117]
# Augmenting train:  98%|█████████▊| 7635/7752 [11:38:02<21:38, 11.10s/it, Written=941, Skipped=2117]
# Augmenting train:  98%|█████████▊| 7635/7752 [11:38:09<21:38, 11.10s/it, Written=942, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7636/7752 [11:38:09<19:09,  9.91s/it, Written=942, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7636/7752 [11:38:19<19:09,  9.91s/it, Written=943, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7637/7752 [11:38:19<18:54,  9.87s/it, Written=943, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7637/7752 [11:38:26<18:54,  9.87s/it, Written=944, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7638/7752 [11:38:26<17:05,  8.99s/it, Written=944, Skipped=2117]
# Augmenting train:  99%|█████████▊| 7638/7752 [11:38:43<17:05,  8.99s/it, Written=944, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7639/7752 [11:38:43<21:37, 11.48s/it, Written=944, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7639/7752 [11:38:52<21:37, 11.48s/it, Written=945, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7640/7752 [11:38:52<20:01, 10.73s/it, Written=945, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7640/7752 [11:38:59<20:01, 10.73s/it, Written=946, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7641/7752 [11:38:59<17:42,  9.57s/it, Written=946, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7641/7752 [11:39:05<17:42,  9.57s/it, Written=947, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7642/7752 [11:39:06<15:47,  8.61s/it, Written=947, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7642/7752 [11:39:12<15:47,  8.61s/it, Written=948, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7643/7752 [11:39:12<14:39,  8.07s/it, Written=948, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7643/7752 [11:39:23<14:39,  8.07s/it, Written=949, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7644/7752 [11:39:23<16:04,  8.93s/it, Written=949, Skipped=2118]
# Augmenting train:  99%|█████████▊| 7644/7752 [11:39:39<16:04,  8.93s/it, Written=949, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7645/7752 [11:39:39<19:49, 11.12s/it, Written=949, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7645/7752 [11:39:44<19:49, 11.12s/it, Written=950, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7646/7752 [11:39:44<16:22,  9.27s/it, Written=950, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7646/7752 [11:39:51<16:22,  9.27s/it, Written=951, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7647/7752 [11:39:51<14:54,  8.52s/it, Written=951, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7647/7752 [11:40:03<14:54,  8.52s/it, Written=952, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7648/7752 [11:40:03<16:26,  9.48s/it, Written=952, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7648/7752 [11:40:09<16:26,  9.48s/it, Written=953, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7649/7752 [11:40:09<14:34,  8.49s/it, Written=953, Skipped=2119]
# Augmenting train:  99%|█████████▊| 7649/7752 [11:40:23<14:34,  8.49s/it, Written=953, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7650/7752 [11:40:23<17:20, 10.20s/it, Written=953, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7650/7752 [11:40:32<17:20, 10.20s/it, Written=954, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7651/7752 [11:40:32<16:10,  9.61s/it, Written=954, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7651/7752 [11:40:38<16:10,  9.61s/it, Written=955, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7652/7752 [11:40:38<14:18,  8.59s/it, Written=955, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7652/7752 [11:40:47<14:18,  8.59s/it, Written=956, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7653/7752 [11:40:47<14:31,  8.80s/it, Written=956, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7653/7752 [11:40:54<14:31,  8.80s/it, Written=957, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7654/7752 [11:40:54<13:41,  8.38s/it, Written=957, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7654/7752 [11:41:09<13:41,  8.38s/it, Written=958, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7655/7752 [11:41:09<16:31, 10.22s/it, Written=958, Skipped=2120]
# Augmenting train:  99%|█████████▊| 7655/7752 [11:41:14<16:31, 10.22s/it, Written=959, Skipped=2120]
# Augmenting train:  99%|█████████▉| 7656/7752 [11:41:14<13:57,  8.73s/it, Written=959, Skipped=2120]
# Augmenting train:  99%|█████████▉| 7656/7752 [11:41:22<13:57,  8.73s/it, Written=960, Skipped=2120]
# Augmenting train:  99%|█████████▉| 7657/7752 [11:41:22<13:23,  8.46s/it, Written=960, Skipped=2120]
# Augmenting train:  99%|█████████▉| 7657/7752 [11:41:37<13:23,  8.46s/it, Written=960, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7658/7752 [11:41:37<16:14, 10.37s/it, Written=960, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7658/7752 [11:41:45<16:14, 10.37s/it, Written=961, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7659/7752 [11:41:45<14:59,  9.68s/it, Written=961, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7659/7752 [11:41:52<14:59,  9.68s/it, Written=962, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7660/7752 [11:41:52<13:31,  8.82s/it, Written=962, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7660/7752 [11:42:00<13:31,  8.82s/it, Written=963, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7661/7752 [11:42:00<13:02,  8.60s/it, Written=963, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7661/7752 [11:42:07<13:02,  8.60s/it, Written=964, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7662/7752 [11:42:07<12:21,  8.24s/it, Written=964, Skipped=2121]
# Augmenting train:  99%|█████████▉| 7662/7752 [11:42:26<12:21,  8.24s/it, Written=964, Skipped=2122]
# Augmenting train:  99%|█████████▉| 7663/7752 [11:42:26<16:59, 11.45s/it, Written=964, Skipped=2122]
# Augmenting train:  99%|█████████▉| 7663/7752 [11:42:43<16:59, 11.45s/it, Written=964, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7664/7752 [11:42:43<19:22, 13.21s/it, Written=964, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7664/7752 [11:42:51<19:22, 13.21s/it, Written=965, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7665/7752 [11:42:51<16:45, 11.56s/it, Written=965, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7665/7752 [11:43:06<16:45, 11.56s/it, Written=966, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7666/7752 [11:43:06<17:58, 12.54s/it, Written=966, Skipped=2123]
# Augmenting train:  99%|█████████▉| 7666/7752 [11:43:20<17:58, 12.54s/it, Written=966, Skipped=2124]
# Augmenting train:  99%|█████████▉| 7667/7752 [11:43:20<18:25, 13.01s/it, Written=966, Skipped=2124]
# Augmenting train:  99%|█████████▉| 7667/7752 [11:43:39<18:25, 13.01s/it, Written=966, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7668/7752 [11:43:39<20:49, 14.87s/it, Written=966, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7668/7752 [11:43:51<20:49, 14.87s/it, Written=967, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7668/7752 [11:44:03<20:49, 14.87s/it, Written=968, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7669/7752 [11:44:03<24:08, 17.45s/it, Written=968, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7669/7752 [11:44:13<24:08, 17.45s/it, Written=969, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7670/7752 [11:44:13<20:54, 15.30s/it, Written=969, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7670/7752 [11:44:23<20:54, 15.30s/it, Written=970, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7671/7752 [11:44:23<18:32, 13.73s/it, Written=970, Skipped=2125]
# Augmenting train:  99%|█████████▉| 7671/7752 [11:44:37<18:32, 13.73s/it, Written=970, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7672/7752 [11:44:37<18:20, 13.76s/it, Written=970, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7672/7752 [11:44:45<18:20, 13.76s/it, Written=971, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7673/7752 [11:44:45<15:52, 12.06s/it, Written=971, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7673/7752 [11:45:03<15:52, 12.06s/it, Written=972, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7674/7752 [11:45:03<17:54, 13.78s/it, Written=972, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7674/7752 [11:45:09<17:54, 13.78s/it, Written=973, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7675/7752 [11:45:09<14:38, 11.41s/it, Written=973, Skipped=2126]
# Augmenting train:  99%|█████████▉| 7675/7752 [11:45:24<14:38, 11.41s/it, Written=973, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7676/7752 [11:45:24<15:46, 12.45s/it, Written=973, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7676/7752 [11:45:29<15:46, 12.45s/it, Written=974, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7677/7752 [11:45:29<12:53, 10.31s/it, Written=974, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7677/7752 [11:45:38<12:53, 10.31s/it, Written=975, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7678/7752 [11:45:38<12:11,  9.88s/it, Written=975, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7678/7752 [11:45:47<12:11,  9.88s/it, Written=976, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7679/7752 [11:45:47<11:49,  9.72s/it, Written=976, Skipped=2127]
# Augmenting train:  99%|█████████▉| 7679/7752 [11:46:06<11:49,  9.72s/it, Written=976, Skipped=2128]
# Augmenting train:  99%|█████████▉| 7680/7752 [11:46:06<14:55, 12.44s/it, Written=976, Skipped=2128]
# Augmenting train:  99%|█████████▉| 7680/7752 [11:46:18<14:55, 12.44s/it, Written=976, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7681/7752 [11:46:18<14:35, 12.33s/it, Written=976, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7681/7752 [11:46:23<14:35, 12.33s/it, Written=977, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7682/7752 [11:46:23<11:56, 10.23s/it, Written=977, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7682/7752 [11:46:34<11:56, 10.23s/it, Written=978, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7683/7752 [11:46:34<11:55, 10.37s/it, Written=978, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7683/7752 [11:46:39<11:55, 10.37s/it, Written=979, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7684/7752 [11:46:39<09:54,  8.74s/it, Written=979, Skipped=2129]
# Augmenting train:  99%|█████████▉| 7684/7752 [11:46:53<09:54,  8.74s/it, Written=979, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7685/7752 [11:46:53<11:35, 10.38s/it, Written=979, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7685/7752 [11:47:00<11:35, 10.38s/it, Written=980, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7686/7752 [11:47:00<10:18,  9.38s/it, Written=980, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7686/7752 [11:47:10<10:18,  9.38s/it, Written=981, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7687/7752 [11:47:10<10:18,  9.52s/it, Written=981, Skipped=2130]
# Augmenting train:  99%|█████████▉| 7687/7752 [11:47:30<10:18,  9.52s/it, Written=981, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7688/7752 [11:47:30<13:29, 12.65s/it, Written=981, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7688/7752 [11:47:38<13:29, 12.65s/it, Written=982, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7689/7752 [11:47:38<11:39, 11.10s/it, Written=982, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7689/7752 [11:47:45<11:39, 11.10s/it, Written=983, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7690/7752 [11:47:45<10:15,  9.93s/it, Written=983, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7690/7752 [11:47:51<10:15,  9.93s/it, Written=984, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7691/7752 [11:47:51<08:51,  8.71s/it, Written=984, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7691/7752 [11:48:06<08:51,  8.71s/it, Written=985, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7692/7752 [11:48:06<10:35, 10.59s/it, Written=985, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7692/7752 [11:48:12<10:35, 10.59s/it, Written=986, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7693/7752 [11:48:12<09:16,  9.43s/it, Written=986, Skipped=2131]
# Augmenting train:  99%|█████████▉| 7693/7752 [11:48:28<09:16,  9.43s/it, Written=986, Skipped=2132]
# Augmenting train:  99%|█████████▉| 7694/7752 [11:48:28<10:51, 11.23s/it, Written=986, Skipped=2132]
# Augmenting train:  99%|█████████▉| 7694/7752 [11:48:42<10:51, 11.23s/it, Written=986, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7695/7752 [11:48:42<11:38, 12.25s/it, Written=986, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7695/7752 [11:48:51<11:38, 12.25s/it, Written=987, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7696/7752 [11:48:51<10:18, 11.05s/it, Written=987, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7696/7752 [11:49:04<10:18, 11.05s/it, Written=988, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7697/7752 [11:49:04<10:48, 11.80s/it, Written=988, Skipped=2133]
# Augmenting train:  99%|█████████▉| 7697/7752 [11:49:16<10:48, 11.80s/it, Written=988, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7698/7752 [11:49:16<10:45, 11.96s/it, Written=988, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7698/7752 [11:49:23<10:45, 11.96s/it, Written=989, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7699/7752 [11:49:23<09:10, 10.40s/it, Written=989, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7699/7752 [11:49:32<09:10, 10.40s/it, Written=990, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7700/7752 [11:49:32<08:33,  9.87s/it, Written=990, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7700/7752 [11:49:40<08:33,  9.87s/it, Written=991, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7701/7752 [11:49:40<07:55,  9.31s/it, Written=991, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7701/7752 [11:49:46<07:55,  9.31s/it, Written=992, Skipped=2134]
# Augmenting train:  99%|█████████▉| 7702/7752 [11:49:46<04:36,  5.53s/it, Written=992, Skipped=2134]
# ⚠️ REACHED 11.85 HOURS. GRACEFULLY STOPPING.
# 📊 Stats this run -> Written: 992 | Skipped: 2134
# 💾 Files safely saved to: /kaggle/working/augmented
