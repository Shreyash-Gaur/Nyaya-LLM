# %%
# !pip install jsonschema transformers accelerate sentencepiece bitsandbytes tiktoken -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 30.8 MB/s eta 0:00:00

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
# Add these tokens in Kaggle's "Secrets" tab (Add-ons -> Secrets)
login(token=user_secrets.get_secret("HF_TOKEN"))

# %%
"""
==============================================================
Nyaya-LLM  —  Phase 2 Dataset Augmentation (Kaggle / P100)
==============================================================
Augments all three splits (train, val, test) using a
HuggingFace model loaded directly on the P100 GPU.

Long sections (>3000 chars) are chunked at subsection
boundaries so every part of the statute gets covered.
==============================================================
"""

import json
import re
import os
import time
import torch
import shutil
import gc
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from jsonschema import validate, ValidationError

# ==============================
# ⚙️  CONFIG
# ==============================
MODEL_NAME = "Qwen/Qwen2.5-7B-Instruct"

# ── Paths ───────────────────────────────────────────────────
INPUT_DIR  = "/kaggle/input/datasets/shreyashgaur221/nyaya-llm-processed"
OUTPUT_DIR = "/kaggle/working/augmented"
WIP_DATASET_PATH = "/kaggle/input/datasets/shreyashgaur221/nyaya-augmented-wip" # For Run 2+

SPLITS = {
    "train": "all_acts_train.jsonl",
    "val":   "all_acts_val.jsonl",
    "test":  "all_acts_test.jsonl",
}

# ── Processing Limits ───────────────────────────────────────
CHUNK_SIZE  = 3000    
RETRY_LIMIT = 3       
MAX_RUNTIME_HOURS = 11.80

# ==============================
# 📦  JSON SCHEMA
# ==============================
AUGMENT_SCHEMA = {
    "type": "object",
    "properties": {
        "instruction": {"type": "string"},
        "input":       {"type": "string"},
        "output":      {"type": "string"}
    },
    "required": ["instruction", "input", "output"]
}

# ==============================
# 💬  PROMPT (CHAT TEMPLATE)
# ==============================
SYSTEM_PROMPT = """You are a strict Indian legal dataset generator.

RULES:
1. Only use the provided statute text. Do NOT add outside legal knowledge.
2. Do NOT invent punishments, sections, or acts not mentioned in the text.
3. Output STRICT JSON only. No markdown, no explanation, no preamble.
4. Return exactly ONE valid JSON object.
5. The instruction must be a realistic question a layperson or law student would ask.
6. The output must apply or explain the statute — not just quote it verbatim."""

def build_messages(original_instruction: str, chunk: str) -> list:
    user_msg = f"""ORIGINAL INSTRUCTION:
{original_instruction}

STATUTE TEXT:
{chunk}

---
Generate a new, enriched training example that:
- Asks a reasoning or application question about this statute text
- Answers it using ONLY the information in the statute text above
- Does NOT reference sections or provisions outside the text above

Respond ONLY with this JSON format, nothing else:
{{
  "instruction": "...",
  "input": "",
  "output": "..."
}}"""

    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": user_msg}
    ]

# ==============================
# ✂️  CHUNKER
# ==============================
def chunk_text(text: str, max_chars: int = CHUNK_SIZE) -> list:
    if len(text) <= max_chars:
        return [text]

    parts   = text.split("\n\n")
    chunks  = []
    current = ""

    for part in parts:
        if len(part) > max_chars:
            if current:
                chunks.append(current.strip())
                current = ""
            sentences = re.split(r'(?<=[.;])\s+', part)
            for sentence in sentences:
                if len(current) + len(sentence) <= max_chars:
                    current += " " + sentence
                else:
                    if current:
                        chunks.append(current.strip())
                    current = sentence
        elif len(current) + len(part) + 2 <= max_chars:
            current += "\n\n" + part
        else:
            if current:
                chunks.append(current.strip())
            current = part

    if current:
        chunks.append(current.strip())

    return [c for c in chunks if len(c) >= 50]

# ==============================
# 🤖  MODEL LOADING
# ==============================
def load_model():
    print(f"Loading {MODEL_NAME} in 4-bit on GPU...")

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16, 
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4"
    )

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=bnb_config,
        device_map="auto",
        torch_dtype=torch.float16,
        trust_remote_code=True
    )
    model.eval()
    print("Model loaded.\n")
    return model, tokenizer

# ==============================
# 🔁  GENERATION (WITH OOM KILLER)
# ==============================
def generate(model, tokenizer, messages: list) -> str:
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=2048
    ).to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1024,
            temperature=0.2,
            do_sample=True,
            top_p=0.8,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id
        )

    new_tokens = outputs[0][inputs["input_ids"].shape[1]:]
    result = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()
    
    del inputs
    del outputs
    del new_tokens
    torch.cuda.empty_cache()
    gc.collect()
    
    return result

# ==============================
# 🔍  JSON EXTRACTION
# ==============================
def extract_json(text: str):
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if not match:
        return None
    try:
        return json.loads(match.group())
    except Exception:
        return None

# ==============================
# 🛡️  HALLUCINATION GUARD (FIXED)
# ==============================
def hallucination_guard(original_text: str, generated_output: str) -> bool:
    out_lower  = generated_output.lower()
    orig_lower = original_text.lower()

    # Lexical overlap only — remove the strict act/section requirement
    orig_words  = set(orig_lower.split())
    gen_words   = set(out_lower.split())
    overlap     = len(orig_words & gen_words)

    # Just needs reasonable overlap with source text
    return overlap > 10

# ==============================
# 💾  CHECKPOINT HELPER
# ==============================
def load_processed_keys(output_path: str) -> set:
    processed = set()
    if os.path.exists(output_path):
        with open(output_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    obj = json.loads(line)
                    key = (obj.get("source_instruction", ""), obj.get("chunk_index", 0))
                    processed.add(key)
                except Exception:
                    pass
    return processed

# ==============================
# 🚀  MAIN
# ==============================
def main():
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # --- RUN 2 RESTORATION LOGIC ---
    if os.path.exists(WIP_DATASET_PATH):
        print("Restoring previous progress from WIP dataset...")
        for filename in os.listdir(WIP_DATASET_PATH):
            if filename.endswith(".jsonl"):
                src = os.path.join(WIP_DATASET_PATH, filename)
                dst = os.path.join(OUTPUT_DIR, filename)
                shutil.copy2(src, dst)
                print(f"✅ Restored: {filename}")
        print("Ready to resume!\n")
    # -------------------------------
    
    START_TIME = time.time()
    MAX_RUNTIME_SEC = MAX_RUNTIME_HOURS * 3600 

    model, tokenizer = load_model()

    total_written = 0
    total_skipped = 0

    for split_name, filename in SPLITS.items():
        input_path  = os.path.join(INPUT_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, f"all_acts_{split_name}_augmented.jsonl")

        if not os.path.exists(input_path):
            print(f"⚠️  {input_path} not found — skipping {split_name}")
            continue

        with open(input_path, "r", encoding="utf-8") as f:
            data = [json.loads(line) for line in f]

        processed_keys = load_processed_keys(output_path)
        total_chunks = sum(len(chunk_text(d["output"])) for d in data)

        print(f"\n{'='*60}")
        print(f"📂  Split         : {split_name.upper()}")
        print(f"    Samples       : {len(data)}")
        print(f"    Total chunks  : {total_chunks}")
        print(f"    Already done  : {len(processed_keys)}")
        print(f"    Remaining     : {total_chunks - len(processed_keys)}")
        print(f"{'='*60}\n")

        split_written = 0
        split_skipped = 0

        pbar = tqdm(data, desc=f"Augmenting {split_name}")
        with open(output_path, "a", encoding="utf-8") as outfile:
            for example in pbar:
                instruction = example["instruction"]
                chunks      = chunk_text(example["output"])

                for chunk_idx, chunk in enumerate(chunks):
                    
                    if time.time() - START_TIME > MAX_RUNTIME_SEC:
                        print(f"\n⚠️ REACHED {MAX_RUNTIME_HOURS} HOURS. GRACEFULLY STOPPING.")
                        print(f"📊 Stats this run -> Written: {split_written} | Skipped: {split_skipped}")
                        print(f"💾 Files safely saved to: {OUTPUT_DIR}")
                        return 
                    
                    key = (instruction, chunk_idx)

                    if key in processed_keys:
                        continue

                    retries = 0
                    success = False

                    while retries < RETRY_LIMIT and not success:
                        try:
                            messages = build_messages(instruction, chunk)
                            raw      = generate(model, tokenizer, messages)
                            parsed   = extract_json(raw)

                            if parsed is None:
                                raise ValueError("No JSON found")

                            validate(instance=parsed, schema=AUGMENT_SCHEMA)

                            if not hallucination_guard(chunk, parsed["output"]):
                                raise ValueError("Hallucination guard failed")

                            parsed["source_instruction"] = instruction
                            parsed["chunk_index"]        = chunk_idx
                            parsed["total_chunks"]       = len(chunks)
                            parsed["split"]              = split_name

                            outfile.write(json.dumps(parsed, ensure_ascii=False) + "\n")
                            outfile.flush()
                            success       = True
                            split_written += 1

                        except (ValidationError, ValueError):
                            retries += 1
                            time.sleep(0.5)
                        except Exception as e:
                            print(f"\n❌ Unexpected error: {e}")
                            retries += 1
                            time.sleep(1)

                    if not success:
                        split_skipped += 1
                        
                    # LIVE TRACKER: Updates the progress bar with real-time stats!
                    pbar.set_postfix({"Written": split_written, "Skipped": split_skipped})

        total_written += split_written
        total_skipped += split_skipped

        print(f"\n✅  {split_name} done")
        print(f"    Written : {split_written}")
        print(f"    Skipped : {split_skipped}")
        print(f"    Saved   : {output_path}")

    print(f"\n{'='*60}")
    print(f"🏁  AUGMENTATION COMPLETE")
    print(f"    Total written : {total_written}")
    print(f"    Total skipped : {total_skipped}")
    print(f"    Output dir    : {OUTPUT_DIR}")
    print(f"{'='*60}")

if __name__ == "__main__":
    main()
# Out:
# Restoring previous progress from WIP dataset...
# ✅ Restored: all_acts_train_augmented.jsonl
# Ready to resume!
#
# Loading Qwen/Qwen2.5-7B-Instruct in 4-bit on GPU...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded.
#
#
# ============================================================
# 📂  Split         : TRAIN
#     Samples       : 7752
#     Total chunks  : 7935
#     Already done  : 3566
#     Remaining     : 4369
# ============================================================
# Augmenting train:   0%|          | 0/7752 [00:00<?, ?it/s]
# Augmenting train:   0%|          | 0/7752 [00:17<?, ?it/s, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:17<38:43:34, 17.99s/it, Written=0, Skipped=1]
# Augmenting train:   0%|          | 1/7752 [00:33<38:43:34, 17.99s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:33<22:36:56, 10.51s/it, Written=0, Skipped=2]
# Augmenting train:   0%|          | 3/7752 [00:50<22:36:56, 10.51s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [00:50<11:31:41,  5.36s/it, Written=0, Skipped=3]
# Augmenting train:   0%|          | 8/7752 [01:05<11:31:41,  5.36s/it, Written=0, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [01:05<2:54:18,  1.35s/it, Written=0, Skipped=4]
# Augmenting train:   0%|          | 33/7752 [01:21<2:54:18,  1.35s/it, Written=0, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:21<3:59:33,  1.86s/it, Written=0, Skipped=5]
# Augmenting train:   0%|          | 36/7752 [01:43<3:59:33,  1.86s/it, Written=0, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [01:43<6:28:29,  3.02s/it, Written=0, Skipped=6]
# Augmenting train:   0%|          | 37/7752 [02:01<6:28:29,  3.02s/it, Written=0, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [02:01<7:11:27,  3.36s/it, Written=0, Skipped=7]
# Augmenting train:   1%|          | 41/7752 [02:19<7:11:27,  3.36s/it, Written=0, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:19<7:17:49,  3.41s/it, Written=0, Skipped=8]
# Augmenting train:   1%|          | 46/7752 [02:35<7:17:49,  3.41s/it, Written=0, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:35<8:45:50,  4.10s/it, Written=0, Skipped=9]
# Augmenting train:   1%|          | 48/7752 [02:54<8:45:50,  4.10s/it, Written=0, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [02:54<6:20:48,  2.97s/it, Written=0, Skipped=10]
# Augmenting train:   1%|          | 58/7752 [03:09<6:20:48,  2.97s/it, Written=0, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [03:09<6:42:16,  3.14s/it, Written=0, Skipped=11]
# Augmenting train:   1%|          | 62/7752 [03:25<6:42:16,  3.14s/it, Written=0, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:25<7:39:47,  3.59s/it, Written=0, Skipped=12]
# Augmenting train:   1%|          | 65/7752 [03:40<7:39:47,  3.59s/it, Written=0, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [03:40<8:55:22,  4.18s/it, Written=0, Skipped=13]
# Augmenting train:   1%|          | 67/7752 [03:55<8:55:22,  4.18s/it, Written=0, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [03:55<11:13:56,  5.26s/it, Written=0, Skipped=14]
# Augmenting train:   1%|          | 68/7752 [04:07<11:13:56,  5.26s/it, Written=0, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [04:07<13:09:27,  6.17s/it, Written=0, Skipped=15]
# Augmenting train:   1%|          | 69/7752 [04:23<13:09:27,  6.17s/it, Written=0, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:23<14:04:46,  6.60s/it, Written=0, Skipped=16]
# Augmenting train:   1%|          | 71/7752 [04:41<14:04:46,  6.60s/it, Written=0, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [04:41<15:34:21,  7.30s/it, Written=0, Skipped=17]
# Augmenting train:   1%|          | 73/7752 [04:58<15:34:21,  7.30s/it, Written=0, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [04:58<10:28:21,  4.91s/it, Written=0, Skipped=18]
# Augmenting train:   1%|          | 79/7752 [05:10<10:28:21,  4.91s/it, Written=0, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [05:10<7:41:26,  3.61s/it, Written=0, Skipped=19]
# Augmenting train:   1%|          | 85/7752 [05:26<7:41:26,  3.61s/it, Written=0, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [05:26<6:30:54,  3.06s/it, Written=0, Skipped=20]
# Augmenting train:   1%|          | 92/7752 [05:49<6:30:54,  3.06s/it, Written=0, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [05:49<7:26:23,  3.50s/it, Written=0, Skipped=21]
# Augmenting train:   1%|▏         | 97/7752 [06:05<7:26:23,  3.50s/it, Written=0, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [06:05<8:21:37,  3.93s/it, Written=0, Skipped=22]
# Augmenting train:   1%|▏         | 100/7752 [06:22<8:21:37,  3.93s/it, Written=0, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [06:22<7:54:37,  3.72s/it, Written=0, Skipped=23]
# Augmenting train:   1%|▏         | 105/7752 [06:37<7:54:37,  3.72s/it, Written=0, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [06:37<8:29:02,  4.00s/it, Written=0, Skipped=24]
# Augmenting train:   1%|▏         | 108/7752 [06:54<8:29:02,  4.00s/it, Written=0, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [06:54<7:07:47,  3.36s/it, Written=0, Skipped=25]
# Augmenting train:   1%|▏         | 115/7752 [07:16<7:07:47,  3.36s/it, Written=1, Skipped=25]
# Augmenting train:   2%|▏         | 119/7752 [07:16<8:11:39,  3.86s/it, Written=1, Skipped=25]
# Augmenting train:   2%|▏         | 119/7752 [07:33<8:11:39,  3.86s/it, Written=1, Skipped=26]
# Augmenting train:   2%|▏         | 121/7752 [07:33<9:48:58,  4.63s/it, Written=1, Skipped=26]
# Augmenting train:   2%|▏         | 121/7752 [07:51<9:48:58,  4.63s/it, Written=1, Skipped=27]
# Augmenting train:   2%|▏         | 123/7752 [07:51<11:26:47,  5.40s/it, Written=1, Skipped=27]
# Augmenting train:   2%|▏         | 123/7752 [08:15<11:26:47,  5.40s/it, Written=1, Skipped=28]
# Augmenting train:   2%|▏         | 124/7752 [08:15<16:00:59,  7.56s/it, Written=1, Skipped=28]
# Augmenting train:   2%|▏         | 124/7752 [08:32<16:00:59,  7.56s/it, Written=1, Skipped=29]
# Augmenting train:   2%|▏         | 126/7752 [08:32<16:29:16,  7.78s/it, Written=1, Skipped=29]
# Augmenting train:   2%|▏         | 126/7752 [08:47<16:29:16,  7.78s/it, Written=1, Skipped=30]
# Augmenting train:   2%|▏         | 128/7752 [08:47<16:13:15,  7.66s/it, Written=1, Skipped=30]
# Augmenting train:   2%|▏         | 128/7752 [09:03<16:13:15,  7.66s/it, Written=1, Skipped=31]
# Augmenting train:   2%|▏         | 138/7752 [09:03<7:50:01,  3.70s/it, Written=1, Skipped=31]
# Augmenting train:   2%|▏         | 138/7752 [09:18<7:50:01,  3.70s/it, Written=1, Skipped=32]
# Augmenting train:   2%|▏         | 139/7752 [09:18<10:01:31,  4.74s/it, Written=1, Skipped=32]
# Augmenting train:   2%|▏         | 139/7752 [09:38<10:01:31,  4.74s/it, Written=1, Skipped=33]
# Augmenting train:   2%|▏         | 140/7752 [09:38<13:20:33,  6.31s/it, Written=1, Skipped=33]
# Augmenting train:   2%|▏         | 140/7752 [09:54<13:20:33,  6.31s/it, Written=1, Skipped=34]
# Augmenting train:   2%|▏         | 145/7752 [09:54<10:28:44,  4.96s/it, Written=1, Skipped=34]
# Augmenting train:   2%|▏         | 145/7752 [10:18<10:28:44,  4.96s/it, Written=1, Skipped=35]
# Augmenting train:   2%|▏         | 146/7752 [10:18<14:58:23,  7.09s/it, Written=1, Skipped=35]
# Augmenting train:   2%|▏         | 146/7752 [10:36<14:58:23,  7.09s/it, Written=1, Skipped=36]
# Augmenting train:   2%|▏         | 147/7752 [10:36<18:02:57,  8.54s/it, Written=1, Skipped=36]
# Augmenting train:   2%|▏         | 147/7752 [10:51<18:02:57,  8.54s/it, Written=1, Skipped=37]
# Augmenting train:   2%|▏         | 149/7752 [10:51<17:28:11,  8.27s/it, Written=1, Skipped=37]
# Augmenting train:   2%|▏         | 149/7752 [11:12<17:28:11,  8.27s/it, Written=1, Skipped=38]
# Augmenting train:   2%|▏         | 151/7752 [11:12<18:50:00,  8.92s/it, Written=1, Skipped=38]
# Augmenting train:   2%|▏         | 151/7752 [11:28<18:50:00,  8.92s/it, Written=1, Skipped=39]
# Augmenting train:   2%|▏         | 153/7752 [11:28<18:25:04,  8.73s/it, Written=1, Skipped=39]
# Augmenting train:   2%|▏         | 153/7752 [11:44<18:25:04,  8.73s/it, Written=1, Skipped=40]
# Augmenting train:   2%|▏         | 155/7752 [11:44<17:48:26,  8.44s/it, Written=1, Skipped=40]
# Augmenting train:   2%|▏         | 155/7752 [12:00<17:48:26,  8.44s/it, Written=1, Skipped=41]
# Augmenting train:   2%|▏         | 156/7752 [12:00<20:33:00,  9.74s/it, Written=1, Skipped=41]
# Augmenting train:   2%|▏         | 156/7752 [12:13<20:33:00,  9.74s/it, Written=2, Skipped=41]
# Augmenting train:   2%|▏         | 157/7752 [12:13<22:05:42, 10.47s/it, Written=2, Skipped=41]
# Augmenting train:   2%|▏         | 157/7752 [12:28<22:05:42, 10.47s/it, Written=2, Skipped=42]
# Augmenting train:   2%|▏         | 161/7752 [12:28<14:26:16,  6.85s/it, Written=2, Skipped=42]
# Augmenting train:   2%|▏         | 161/7752 [12:43<14:26:16,  6.85s/it, Written=2, Skipped=43]
# Augmenting train:   2%|▏         | 163/7752 [12:43<14:45:42,  7.00s/it, Written=2, Skipped=43]
# Augmenting train:   2%|▏         | 163/7752 [12:59<14:45:42,  7.00s/it, Written=2, Skipped=44]
# Augmenting train:   2%|▏         | 165/7752 [12:59<15:21:51,  7.29s/it, Written=2, Skipped=44]
# Augmenting train:   2%|▏         | 165/7752 [13:16<15:21:51,  7.29s/it, Written=2, Skipped=45]
# Augmenting train:   2%|▏         | 167/7752 [13:16<16:18:01,  7.74s/it, Written=2, Skipped=45]
# Augmenting train:   2%|▏         | 167/7752 [13:33<16:18:01,  7.74s/it, Written=2, Skipped=46]
# Augmenting train:   2%|▏         | 170/7752 [13:33<14:27:02,  6.86s/it, Written=2, Skipped=46]
# Augmenting train:   2%|▏         | 170/7752 [13:53<14:27:02,  6.86s/it, Written=2, Skipped=47]
# Augmenting train:   2%|▏         | 175/7752 [13:53<11:32:32,  5.48s/it, Written=2, Skipped=47]
# Augmenting train:   2%|▏         | 175/7752 [14:11<11:32:32,  5.48s/it, Written=2, Skipped=48]
# Augmenting train:   2%|▏         | 180/7752 [14:11<10:02:09,  4.77s/it, Written=2, Skipped=48]
# Augmenting train:   2%|▏         | 180/7752 [14:27<10:02:09,  4.77s/it, Written=2, Skipped=49]
# Augmenting train:   2%|▏         | 182/7752 [14:27<11:12:38,  5.33s/it, Written=2, Skipped=49]
# Augmenting train:   2%|▏         | 182/7752 [14:44<11:12:38,  5.33s/it, Written=2, Skipped=50]
# Augmenting train:   2%|▏         | 183/7752 [14:44<14:09:49,  6.74s/it, Written=2, Skipped=50]
# Augmenting train:   2%|▏         | 183/7752 [14:59<14:09:49,  6.74s/it, Written=2, Skipped=51]
# Augmenting train:   2%|▏         | 187/7752 [14:59<11:43:01,  5.58s/it, Written=2, Skipped=51]
# Augmenting train:   2%|▏         | 187/7752 [15:14<11:43:01,  5.58s/it, Written=2, Skipped=52]
# Augmenting train:   2%|▏         | 188/7752 [15:14<14:01:54,  6.68s/it, Written=2, Skipped=52]
# Augmenting train:   2%|▏         | 188/7752 [15:28<14:01:54,  6.68s/it, Written=2, Skipped=53]
# Augmenting train:   3%|▎         | 195/7752 [15:28<8:32:39,  4.07s/it, Written=2, Skipped=53]
# Augmenting train:   3%|▎         | 195/7752 [15:44<8:32:39,  4.07s/it, Written=2, Skipped=54]
# Augmenting train:   3%|▎         | 199/7752 [15:44<8:32:43,  4.07s/it, Written=2, Skipped=54]
# Augmenting train:   3%|▎         | 199/7752 [16:00<8:32:43,  4.07s/it, Written=2, Skipped=55]
# Augmenting train:   3%|▎         | 200/7752 [16:00<11:02:40,  5.26s/it, Written=2, Skipped=55]
# Augmenting train:   3%|▎         | 200/7752 [16:13<11:02:40,  5.26s/it, Written=2, Skipped=56]
# Augmenting train:   3%|▎         | 206/7752 [16:13<8:02:24,  3.84s/it, Written=2, Skipped=56]
# Augmenting train:   3%|▎         | 206/7752 [16:32<8:02:24,  3.84s/it, Written=2, Skipped=57]
# Augmenting train:   3%|▎         | 212/7752 [16:32<7:25:47,  3.55s/it, Written=2, Skipped=57]
# Augmenting train:   3%|▎         | 212/7752 [16:49<7:25:47,  3.55s/it, Written=2, Skipped=58]
# Augmenting train:   3%|▎         | 214/7752 [16:49<9:07:35,  4.36s/it, Written=2, Skipped=58]
# Augmenting train:   3%|▎         | 214/7752 [17:04<9:07:35,  4.36s/it, Written=2, Skipped=59]
# Augmenting train:   3%|▎         | 216/7752 [17:04<10:22:15,  4.95s/it, Written=2, Skipped=59]
# Augmenting train:   3%|▎         | 216/7752 [17:20<10:22:15,  4.95s/it, Written=2, Skipped=60]
# Augmenting train:   3%|▎         | 218/7752 [17:20<11:46:31,  5.63s/it, Written=2, Skipped=60]
# Augmenting train:   3%|▎         | 218/7752 [17:44<11:46:31,  5.63s/it, Written=2, Skipped=61]
# Augmenting train:   3%|▎         | 222/7752 [17:44<12:00:45,  5.74s/it, Written=2, Skipped=61]
# Augmenting train:   3%|▎         | 222/7752 [18:02<12:00:45,  5.74s/it, Written=2, Skipped=62]
# Augmenting train:   3%|▎         | 223/7752 [18:02<15:06:30,  7.22s/it, Written=2, Skipped=62]
# Augmenting train:   3%|▎         | 223/7752 [18:19<15:06:30,  7.22s/it, Written=2, Skipped=63]
# Augmenting train:   3%|▎         | 224/7752 [18:19<17:57:05,  8.58s/it, Written=2, Skipped=63]
# Augmenting train:   3%|▎         | 224/7752 [18:34<17:57:05,  8.58s/it, Written=2, Skipped=64]
# Augmenting train:   3%|▎         | 226/7752 [18:34<17:22:22,  8.31s/it, Written=2, Skipped=64]
# Augmenting train:   3%|▎         | 226/7752 [18:50<17:22:22,  8.31s/it, Written=2, Skipped=65]
# Augmenting train:   3%|▎         | 229/7752 [18:50<14:50:47,  7.10s/it, Written=2, Skipped=65]
# Augmenting train:   3%|▎         | 229/7752 [19:08<14:50:47,  7.10s/it, Written=2, Skipped=66]
# Augmenting train:   3%|▎         | 232/7752 [19:08<14:04:28,  6.74s/it, Written=2, Skipped=66]
# Augmenting train:   3%|▎         | 232/7752 [19:29<14:04:28,  6.74s/it, Written=2, Skipped=67]
# Augmenting train:   3%|▎         | 235/7752 [19:29<14:12:11,  6.80s/it, Written=2, Skipped=67]
# Augmenting train:   3%|▎         | 235/7752 [19:44<14:12:11,  6.80s/it, Written=2, Skipped=68]
# Augmenting train:   3%|▎         | 236/7752 [19:44<16:39:21,  7.98s/it, Written=2, Skipped=68]
# Augmenting train:   3%|▎         | 236/7752 [19:59<16:39:21,  7.98s/it, Written=2, Skipped=69]
# Augmenting train:   3%|▎         | 243/7752 [19:59<9:37:38,  4.62s/it, Written=2, Skipped=69]
# Augmenting train:   3%|▎         | 243/7752 [20:14<9:37:38,  4.62s/it, Written=2, Skipped=70]
# Augmenting train:   3%|▎         | 244/7752 [20:14<11:42:57,  5.62s/it, Written=2, Skipped=70]
# Augmenting train:   3%|▎         | 244/7752 [20:33<11:42:57,  5.62s/it, Written=2, Skipped=71]
# Augmenting train:   3%|▎         | 245/7752 [20:33<15:34:29,  7.47s/it, Written=2, Skipped=71]
# Augmenting train:   3%|▎         | 245/7752 [20:49<15:34:29,  7.47s/it, Written=2, Skipped=72]
# Augmenting train:   3%|▎         | 247/7752 [20:49<15:51:54,  7.61s/it, Written=2, Skipped=72]
# Augmenting train:   3%|▎         | 247/7752 [21:04<15:51:54,  7.61s/it, Written=2, Skipped=73]
# Augmenting train:   3%|▎         | 250/7752 [21:04<13:47:58,  6.62s/it, Written=2, Skipped=73]
# Augmenting train:   3%|▎         | 250/7752 [21:19<13:47:58,  6.62s/it, Written=2, Skipped=74]
# Augmenting train:   3%|▎         | 252/7752 [21:19<14:16:40,  6.85s/it, Written=2, Skipped=74]
# Augmenting train:   3%|▎         | 252/7752 [21:38<14:16:40,  6.85s/it, Written=2, Skipped=75]
# Augmenting train:   3%|▎         | 253/7752 [21:38<18:10:59,  8.73s/it, Written=2, Skipped=75]
# Augmenting train:   3%|▎         | 253/7752 [21:57<18:10:59,  8.73s/it, Written=2, Skipped=76]
# Augmenting train:   3%|▎         | 257/7752 [21:57<14:24:52,  6.92s/it, Written=2, Skipped=76]
# Augmenting train:   3%|▎         | 257/7752 [22:15<14:24:52,  6.92s/it, Written=2, Skipped=77]
# Augmenting train:   3%|▎         | 259/7752 [22:15<15:16:50,  7.34s/it, Written=2, Skipped=77]
# Augmenting train:   3%|▎         | 259/7752 [22:31<15:16:50,  7.34s/it, Written=2, Skipped=78]
# Augmenting train:   3%|▎         | 261/7752 [22:31<15:36:59,  7.50s/it, Written=2, Skipped=78]
# Augmenting train:   3%|▎         | 261/7752 [22:55<15:36:59,  7.50s/it, Written=2, Skipped=79]
# Augmenting train:   3%|▎         | 263/7752 [22:55<18:14:31,  8.77s/it, Written=2, Skipped=79]
# Augmenting train:   3%|▎         | 263/7752 [23:09<18:14:31,  8.77s/it, Written=2, Skipped=80]
# Augmenting train:   3%|▎         | 268/7752 [23:09<12:13:34,  5.88s/it, Written=2, Skipped=80]
# Augmenting train:   3%|▎         | 268/7752 [23:29<12:13:34,  5.88s/it, Written=2, Skipped=81]
# Augmenting train:   4%|▎         | 279/7752 [23:29<6:57:49,  3.35s/it, Written=2, Skipped=81]
# Augmenting train:   4%|▎         | 279/7752 [23:48<6:57:49,  3.35s/it, Written=2, Skipped=82]
# Augmenting train:   4%|▎         | 280/7752 [23:48<9:23:15,  4.52s/it, Written=2, Skipped=82]
# Augmenting train:   4%|▎         | 280/7752 [24:10<9:23:15,  4.52s/it, Written=2, Skipped=83]
# Augmenting train:   4%|▎         | 281/7752 [24:10<12:55:18,  6.23s/it, Written=2, Skipped=83]
# Augmenting train:   4%|▎         | 281/7752 [24:27<12:55:18,  6.23s/it, Written=2, Skipped=84]
# Augmenting train:   4%|▎         | 282/7752 [24:27<15:25:14,  7.43s/it, Written=2, Skipped=84]
# Augmenting train:   4%|▎         | 282/7752 [24:43<15:25:14,  7.43s/it, Written=2, Skipped=85]
# Augmenting train:   4%|▎         | 289/7752 [24:43<9:36:08,  4.63s/it, Written=2, Skipped=85]
# Augmenting train:   4%|▎         | 289/7752 [24:59<9:36:08,  4.63s/it, Written=2, Skipped=86]
# Augmenting train:   4%|▍         | 293/7752 [24:59<9:12:01,  4.44s/it, Written=2, Skipped=86]
# Augmenting train:   4%|▍         | 293/7752 [25:18<9:12:01,  4.44s/it, Written=2, Skipped=87]
# Augmenting train:   4%|▍         | 297/7752 [25:18<9:25:56,  4.55s/it, Written=2, Skipped=87]
# Augmenting train:   4%|▍         | 297/7752 [25:32<9:25:56,  4.55s/it, Written=2, Skipped=88]
# Augmenting train:   4%|▍         | 298/7752 [25:32<11:21:24,  5.48s/it, Written=2, Skipped=88]
# Augmenting train:   4%|▍         | 298/7752 [25:49<11:21:24,  5.48s/it, Written=2, Skipped=89]
# Augmenting train:   4%|▍         | 300/7752 [25:49<12:49:34,  6.20s/it, Written=2, Skipped=89]
# Augmenting train:   4%|▍         | 300/7752 [26:08<12:49:34,  6.20s/it, Written=2, Skipped=90]
# Augmenting train:   4%|▍         | 303/7752 [26:08<12:43:05,  6.15s/it, Written=2, Skipped=90]
# Augmenting train:   4%|▍         | 303/7752 [26:30<12:43:05,  6.15s/it, Written=2, Skipped=91]
# Augmenting train:   4%|▍         | 308/7752 [26:30<11:13:43,  5.43s/it, Written=2, Skipped=91]
# Augmenting train:   4%|▍         | 308/7752 [26:46<11:13:43,  5.43s/it, Written=2, Skipped=92]
# Augmenting train:   4%|▍         | 323/7752 [26:46<5:19:25,  2.58s/it, Written=2, Skipped=92]
# Augmenting train:   4%|▍         | 323/7752 [27:01<5:19:25,  2.58s/it, Written=2, Skipped=93]
# Augmenting train:   4%|▍         | 325/7752 [27:01<6:30:28,  3.15s/it, Written=2, Skipped=93]
# Augmenting train:   4%|▍         | 325/7752 [27:15<6:30:28,  3.15s/it, Written=2, Skipped=94]
# Augmenting train:   4%|▍         | 326/7752 [27:15<8:09:58,  3.96s/it, Written=2, Skipped=94]
# Augmenting train:   4%|▍         | 326/7752 [27:31<8:09:58,  3.96s/it, Written=2, Skipped=95]
# Augmenting train:   4%|▍         | 334/7752 [27:31<6:17:37,  3.05s/it, Written=2, Skipped=95]
# Augmenting train:   4%|▍         | 334/7752 [27:47<6:17:37,  3.05s/it, Written=2, Skipped=96]
# Augmenting train:   4%|▍         | 340/7752 [27:47<6:01:56,  2.93s/it, Written=2, Skipped=96]
# Augmenting train:   4%|▍         | 340/7752 [28:08<6:01:56,  2.93s/it, Written=2, Skipped=97]
# Augmenting train:   4%|▍         | 342/7752 [28:08<8:04:23,  3.92s/it, Written=2, Skipped=97]
# Augmenting train:   4%|▍         | 342/7752 [28:25<8:04:23,  3.92s/it, Written=2, Skipped=98]
# Augmenting train:   4%|▍         | 343/7752 [28:25<10:24:49,  5.06s/it, Written=2, Skipped=98]
# Augmenting train:   4%|▍         | 343/7752 [28:39<10:24:49,  5.06s/it, Written=2, Skipped=99]
# Augmenting train:   4%|▍         | 344/7752 [28:39<12:37:30,  6.14s/it, Written=2, Skipped=99]
# Augmenting train:   4%|▍         | 344/7752 [28:54<12:37:30,  6.14s/it, Written=2, Skipped=100]
# Augmenting train:   4%|▍         | 345/7752 [28:54<14:56:28,  7.26s/it, Written=2, Skipped=100]
# Augmenting train:   4%|▍         | 345/7752 [29:09<14:56:28,  7.26s/it, Written=2, Skipped=101]
# Augmenting train:   4%|▍         | 347/7752 [29:09<15:04:44,  7.33s/it, Written=2, Skipped=101]
# Augmenting train:   4%|▍         | 347/7752 [29:26<15:04:44,  7.33s/it, Written=2, Skipped=102]
# Augmenting train:   5%|▍         | 353/7752 [29:26<10:06:57,  4.92s/it, Written=2, Skipped=102]
# Augmenting train:   5%|▍         | 353/7752 [29:45<10:06:57,  4.92s/it, Written=2, Skipped=103]
# Augmenting train:   5%|▍         | 354/7752 [29:45<13:23:44,  6.52s/it, Written=2, Skipped=103]
# Augmenting train:   5%|▍         | 354/7752 [30:00<13:23:44,  6.52s/it, Written=2, Skipped=104]
# Augmenting train:   5%|▍         | 355/7752 [30:00<15:47:06,  7.68s/it, Written=2, Skipped=104]
# Augmenting train:   5%|▍         | 355/7752 [30:15<15:47:06,  7.68s/it, Written=2, Skipped=105]
# Augmenting train:   5%|▍         | 358/7752 [30:15<13:48:35,  6.72s/it, Written=2, Skipped=105]
# Augmenting train:   5%|▍         | 358/7752 [30:38<13:48:35,  6.72s/it, Written=2, Skipped=106]
# Augmenting train:   5%|▍         | 359/7752 [30:38<18:55:02,  9.21s/it, Written=2, Skipped=106]
# Augmenting train:   5%|▍         | 359/7752 [30:54<18:55:02,  9.21s/it, Written=2, Skipped=107]
# Augmenting train:   5%|▍         | 360/7752 [30:54<21:17:01, 10.37s/it, Written=2, Skipped=107]
# Augmenting train:   5%|▍         | 360/7752 [31:08<21:17:01, 10.37s/it, Written=2, Skipped=108]
# Augmenting train:   5%|▍         | 362/7752 [31:08<18:59:51,  9.25s/it, Written=2, Skipped=108]
# Augmenting train:   5%|▍         | 362/7752 [31:27<18:59:51,  9.25s/it, Written=2, Skipped=109]
# Augmenting train:   5%|▍         | 365/7752 [31:27<16:27:37,  8.02s/it, Written=2, Skipped=109]
# Augmenting train:   5%|▍         | 365/7752 [31:42<16:27:37,  8.02s/it, Written=2, Skipped=110]
# Augmenting train:   5%|▍         | 368/7752 [31:42<14:13:06,  6.93s/it, Written=2, Skipped=110]
# Augmenting train:   5%|▍         | 368/7752 [32:02<14:13:06,  6.93s/it, Written=2, Skipped=111]
# Augmenting train:   5%|▍         | 371/7752 [32:02<14:02:38,  6.85s/it, Written=2, Skipped=111]
# Augmenting train:   5%|▍         | 371/7752 [32:11<14:02:38,  6.85s/it, Written=3, Skipped=111]
# Augmenting train:   5%|▍         | 375/7752 [32:11<10:06:48,  4.94s/it, Written=3, Skipped=111]
# Augmenting train:   5%|▍         | 375/7752 [32:31<10:06:48,  4.94s/it, Written=3, Skipped=112]
# Augmenting train:   5%|▍         | 376/7752 [32:31<14:06:57,  6.89s/it, Written=3, Skipped=112]
# Augmenting train:   5%|▍         | 376/7752 [32:47<14:06:57,  6.89s/it, Written=3, Skipped=113]
# Augmenting train:   5%|▍         | 380/7752 [32:47<11:35:48,  5.66s/it, Written=3, Skipped=113]
# Augmenting train:   5%|▍         | 380/7752 [33:02<11:35:48,  5.66s/it, Written=3, Skipped=114]
# Augmenting train:   5%|▍         | 381/7752 [33:02<13:56:56,  6.81s/it, Written=3, Skipped=114]
# Augmenting train:   5%|▍         | 381/7752 [33:20<13:56:56,  6.81s/it, Written=3, Skipped=115]
# Augmenting train:   5%|▍         | 382/7752 [33:20<17:35:11,  8.59s/it, Written=3, Skipped=115]
# Augmenting train:   5%|▍         | 382/7752 [33:39<17:35:11,  8.59s/it, Written=3, Skipped=116]
# Augmenting train:   5%|▍         | 384/7752 [33:39<18:10:29,  8.88s/it, Written=3, Skipped=116]
# Augmenting train:   5%|▍         | 384/7752 [33:56<18:10:29,  8.88s/it, Written=3, Skipped=117]
# Augmenting train:   5%|▌         | 388/7752 [33:56<13:52:19,  6.78s/it, Written=3, Skipped=117]
# Augmenting train:   5%|▌         | 388/7752 [34:12<13:52:19,  6.78s/it, Written=3, Skipped=118]
# Augmenting train:   5%|▌         | 389/7752 [34:12<16:27:50,  8.05s/it, Written=3, Skipped=118]
# Augmenting train:   5%|▌         | 389/7752 [34:28<16:27:50,  8.05s/it, Written=3, Skipped=119]
# Augmenting train:   5%|▌         | 400/7752 [34:28<7:03:05,  3.45s/it, Written=3, Skipped=119]
# Augmenting train:   5%|▌         | 400/7752 [34:46<7:03:05,  3.45s/it, Written=3, Skipped=120]
# Augmenting train:   5%|▌         | 402/7752 [34:46<8:46:16,  4.30s/it, Written=3, Skipped=120]
# Augmenting train:   5%|▌         | 402/7752 [35:08<8:46:16,  4.30s/it, Written=3, Skipped=121]
# Augmenting train:   5%|▌         | 403/7752 [35:08<12:28:47,  6.11s/it, Written=3, Skipped=121]
# Augmenting train:   5%|▌         | 403/7752 [35:25<12:28:47,  6.11s/it, Written=3, Skipped=122]
# Augmenting train:   5%|▌         | 408/7752 [35:25<10:04:57,  4.94s/it, Written=3, Skipped=122]
# Augmenting train:   5%|▌         | 408/7752 [35:42<10:04:57,  4.94s/it, Written=3, Skipped=123]
# Augmenting train:   5%|▌         | 418/7752 [35:42<6:33:47,  3.22s/it, Written=3, Skipped=123]
# Augmenting train:   5%|▌         | 418/7752 [35:57<6:33:47,  3.22s/it, Written=3, Skipped=124]
# Augmenting train:   5%|▌         | 419/7752 [35:57<8:17:14,  4.07s/it, Written=3, Skipped=124]
# Augmenting train:   5%|▌         | 419/7752 [36:12<8:17:14,  4.07s/it, Written=3, Skipped=125]
# Augmenting train:   5%|▌         | 423/7752 [36:12<7:59:43,  3.93s/it, Written=3, Skipped=125]
# Augmenting train:   5%|▌         | 423/7752 [36:29<7:59:43,  3.93s/it, Written=3, Skipped=126]
# Augmenting train:   5%|▌         | 426/7752 [36:29<8:55:12,  4.38s/it, Written=3, Skipped=126]
# Augmenting train:   5%|▌         | 426/7752 [36:46<8:55:12,  4.38s/it, Written=3, Skipped=127]
# Augmenting train:   6%|▌         | 428/7752 [36:46<10:30:06,  5.16s/it, Written=3, Skipped=127]
# Augmenting train:   6%|▌         | 428/7752 [37:04<10:30:06,  5.16s/it, Written=3, Skipped=128]
# Augmenting train:   6%|▌         | 429/7752 [37:04<13:31:42,  6.65s/it, Written=3, Skipped=128]
# Augmenting train:   6%|▌         | 429/7752 [37:18<13:31:42,  6.65s/it, Written=3, Skipped=129]
# Augmenting train:   6%|▌         | 431/7752 [37:18<13:34:51,  6.68s/it, Written=3, Skipped=129]
# Augmenting train:   6%|▌         | 431/7752 [37:34<13:34:51,  6.68s/it, Written=3, Skipped=130]
# Augmenting train:   6%|▌         | 433/7752 [37:34<14:10:53,  6.98s/it, Written=3, Skipped=130]
# Augmenting train:   6%|▌         | 433/7752 [37:48<14:10:53,  6.98s/it, Written=3, Skipped=131]
# Augmenting train:   6%|▌         | 436/7752 [37:48<12:42:32,  6.25s/it, Written=3, Skipped=131]
# Augmenting train:   6%|▌         | 436/7752 [38:05<12:42:32,  6.25s/it, Written=3, Skipped=132]
# Augmenting train:   6%|▌         | 437/7752 [38:05<15:42:27,  7.73s/it, Written=3, Skipped=132]
# Augmenting train:   6%|▌         | 437/7752 [38:19<15:42:27,  7.73s/it, Written=3, Skipped=133]
# Augmenting train:   6%|▌         | 440/7752 [38:19<13:15:22,  6.53s/it, Written=3, Skipped=133]
# Augmenting train:   6%|▌         | 440/7752 [38:34<13:15:22,  6.53s/it, Written=3, Skipped=134]
# Augmenting train:   6%|▌         | 444/7752 [38:34<10:53:32,  5.37s/it, Written=3, Skipped=134]
# Augmenting train:   6%|▌         | 444/7752 [38:49<10:53:32,  5.37s/it, Written=3, Skipped=135]
# Augmenting train:   6%|▌         | 445/7752 [38:49<13:25:50,  6.62s/it, Written=3, Skipped=135]
# Augmenting train:   6%|▌         | 445/7752 [39:03<13:25:50,  6.62s/it, Written=3, Skipped=136]
# Augmenting train:   6%|▌         | 446/7752 [39:03<15:58:44,  7.87s/it, Written=3, Skipped=136]
# Augmenting train:   6%|▌         | 446/7752 [39:19<15:58:44,  7.87s/it, Written=3, Skipped=137]
# Augmenting train:   6%|▌         | 449/7752 [39:19<13:50:42,  6.82s/it, Written=3, Skipped=137]
# Augmenting train:   6%|▌         | 449/7752 [39:37<13:50:42,  6.82s/it, Written=3, Skipped=138]
# Augmenting train:   6%|▌         | 453/7752 [39:37<11:49:57,  5.84s/it, Written=3, Skipped=138]
# Augmenting train:   6%|▌         | 453/7752 [39:53<11:49:57,  5.84s/it, Written=3, Skipped=139]
# Augmenting train:   6%|▌         | 454/7752 [39:53<14:29:29,  7.15s/it, Written=3, Skipped=139]
# Augmenting train:   6%|▌         | 454/7752 [40:07<14:29:29,  7.15s/it, Written=3, Skipped=140]
# Augmenting train:   6%|▌         | 455/7752 [40:07<16:52:06,  8.32s/it, Written=3, Skipped=140]
# Augmenting train:   6%|▌         | 455/7752 [40:21<16:52:06,  8.32s/it, Written=3, Skipped=141]
# Augmenting train:   6%|▌         | 459/7752 [40:21<12:07:48,  5.99s/it, Written=3, Skipped=141]
# Augmenting train:   6%|▌         | 459/7752 [40:36<12:07:48,  5.99s/it, Written=3, Skipped=142]
# Augmenting train:   6%|▌         | 462/7752 [40:36<11:27:25,  5.66s/it, Written=3, Skipped=142]
# Augmenting train:   6%|▌         | 462/7752 [40:51<11:27:25,  5.66s/it, Written=3, Skipped=143]
# Augmenting train:   6%|▌         | 464/7752 [40:51<12:20:26,  6.10s/it, Written=3, Skipped=143]
# Augmenting train:   6%|▌         | 464/7752 [41:06<12:20:26,  6.10s/it, Written=3, Skipped=144]
# Augmenting train:   6%|▌         | 467/7752 [41:06<11:36:25,  5.74s/it, Written=3, Skipped=144]
# Augmenting train:   6%|▌         | 467/7752 [41:22<11:36:25,  5.74s/it, Written=3, Skipped=145]
# Augmenting train:   6%|▌         | 468/7752 [41:22<14:19:44,  7.08s/it, Written=3, Skipped=145]
# Augmenting train:   6%|▌         | 468/7752 [41:41<14:19:44,  7.08s/it, Written=3, Skipped=146]
# Augmenting train:   6%|▌         | 470/7752 [41:41<15:55:01,  7.87s/it, Written=3, Skipped=146]
# Augmenting train:   6%|▌         | 470/7752 [41:58<15:55:01,  7.87s/it, Written=3, Skipped=147]
# Augmenting train:   6%|▌         | 474/7752 [41:58<12:34:49,  6.22s/it, Written=3, Skipped=147]
# Augmenting train:   6%|▌         | 474/7752 [42:14<12:34:49,  6.22s/it, Written=3, Skipped=148]
# Augmenting train:   6%|▌         | 476/7752 [42:14<13:32:25,  6.70s/it, Written=3, Skipped=148]
# Augmenting train:   6%|▌         | 476/7752 [42:34<13:32:25,  6.70s/it, Written=3, Skipped=149]
# Augmenting train:   6%|▌         | 477/7752 [42:34<17:20:17,  8.58s/it, Written=3, Skipped=149]
# Augmenting train:   6%|▌         | 477/7752 [42:50<17:20:17,  8.58s/it, Written=3, Skipped=150]
# Augmenting train:   6%|▌         | 484/7752 [42:50<9:44:14,  4.82s/it, Written=3, Skipped=150]
# Augmenting train:   6%|▌         | 484/7752 [43:07<9:44:14,  4.82s/it, Written=3, Skipped=151]
# Augmenting train:   6%|▋         | 485/7752 [43:07<12:29:27,  6.19s/it, Written=3, Skipped=151]
# Augmenting train:   6%|▋         | 485/7752 [43:26<12:29:27,  6.19s/it, Written=3, Skipped=152]
# Augmenting train:   6%|▋         | 489/7752 [43:26<11:21:00,  5.63s/it, Written=3, Skipped=152]
# Augmenting train:   6%|▋         | 489/7752 [43:44<11:21:00,  5.63s/it, Written=3, Skipped=153]
# Augmenting train:   6%|▋         | 491/7752 [43:44<12:44:36,  6.32s/it, Written=3, Skipped=153]
# Augmenting train:   6%|▋         | 491/7752 [44:04<12:44:36,  6.32s/it, Written=3, Skipped=154]
# Augmenting train:   6%|▋         | 494/7752 [44:04<12:55:55,  6.41s/it, Written=3, Skipped=154]
# Augmenting train:   6%|▋         | 494/7752 [44:20<12:55:55,  6.41s/it, Written=3, Skipped=155]
# Augmenting train:   6%|▋         | 495/7752 [44:20<15:27:37,  7.67s/it, Written=3, Skipped=155]
# Augmenting train:   6%|▋         | 495/7752 [44:36<15:27:37,  7.67s/it, Written=3, Skipped=156]
# Augmenting train:   6%|▋         | 496/7752 [44:36<18:18:51,  9.09s/it, Written=3, Skipped=156]
# Augmenting train:   6%|▋         | 496/7752 [44:56<18:18:51,  9.09s/it, Written=3, Skipped=157]
# Augmenting train:   6%|▋         | 497/7752 [44:56<22:09:26, 10.99s/it, Written=3, Skipped=157]
# Augmenting train:   6%|▋         | 497/7752 [45:11<22:09:26, 10.99s/it, Written=3, Skipped=158]
# Augmenting train:   6%|▋         | 499/7752 [45:11<19:48:42,  9.83s/it, Written=3, Skipped=158]
# Augmenting train:   6%|▋         | 499/7752 [45:30<19:48:42,  9.83s/it, Written=3, Skipped=159]
# Augmenting train:   6%|▋         | 502/7752 [45:30<16:41:22,  8.29s/it, Written=3, Skipped=159]
# Augmenting train:   6%|▋         | 502/7752 [45:47<16:41:22,  8.29s/it, Written=3, Skipped=160]
# Augmenting train:   6%|▋         | 503/7752 [45:47<19:52:54,  9.87s/it, Written=3, Skipped=160]
# Augmenting train:   6%|▋         | 503/7752 [45:59<19:52:54,  9.87s/it, Written=3, Skipped=161]
# Augmenting train:   7%|▋         | 504/7752 [45:59<20:39:44, 10.26s/it, Written=3, Skipped=161]
# Augmenting train:   7%|▋         | 504/7752 [46:13<20:39:44, 10.26s/it, Written=3, Skipped=162]
# Augmenting train:   7%|▋         | 507/7752 [46:13<15:32:39,  7.72s/it, Written=3, Skipped=162]
# Augmenting train:   7%|▋         | 507/7752 [46:28<15:32:39,  7.72s/it, Written=3, Skipped=163]
# Augmenting train:   7%|▋         | 511/7752 [46:28<11:43:26,  5.83s/it, Written=3, Skipped=163]
# Augmenting train:   7%|▋         | 511/7752 [46:42<11:43:26,  5.83s/it, Written=3, Skipped=164]
# Augmenting train:   7%|▋         | 516/7752 [46:42<9:01:46,  4.49s/it, Written=3, Skipped=164]
# Augmenting train:   7%|▋         | 516/7752 [47:03<9:01:46,  4.49s/it, Written=3, Skipped=165]
# Augmenting train:   7%|▋         | 517/7752 [47:03<12:44:23,  6.34s/it, Written=3, Skipped=165]
# Augmenting train:   7%|▋         | 517/7752 [47:16<12:44:23,  6.34s/it, Written=3, Skipped=166]
# Augmenting train:   7%|▋         | 520/7752 [47:16<11:30:25,  5.73s/it, Written=3, Skipped=166]
# Augmenting train:   7%|▋         | 520/7752 [47:31<11:30:25,  5.73s/it, Written=3, Skipped=167]
# Augmenting train:   7%|▋         | 524/7752 [47:31<9:57:16,  4.96s/it, Written=3, Skipped=167]
# Augmenting train:   7%|▋         | 524/7752 [47:48<9:57:16,  4.96s/it, Written=3, Skipped=168]
# Augmenting train:   7%|▋         | 525/7752 [47:48<12:53:48,  6.42s/it, Written=3, Skipped=168]
# Augmenting train:   7%|▋         | 525/7752 [48:05<12:53:48,  6.42s/it, Written=3, Skipped=169]
# Augmenting train:   7%|▋         | 526/7752 [48:05<15:50:37,  7.89s/it, Written=3, Skipped=169]
# Augmenting train:   7%|▋         | 526/7752 [48:22<15:50:37,  7.89s/it, Written=3, Skipped=170]
# Augmenting train:   7%|▋         | 527/7752 [48:22<19:10:36,  9.56s/it, Written=3, Skipped=170]
# Augmenting train:   7%|▋         | 527/7752 [48:41<19:10:36,  9.56s/it, Written=3, Skipped=171]
# Augmenting train:   7%|▋         | 529/7752 [48:41<19:03:30,  9.50s/it, Written=3, Skipped=171]
# Augmenting train:   7%|▋         | 529/7752 [49:00<19:03:30,  9.50s/it, Written=3, Skipped=172]
# Augmenting train:   7%|▋         | 532/7752 [49:00<16:29:50,  8.23s/it, Written=3, Skipped=172]
# Augmenting train:   7%|▋         | 532/7752 [49:14<16:29:50,  8.23s/it, Written=3, Skipped=173]
# Augmenting train:   7%|▋         | 533/7752 [49:14<18:16:59,  9.12s/it, Written=3, Skipped=173]
# Augmenting train:   7%|▋         | 533/7752 [49:36<18:16:59,  9.12s/it, Written=3, Skipped=174]
# Augmenting train:   7%|▋         | 536/7752 [49:36<16:56:23,  8.45s/it, Written=3, Skipped=174]
# Augmenting train:   7%|▋         | 536/7752 [49:52<16:56:23,  8.45s/it, Written=3, Skipped=175]
# Augmenting train:   7%|▋         | 538/7752 [49:52<16:36:34,  8.29s/it, Written=3, Skipped=175]
# Augmenting train:   7%|▋         | 538/7752 [50:08<16:36:34,  8.29s/it, Written=4, Skipped=175]
# Augmenting train:   7%|▋         | 541/7752 [50:08<14:25:17,  7.20s/it, Written=4, Skipped=175]
# Augmenting train:   7%|▋         | 541/7752 [50:22<14:25:17,  7.20s/it, Written=4, Skipped=176]
# Augmenting train:   7%|▋         | 544/7752 [50:22<12:33:38,  6.27s/it, Written=4, Skipped=176]
# Augmenting train:   7%|▋         | 544/7752 [50:37<12:33:38,  6.27s/it, Written=4, Skipped=177]
# Augmenting train:   7%|▋         | 546/7752 [50:37<13:07:49,  6.56s/it, Written=4, Skipped=177]
# Augmenting train:   7%|▋         | 546/7752 [50:51<13:07:49,  6.56s/it, Written=4, Skipped=178]
# Augmenting train:   7%|▋         | 552/7752 [50:51<8:49:04,  4.41s/it, Written=4, Skipped=178]
# Augmenting train:   7%|▋         | 552/7752 [50:58<8:49:04,  4.41s/it, Written=5, Skipped=178]
# Augmenting train:   7%|▋         | 558/7752 [50:58<6:03:49,  3.03s/it, Written=5, Skipped=178]
# Augmenting train:   7%|▋         | 558/7752 [51:49<6:03:49,  3.03s/it, Written=5, Skipped=179]
# Augmenting train:   7%|▋         | 560/7752 [51:49<13:34:14,  6.79s/it, Written=5, Skipped=179]
# Augmenting train:   7%|▋         | 560/7752 [52:06<13:34:14,  6.79s/it, Written=5, Skipped=180]
# Augmenting train:   7%|▋         | 565/7752 [52:06<10:57:30,  5.49s/it, Written=5, Skipped=180]
# Augmenting train:   7%|▋         | 565/7752 [52:27<10:57:30,  5.49s/it, Written=5, Skipped=181]
# Augmenting train:   7%|▋         | 566/7752 [52:27<13:59:48,  7.01s/it, Written=5, Skipped=181]
# Augmenting train:   7%|▋         | 566/7752 [52:42<13:59:48,  7.01s/it, Written=5, Skipped=182]
# Augmenting train:   7%|▋         | 567/7752 [52:42<16:04:46,  8.06s/it, Written=5, Skipped=182]
# Augmenting train:   7%|▋         | 567/7752 [52:57<16:04:46,  8.06s/it, Written=5, Skipped=183]
# Augmenting train:   7%|▋         | 568/7752 [52:57<18:04:02,  9.05s/it, Written=5, Skipped=183]
# Augmenting train:   7%|▋         | 568/7752 [53:11<18:04:02,  9.05s/it, Written=5, Skipped=184]
# Augmenting train:   7%|▋         | 571/7752 [53:11<14:38:46,  7.34s/it, Written=5, Skipped=184]
# Augmenting train:   7%|▋         | 571/7752 [53:26<14:38:46,  7.34s/it, Written=5, Skipped=185]
# Augmenting train:   7%|▋         | 579/7752 [53:26<8:05:28,  4.06s/it, Written=5, Skipped=185]
# Augmenting train:   7%|▋         | 579/7752 [53:46<8:05:28,  4.06s/it, Written=5, Skipped=186]
# Augmenting train:   8%|▊         | 583/7752 [53:46<8:44:11,  4.39s/it, Written=5, Skipped=186]
# Augmenting train:   8%|▊         | 583/7752 [54:02<8:44:11,  4.39s/it, Written=5, Skipped=187]
# Augmenting train:   8%|▊         | 590/7752 [54:02<6:51:02,  3.44s/it, Written=5, Skipped=187]
# Augmenting train:   8%|▊         | 590/7752 [54:17<6:51:02,  3.44s/it, Written=5, Skipped=188]
# Augmenting train:   8%|▊         | 593/7752 [54:17<7:35:01,  3.81s/it, Written=5, Skipped=188]
# Augmenting train:   8%|▊         | 593/7752 [54:33<7:35:01,  3.81s/it, Written=5, Skipped=189]
# Augmenting train:   8%|▊         | 600/7752 [54:33<6:18:59,  3.18s/it, Written=5, Skipped=189]
# Augmenting train:   8%|▊         | 600/7752 [54:59<6:18:59,  3.18s/it, Written=5, Skipped=190]
# Augmenting train:   8%|▊         | 602/7752 [54:59<9:00:33,  4.54s/it, Written=5, Skipped=190]
# Augmenting train:   8%|▊         | 602/7752 [55:23<9:00:33,  4.54s/it, Written=5, Skipped=191]
# Augmenting train:   8%|▊         | 609/7752 [55:23<8:05:16,  4.08s/it, Written=5, Skipped=191]
# Augmenting train:   8%|▊         | 609/7752 [55:40<8:05:16,  4.08s/it, Written=5, Skipped=192]
# Augmenting train:   8%|▊         | 611/7752 [55:40<9:27:19,  4.77s/it, Written=5, Skipped=192]
# Augmenting train:   8%|▊         | 611/7752 [56:00<9:27:19,  4.77s/it, Written=5, Skipped=193]
# Augmenting train:   8%|▊         | 619/7752 [56:00<7:21:52,  3.72s/it, Written=5, Skipped=193]
# Augmenting train:   8%|▊         | 619/7752 [56:15<7:21:52,  3.72s/it, Written=5, Skipped=194]
# Augmenting train:   8%|▊         | 624/7752 [56:15<7:00:56,  3.54s/it, Written=5, Skipped=194]
# Augmenting train:   8%|▊         | 624/7752 [56:32<7:00:56,  3.54s/it, Written=5, Skipped=195]
# Augmenting train:   8%|▊         | 630/7752 [56:32<6:28:32,  3.27s/it, Written=5, Skipped=195]
# Augmenting train:   8%|▊         | 630/7752 [56:56<6:28:32,  3.27s/it, Written=6, Skipped=195]
# Augmenting train:   8%|▊         | 636/7752 [56:56<6:54:21,  3.49s/it, Written=6, Skipped=195]
# Augmenting train:   8%|▊         | 636/7752 [57:10<6:54:21,  3.49s/it, Written=6, Skipped=196]
# Augmenting train:   8%|▊         | 637/7752 [57:10<8:26:31,  4.27s/it, Written=6, Skipped=196]
# Augmenting train:   8%|▊         | 637/7752 [57:24<8:26:31,  4.27s/it, Written=6, Skipped=197]
# Augmenting train:   8%|▊         | 639/7752 [57:24<9:21:03,  4.73s/it, Written=6, Skipped=197]
# Augmenting train:   8%|▊         | 639/7752 [57:41<9:21:03,  4.73s/it, Written=6, Skipped=198]
# Augmenting train:   8%|▊         | 643/7752 [57:41<8:58:41,  4.55s/it, Written=6, Skipped=198]
# Augmenting train:   8%|▊         | 643/7752 [57:57<8:58:41,  4.55s/it, Written=6, Skipped=199]
# Augmenting train:   8%|▊         | 645/7752 [57:57<10:18:25,  5.22s/it, Written=6, Skipped=199]
# Augmenting train:   8%|▊         | 645/7752 [58:10<10:18:25,  5.22s/it, Written=6, Skipped=200]
# Augmenting train:   8%|▊         | 647/7752 [58:10<10:49:52,  5.49s/it, Written=6, Skipped=200]
# Augmenting train:   8%|▊         | 647/7752 [58:28<10:49:52,  5.49s/it, Written=6, Skipped=201]
# Augmenting train:   8%|▊         | 654/7752 [58:28<7:50:51,  3.98s/it, Written=6, Skipped=201]
# Augmenting train:   8%|▊         | 654/7752 [58:51<7:50:51,  3.98s/it, Written=6, Skipped=202]
# Augmenting train:   8%|▊         | 658/7752 [58:51<8:54:30,  4.52s/it, Written=6, Skipped=202]
# Augmenting train:   8%|▊         | 658/7752 [59:07<8:54:30,  4.52s/it, Written=6, Skipped=203]
# Augmenting train:   9%|▊         | 660/7752 [59:07<10:01:58,  5.09s/it, Written=6, Skipped=203]
# Augmenting train:   9%|▊         | 660/7752 [59:24<10:01:58,  5.09s/it, Written=6, Skipped=204]
# Augmenting train:   9%|▊         | 661/7752 [59:24<12:46:30,  6.49s/it, Written=6, Skipped=204]
# Augmenting train:   9%|▊         | 661/7752 [59:41<12:46:30,  6.49s/it, Written=6, Skipped=205]
# Augmenting train:   9%|▊         | 662/7752 [59:41<15:30:18,  7.87s/it, Written=6, Skipped=205]
# Augmenting train:   9%|▊         | 662/7752 [59:55<15:30:18,  7.87s/it, Written=6, Skipped=206]
# Augmenting train:   9%|▊         | 668/7752 [59:55<9:42:03,  4.93s/it, Written=6, Skipped=206]
# Augmenting train:   9%|▊         | 668/7752 [1:00:09<9:42:03,  4.93s/it, Written=6, Skipped=207]
# Augmenting train:   9%|▊         | 669/7752 [1:00:09<11:39:52,  5.93s/it, Written=6, Skipped=207]
# Augmenting train:   9%|▊         | 669/7752 [1:00:26<11:39:52,  5.93s/it, Written=6, Skipped=208]
# Augmenting train:   9%|▊         | 670/7752 [1:00:26<14:38:25,  7.44s/it, Written=6, Skipped=208]
# Augmenting train:   9%|▊         | 670/7752 [1:00:40<14:38:25,  7.44s/it, Written=6, Skipped=209]
# Augmenting train:   9%|▉         | 680/7752 [1:00:40<6:45:29,  3.44s/it, Written=6, Skipped=209]
# Augmenting train:   9%|▉         | 680/7752 [1:00:56<6:45:29,  3.44s/it, Written=6, Skipped=210]
# Augmenting train:   9%|▉         | 686/7752 [1:00:56<6:09:43,  3.14s/it, Written=6, Skipped=210]
# Augmenting train:   9%|▉         | 686/7752 [1:01:12<6:09:43,  3.14s/it, Written=6, Skipped=211]
# Augmenting train:   9%|▉         | 688/7752 [1:01:12<7:33:52,  3.86s/it, Written=6, Skipped=211]
# Augmenting train:   9%|▉         | 688/7752 [1:01:28<7:33:52,  3.86s/it, Written=6, Skipped=212]
# Augmenting train:   9%|▉         | 689/7752 [1:01:28<9:51:59,  5.03s/it, Written=6, Skipped=212]
# Augmenting train:   9%|▉         | 689/7752 [1:01:43<9:51:59,  5.03s/it, Written=6, Skipped=213]
# Augmenting train:   9%|▉         | 695/7752 [1:01:43<7:40:21,  3.91s/it, Written=6, Skipped=213]
# Augmenting train:   9%|▉         | 695/7752 [1:02:03<7:40:21,  3.91s/it, Written=6, Skipped=214]
# Augmenting train:   9%|▉         | 698/7752 [1:02:03<8:51:08,  4.52s/it, Written=6, Skipped=214]
# Augmenting train:   9%|▉         | 698/7752 [1:02:17<8:51:08,  4.52s/it, Written=6, Skipped=215]
# Augmenting train:   9%|▉         | 707/7752 [1:02:17<5:58:04,  3.05s/it, Written=6, Skipped=215]
# Augmenting train:   9%|▉         | 707/7752 [1:02:36<5:58:04,  3.05s/it, Written=6, Skipped=216]
# Augmenting train:   9%|▉         | 708/7752 [1:02:36<8:12:12,  4.19s/it, Written=6, Skipped=216]
# Augmenting train:   9%|▉         | 708/7752 [1:02:50<8:12:12,  4.19s/it, Written=6, Skipped=217]
# Augmenting train:   9%|▉         | 711/7752 [1:02:50<8:30:52,  4.35s/it, Written=6, Skipped=217]
# Augmenting train:   9%|▉         | 711/7752 [1:03:05<8:30:52,  4.35s/it, Written=6, Skipped=218]
# Augmenting train:   9%|▉         | 713/7752 [1:03:05<9:35:48,  4.91s/it, Written=6, Skipped=218]
# Augmenting train:   9%|▉         | 713/7752 [1:03:20<9:35:48,  4.91s/it, Written=6, Skipped=219]
# Augmenting train:   9%|▉         | 715/7752 [1:03:20<10:43:34,  5.49s/it, Written=6, Skipped=219]
# Augmenting train:   9%|▉         | 715/7752 [1:03:34<10:43:34,  5.49s/it, Written=6, Skipped=220]
# Augmenting train:   9%|▉         | 718/7752 [1:03:34<10:11:17,  5.21s/it, Written=6, Skipped=220]
# Augmenting train:   9%|▉         | 718/7752 [1:03:48<10:11:17,  5.21s/it, Written=6, Skipped=221]
# Augmenting train:   9%|▉         | 726/7752 [1:03:48<6:33:00,  3.36s/it, Written=6, Skipped=221]
# Augmenting train:   9%|▉         | 726/7752 [1:04:02<6:33:00,  3.36s/it, Written=6, Skipped=222]
# Augmenting train:   9%|▉         | 727/7752 [1:04:02<8:18:05,  4.25s/it, Written=6, Skipped=222]
# Augmenting train:   9%|▉         | 727/7752 [1:04:19<8:18:05,  4.25s/it, Written=6, Skipped=223]
# Augmenting train:   9%|▉         | 730/7752 [1:04:19<9:00:15,  4.62s/it, Written=6, Skipped=223]
# Augmenting train:   9%|▉         | 730/7752 [1:04:40<9:00:15,  4.62s/it, Written=6, Skipped=224]
# Augmenting train:   9%|▉         | 734/7752 [1:04:40<9:25:53,  4.84s/it, Written=6, Skipped=224]
# Augmenting train:   9%|▉         | 734/7752 [1:04:53<9:25:53,  4.84s/it, Written=6, Skipped=225]
# Augmenting train:  10%|▉         | 740/7752 [1:04:53<7:19:25,  3.76s/it, Written=6, Skipped=225]
# Augmenting train:  10%|▉         | 740/7752 [1:05:10<7:19:25,  3.76s/it, Written=6, Skipped=226]
# Augmenting train:  10%|▉         | 748/7752 [1:05:10<5:54:18,  3.04s/it, Written=6, Skipped=226]
# Augmenting train:  10%|▉         | 748/7752 [1:05:25<5:54:18,  3.04s/it, Written=6, Skipped=227]
# Augmenting train:  10%|▉         | 753/7752 [1:05:25<5:46:49,  2.97s/it, Written=6, Skipped=227]
# Augmenting train:  10%|▉         | 753/7752 [1:05:41<5:46:49,  2.97s/it, Written=6, Skipped=228]
# Augmenting train:  10%|▉         | 756/7752 [1:05:41<6:46:48,  3.49s/it, Written=6, Skipped=228]
# Augmenting train:  10%|▉         | 756/7752 [1:05:57<6:46:48,  3.49s/it, Written=6, Skipped=229]
# Augmenting train:  10%|▉         | 757/7752 [1:05:57<8:47:37,  4.53s/it, Written=6, Skipped=229]
# Augmenting train:  10%|▉         | 757/7752 [1:06:16<8:47:37,  4.53s/it, Written=6, Skipped=230]
# Augmenting train:  10%|▉         | 760/7752 [1:06:16<9:39:39,  4.97s/it, Written=6, Skipped=230]
# Augmenting train:  10%|▉         | 760/7752 [1:06:34<9:39:39,  4.97s/it, Written=6, Skipped=231]
# Augmenting train:  10%|▉         | 762/7752 [1:06:34<11:19:25,  5.83s/it, Written=6, Skipped=231]
# Augmenting train:  10%|▉         | 762/7752 [1:06:49<11:19:25,  5.83s/it, Written=6, Skipped=232]
# Augmenting train:  10%|▉         | 764/7752 [1:06:49<12:05:05,  6.23s/it, Written=6, Skipped=232]
# Augmenting train:  10%|▉         | 764/7752 [1:07:04<12:05:05,  6.23s/it, Written=6, Skipped=233]
# Augmenting train:  10%|▉         | 768/7752 [1:07:04<10:13:02,  5.27s/it, Written=6, Skipped=233]
# Augmenting train:  10%|▉         | 768/7752 [1:07:25<10:13:02,  5.27s/it, Written=6, Skipped=234]
# Augmenting train:  10%|▉         | 770/7752 [1:07:25<12:22:05,  6.38s/it, Written=6, Skipped=234]
# Augmenting train:  10%|▉         | 770/7752 [1:07:42<12:22:05,  6.38s/it, Written=6, Skipped=235]
# Augmenting train:  10%|▉         | 772/7752 [1:07:42<13:17:34,  6.86s/it, Written=6, Skipped=235]
# Augmenting train:  10%|▉         | 772/7752 [1:07:58<13:17:34,  6.86s/it, Written=6, Skipped=236]
# Augmenting train:  10%|▉         | 775/7752 [1:07:58<12:27:56,  6.43s/it, Written=6, Skipped=236]
# Augmenting train:  10%|▉         | 775/7752 [1:08:14<12:27:56,  6.43s/it, Written=6, Skipped=237]
# Augmenting train:  10%|█         | 776/7752 [1:08:14<14:48:27,  7.64s/it, Written=6, Skipped=237]
# Augmenting train:  10%|█         | 776/7752 [1:08:34<14:48:27,  7.64s/it, Written=6, Skipped=238]
# Augmenting train:  10%|█         | 777/7752 [1:08:34<18:46:09,  9.69s/it, Written=6, Skipped=238]
# Augmenting train:  10%|█         | 777/7752 [1:08:50<18:46:09,  9.69s/it, Written=6, Skipped=239]
# Augmenting train:  10%|█         | 778/7752 [1:08:50<21:20:56, 11.02s/it, Written=6, Skipped=239]
# Augmenting train:  10%|█         | 778/7752 [1:09:11<21:20:56, 11.02s/it, Written=6, Skipped=240]
# Augmenting train:  10%|█         | 786/7752 [1:09:11<10:03:10,  5.20s/it, Written=6, Skipped=240]
# ...
# Augmenting train:  83%|████████▎ | 6425/7752 [11:31:48<3:38:09,  9.86s/it, Written=1062, Skipped=1944]
# Augmenting train:  83%|████████▎ | 6425/7752 [11:31:56<3:38:09,  9.86s/it, Written=1063, Skipped=1944]
# Augmenting train:  83%|████████▎ | 6426/7752 [11:31:56<5:10:40, 14.06s/it, Written=1063, Skipped=1944]
# Augmenting train:  83%|████████▎ | 6426/7752 [11:32:11<5:10:40, 14.06s/it, Written=1064, Skipped=1944]
# Augmenting train:  83%|████████▎ | 6427/7752 [11:32:11<5:20:26, 14.51s/it, Written=1064, Skipped=1944]
# Augmenting train:  83%|████████▎ | 6427/7752 [11:32:31<5:20:26, 14.51s/it, Written=1064, Skipped=1945]
# Augmenting train:  83%|████████▎ | 6428/7752 [11:32:31<5:53:08, 16.00s/it, Written=1064, Skipped=1945]
# Augmenting train:  83%|████████▎ | 6428/7752 [11:32:47<5:53:08, 16.00s/it, Written=1064, Skipped=1946]
# Augmenting train:  83%|████████▎ | 6429/7752 [11:32:47<5:53:18, 16.02s/it, Written=1064, Skipped=1946]
# Augmenting train:  83%|████████▎ | 6429/7752 [11:33:08<5:53:18, 16.02s/it, Written=1064, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6430/7752 [11:33:08<6:23:49, 17.42s/it, Written=1064, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6430/7752 [11:33:26<6:23:49, 17.42s/it, Written=1065, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6431/7752 [11:33:26<6:32:21, 17.82s/it, Written=1065, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6431/7752 [11:33:34<6:32:21, 17.82s/it, Written=1066, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6432/7752 [11:33:34<5:21:28, 14.61s/it, Written=1066, Skipped=1947]
# Augmenting train:  83%|████████▎ | 6432/7752 [11:33:50<5:21:28, 14.61s/it, Written=1066, Skipped=1948]
# Augmenting train:  83%|████████▎ | 6433/7752 [11:33:50<5:34:57, 15.24s/it, Written=1066, Skipped=1948]
# Augmenting train:  83%|████████▎ | 6433/7752 [11:34:10<5:34:57, 15.24s/it, Written=1066, Skipped=1949]
# Augmenting train:  83%|████████▎ | 6434/7752 [11:34:10<6:06:35, 16.69s/it, Written=1066, Skipped=1949]
# Augmenting train:  83%|████████▎ | 6434/7752 [11:34:19<6:06:35, 16.69s/it, Written=1067, Skipped=1949]
# Augmenting train:  83%|████████▎ | 6435/7752 [11:34:19<5:12:51, 14.25s/it, Written=1067, Skipped=1949]
# Augmenting train:  83%|████████▎ | 6435/7752 [11:34:32<5:12:51, 14.25s/it, Written=1067, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6436/7752 [11:34:32<5:06:37, 13.98s/it, Written=1067, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6436/7752 [11:34:38<5:06:37, 13.98s/it, Written=1068, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6437/7752 [11:34:38<4:12:53, 11.54s/it, Written=1068, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6437/7752 [11:34:45<4:12:53, 11.54s/it, Written=1069, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6438/7752 [11:34:45<3:43:43, 10.22s/it, Written=1069, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6438/7752 [11:34:51<3:43:43, 10.22s/it, Written=1070, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6439/7752 [11:34:51<3:15:18,  8.92s/it, Written=1070, Skipped=1950]
# Augmenting train:  83%|████████▎ | 6439/7752 [11:35:09<3:15:18,  8.92s/it, Written=1070, Skipped=1951]
# Augmenting train:  83%|████████▎ | 6440/7752 [11:35:09<4:15:19, 11.68s/it, Written=1070, Skipped=1951]
# Augmenting train:  83%|████████▎ | 6440/7752 [11:35:27<4:15:19, 11.68s/it, Written=1070, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6441/7752 [11:35:27<4:53:09, 13.42s/it, Written=1070, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6441/7752 [11:35:35<4:53:09, 13.42s/it, Written=1071, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6442/7752 [11:35:35<4:19:56, 11.91s/it, Written=1071, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6442/7752 [11:35:41<4:19:56, 11.91s/it, Written=1072, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6443/7752 [11:35:41<3:43:09, 10.23s/it, Written=1072, Skipped=1952]
# Augmenting train:  83%|████████▎ | 6443/7752 [11:36:01<3:43:09, 10.23s/it, Written=1072, Skipped=1953]
# Augmenting train:  83%|████████▎ | 6444/7752 [11:36:01<4:46:56, 13.16s/it, Written=1072, Skipped=1953]
# Augmenting train:  83%|████████▎ | 6444/7752 [11:36:06<4:46:56, 13.16s/it, Written=1073, Skipped=1953]
# Augmenting train:  83%|████████▎ | 6445/7752 [11:36:06<3:52:45, 10.69s/it, Written=1073, Skipped=1953]
# Augmenting train:  83%|████████▎ | 6445/7752 [11:36:21<3:52:45, 10.69s/it, Written=1073, Skipped=1954]
# Augmenting train:  83%|████████▎ | 6446/7752 [11:36:21<4:16:39, 11.79s/it, Written=1073, Skipped=1954]
# Augmenting train:  83%|████████▎ | 6446/7752 [11:36:36<4:16:39, 11.79s/it, Written=1073, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6447/7752 [11:36:36<4:36:41, 12.72s/it, Written=1073, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6447/7752 [11:36:43<4:36:41, 12.72s/it, Written=1074, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6448/7752 [11:36:43<3:59:20, 11.01s/it, Written=1074, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6448/7752 [11:36:48<3:59:20, 11.01s/it, Written=1075, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6449/7752 [11:36:48<3:24:26,  9.41s/it, Written=1075, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6449/7752 [11:36:55<3:24:26,  9.41s/it, Written=1076, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6450/7752 [11:36:55<3:08:49,  8.70s/it, Written=1076, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6450/7752 [11:37:02<3:08:49,  8.70s/it, Written=1077, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6451/7752 [11:37:02<2:57:06,  8.17s/it, Written=1077, Skipped=1955]
# Augmenting train:  83%|████████▎ | 6451/7752 [11:37:19<2:57:06,  8.17s/it, Written=1077, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6452/7752 [11:37:19<3:55:14, 10.86s/it, Written=1077, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6452/7752 [11:37:26<3:55:14, 10.86s/it, Written=1078, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6453/7752 [11:37:26<3:30:04,  9.70s/it, Written=1078, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6453/7752 [11:37:33<3:30:04,  9.70s/it, Written=1079, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6454/7752 [11:37:33<3:09:38,  8.77s/it, Written=1079, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6454/7752 [11:37:40<3:09:38,  8.77s/it, Written=1080, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6455/7752 [11:37:40<2:56:35,  8.17s/it, Written=1080, Skipped=1956]
# Augmenting train:  83%|████████▎ | 6455/7752 [11:38:02<2:56:35,  8.17s/it, Written=1080, Skipped=1957]
# Augmenting train:  83%|████████▎ | 6456/7752 [11:38:02<4:28:57, 12.45s/it, Written=1080, Skipped=1957]
# Augmenting train:  83%|████████▎ | 6456/7752 [11:38:20<4:28:57, 12.45s/it, Written=1080, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6457/7752 [11:38:20<5:01:21, 13.96s/it, Written=1080, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6457/7752 [11:38:28<5:01:21, 13.96s/it, Written=1081, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6458/7752 [11:38:28<4:23:22, 12.21s/it, Written=1081, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6458/7752 [11:38:34<4:23:22, 12.21s/it, Written=1082, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6459/7752 [11:38:34<3:44:46, 10.43s/it, Written=1082, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6459/7752 [11:38:40<3:44:46, 10.43s/it, Written=1083, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6460/7752 [11:38:40<3:17:40,  9.18s/it, Written=1083, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6460/7752 [11:38:51<3:17:40,  9.18s/it, Written=1084, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6461/7752 [11:38:51<3:29:52,  9.75s/it, Written=1084, Skipped=1958]
# Augmenting train:  83%|████████▎ | 6461/7752 [11:39:08<3:29:52,  9.75s/it, Written=1084, Skipped=1959]
# Augmenting train:  83%|████████▎ | 6462/7752 [11:39:08<4:13:07, 11.77s/it, Written=1084, Skipped=1959]
# Augmenting train:  83%|████████▎ | 6462/7752 [11:39:15<4:13:07, 11.77s/it, Written=1085, Skipped=1959]
# Augmenting train:  83%|████████▎ | 6463/7752 [11:39:15<3:44:02, 10.43s/it, Written=1085, Skipped=1959]
# Augmenting train:  83%|████████▎ | 6463/7752 [11:39:35<3:44:02, 10.43s/it, Written=1085, Skipped=1960]
# Augmenting train:  83%|████████▎ | 6464/7752 [11:39:35<4:42:39, 13.17s/it, Written=1085, Skipped=1960]
# Augmenting train:  83%|████████▎ | 6464/7752 [11:39:54<4:42:39, 13.17s/it, Written=1085, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6465/7752 [11:39:54<5:22:28, 15.03s/it, Written=1085, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6465/7752 [11:40:04<5:22:28, 15.03s/it, Written=1086, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6466/7752 [11:40:04<4:50:50, 13.57s/it, Written=1086, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6466/7752 [11:40:11<4:50:50, 13.57s/it, Written=1087, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6467/7752 [11:40:11<4:05:15, 11.45s/it, Written=1087, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6467/7752 [11:40:19<4:05:15, 11.45s/it, Written=1088, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6468/7752 [11:40:19<3:44:42, 10.50s/it, Written=1088, Skipped=1961]
# Augmenting train:  83%|████████▎ | 6468/7752 [11:40:40<3:44:42, 10.50s/it, Written=1088, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6469/7752 [11:40:40<4:53:32, 13.73s/it, Written=1088, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6469/7752 [11:40:47<4:53:32, 13.73s/it, Written=1089, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6470/7752 [11:40:47<4:09:46, 11.69s/it, Written=1089, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6470/7752 [11:40:54<4:09:46, 11.69s/it, Written=1090, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6470/7752 [11:41:01<4:09:46, 11.69s/it, Written=1091, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6471/7752 [11:41:01<4:19:23, 12.15s/it, Written=1091, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6471/7752 [11:41:09<4:19:23, 12.15s/it, Written=1092, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6472/7752 [11:41:09<3:54:28, 10.99s/it, Written=1092, Skipped=1962]
# Augmenting train:  83%|████████▎ | 6472/7752 [11:41:22<3:54:28, 10.99s/it, Written=1093, Skipped=1962]
# Augmenting train:  84%|████████▎ | 6473/7752 [11:41:22<4:08:37, 11.66s/it, Written=1093, Skipped=1962]
# Augmenting train:  84%|████████▎ | 6473/7752 [11:41:27<4:08:37, 11.66s/it, Written=1094, Skipped=1962]
# Augmenting train:  84%|████████▎ | 6474/7752 [11:41:27<3:26:38,  9.70s/it, Written=1094, Skipped=1962]
# Augmenting train:  84%|████████▎ | 6474/7752 [11:41:48<3:26:38,  9.70s/it, Written=1094, Skipped=1963]
# Augmenting train:  84%|████████▎ | 6475/7752 [11:41:48<4:35:05, 12.93s/it, Written=1094, Skipped=1963]
# Augmenting train:  84%|████████▎ | 6475/7752 [11:41:54<4:35:05, 12.93s/it, Written=1095, Skipped=1963]
# Augmenting train:  84%|████████▎ | 6476/7752 [11:41:54<3:51:38, 10.89s/it, Written=1095, Skipped=1963]
# Augmenting train:  84%|████████▎ | 6476/7752 [11:42:10<3:51:38, 10.89s/it, Written=1095, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6477/7752 [11:42:10<4:25:12, 12.48s/it, Written=1095, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6477/7752 [11:42:28<4:25:12, 12.48s/it, Written=1096, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6478/7752 [11:42:28<5:03:16, 14.28s/it, Written=1096, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6478/7752 [11:42:37<5:03:16, 14.28s/it, Written=1097, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6479/7752 [11:42:37<4:24:10, 12.45s/it, Written=1097, Skipped=1964]
# Augmenting train:  84%|████████▎ | 6479/7752 [11:42:51<4:24:10, 12.45s/it, Written=1097, Skipped=1965]
# Augmenting train:  84%|████████▎ | 6480/7752 [11:42:51<4:35:40, 13.00s/it, Written=1097, Skipped=1965]
# Augmenting train:  84%|████████▎ | 6480/7752 [11:43:07<4:35:40, 13.00s/it, Written=1097, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6481/7752 [11:43:07<4:54:44, 13.91s/it, Written=1097, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6481/7752 [11:43:12<4:54:44, 13.91s/it, Written=1098, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6482/7752 [11:43:12<3:59:05, 11.30s/it, Written=1098, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6482/7752 [11:43:28<3:59:05, 11.30s/it, Written=1099, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6483/7752 [11:43:28<4:29:52, 12.76s/it, Written=1099, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6483/7752 [11:43:35<4:29:52, 12.76s/it, Written=1100, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6484/7752 [11:43:35<3:50:49, 10.92s/it, Written=1100, Skipped=1966]
# Augmenting train:  84%|████████▎ | 6484/7752 [11:43:50<3:50:49, 10.92s/it, Written=1100, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6485/7752 [11:43:50<4:18:14, 12.23s/it, Written=1100, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6485/7752 [11:43:58<4:18:14, 12.23s/it, Written=1101, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6486/7752 [11:43:58<3:49:19, 10.87s/it, Written=1101, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6486/7752 [11:44:09<3:49:19, 10.87s/it, Written=1102, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6487/7752 [11:44:09<3:51:01, 10.96s/it, Written=1102, Skipped=1967]
# Augmenting train:  84%|████████▎ | 6487/7752 [11:44:27<3:51:01, 10.96s/it, Written=1102, Skipped=1968]
# Augmenting train:  84%|████████▎ | 6487/7752 [11:44:35<3:51:01, 10.96s/it, Written=1103, Skipped=1968]
# Augmenting train:  84%|████████▎ | 6487/7752 [11:44:52<3:51:01, 10.96s/it, Written=1103, Skipped=1969]
# Augmenting train:  84%|████████▎ | 6488/7752 [11:44:52<7:10:14, 20.42s/it, Written=1103, Skipped=1969]
# Augmenting train:  84%|████████▎ | 6488/7752 [11:45:06<7:10:14, 20.42s/it, Written=1103, Skipped=1970]
# Augmenting train:  84%|████████▎ | 6489/7752 [11:45:06<6:31:29, 18.60s/it, Written=1103, Skipped=1970]
# Augmenting train:  84%|████████▎ | 6489/7752 [11:45:14<6:31:29, 18.60s/it, Written=1104, Skipped=1970]
# Augmenting train:  84%|████████▎ | 6490/7752 [11:45:14<5:21:40, 15.29s/it, Written=1104, Skipped=1970]
# Augmenting train:  84%|████████▎ | 6490/7752 [11:45:31<5:21:40, 15.29s/it, Written=1104, Skipped=1971]
# Augmenting train:  84%|████████▎ | 6491/7752 [11:45:31<5:36:04, 15.99s/it, Written=1104, Skipped=1971]
# Augmenting train:  84%|████████▎ | 6491/7752 [11:45:37<5:36:04, 15.99s/it, Written=1105, Skipped=1971]
# Augmenting train:  84%|████████▎ | 6492/7752 [11:45:37<4:34:01, 13.05s/it, Written=1105, Skipped=1971]
# Augmenting train:  84%|████████▎ | 6492/7752 [11:45:44<4:34:01, 13.05s/it, Written=1106, Skipped=1971]
# Augmenting train:  84%|████████▍ | 6493/7752 [11:45:44<3:53:02, 11.11s/it, Written=1106, Skipped=1971]
# Augmenting train:  84%|████████▍ | 6493/7752 [11:46:00<3:53:02, 11.11s/it, Written=1106, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6494/7752 [11:46:00<4:22:43, 12.53s/it, Written=1106, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6494/7752 [11:46:05<4:22:43, 12.53s/it, Written=1107, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6495/7752 [11:46:05<3:38:53, 10.45s/it, Written=1107, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6495/7752 [11:46:12<3:38:53, 10.45s/it, Written=1108, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6496/7752 [11:46:12<3:15:23,  9.33s/it, Written=1108, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6496/7752 [11:46:21<3:15:23,  9.33s/it, Written=1109, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6497/7752 [11:46:21<3:10:54,  9.13s/it, Written=1109, Skipped=1972]
# Augmenting train:  84%|████████▍ | 6497/7752 [11:46:35<3:10:54,  9.13s/it, Written=1109, Skipped=1973]
# Augmenting train:  84%|████████▍ | 6498/7752 [11:46:35<3:44:22, 10.74s/it, Written=1109, Skipped=1973]
# Augmenting train:  84%|████████▍ | 6498/7752 [11:46:43<3:44:22, 10.74s/it, Written=1110, Skipped=1973]
# Augmenting train:  84%|████████▍ | 6499/7752 [11:46:43<3:24:45,  9.80s/it, Written=1110, Skipped=1973]
# Augmenting train:  84%|████████▍ | 6499/7752 [11:46:56<2:16:17,  6.53s/it, Written=1111, Skipped=1973]
# ⚠️ REACHED 11.8 HOURS. GRACEFULLY STOPPING.
# 📊 Stats this run -> Written: 1111 | Skipped: 1973
# 💾 Files safely saved to: /kaggle/working/augmented
